# %% [markdown]
# # Modélisation de la variabilité solaire à court terme
#
# Dans ce notebook, nous cherchons à prédire la **variabilité future** de la production solaire normalisée.
#
# La variable cible est définie par :
# $$
# y_t = |tch_{t+1} - tch_t|
# $$
#
# où `tch` représente la production solaire rapportée à la capacité maximale.
#
# Comme chaque pas de temps correspond à **30 minutes**, cette cible mesure donc **l'amplitude de la variation de production dans les 30 minutes suivantes**.
#
# L'objectif n'est donc pas de prévoir si la production va augmenter ou diminuer, mais plutôt **à quel point elle va changer**.
#
# La démarche suivie est la suivante :
#
# 1. préparation des données de modélisation ;
# 2. définition des métriques d'évaluation ;
# 3. construction d'un modèle naïf de référence ;
# 4. comparaison de modèles linéaires ;
# 5. sélection exploratoire avec LazyPredict ;
# 6. optimisation de modèles d'arbres et de boosting ;
# 7. entraînement d'un réseau de neurones ;
# 8. comparaison finale des performances ;
# 9. évaluation sur l'ensemble de test pour les trois meilleurs modèles.
#
# > **Important :** l'ensemble de test n'est utilisé qu'à la fin. Les choix de modèles et d'hyperparamètres sont faits à partir de l'entraînement et de la validation afin de limiter les fuites d'information.

# %% [markdown]
# ## 0. Environnement de travail
#
# Cette première cellule regroupe les librairies utilisées dans le notebook : manipulation de données, visualisation, modèles de machine learning, optimisation avec Optuna et réseau de neurones avec Keras.
#
# Les imports sont centralisés afin de rendre le notebook plus lisible et plus facile à maintenir.

# %%
# ===========
# 1. Imports
# ===========
import numpy as np
import pandas as pd
from scipy.stats import uniform, randint, loguniform

import matplotlib.pyplot as plt
import seaborn as sns

import lightgbm as lgb
from lightgbm import LGBMRegressor
from xgboost import XGBRegressor
from lazypredict.Supervised import LazyRegressor

import optuna

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers
from tensorflow.keras import backend as K

from sklearn.svm import SVR
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.inspection import permutation_importance
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import LinearRegression, ElasticNetCV, ElasticNet
from sklearn.linear_model import Ridge, RidgeCV, Lasso, LassoCV
from sklearn.ensemble import ExtraTreesRegressor, RandomForestRegressor, HistGradientBoostingRegressor
from sklearn.model_selection import train_test_split, TimeSeriesSplit
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

from sklearn.neural_network import MLPRegressor

import pickle
import joblib

# %% [markdown]
# ## 1. Chargement des données de modélisation
#
# Les données utilisées ici proviennent du notebook de *feature engineering*.
# À ce stade, les variables explicatives ont déjà été construites : retards temporels, statistiques glissantes, variables météorologiques, variables régionales et variables cycliques.
#
# La cellule suivante charge les trois ensembles chronologiques utilisés pour la modélisation :
#
# - **train** : données de **2020 à 2023**, utilisées pour l'entraînement initial des modèles et la **pré-sélection rapide** des approches les plus prometteuses ;
# - **valid** : données de **2024**, utilisées pour la **recherche des hyperparamètres**, la comparaison plus rigoureuse des modèles et le choix final de la configuration ;
# - **test** : données de **2025 jusqu'au 19 février 2026**, utilisées uniquement pour l'évaluation finale du modèle retenu.
#
# Cette séparation respecte l'ordre temporel des données et est essentielle afin d'éviter toute fuite d'information entre les périodes d'apprentissage, de validation et de test.
#
# L'ensemble de test reste complètement indépendant et ne sera utilisé qu'à la toute dernière étape, après la sélection du modèle et le réglage de ses hyperparamètres.

# %%
# ================================
# Chargement des données préparées
# ================================

# Chemin vers les fichiers issus de l'étape de feature engineering
filepath_input = "/Users/mibrahim/Desktop/Varaiability/data/local_data/04_Features_engineering/output/"

# Chemin où seront sauvegardés les résultats de la modélisation
filepath_output = "/Users/mibrahim/Desktop/Varaiability/data/local_data/05_Modelisation/output/output_jour_nuit/"

# Chargement de l'ensemble d'entraînement : période 2020-2023
train = pd.read_csv(filepath_input + "train_region.csv", index_col="datetime_utc", parse_dates=True)

# Chargement de l'ensemble de validation : période 2024
valid = pd.read_csv(filepath_input + "valid_region.csv", index_col="datetime_utc", parse_dates=True)

# Chargement de l'ensemble de test : période 2025 jusqu'au 19 février 2026
test = pd.read_csv(filepath_input + "test_region.csv", index_col="datetime_utc", parse_dates=True)

# Affichage de la taille de l'ensemble d'entraînement
print("Train :", train.shape)
display(train)

# Affichage de la taille de l'ensemble de validation
print("Valid :", valid.shape)
display(valid)

# Affichage de la taille de l'ensemble de test
print("Test  :", test.shape)
display(test)
# Out:
# Train : (70125, 67)
#                            abs_dtch_dt  abs_dtch_lag_1  abs_dtch_lag_2  \
# datetime_utc
# 2020-01-01 01:00:00+00:00         0.00            0.00            0.00
# 2020-01-01 01:30:00+00:00         0.00            0.00            0.00
# 2020-01-01 02:00:00+00:00         0.00            0.00            0.00
# 2020-01-01 02:30:00+00:00         0.00            0.00            0.00
# 2020-01-01 03:00:00+00:00         0.00            0.00            0.00
# ...                                ...             ...             ...
# 2023-12-31 21:00:00+00:00         0.00            0.00            0.00
# 2023-12-31 21:30:00+00:00         0.00            0.00            0.00
# 2023-12-31 22:00:00+00:00         0.00            0.00            0.00
# 2023-12-31 22:30:00+00:00         0.00            0.00            0.00
# 2023-12-31 23:00:00+00:00         0.00            0.00            0.00
#
#                            abs_dtch_lag_3  abs_dtch_roll_mean_4h  \
# datetime_utc
# 2020-01-01 01:00:00+00:00            0.00                   0.00
# 2020-01-01 01:30:00+00:00            0.00                   0.00
# 2020-01-01 02:00:00+00:00            0.00                   0.00
# 2020-01-01 02:30:00+00:00            0.00                   0.00
# 2020-01-01 03:00:00+00:00            0.00                   0.00
# ...                                   ...                    ...
# 2023-12-31 21:00:00+00:00            0.00                   0.00
# 2023-12-31 21:30:00+00:00            0.00                   0.00
# 2023-12-31 22:00:00+00:00            0.00                   0.00
# 2023-12-31 22:30:00+00:00            0.00                   0.00
# 2023-12-31 23:00:00+00:00            0.00                   0.00
#
#                            abs_dtch_roll_std_4h  consommation  cos_doy  \
# datetime_utc
# 2020-01-01 01:00:00+00:00                  0.00       5700.00     1.00
# 2020-01-01 01:30:00+00:00                  0.00       5803.00     1.00
# 2020-01-01 02:00:00+00:00                  0.00       5566.00     1.00
# 2020-01-01 02:30:00+00:00                  0.00       5433.00     1.00
# 2020-01-01 03:00:00+00:00                  0.00       5332.00     1.00
# ...                                         ...           ...      ...
# 2023-12-31 21:00:00+00:00                  0.00       4752.00     1.00
# 2023-12-31 21:30:00+00:00                  0.00       4827.00     1.00
# 2023-12-31 22:00:00+00:00                  0.00       4982.00     1.00
# 2023-12-31 22:30:00+00:00                  0.00       5232.00     1.00
# 2023-12-31 23:00:00+00:00                  0.00       5104.00     1.00
#
#                            cos_hour  dtch_dt  ...  sin_hour  solaire  target  \
# datetime_utc                                  ...
# 2020-01-01 01:00:00+00:00      0.97     0.00  ...      0.26     0.00    0.00
# 2020-01-01 01:30:00+00:00      0.92     0.00  ...      0.38     0.00    0.00
# 2026-02-19 12:30:00+00:00                  2.30       5177.00     0.66
#
#                            cos_hour  dtch_dt  ...  sin_hour  solaire  target  \
# datetime_utc                                  ...
# 2025-01-01 02:00:00+00:00      0.87     0.00  ...      0.50     0.00    0.00
# 2025-01-01 02:30:00+00:00      0.79     0.00  ...      0.61     0.00    0.00
# 2025-01-01 03:00:00+00:00      0.71     0.00  ...      0.71     0.00    0.00
# 2025-01-01 03:30:00+00:00      0.61     0.00  ...      0.79     0.00    0.00
# 2025-01-01 04:00:00+00:00      0.50     0.00  ...      0.87     0.00    0.00
# ...                             ...      ...  ...       ...      ...     ...
# 2026-02-19 10:30:00+00:00     -0.92     4.93  ...      0.38   674.00    0.15
# 2026-02-19 11:00:00+00:00     -0.97     0.15  ...      0.26   678.00    5.22
# 2026-02-19 11:30:00+00:00     -0.99     5.22  ...      0.13   825.00    0.60
# 2026-02-19 12:00:00+00:00     -1.00     0.60  ...      0.00   842.00    2.38
# 2026-02-19 12:30:00+00:00     -0.99     2.38  ...     -0.13   909.00    6.50
#
#                            tch_lag_1  tch_lag_2  tch_lag_3  tch_roll_mean_4h  \
# datetime_utc
# 2025-01-01 02:00:00+00:00       0.00       0.00       0.00              0.00
# 2025-01-01 02:30:00+00:00       0.00       0.00       0.00              0.00
# 2025-01-01 03:00:00+00:00       0.00       0.00       0.00              0.00
# 2025-01-01 03:30:00+00:00       0.00       0.00       0.00              0.00
# 2025-01-01 04:00:00+00:00       0.00       0.00       0.00              0.00
# ...                              ...        ...        ...               ...
# 2026-02-19 10:30:00+00:00      19.00      21.02      18.89             20.71
# 2026-02-19 11:00:00+00:00      23.93      19.00      21.02             22.01
# 2026-02-19 11:30:00+00:00      24.08      23.93      19.00             24.08
# 2026-02-19 12:00:00+00:00      29.30      24.08      23.93             26.80
# 2026-02-19 12:30:00+00:00      29.90      29.30      24.08             28.89
#
#                            tch_roll_std_4h  tch_solaire  tco_solaire
# datetime_utc
# 2025-01-01 02:00:00+00:00             0.00         0.00         0.00
# 2025-01-01 02:30:00+00:00             0.00         0.00         0.00
# 2025-01-01 03:00:00+00:00             0.00         0.00         0.00
# 2025-01-01 03:30:00+00:00             0.00         0.00         0.00
# 2025-01-01 04:00:00+00:00             0.00         0.00         0.00
# ...                                    ...          ...          ...
# 2026-02-19 10:30:00+00:00             2.36        23.93        13.30
# 2026-02-19 11:00:00+00:00             2.45        24.08        13.09
# 2026-02-19 11:30:00+00:00             4.21        29.30        15.83
# 2026-02-19 12:00:00+00:00             3.24        29.90        16.34
# 2026-02-19 12:30:00+00:00             3.46        32.28        17.56
#
# [19894 rows x 67 columns]

# %% [markdown]
# ### 1.1 Séparation entre variables explicatives et cible
#
# La colonne `target` correspond à la variable à prédire. Elle est donc séparée des variables explicatives.
#
# Toutes les autres colonnes sont considérées comme des informations disponibles au temps $t$ pour prédire la variabilité future de la production photovoltaïque.
#
# On construit ainsi :
#
# - `X_train`, `y_train` : utilisés pour l'entraînement initial et la pré-sélection rapide des modèles ;
# - `X_valid`, `y_valid` : utilisés pour la recherche des hyperparamètres et la comparaison des configurations ;
# - `X_test`, `y_test` : utilisés uniquement pour l'évaluation finale.
#
# On construit également `X_dev` et `y_dev`, qui correspondent à la réunion de l'ensemble d'entraînement et de l'ensemble de validation.
# Ils serviront à réentraîner le modèle sélectionné après la recherche des hyperparamètres, avant son évaluation finale sur l'ensemble de test.
#
# Cet ensemble de développement sera utilisé uniquement après la sélection du modèle et de ses hyperparamètres, afin de réentraîner le modèle retenu sur toutes les données disponibles avant l'évaluation finale sur l'ensemble de test.

# %%
# Séparation des variables explicatives et de la cible pour l'ensemble train
# X_train contient toutes les colonnes sauf "target"
# y_train contient uniquement la variable à prédire
X_train = train.drop(columns=["target"])
y_train = train["target"]

# Même séparation pour l'ensemble de validation
X_valid = valid.drop(columns=["target"])
y_valid = valid["target"]

# Même séparation pour l'ensemble de test final
X_test = test.drop(columns=["target"])
y_test = test["target"]

# Affichage des dimensions des matrices de variables explicatives
print("X_train :", X_train.shape)
print("X_valid :", X_valid.shape)
print("X_test  :", X_test.shape)

# Construction de l'ensemble de développement
# Il regroupe train et validation
# Il sera utilisé plus tard pour réentraîner le modèle sélectionné
X_dev = pd.concat([X_train, X_valid]).sort_index()
y_dev = pd.concat([y_train, y_valid]).sort_index()
# Out:
# X_train : (70125, 66)
# X_valid : (17563, 66)
# X_test  : (19894, 66)

# %% [markdown]
# ### 1.2 Folds de validation croisée temporelle
#
# Comme les données sont temporelles, l'ordre chronologique des observations doit être respecté lors de l'évaluation des modèles.
#
# Un découpage aléatoire n'est pas adapté dans ce contexte, car il pourrait mélanger des observations passées et futures. Cela créerait une fuite d'information et donnerait une estimation trop optimiste des performances.
#
# Nous définissons donc une fonction qui construit des folds chronologiques.
# Pour chaque fold, le modèle est entraîné sur une période passée, puis évalué sur une période future.
#
# Cette stratégie reproduit mieux une situation réelle de prédiction : le modèle apprend uniquement à partir des informations disponibles dans le passé, puis il est testé sur des données plus récentes.
#
# Elle permet aussi de vérifier si les performances du modèle restent stables sur différentes périodes temporelles.

# %%
# ---------------------
# Folds temporels
# ---------------------

def get_folds(X, y):
    """
    Génère des folds de validation croisée temporelle.

    Le principe est simple :
    - le modèle apprend sur une période passée ;
    - il est validé sur une période future ;
    - l'ordre chronologique est respecté pour éviter la fuite d'information.

    Paramètres
    ----------
    X : DataFrame
        Variables explicatives indexées par date.

    y : Series
        Variable cible alignée avec X.

    Retour
    ------
    folds : list
        Liste contenant les ensembles train et validation pour chaque fold.
    """

    # Liste qui contiendra tous les folds
    folds = []

    # Définition manuelle des périodes temporelles
    # Chaque ligne correspond à :
    # (date début train, date fin train, date début valid, date fin valid)
    splits = [
        ("2020-01-01", "2023-12-31", "2024-01-01", "2024-12-31"),
        ("2020-01-01", "2022-12-31", "2023-01-01", "2023-12-31"),
        ("2020-01-01", "2021-12-31", "2022-01-01", "2022-12-31"),
        ("2020-01-01", "2020-12-31", "2021-01-01", "2021-12-31"),
    ]

    # Construction de chaque fold
    for debut_train, fin_train, debut_val, fin_val in splits:

        # Sélection des données d'entraînement sur la période passée
        X_tr = X.loc[debut_train:fin_train]
        y_tr = y.loc[debut_train:fin_train]

        # Sélection des données de validation sur la période future
        X_val = X.loc[debut_val:fin_val]
        y_val = y.loc[debut_val:fin_val]

        # Ajout du fold à la liste
        folds.append((X_tr, X_val, y_tr, y_val))

    return folds

# %% [markdown]
# ## 2. Métriques d'évaluation
#
# Pour comparer les modèles, plusieurs métriques complémentaires sont utilisées :
#
# - **MAE (Mean Absolute Error)** : erreur absolue moyenne. C'est la métrique principale utilisée dans ce notebook ;
# - **NMAE (Normalized Mean Absolute Error)** : MAE normalisée, exprimée en pourcentage, afin de faciliter l'interprétation de l'erreur ;
# - **RMSE (Root Mean Squared Error)** : racine de l'erreur quadratique moyenne. Cette métrique pénalise davantage les grandes erreurs ;
# - **R² (coefficient de détermination)** : mesure la part de variance de la cible expliquée par le modèle ;
# - **gap train/validation** : différence entre les performances sur l'entraînement et la validation, utilisée comme indicateur de surapprentissage.
#
# > - La **MAE** est privilégiée comme métrique principale, car elle est directement interprétable : elle représente l'erreur moyenne sur l'amplitude de variabilité solaire prédite.
# >
# > - Le **gap train/validation** permet de vérifier si le modèle généralise correctement.
# > Un faible gap indique généralement un comportement plus stable, tandis qu'un gap élevé peut révéler un surapprentissage.

# %%
# ========================
# 4. Fonction d'évaluation
# ========================
def calculer_nmae(y_true, y_pred):
    """
    Calcule la NMAE en pourcentage.

    La NMAE correspond à la MAE normalisée par la moyenne
    des valeurs absolues de la cible réelle.

    Formule :
        NMAE = 100 * MAE / moyenne(|y_true|)
    """

    # Calcul de l'erreur absolue moyenne
    mae = mean_absolute_error(y_true, y_pred)

    # Normalisation par la moyenne des valeurs absolues réelles
    denom = np.mean(np.abs(y_true))

    # Retour de la NMAE en pourcentage
    return 100 * mae / denom


def calculer_metriques(
    y_train, y_pred_train,
    y_valid, y_pred_valid,
    nom_modele,
    MAE_CV_moyenne=np.nan
):
    """
    Calcule les métriques de régression sur les ensembles
    d'entraînement et de validation.

    Paramètres
    ----------
    y_train, y_valid, y_test : array-like
        Valeurs réelles.
    y_pred_train, y_pred_valid, y_pred_test : array-like
        Prédictions du modèle.
    nom_modele : str
        Nom du modèle évalué.
    MAE_CV_moyenne : float, optionnel
        MAE moyenne obtenue lors de la validation croisée temporelle.

    Retour
    ------
    dict
        Dictionnaire contenant toutes les métriques utiles pour comparer les modèles.
    """

    # Métriques sur l'entraînement
    mae_train = mean_absolute_error(y_train, y_pred_train)
    nmae_train = calculer_nmae(y_train, y_pred_train)
    rmse_train = np.sqrt(mean_squared_error(y_train, y_pred_train))
    r2_train = r2_score(y_train, y_pred_train)

    # Métriques sur la validation
    mae_valid = mean_absolute_error(y_valid, y_pred_valid)
    nmae_valid = calculer_nmae(y_valid, y_pred_valid)
    rmse_valid = np.sqrt(mean_squared_error(y_valid, y_pred_valid))
    r2_valid = r2_score(y_valid, y_pred_valid)

    # Résultats regroupés
    return {
        "Modèle": nom_modele,

        # Performances sur l'entraînement
        "MAE_train": mae_train,
        "NMAE_train (%)": nmae_train,
        "RMSE_train": rmse_train,
        "R2_train": r2_train,

        # Performances sur la validation
        "MAE_valid": mae_valid,
        "NMAE_valid (%)": nmae_valid,
        "RMSE_valid": rmse_valid,
        "R2_valid": r2_valid,

        # Performance moyenne obtenue en validation croisée temporelle
        "MAE_CV_moyenne": MAE_CV_moyenne,

        # Écart entre validation et entraînement
        # Un grand écart peut indiquer du surapprentissage
        "Gap_MAE_valid_train": mae_valid - mae_train,
        "Gap_R2_train_valid": r2_train - r2_valid
    }


# Liste qui servira à stocker les résultats des différents modèles
resultats = []

# %% [markdown]
# ## 3. Modèle naïf de référence
#
# Avant d'utiliser des modèles plus avancés, on définit une **baseline naïve** servant de référence.
#
# L'idée est de prédire que la variabilité future sera proche de la dernière variation observée de la production photovoltaïque normalisée :
#
# $$
# \hat{y}_{t+1} \approx |\Delta tch_t|
# $$
#
# Dans les variables explicatives, cette information est représentée par la variable `abs_dtch_dt`.
#
# Ce modèle naïf permet d'avoir un point de comparaison simple.
# Les modèles plus complexes devront donc obtenir de meilleures performances que cette baseline pour montrer qu'ils apportent une vraie valeur ajoutée.

# %%
# ===========
# Modèle naïf
# ===========

# Variable utilisée comme prédiction naïve
baseline_feature = "abs_dtch_dt"

# Prédictions naïves sur l'ensemble de validation
y_pred_valid_naif = X_valid[baseline_feature]

# Prédictions naïves sur l'ensemble d'entraînement
y_pred_train_naif = X_train[baseline_feature]

# Calcul des métriques du modèle naïf
# Ce modèle sert de référence simple pour comparer les modèles plus avancés
resultats.append(
    calculer_metriques(
        y_train,
        y_pred_train_naif,
        y_valid,
        y_pred_valid_naif,
        "Naïf",
        MAE_CV_moyenne=np.nan
    )
)

# Affichage des résultats sous forme d'un dataframe
pd.DataFrame(resultats)
# Out:
#   Modèle  MAE_train  NMAE_train (%)  RMSE_train  R2_train  MAE_valid  \
# 0   Naïf       0.95           38.84        1.66      0.75       0.98
#
#    NMAE_valid (%)  RMSE_valid  R2_valid  MAE_CV_moyenne  Gap_MAE_valid_train  \
# 0           40.69        1.78      0.71             NaN                 0.03
#
#    Gap_R2_train_valid
# 0                0.04

# %% [markdown]
# ## 4. Modèles linéaires
#
# Les modèles linéaires constituent une première famille de modèles simples, rapides à entraîner et facilement interprétables.
#
# Ils sont intéressants dans ce contexte car la production photovoltaïque est fortement liée à l'irradiance solaire reçue. En première approximation, on peut écrire :
#
# $$
# P_t \approx \beta \, GHI_t
# $$
#
# où $P_t$ désigne la production solaire à l'instant $t$, $GHI_t$ l'irradiance globale horizontale, et $\beta$ une constante regroupant notamment la puissance installée, le rendement moyen du système et les effets d'orientation.
#
# En considérant les variations temporelles, cette relation suggère que les variations de production sont en partie liées aux variations d'irradiance :
#
# $$
# |\Delta P_t| \approx \beta \, |\Delta GHI_t|
# $$
#
# Dans ce notebook, la cible `target` représente la variabilité future de la production photovoltaïque, construite avec un décalage temporel :
#
# $$
# target_t = |\Delta tch_{t \rightarrow t+1}|
# $$
#
# Le modèle linéaire utilise donc la variation récente de l'irradiance, disponible au temps $t$, pour prédire la variabilité future :
#
# $$
# \hat{y}_{t+1} = \alpha \, |\Delta GHI_t|
# $$
#
# La variable `region_abs_dghi_dt` représente cette variation absolue récente de l'irradiance régionale.
#
# Le modèle est défini sans intercept afin d'imposer que lorsque la variation d'irradiance est nulle, la variation prédite de production est également nulle.
#
# Le coefficient $\alpha$ représente alors la sensibilité moyenne de la variabilité future de production aux variations récentes de l'irradiance.
#
# Cette approche reste une vraie approche prédictive, car elle utilise uniquement des informations disponibles au temps $t$ pour prédire la variabilité à l'instant suivant.

# %%
# Cette cellule entraîne une régression linéaire simple
# basée sur une seule variable physique principale.

# ==========================
# Régression linéaire simple
# ==========================

# Variable explicative physique utilisée dans ce modèle
# Elle représente la variation absolue de l'irradiance régionale au temps t
feature_physique = "region_abs_dghi_dt"

# Sélection de la variable explicative pour train et validation
X_train_lr = X_train[[feature_physique]]
X_valid_lr = X_valid[[feature_physique]]

# La cible target a déjà été construite avec shift(-1)
# Donc X_train_lr et y_train sont déjà alignés :
# les variables au temps t servent à prédire la variabilité future à t+1

# Création du modèle linéaire simple sans intercept
# Le modèle est forcé à passer par l'origine
modele_lr_simple = LinearRegression(fit_intercept=False)

# Entraînement du modèle
modele_lr_simple.fit(X_train_lr, y_train)

# Prédictions sur train et validation
y_pred_train_lr = modele_lr_simple.predict(X_train_lr)
y_pred_valid_lr = modele_lr_simple.predict(X_valid_lr)

# Calcul et stockage des métriques
resultats.append(
    calculer_metriques(
        y_train,
        y_pred_train_lr,
        y_valid,
        y_pred_valid_lr,
        "Régression linéaire simple",
        MAE_CV_moyenne=np.nan
    )
)

# Affichage du tableau des résultats
pd.DataFrame(resultats)
# Out:
#                        Modèle  MAE_train  NMAE_train (%)  RMSE_train  \
# 0                        Naïf       0.95           38.84        1.66
# 1  Régression linéaire simple       1.05           43.05        1.88
#
#    R2_train  MAE_valid  NMAE_valid (%)  RMSE_valid  R2_valid  MAE_CV_moyenne  \
# 0      0.75       0.98           40.69        1.78      0.71             NaN
# 1      0.68       1.11           45.96        2.00      0.63             NaN
#
#    Gap_MAE_valid_train  Gap_R2_train_valid
# 0                 0.03                0.04
# 1                 0.06                0.05

# %% [markdown]
# ### 4.1 Régression linéaire multivariée
#
# La variabilité solaire ne dépend pas uniquement de l'irradiance.
# Elle peut aussi être influencée par plusieurs variables disponibles au temps $t$, comme :
#
# - la production récente ;
# - la nébulosité ;
# - les conditions de ciel clair ;
# - les cycles journaliers et saisonniers ;
# - la volatilité passée.
#
# On entraîne donc une régression linéaire multivariée sur l'ensemble des variables explicatives disponibles.
#
# Ce modèle est principalement utilisé comme référence prédictive linéaire. Les performances sur validation permettront donc de vérifier si l'utilisation de toutes les variables apporte un gain par rapport aux modèles plus simples.

# %%
# Cette cellule entraîne une régression linéaire multivariée
# sur l'ensemble des variables explicatives disponibles.

# ===============================
# Régression linéaire multivariée
# ===============================
# features_lineaires = [
#     "region_dghi_dt",
#     "region_abs_dghi_dt",
#     "region_csi",
#     "region_nebulosite",
#     "abs_dtch_dt",
#     "abs_dtch_lag_1",
#     "abs_dtch_lag_2",
#     "tch_roll_std_4h",
#     "sin_hour",
#     "cos_hour",
#     "sin_doy",
#     "cos_doy"
# ]

# features_lineaires = [col for col in features_lineaires if col in X_train.columns]

# print("Variables retenues pour le modèle linéaire multivarié :")
# print(features_lineaires)


# Création du modèle de régression linéaire
modele_lin_multi = LinearRegression()

# Entraînement du modèle sur l'ensemble train
modele_lin_multi.fit(X_train, y_train)

# Prédictions sur l'ensemble de validation
y_pred_valid_lin_multi = modele_lin_multi.predict(X_valid)

# Prédictions sur l'ensemble d'entraînement
y_pred_train_lin_multi = modele_lin_multi.predict(X_train)

# Calcul et stockage des métriques du modèle
resultats.append(
    calculer_metriques(
        y_train,
        y_pred_train_lin_multi,
        y_valid,
        y_pred_valid_lin_multi,
        "Régression linéaire multivariée",
        MAE_CV_moyenne=np.nan
    )
)

# Affichage du tableau des résultats
pd.DataFrame(resultats)
# Out:
#                             Modèle  MAE_train  NMAE_train (%)  RMSE_train  \
# 0                             Naïf       0.95           38.84        1.66
# 1       Régression linéaire simple       1.05           43.05        1.88
# 2  Régression linéaire multivariée       0.72           29.62        1.18
#
#    R2_train  MAE_valid  NMAE_valid (%)  RMSE_valid  R2_valid  MAE_CV_moyenne  \
# 0      0.75       0.98           40.69        1.78      0.71             NaN
# 1      0.68       1.11           45.96        2.00      0.63             NaN
# 2      0.87       0.76           31.75        1.33      0.84             NaN
#
#    Gap_MAE_valid_train  Gap_R2_train_valid
# 0                 0.03                0.04
# 1                 0.06                0.05
# 2                 0.04                0.04

# %% [markdown]
# ### 4.2 Modèles linéaires régularisés : Ridge, Lasso
#
# Après la régression linéaire multivariée classique, on explore des modèles linéaires **régularisés**.
#
# Cette étape est importante car le jeu de données contient de nombreuses variables explicatives : variables retardées, statistiques glissantes, variables météorologiques, variables régionales et variables cycliques.
#
# Dans ce contexte, il peut exister :
#
# - de la **colinéarité** entre certaines variables ;
# - des coefficients peu stables ;
# - un risque de **surapprentissage** ;
# - une difficulté à interpréter ou généraliser le modèle linéaire classique.
#
# Nous testons donc deux approches complémentaires :
#
# - **Ridge** : utilise une régularisation L2. Elle réduit l'amplitude des coefficients et est utile lorsque plusieurs variables sont corrélées ;
# - **Lasso** : utilise une régularisation L1. Elle peut ramener certains coefficients à zéro et effectuer une forme de sélection de variables ;
#
#
# Comme ces méthodes pénalisent directement les coefficients, les variables doivent être standardisées.
# Pour cela, on utilise un pipeline contenant une étape de standardisation suivie du modèle régularisé.
#
# #### a. Ridge

# %%
# Cette cellule entraîne un modèle Ridge avec standardisation.
# Le meilleur alpha est choisi à partir des folds temporels définis manuellement.

# ========================
# Ridge avec folds manuels
# ========================

# Valeurs de alpha à tester
alphas_ridge = [0.001, 0.01, 0.1, 1, 10, 100, 200, 300]

# Construction des folds temporels manuels
# Ici, on utilise X_dev et y_dev car les folds incluent la période 2024
folds = get_folds(X_dev, y_dev)

# Liste pour stocker les résultats de chaque alpha
resultats_ridge_cv = []

# Boucle sur les valeurs de alpha
for alpha in alphas_ridge:

    mae_folds = []

    # Évaluation de alpha sur chaque fold temporel
    for X_tr, X_val, y_tr, y_val in folds:

        # Pipeline : standardisation puis Ridge
        modele = Pipeline([
            ("scaler", StandardScaler()),
            ("model", Ridge(alpha=alpha))
        ])

        # Entraînement sur la partie passée du fold
        modele.fit(X_tr, y_tr)

        # Prédiction sur la partie future du fold
        y_pred_val = modele.predict(X_val)

        # Calcul de la MAE du fold
        mae_fold = mean_absolute_error(y_val, y_pred_val)
        mae_folds.append(mae_fold)

    # MAE moyenne sur tous les folds
    mae_moyenne = np.mean(mae_folds)

    # Stockage du résultat
    resultats_ridge_cv.append({
        "alpha": alpha,
        "MAE_CV_moyenne": mae_moyenne
    })

# Conversion en DataFrame
resultats_ridge_cv = pd.DataFrame(resultats_ridge_cv)

# Tri des résultats par MAE croissante
resultats_ridge_cv = resultats_ridge_cv.sort_values("MAE_CV_moyenne")

# Affichage des résultats de validation croisée
display(resultats_ridge_cv)

# Meilleur alpha
best_alpha_ridge = resultats_ridge_cv.iloc[0]["alpha"]
best_mae_ridge = resultats_ridge_cv.iloc[0]["MAE_CV_moyenne"]

print("Meilleur alpha Ridge :", best_alpha_ridge)
print("MAE CV moyenne Ridge :", best_mae_ridge)
# Out:
#    alpha  MAE_CV_moyenne
# 6 200.00            0.73
# 7 300.00            0.73
# 5 100.00            0.73
# 4  10.00            0.74
# 3   1.00            0.76
# 2   0.10            0.78
# 1   0.01            0.78
# 0   0.00            0.78
# Meilleur alpha Ridge : 200.0
# MAE CV moyenne Ridge : 0.7325830024336494

# %%
# ==============================
# Entraînement du Ridge final
# ==============================

# Modèle Ridge final avec le meilleur alpha trouvé
ridge = Pipeline([
    ("scaler", StandardScaler()),
    ("model", Ridge(alpha=best_alpha_ridge))
])

# Entraînement sur l'ensemble train
ridge.fit(X_train, y_train)

# Prédictions sur train et validation
y_pred_train_ridge = ridge.predict(X_train)
y_pred_valid_ridge = ridge.predict(X_valid)

# Calcul et stockage des métriques
resultats.append(
    calculer_metriques(
        y_train,
        y_pred_train_ridge,
        y_valid,
        y_pred_valid_ridge,
        "Ridge",
        MAE_CV_moyenne=best_mae_ridge
    )
)

# Affichage du tableau des résultats
pd.DataFrame(resultats)
# Out:
#                             Modèle  MAE_train  NMAE_train (%)  RMSE_train  \
# 0                             Naïf       0.95           38.84        1.66
# 1       Régression linéaire simple       1.05           43.05        1.88
# 2  Régression linéaire multivariée       0.72           29.62        1.18
# 3                            Ridge       0.72           29.42        1.20
#
#    R2_train  MAE_valid  NMAE_valid (%)  RMSE_valid  R2_valid  MAE_CV_moyenne  \
# 0      0.75       0.98           40.69        1.78      0.71             NaN
# 1      0.68       1.11           45.96        2.00      0.63             NaN
# 2      0.87       0.76           31.75        1.33      0.84             NaN
# 3      0.87       0.76           31.53        1.34      0.83            0.73
#
#    Gap_MAE_valid_train  Gap_R2_train_valid
# 0                 0.03                0.04
# 1                 0.06                0.05
# 2                 0.04                0.04
# 3                 0.04                0.04

# %% [markdown]
# #### b. Lasso
#
# Le modèle **Lasso** est une régression linéaire régularisée avec une pénalisation de type L1.
#
# Cette régularisation a une propriété particulière : elle peut ramener certains coefficients exactement à zéro.
# Le Lasso peut donc jouer deux rôles :
#
# - construire un modèle prédictif régularisé ;
# - effectuer une forme de sélection automatique de variables.
#
# Cette approche est intéressante lorsque le jeu de données contient beaucoup de variables explicatives, dont certaines peuvent être peu utiles ou redondantes.
#
# Comme pour Ridge, le paramètre de régularisation `alpha` est sélectionné à l'aide des folds temporels définis manuellement.
# Le modèle final est ensuite réentraîné avec le meilleur `alpha` avant d'être évalué sur l'ensemble de validation.

# %%
# Cette cellule entraîne le modèle Lasso avec standardisation.
# Le meilleur alpha est choisi à partir des folds temporels définis manuellement.

# ==============================
# Lasso avec folds manuels
# ==============================

# Valeurs de alpha à tester
# alpha contrôle la force de la régularisation L1
alphas_lasso = [0.001, 0.005, 0.01, 0.05, 0.1, 1]

# Construction des folds temporels manuels
# On utilise X_dev et y_dev car les folds couvrent plusieurs années jusqu'à 2024
folds = get_folds(X_dev, y_dev)

# Liste pour stocker les résultats de validation croisée
resultats_lasso_cv = []

# Boucle sur les valeurs de alpha
for alpha in alphas_lasso:

    mae_folds = []

    # Évaluation de chaque alpha sur les folds temporels
    for X_tr, X_val, y_tr, y_val in folds:

        # Pipeline : standardisation puis Lasso
        modele = Pipeline([
            ("scaler", StandardScaler()),
            ("model", Lasso(alpha=alpha, max_iter=50000))
        ])

        # Entraînement sur la période passée du fold
        modele.fit(X_tr, y_tr)

        # Prédiction sur la période future du fold
        y_pred_val = modele.predict(X_val)

        # Calcul de la MAE du fold
        mae_fold = mean_absolute_error(y_val, y_pred_val)
        mae_folds.append(mae_fold)

    # MAE moyenne sur tous les folds
    mae_moyenne = np.mean(mae_folds)

    # Stockage du résultat pour cet alpha
    resultats_lasso_cv.append({
        "alpha": alpha,
        "MAE_CV_moyenne": mae_moyenne
    })

# Conversion en DataFrame
resultats_lasso_cv = pd.DataFrame(resultats_lasso_cv)

# Tri par MAE croissante
resultats_lasso_cv = resultats_lasso_cv.sort_values("MAE_CV_moyenne")

# Affichage des résultats de validation croisée
display(resultats_lasso_cv)

# Sélection du meilleur alpha
best_alpha_lasso = resultats_lasso_cv.iloc[0]["alpha"]
best_mae_lasso = resultats_lasso_cv.iloc[0]["MAE_CV_moyenne"]

print("Meilleur alpha Lasso :", best_alpha_lasso)
print("MAE CV moyenne Lasso :", best_mae_lasso)
# Out:
#    alpha  MAE_CV_moyenne
# 1   0.01            0.73
# 0   0.00            0.74
# 2   0.01            0.74
# 3   0.05            0.77
# 4   0.10            0.83
# 5   1.00            1.47
# Meilleur alpha Lasso : 0.005
# MAE CV moyenne Lasso : 0.7299366791076155

# %%
# ==============================
# Entraînement du Lasso final
# ==============================

# Modèle Lasso final avec le meilleur alpha trouvé
lasso = Pipeline([
    ("scaler", StandardScaler()),
    ("model", Lasso(alpha=best_alpha_lasso, max_iter=50000))
])

# Entraînement sur l'ensemble train
lasso.fit(X_train, y_train)

# Prédictions sur train et validation
y_pred_train_lasso = lasso.predict(X_train)
y_pred_valid_lasso = lasso.predict(X_valid)

# Calcul et stockage des métriques
resultats.append(
    calculer_metriques(
        y_train,
        y_pred_train_lasso,
        y_valid,
        y_pred_valid_lasso,
        "Lasso",
        MAE_CV_moyenne=best_mae_lasso
    )
)

# Affichage du tableau des résultats
pd.DataFrame(resultats)
# Out:
#                             Modèle  MAE_train  NMAE_train (%)  RMSE_train  \
# 0                             Naïf       0.95           38.84        1.66
# 1       Régression linéaire simple       1.05           43.05        1.88
# 2  Régression linéaire multivariée       0.72           29.62        1.18
# 3                            Ridge       0.72           29.42        1.20
# 4                            Lasso       0.72           29.44        1.21
#
#    R2_train  MAE_valid  NMAE_valid (%)  RMSE_valid  R2_valid  MAE_CV_moyenne  \
# 0      0.75       0.98           40.69        1.78      0.71             NaN
# 1      0.68       1.11           45.96        2.00      0.63             NaN
# 2      0.87       0.76           31.75        1.33      0.84             NaN
# 3      0.87       0.76           31.53        1.34      0.83            0.73
# 4      0.87       0.76           31.41        1.34      0.83            0.73
#
#    Gap_MAE_valid_train  Gap_R2_train_valid
# 0                 0.03                0.04
# 1                 0.06                0.05
# 2                 0.04                0.04
# 3                 0.04                0.04
# 4                 0.04                0.03

# %%
# Nombre de variables sélectionnées par le Lasso
coef_lasso = lasso.named_steps["model"].coef_
nb_variables_selectionnees = np.sum(coef_lasso != 0)

print("Nombre de variables sélectionnées par Lasso :", nb_variables_selectionnees)
print("Nombre total de variables :", len(coef_lasso))
# Out:
# Nombre de variables sélectionnées par Lasso : 33
# Nombre total de variables : 66

# %%
# ==========================================
# Variables sélectionnées par le modèle Lasso
# ==========================================

# Récupération des coefficients du modèle Lasso
coef_lasso = lasso.named_steps["model"].coef_

# Création d'un DataFrame avec les noms des variables et leurs coefficients
variables_lasso = pd.DataFrame({
    "variable": X_train.columns,
    "coefficient": coef_lasso
})

# Sélection des variables dont le coefficient est non nul
variables_selectionnees_lasso = variables_lasso[
    variables_lasso["coefficient"] != 0
].copy()

# Ajout de la valeur absolue du coefficient pour trier les variables
variables_selectionnees_lasso["abs_coefficient"] = variables_selectionnees_lasso["coefficient"].abs()

# Tri des variables sélectionnées par importance du coefficient
variables_selectionnees_lasso = variables_selectionnees_lasso.sort_values(
    by="abs_coefficient",
    ascending=False
).reset_index(drop=True)

# Affichage du nombre de variables sélectionnées
print("Nombre de variables sélectionnées par Lasso :", len(variables_selectionnees_lasso))
print("Nombre total de variables :", X_train.shape[1])

# Affichage des variables sélectionnées
display(variables_selectionnees_lasso)
# Out:
# Nombre de variables sélectionnées par Lasso : 33
# Nombre total de variables : 66
#                           variable  coefficient  abs_coefficient
# 0                      abs_dtch_dt         1.59             1.59
# 1                       region_bni         1.30             1.30
# 2                       region_bhi        -0.83             0.83
# 3             region_clear_sky_bhi        -0.74             0.74
# 4                      tco_solaire         0.69             0.69
# 5             region_clear_sky_bni         0.66             0.66
# 6                          solaire        -0.65             0.65
# 7               region_abs_dghi_dt         0.57             0.57
# 8                   abs_dtch_lag_3        -0.55             0.55
# 9               region_azimuth_cos         0.35             0.35
# 10                        cos_hour        -0.32             0.32
# 11                  abs_dtch_lag_2        -0.30             0.30
# 12            region_clear_sky_dhi         0.28             0.28
# 13                  region_anomaly         0.21             0.21
# 14                        sin_hour         0.20             0.20
# 15            abs_dtch_roll_std_4h         0.20             0.20
# 16                      dtch_lag_3        -0.17             0.17
# 17                      region_csi         0.14             0.14
# 18                  region_dghi_dt         0.14             0.14
# 19               region_dghi_lag_3        -0.13             0.13
# 20               region_dghi_lag_2        -0.09             0.09
# 21                      region_dhi         0.08             0.08
# 22          region_ghi_roll_std_4h         0.05             0.05
# 23                 region_humidite        -0.04             0.04
# 24                 region_altitude         0.04             0.04
# 25                    consommation         0.03             0.03
# 26             region_vitesse_vent         0.03             0.03
# 27         region_dghi_roll_std_4h         0.02             0.02
# 28         region_nebulosite_lag_3        -0.02             0.02
# 29              region_temperature         0.01             0.01
# 30  region_dnebulosite_roll_std_4h        -0.00             0.00
# 31        region_dnebulosite_lag_3        -0.00             0.00
# 32                         dtch_dt        -0.00             0.00

# %% [markdown]
# ## 5. Sélection exploratoire avec LazyPredict
#
# Après avoir testé des modèles de référence simples, comme le modèle naïf et les modèles linéaires, l'objectif est d'explorer rapidement plusieurs familles de modèles de machine learning.
#
# Pour cela, on utilise **LazyPredict**, qui entraîne automatiquement plusieurs modèles de régression avec leurs paramètres par défaut.
# Cette étape sert uniquement à faire une **pré-sélection rapide** des modèles les plus prometteurs. Elle ne sert pas à choisir le modèle final.
#
# ### Méthodologie
#
# Pour cette étape exploratoire, on utilise uniquement l'ensemble `train`, qui couvre la période **2020–2023**.
#
# Cet ensemble est lui-même séparé chronologiquement en deux parties :
#
# - `X_tr`, `y_tr` : données jusqu'au **31 décembre 2022**, utilisées pour entraîner les modèles ;
# - `X_val`, `y_val` : données à partir du **1er janvier 2023**, utilisées pour une validation interne.
#
# Ce découpage respecte l'ordre temporel des données : les modèles sont entraînés sur le passé, puis évalués sur une période future.
#
# LazyPredict entraîne ensuite plusieurs modèles sur `X_tr` et `y_tr`, puis compare leurs performances sur `X_val` et `y_val`.
#
# ### Évaluation et sélection
#
# Les modèles sont comparés à l'aide de plusieurs métriques, notamment :
#
# - le **MAE** ;
# - le **RMSE** ;
# - le **R²**.
#
# Cette étape permet d'identifier rapidement les modèles qui donnent de bonnes performances avec leurs paramètres par défaut.
#
# Les modèles ayant un `R²` positif et de faibles erreurs de validation interne sont considérés comme des candidats intéressants pour la suite.
#
# ### Objectif
#
# L'objectif de LazyPredict n'est pas de produire le meilleur modèle final, mais de réduire le nombre de modèles à étudier.
#
# Les modèles les plus prometteurs seront ensuite optimisés plus rigoureusement à l'aide d'une recherche d'hyperparamètres et des folds temporels définis manuellement.
#
# L'ensemble `test` reste complètement indépendant et sera utilisé uniquement à la dernière étape, pour l'évaluation finale du modèle retenu.

# %%
# ============================================================
# Séparation temporelle interne pour LazyPredict
# ============================================================

# On utilise uniquement l'ensemble train, qui couvre 2020-2023.
# Les années 2020-2022 servent à entraîner les modèles.
X_tr = X_train.loc[:"2022-12-31 23:30:00+00:00"]
y_tr = y_train.loc[:"2022-12-31 23:30:00+00:00"]

# L'année 2023 sert à faire une validation interne.
X_val = X_train.loc["2023-01-01 00:00:00+00:00":]
y_val = y_train.loc["2023-01-01 00:00:00+00:00":]

def run_lazy(X_train, X_valid, y_train, y_valid):
    """
    Exécute LazyPredict sur un découpage temporel train/validation.

    Cette fonction :
    - entraîne plusieurs modèles de régression avec leurs paramètres par défaut ;
    - calcule les performances sur validation ;
    - calcule aussi les performances sur train pour détecter un éventuel surapprentissage.
    """

    # Initialisation de LazyRegressor
    reg = LazyRegressor(verbose=0, 
                        ignore_warnings=True, 
                        random_state=42, 
                        predictions=True # permet de récupérer les prédictions de chaque modèle
                       )

    # Entraîne tous les modèles de LazyPredict
    # models : tableau contenant les métriques calculées par LazyPredict
    # preds : DataFrame contenant les prédictions de chaque modèle
    models, preds = reg.fit(X_train, X_valid, y_train, y_valid)

    # Moyennes des cibles (pour MAE normalisés)
    y_valid_mean = y_valid.mean()
    y_train_mean = y_train.mean()

    # Dictionnaires pour stocker les métriques calculées manuellement
    r2_scores_train = {}
    mae_val_scores = {}
    mae_rel_val_scores = {}
    mae_train_scores = {}
    mae_rel_train_scores = {}
    rmse_val_scores = {}
    rmse_rel_val_scores = {}
    rmse_train_scores = {}
    rmse_rel_train_scores = {}

    # Récupération des modèles entraînés par LazyPredict
    trained_models = reg.models

    # Boucle sur chaque modèle testé par LazyPredict
    for model_name in preds.columns:
        # ===== Validation =====
        # Prédictions du modèle sur l'ensemble de validation
        pred_val = preds[model_name]

        # MAE validation
        mae_val = mean_absolute_error(y_valid, pred_val)

        # MAE relatif validation (%)
        mae_rel_val = round(mae_val / y_valid_mean * 100, 2) if y_valid_mean != 0 else np.nan

        # RMSE validation
        rmse_val = np.sqrt(mean_squared_error(y_valid, pred_val))

        # RMSE relatif validation (%)
        rmse_rel_val = round(rmse_val / y_valid_mean * 100, 2) if y_valid_mean != 0 else np.nan

        # ===== Train =====
        # Récupération du modèle entraîné
        model = trained_models[model_name]

        # Prédictions sur train
        pred_train = model.predict(X_train)

        # R2 score train
        r2_score_train = r2_score(y_train, pred_train)
        
        # MAE train
        mae_train = mean_absolute_error(y_train, pred_train)

        # MAE relatif train (%)
        mae_rel_train = round(mae_train / y_train_mean * 100, 2) if y_train_mean != 0 else np.nan

        # RMSE train
        rmse_train = np.sqrt(mean_squared_error(y_train, pred_train))

        # RMSE relatif train (%)
        rmse_rel_train = round(rmse_train / y_train_mean * 100, 2) if y_train_mean != 0 else np.nan

        # Stockage des métriques
        r2_scores_train[model_name] = r2_score_train
        mae_val_scores[model_name] = mae_val
        mae_rel_val_scores[model_name] = mae_rel_val
        mae_train_scores[model_name] = mae_train
        mae_rel_train_scores[model_name] = mae_rel_train
        rmse_val_scores[model_name] = rmse_val
        rmse_rel_val_scores[model_name] = rmse_rel_val
        rmse_train_scores[model_name] = rmse_train
        rmse_rel_train_scores[model_name] = rmse_rel_train

    # Création d'un DataFrame contenant les métriques calculées manuellement
    mae_df = pd.DataFrame({
        "r2_score_train": pd.Series(r2_scores_train),
        "MAE_train": pd.Series(mae_train_scores),
        "MAE_relatif_train(%)": pd.Series(mae_rel_train_scores),
        "MAE_val": pd.Series(mae_val_scores),
        "MAE_relatif_val(%)": pd.Series(mae_rel_val_scores),
        "RMSE_train": pd.Series(rmse_train_scores),
        "RMSE_relatif_train(%)": pd.Series(rmse_rel_train_scores),
        "RMSE_val": pd.Series(rmse_val_scores),
        "RMSE_relatif_val(%)": pd.Series(rmse_rel_val_scores)
    })
    
    # Fusion avec les résultats fournis par LazyPredict
    out = models.merge(mae_df, left_index=True, right_index=True)

    return out, reg

# Exécution de LazyPredict sur le découpage temporel interne
lazy_results_df, lazy_runner = run_lazy(X_tr, X_val, y_tr, y_val)

# Sauvegarde de tous les modèles entraînés par LazyPredict
joblib.dump(lazy_runner.models, "lazy_all_models.joblib")

# Renommage de certaines colonnes pour plus de clarté
lazy_results_df = lazy_results_df.rename({
    "R-Squared": "r2_val",
    "Time Taken": "fit_time_sec"
}, axis=1)

# Sélection des colonnes utiles pour l'analyse
lazy_metrics_df = lazy_results_df[
    [
        "r2_val", "r2_score_train",
        "MAE_train", "MAE_val",
        "MAE_relatif_train(%)", "MAE_relatif_val(%)",
        "RMSE_train", "RMSE_val",
        "RMSE_relatif_train(%)", "RMSE_relatif_val(%)",
        "fit_time_sec"
    ]
].copy()


# Calcul des écarts train-validation
# Un grand écart peut indiquer un surapprentissage
lazy_metrics_df["mae_gap"] = lazy_metrics_df["MAE_val"] - lazy_metrics_df["MAE_train"]
lazy_metrics_df["rmse_gap"] = lazy_metrics_df["RMSE_val"] - lazy_metrics_df["RMSE_train"]

# Score global de classement
# Plus ce score est faible, meilleur est le modèle
# Ici, la MAE est privilégiée par rapport au RMSE
lazy_metrics_df["global_score"] = (
    lazy_metrics_df["MAE_val"] * 0.7 +
    lazy_metrics_df["RMSE_val"] * 0.3
)

# Sauvegarde les résultats de LazyPredict dans un fichier CSV
# pour éviter de relancer l'entraînement (qui prend du temps)
lazy_metrics_df.reset_index(names="model_name").to_csv(
    "lazy_metrics.csv", index=False
)

# Sélection des meilleurs modèles
# On garde seulement les modèles avec un R² positif sur validation
top_models_df = (
    lazy_metrics_df[lazy_metrics_df["r2_val"] > 0]
    .sort_values(["MAE_val", "r2_val"], ascending=[True, False])
    .head(40)
)
# Affichage des meilleurs modèles
top_models_df
# Out:
# D:\Projet_Moustafa_Datascience\variability\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(
#                                  r2_val  r2_score_train     MAE_train  \
# ExtraTreesRegressor            0.917384        1.000000  3.113808e-15
# NuSVR                          0.920729        0.927944  4.013378e-01
# RandomForestRegressor          0.915784        0.988216  1.592995e-01
# SVR                            0.920847        0.928029  4.088856e-01
# LGBMRegressor                  0.915607        0.941670  3.914221e-01
# HistGradientBoostingRegressor  0.914869        0.941181  3.929454e-01
# BaggingRegressor               0.908449        0.983541  1.818989e-01
# XGBRegressor                   0.909390        0.969968  2.923232e-01
# GradientBoostingRegressor      0.907814        0.912709  4.900826e-01
# MLPRegressor                   0.915625        0.938651  4.448315e-01
# KNeighborsRegressor            0.896969        0.933035  4.086277e-01
# LinearSVR                      0.867784        0.858932  6.415990e-01
# ExtraTreeRegressor             0.816228        1.000000  2.231893e-17
# HuberRegressor                 0.868123        0.859252  6.575789e-01
# DecisionTreeRegressor          0.814547        1.000000  3.791818e-17
# LassoCV                        0.872992        0.865733  7.102594e-01
# ElasticNetCV                   0.872543        0.864951  7.113418e-01
# LarsCV                         0.870894        0.862842  7.170621e-01
# LassoLarsCV                    0.875356        0.869929  7.150730e-01
# Ridge                          0.875332        0.869940  7.155396e-01
# BayesianRidge                  0.875326        0.869942  7.157816e-01
# RidgeCV                        0.875309        0.869946  7.163373e-01
# LassoLarsIC                    0.875306        0.869946  7.164333e-01
# TransformedTargetRegressor     0.875271        0.869958  7.164885e-01
# LinearRegression               0.875271        0.869958  7.164885e-01
# SGDRegressor                   0.872756        0.865018  7.262854e-01
# OrthogonalMatchingPursuitCV    0.838740        0.828946  7.872402e-01
# OrthogonalMatchingPursuit      0.838740        0.828946  7.872402e-01
# PoissonRegressor               0.798351        0.755238  9.570414e-01
# TweedieRegressor               0.772355        0.770406  1.046763e+00
# PassiveAggressiveRegressor     0.747205        0.732858  1.107070e+00
# ElasticNet                     0.705104        0.704325  1.308225e+00
# Lasso                          0.686023        0.681767  1.445030e+00
# LassoLars                      0.686012        0.681757  1.445051e+00
# AdaBoostRegressor              0.597747        0.567425  1.931077e+00
#
#                                 MAE_val  MAE_relatif_train(%)  \
# ExtraTreesRegressor            0.460346                  0.00
# NuSVR                          0.462515                 16.70
# RandomForestRegressor          0.466994                  6.63
# SVR                            0.468515                 17.01
# LGBMRegressor                  0.483202                 16.29
# HistGradientBoostingRegressor  0.485413                 16.35
# BaggingRegressor               0.489316                  7.57
# XGBRegressor                   0.495809                 12.16
# GradientBoostingRegressor      0.526400                 20.39
# MLPRegressor                   0.532678                 18.51
# KNeighborsRegressor            0.546666                 17.00
# LinearSVR                      0.667240                 26.70
# ExtraTreeRegressor             0.680203                  0.00
# HuberRegressor                 0.682396                 27.36
# DecisionTreeRegressor          0.683937                  0.00
# LassoCV                        0.734737                 29.55
# ElasticNetCV                   0.735768                 29.60
# LarsCV                         0.740935                 29.84
# LassoLarsCV                    0.745328                 29.75
# Ridge                          0.745967                 29.77
# BayesianRidge                  0.746250                 29.78
# RidgeCV                        0.746900                 29.81
# LassoLarsIC                    0.747012                 29.81
# TransformedTargetRegressor     0.747016                 29.81
# LinearRegression               0.747016                 29.81
# SGDRegressor                   0.748951                 30.22
# OrthogonalMatchingPursuitCV    0.808274                 32.76
# OrthogonalMatchingPursuit      0.808274                 32.76
# PoissonRegressor               0.993844                 39.82
# TweedieRegressor               1.104338                 43.55
# PassiveAggressiveRegressor     1.135221                 46.06
# ElasticNet                     1.369998                 54.43
# Lasso                          1.502567                 60.13
# LassoLars                      1.502590                 60.13
# AdaBoostRegressor              1.949377                 80.35
#
#                                MAE_relatif_val(%)    RMSE_train  RMSE_val  \
# ExtraTreesRegressor                         18.02  6.038151e-15  0.986772
# NuSVR                                       18.10  8.768894e-01  0.966592
# RandomForestRegressor                       18.28  3.546119e-01  0.996283
# SVR                                         18.34  8.763743e-01  0.965868
# LGBMRegressor                               18.91  7.889648e-01  0.997330
# HistGradientBoostingRegressor               19.00  7.922611e-01  1.001680
# BaggingRegressor                            19.15  4.190906e-01  1.038760
# XGBRegressor                                19.40  5.661098e-01  1.033410
# GradientBoostingRegressor                   20.60  9.651522e-01  1.042361
# MLPRegressor                                20.85  8.091248e-01  0.997222
# KNeighborsRegressor                         21.39  8.453471e-01  1.101970
# LinearSVR                                   26.11  1.226943e+00  1.248324
# ExtraTreeRegressor                          26.62  3.279686e-16  1.471717
# HuberRegressor                              26.71  1.225550e+00  1.246721
# DecisionTreeRegressor                       26.77  4.223160e-16  1.478432
# LassoCV                                     28.76  1.197002e+00  1.223488
# ElasticNetCV                                28.80  1.200483e+00  1.225651
# LarsCV                                      29.00  1.209822e+00  1.233554
# LassoLarsCV                                 29.17  1.178149e+00  1.212049
# Ridge                                       29.19  1.178103e+00  1.212167
# BayesianRidge                               29.21  1.178090e+00  1.212198
# RidgeCV                                     29.23  1.178076e+00  1.212278
# LassoLarsIC                                 29.24  1.178076e+00  1.212294
# TransformedTargetRegressor                  29.24  1.178018e+00  1.212463
# LinearRegression                            29.24  1.178018e+00  1.212463
# SGDRegressor                                29.31  1.200186e+00  1.224625
# OrthogonalMatchingPursuitCV                 31.63  1.351067e+00  1.378632
# OrthogonalMatchingPursuit                   31.63  1.351067e+00  1.378632
# PoissonRegressor                            38.90  1.616153e+00  1.541640
# TweedieRegressor                            43.22  1.565276e+00  1.637999
# PassiveAggressiveRegressor                  44.43  1.688425e+00  1.726112
# ElasticNet                                  53.62  1.776305e+00  1.864316
# Lasso                                       58.81  1.842823e+00  1.923684
# LassoLars                                   58.81  1.842850e+00  1.923718
# AdaBoostRegressor                           76.29  2.148529e+00  2.177381
#
#                                RMSE_relatif_train(%)  RMSE_relatif_val(%)  \
# ExtraTreesRegressor                             0.00                38.62
# NuSVR                                          36.49                37.83
# RandomForestRegressor                          14.75                38.99
# SVR                                            36.46                37.80
# LGBMRegressor                                  32.83                39.03
# HistGradientBoostingRegressor                  32.96                39.20
# BaggingRegressor                               17.44                40.65
# XGBRegressor                                   23.56                40.44
# GradientBoostingRegressor                      40.16                40.79
# MLPRegressor                                   33.67                39.03
# KNeighborsRegressor                            35.17                43.13
# LinearSVR                                      51.05                48.86
# ExtraTreeRegressor                              0.00                57.60
# HuberRegressor                                 50.99                48.79
# DecisionTreeRegressor                           0.00                57.86
# LassoCV                                        49.81                47.88
# ElasticNetCV                                   49.95                47.97
# LarsCV                                         50.34                48.28
# LassoLarsCV                                    49.02                47.44
# Ridge                                          49.02                47.44
# BayesianRidge                                  49.02                47.44
# RidgeCV                                        49.02                47.44
# LassoLarsIC                                    49.02                47.45
# TransformedTargetRegressor                     49.02                47.45
# LinearRegression                               49.02                47.45
# SGDRegressor                                   49.94                47.93
# OrthogonalMatchingPursuitCV                    56.22                53.96
# OrthogonalMatchingPursuit                      56.22                53.96
# PoissonRegressor                               67.25                60.34
# TweedieRegressor                               65.13                64.11
# PassiveAggressiveRegressor                     70.25                67.55
# ElasticNet                                     73.91                72.96
# Lasso                                          76.68                75.29
# LassoLars                                      76.68                75.29
# AdaBoostRegressor                              89.40                85.22
#
#                                fit_time_sec   mae_gap  rmse_gap  global_score
# ExtraTreesRegressor              104.011271  0.460346  0.986772      0.618274
# NuSVR                           1038.519336  0.061177  0.089703      0.613738
# RandomForestRegressor            539.960986  0.307694  0.641671      0.625780
# SVR                              290.562116  0.059629  0.089494      0.617721
# LGBMRegressor                      0.776956  0.091780  0.208365      0.637441
# HistGradientBoostingRegressor      4.263728  0.092468  0.209418      0.640293
# BaggingRegressor                  55.450743  0.307418  0.619670      0.654150
# XGBRegressor                       0.772809  0.203486  0.467300      0.657089
# GradientBoostingRegressor        166.327194  0.036317  0.077209      0.681188
# MLPRegressor                      43.785611  0.087847  0.188098      0.672041
# KNeighborsRegressor                1.265263  0.138038  0.256622      0.713257
# LinearSVR                         28.999925  0.025641  0.021381      0.841565
# ExtraTreeRegressor                 1.416855  0.680203  1.471717      0.917657
# HuberRegressor                     4.832651  0.024817  0.021171      0.851693
# DecisionTreeRegressor              7.408673  0.683937  1.478432      0.922286
# LassoCV                           30.167900  0.024477  0.026487      0.881362
# ElasticNetCV                      30.843560  0.024426  0.025168      0.882733
# LarsCV                             1.334110  0.023873  0.023732      0.888721
# LassoLarsCV                        1.584398  0.030255  0.033900      0.885344
# Ridge                              0.472506  0.030427  0.034064      0.885827
# BayesianRidge                      0.488202  0.030468  0.034108      0.886034
# RidgeCV                            0.749883  0.030562  0.034202      0.886513
# LassoLarsIC                        0.750101  0.030579  0.034218      0.886597
# TransformedTargetRegressor         0.516077  0.030527  0.034445      0.886650
# LinearRegression                   0.564091  0.030527  0.034445      0.886650
# SGDRegressor                       0.853089  0.022666  0.024439      0.891654
# OrthogonalMatchingPursuitCV        0.982962  0.021034  0.027565      0.979382
# OrthogonalMatchingPursuit          0.494158  0.021034  0.027565      0.979382
# PoissonRegressor                   0.504762  0.036803 -0.074513      1.158183
# TweedieRegressor                   0.443434  0.057575  0.072723      1.264436
# PassiveAggressiveRegressor         0.721319  0.028151  0.037687      1.312489
# ElasticNet                         0.811811  0.061773  0.088010      1.518293
# Lasso                              0.516542  0.057537  0.080861      1.628902
# LassoLars                          0.450999  0.057539  0.080868      1.628929
# AdaBoostRegressor                 49.335285  0.018300  0.028852      2.017778

# %%
lazy_metrics_df = pd.read_csv("lazy_metrics.csv", index_col=0)

# On garde seulement les modèles avec un R² positif sur validation
top_models_df = (
    lazy_metrics_df[lazy_metrics_df["r2_val"] > 0]
    .sort_values(["MAE_val", "r2_val"], ascending=[True, False])
    .head(40)
)

# %% [markdown]
# Les modèles testés par LazyPredict appartiennent à plusieurs grandes familles. Le tableau suivant résume brièvement l'idée principale de chaque catégorie.
# | Catégorie                          | Idée                                                         |
# | ---------------------------------- | ------------------------------------------------------------ |
# | **Modèles linéaires**              | supposent une relation linéaire entre variables              |
# | **Machines à vecteurs de support (SVM)** | modèles non linéaires utilisant des noyaux                   |
# | **Arbres de décision**             | règles de décision successives (tests sur les variables)     |
# | **Ensembles d'arbres**             | combinaison de plusieurs arbres pour améliorer la prédiction (RandomForest, XGBoost…) |
# | **Réseaux de neurones**            | modèles non linéaires (MLPRegressor)                   |
# | **Méthodes à base de voisins**     | prédiction basée sur les k échantillons d'apprentissage les plus proches (selon une distance) du nouveau point (KNN)       |
# | **Méthodes particulières**                   | modèles utilisant des stratégies particulières d'apprentissage ou de transformation pour améliorer la prédiction (TransformedTargetRegressor, PassiveAggressiveRegressor)         |

# %%
# Cette cellule associe chaque modèle sélectionné par LazyPredict
# à une grande famille de modèles.

# Dictionnaire associant le nom du modèle à sa catégorie
model_categories = {

    # Modèles linéaires
    'LinearRegression': 'Modèles linéaires',
    'Ridge': 'Modèles linéaires',
    'RidgeCV': 'Modèles linéaires',
    'Lasso': 'Modèles linéaires',
    'LassoCV': 'Modèles linéaires',
    'ElasticNet': 'Modèles linéaires',
    'ElasticNetCV': 'Modèles linéaires',
    'BayesianRidge': 'Modèles linéaires',
    'HuberRegressor': 'Modèles linéaires',
    'SGDRegressor': 'Modèles linéaires',
    'LarsCV': 'Modèles linéaires',
    'LassoLars': 'Modèles linéaires',
    'LassoLarsCV': 'Modèles linéaires',
    'LassoLarsIC': 'Modèles linéaires',
    'OrthogonalMatchingPursuit': 'Modèles linéaires',
    'OrthogonalMatchingPursuitCV': 'Modèles linéaires',
    'PoissonRegressor': 'Modèles linéaires',
    'TweedieRegressor': 'Modèles linéaires',

    # Machines à vecteurs de support
    'SVR': 'SVM',
    'NuSVR': 'SVM',
    'LinearSVR': 'SVM',

    # Arbres de décision simples
    'DecisionTreeRegressor': 'Arbres de décision',
    'ExtraTreeRegressor': 'Arbres de décision',

    # Ensembles d'arbres
    'RandomForestRegressor': "Ensembles d'arbres",
    'ExtraTreesRegressor': "Ensembles d'arbres",
    'GradientBoostingRegressor': "Ensembles d'arbres",
    'HistGradientBoostingRegressor': "Ensembles d'arbres",
    'XGBRegressor': "Ensembles d'arbres",
    'LGBMRegressor': "Ensembles d'arbres",
    'BaggingRegressor': "Ensembles d'arbres",
    'AdaBoostRegressor': "Ensembles d'arbres",

    # Réseaux de neurones
    'MLPRegressor': 'Réseaux de neurones',

    # Méthodes basées sur les voisins
    'KNeighborsRegressor': 'Méthodes à base de voisins',

    # Méthodes particulières
    'TransformedTargetRegressor': 'Méthodes particulières',
    'PassiveAggressiveRegressor': 'Méthodes particulières'
}

# Ajout d'une colonne indiquant la famille de chaque modèle
top_models_df["Category"] = top_models_df.index.map(model_categories)

# Affichage des 10 meilleurs modèles avec leur catégorie
top_models_df.head(10)
# Out:
#                                r2_val  r2_score_train  MAE_train  MAE_val  \
# model_name
# SVR                              0.83            0.85       0.76     0.89
# NuSVR                            0.82            0.85       0.79     0.90
# ExtraTreesRegressor              0.82            1.00       0.00     0.92
# RandomForestRegressor            0.81            0.97       0.32     0.94
# LGBMRegressor                    0.81            0.88       0.76     0.96
# MLPRegressor                     0.81            0.88       0.75     0.96
# HistGradientBoostingRegressor    0.81            0.87       0.78     0.96
# BaggingRegressor                 0.80            0.96       0.37     0.98
# XGBRegressor                     0.80            0.94       0.56     0.99
# GradientBoostingRegressor        0.80            0.82       0.92     1.01
#
#                                MAE_relatif_train(%)  MAE_relatif_val(%)  \
# model_name
# SVR                                           15.72               17.22
# NuSVR                                         16.19               17.50
# ExtraTreesRegressor                            0.00               17.83
# RandomForestRegressor                          6.64               18.19
# LGBMRegressor                                 15.69               18.57
# MLPRegressor                                  15.45               18.59
# HistGradientBoostingRegressor                 16.13               18.72
# BaggingRegressor                               7.61               19.00
# XGBRegressor                                  11.46               19.16
# GradientBoostingRegressor                     19.04               19.56
#
#                                RMSE_train  RMSE_val  RMSE_relatif_train(%)  \
# model_name
# SVR                                  1.24      1.37                  25.46
# NuSVR                                1.24      1.37                  25.48
# ExtraTreesRegressor                  0.00      1.40                   0.00
# RandomForestRegressor                0.51      1.43                  10.50
# LGBMRegressor                        1.11      1.42                  22.92
# MLPRegressor                         1.09      1.43                  22.48
# HistGradientBoostingRegressor        1.15      1.42                  23.76
# BaggingRegressor                     0.61      1.48                  12.57
# XGBRegressor                         0.78      1.48                  16.16
# GradientBoostingRegressor            1.36      1.49                  27.97
#
#                                RMSE_relatif_val(%)  fit_time_sec  mae_gap  \
# model_name
# SVR                                          26.56         25.92     0.12
# NuSVR                                        26.67         27.44     0.12
# ExtraTreesRegressor                          27.28         24.94     0.92
# RandomForestRegressor                        27.73        112.57     0.61
# LGBMRegressor                                27.60          0.75     0.19
# MLPRegressor                                 27.68          6.71     0.21
# HistGradientBoostingRegressor                27.64          0.92     0.18
# BaggingRegressor                             28.67         11.17     0.61
# XGBRegressor                                 28.78          0.51     0.43
# GradientBoostingRegressor                    28.85         39.85     0.08
#
#                                rmse_gap  global_score             Category
# model_name
# SVR                                0.13          1.03                  SVM
# NuSVR                              0.14          1.04                  SVM
# ExtraTreesRegressor                1.40          1.06   Ensembles d'arbres
# RandomForestRegressor              0.92          1.08   Ensembles d'arbres
# LGBMRegressor                      0.31          1.10   Ensembles d'arbres
# MLPRegressor                       0.33          1.10  Réseaux de neurones
# HistGradientBoostingRegressor      0.27          1.10   Ensembles d'arbres
# BaggingRegressor                   0.87          1.13   Ensembles d'arbres
# XGBRegressor                       0.70          1.14   Ensembles d'arbres
# GradientBoostingRegressor          0.13          1.15   Ensembles d'arbres

# %%
# Cette cellule résume les performances moyennes par famille de modèles.
# Elle permet de voir quelles catégories de modèles semblent les plus prometteuses.

# Agrégation des performances par catégorie de modèles
category_performance = (
    top_models_df
    .groupby("Category")[["MAE_val", "r2_val"]]
    .agg(["mean", "median", "std", "min", "max"])
    .sort_values(by=("MAE_val", "mean"))
)

# Remplacement des valeurs NaN par une chaîne vide pour un affichage plus propre
# Cela arrive notamment si une catégorie contient un seul modèle, donc pas d'écart-type calculable
category_performance = category_performance.fillna("")

# Affichage du tableau récapitulatif
display(category_performance)
# Out:
#                            MAE_val                       r2_val              \
#                               mean median  std  min  max   mean median  std
# Category
# Réseaux de neurones           0.96   0.96      0.96 0.96   0.81   0.81
# SVM                           0.99   0.90 0.16 0.89 1.17   0.80   0.82 0.04
# Méthodes à base de voisins    1.07   1.07      1.07 1.07   0.77   0.77
# Ensembles d'arbres            1.08   0.97 0.32 0.92 1.88   0.77   0.80 0.10
# Arbres de décision            1.35   1.35 0.02 1.34 1.36   0.61   0.61 0.00
# Modèles linéaires             1.40   1.22 0.30 1.18 2.03   0.68   0.74 0.11
# Méthodes particulières        1.42   1.42 0.31 1.20 1.64   0.66   0.66 0.13
#
#
#                             min  max
# Category
# Réseaux de neurones        0.81 0.81
# SVM                        0.75 0.83
# Méthodes à base de voisins 0.77 0.77
# Ensembles d'arbres         0.52 0.82
# Arbres de décision         0.61 0.62
# Modèles linéaires          0.45 0.75
# Méthodes particulières     0.57 0.75

# %%
# Cette cellule visualise les performances moyennes par famille de modèles.
# Elle permet de comparer rapidement les catégories de modèles selon la MAE et le R².

# Sélection des métriques principales à visualiser
plot_df = category_performance[
    [
        ("MAE_val", "mean"),
        ("r2_val", "mean"),
        ("MAE_val", "min"),
        ("r2_val", "max")
    ]
].copy()

# Renommage des colonnes pour un affichage plus clair
plot_df.columns = [
    "MAE moyenne",
    "R² moyen",
    "MAE minimale",
    "R² maximal"
]

# Conversion en valeurs numériques
# Utile si certaines valeurs ont été remplacées par des chaînes vides auparavant
plot_df = plot_df.apply(pd.to_numeric, errors="coerce")

# Affichage du tableau utilisé pour le graphique
display(plot_df)

# Graphique comparatif
plot_df.plot(kind="barh", figsize=(8, 6))

plt.title("Comparaison des performances par famille de modèles")
plt.xlabel("Valeur des métriques")
plt.ylabel("Famille de modèles")

plt.tight_layout()
plt.show()
# Out:
#                             MAE moyenne  R² moyen  MAE minimale  R² maximal
# Category
# Réseaux de neurones                0.96      0.81          0.96        0.81
# SVM                                0.99      0.80          0.89        0.83
# Méthodes à base de voisins         1.07      0.77          1.07        0.77
# Ensembles d'arbres                 1.08      0.77          0.92        0.82
# Arbres de décision                 1.35      0.61          1.34        0.62
# Modèles linéaires                  1.40      0.68          1.18        0.75
# Méthodes particulières             1.42      0.66          1.20        0.75

# %% [markdown]
# ## 6. Modèles d'arbres et de boosting
#
# Les résultats exploratoires obtenus avec LazyPredict orientent ensuite l'analyse vers les modèles d'arbres et de boosting.
#
# Ces modèles sont particulièrement adaptés aux données tabulaires.
# Ils permettent de capturer des relations non linéaires entre les variables explicatives et la cible, sans imposer une forme fonctionnelle simple comme dans les modèles linéaires.
#
# Les modèles d'arbres sont également capables de prendre en compte des interactions entre variables, par exemple entre l'irradiance, la nébulosité, les conditions de ciel clair et les variables temporelles.
#
# ### 6.1 LightGBM
#
# LightGBM est un modèle de gradient boosting basé sur des arbres de décision.
# Il construit progressivement plusieurs arbres, où chaque nouvel arbre cherche à corriger les erreurs commises par les arbres précédents.
#
# Dans cette section, on suit trois étapes :
#
# 1. entraînement d'un premier modèle LightGBM de référence ;
# 2. recherche des meilleurs hyperparamètres à l'aide d'une recherche par grille et des folds temporels définis manuellement ;
# 3. entraînement et évaluation du meilleur modèle sur l'ensemble de validation.
#
# L'objectif est de vérifier si LightGBM améliore les performances par rapport aux modèles de référence, tout en respectant la structure temporelle des données.

# %% [markdown]
# L'analyse de l'importance des variables est considérée ici comme une étape complémentaire d'interprétation. Elle n'est pas utilisée pour choisir le modèle final, qui sera sélectionné principalement à partir des performances obtenues en validation temporelle.

# %% [markdown]
# #### 6.1.1 Optimisation des hyperparamètres LightGBM avec Optuna
#
# L'optimisation des hyperparamètres de LightGBM est réalisée avec **Optuna**, en utilisant les folds temporels définis manuellement.
#
# Contrairement à une recherche par grille, Optuna ne teste pas toutes les combinaisons possibles.
# Il explore progressivement l'espace des hyperparamètres et concentre la recherche sur les zones les plus prometteuses.
#
# Pour chaque essai Optuna, une combinaison d'hyperparamètres est proposée.
# Cette combinaison est évaluée sur plusieurs folds temporels : le modèle est entraîné sur une période passée puis validé sur une période future.
#
# L'évaluation repose principalement sur :
#
# - la **MAE moyenne de validation**, qui mesure l'erreur prédictive ;
# - le **gap train/validation**, qui sert d'indicateur de surapprentissage ;
# - l'**early stopping**, utilisé à l'intérieur de chaque fold afin d'arrêter l'entraînement lorsque la performance sur la période de validation intérieur ne s'améliore plus.
#
# L'objectif est donc de choisir un modèle performant en validation temporelle, tout en restant robuste et en limitant le surapprentissage.
#
# | Paramètre | Explication |
# |---|---|
# | `n_estimators` | Nombre maximal d'arbres de boosting. Un nombre plus grand permet au modèle d'apprendre plus longtemps, mais augmente le temps d'entraînement et le risque de surapprentissage. |
# | `learning_rate` | Taille du pas d'apprentissage. Une valeur faible rend l'apprentissage plus progressif et peut améliorer la généralisation, mais nécessite souvent plus d'arbres. |
# | `num_leaves` | Nombre maximal de feuilles par arbre. Une valeur plus grande permet de capturer des relations plus complexes, mais peut augmenter le risque de surapprentissage. |
# | `max_depth` | Profondeur maximale des arbres. Limiter cette profondeur permet de contrôler la complexité du modèle. |
# | `min_child_samples` | Nombre minimum d'échantillons dans une feuille. Une valeur plus élevée rend le modèle plus conservateur. |
# | `subsample` | Fraction des observations utilisées pour entraîner chaque arbre. Une valeur inférieure à 1 introduit de l'aléatoire et peut améliorer la généralisation. |
# | `colsample_bytree` | Fraction des variables utilisées pour construire chaque arbre. Cela peut réduire la corrélation entre les arbres et limiter le surapprentissage. |
# | `reg_alpha` | Régularisation L1. Elle pénalise certains poids et peut rendre le modèle plus parcimonieux. |
# | `reg_lambda` | Régularisation L2. Elle stabilise le modèle en pénalisant les poids trop grands. |

# %%
# Copie des ensembles utilisés pour LightGBM
X_train_lgbm = X_train.copy()
X_valid_lgbm = X_valid.copy()

# =======================================================
# Évaluation d'une combinaison d'hyperparamètres LightGBM
# =======================================================
def evaluate_params(params, X, y, trial=None):
    """
    Évalue une combinaison d'hyperparamètres LightGBM
    sur les folds temporels définis manuellement.

    La fonction retourne deux objectifs :
    - la MAE moyenne sur validation ;
    - le gap moyen entre train et validation.
    """
    # listes pour stocker les métriques
    maes_valid = []; maes_train = []
    rmses_valid = []; rmses_train = []
    r2_trains = []; r2_valids = []
    gaps = []; best_iterations = []

    # génération des folds temporels manuels
    folds = get_folds(X, y)

    # boucle sur les folds temporels
    for step, (X_tr, X_v, y_tr, y_v) in enumerate(folds):

        # Création du modèle LightGBM avec les paramètres proposés
        model = LGBMRegressor(**params)

        # Entraînement du modèle avec early stopping
        model.fit(
            X_tr,
            y_tr,
            eval_set=[(X_v, y_v)],
            eval_metric="mae",
            callbacks=[lgb.early_stopping(50, verbose=False)]
        )

        # Récupération de la meilleure itération
        best_iter = model.best_iteration_ or params["n_estimators"]
        best_iterations.append(best_iter)
        
        # Prédictions sur train et validation avec la meilleure itération
        pred_train = model.predict(X_tr, num_iteration=best_iter)
        pred_valid = model.predict(X_v, num_iteration=best_iter)

        # MAE train et validation
        mae_train = mean_absolute_error(y_tr, pred_train)
        mae_valid = mean_absolute_error(y_v, pred_valid)
        
        # RMSE train et validation
        rmse_train = np.sqrt(mean_squared_error(y_tr, pred_train))
        rmse_valid = np.sqrt(mean_squared_error(y_v, pred_valid))
        
        # R2 train et validation
        r2_train = r2_score(y_tr, pred_train)
        r2_valid = r2_score(y_v, pred_valid)

        # Gap train/validation
        gap = max(0, mae_valid - mae_train)

        # Stockage des métriques du fold
        maes_valid.append(mae_valid)
        maes_train.append(mae_train)
        rmses_valid.append(rmse_valid)
        rmses_train.append(rmse_train)
        r2_trains.append(r2_train)
        r2_valids.append(r2_valid)
        gaps.append(gap)

    # Résumé des métriques sur tous les folds
    median_best_iteration = int(np.median(best_iterations))
    
    mean_mae_valid = np.mean(maes_valid)
    mean_mae_train = np.mean(maes_train)
    
    std_mae_valid = np.std(maes_valid)
    std_mae_train = np.std(maes_train)
    
    mean_r2_train = np.mean(r2_trains)
    mean_r2_valid = np.mean(r2_valids)
    
    mean_rmse_valid = np.mean(rmses_valid)
    mean_rmse_train = np.mean(rmses_train)
    
    mean_gap = np.mean(gaps)

    # Pourcentage de gap par rapport à la MAE de validation
    gap_pct = 100 * max(0, mean_mae_valid - mean_mae_train) / mean_mae_valid

    # Sauvegarde des informations utiles dans Optuna
    if trial is not None:
        trial.set_user_attr("best_iteration", median_best_iteration)

        trial.set_user_attr("mean_mae_valid", mean_mae_valid)
        trial.set_user_attr("mean_mae_train", mean_mae_train)

        trial.set_user_attr("std_mae_valid", std_mae_valid)
        trial.set_user_attr("std_mae_train", std_mae_train)
    
        trial.set_user_attr("mean_rmse_valid", mean_rmse_valid)
        trial.set_user_attr("mean_rmse_train", mean_rmse_train)
    
        trial.set_user_attr("mean_r2_valid", mean_r2_valid)
        trial.set_user_attr("mean_r2_train", mean_r2_train)
    
        trial.set_user_attr("mean_gap", mean_gap)
        trial.set_user_attr("std_gap", np.std(gaps))
        trial.set_user_attr("max_gap", np.max(gaps))
        trial.set_user_attr("overfit_gap_pct", gap_pct)
        
    # Optuna va minimiser ces deux objectifs
    return mean_mae_valid, mean_gap


# ========================================
# Fonction objective Optuna pour LightGBM
# ========================================
def objective_lgbm(trial):
    """
    Fonction appelée par Optuna à chaque essai.

    À chaque essai, Optuna propose une combinaison d'hyperparamètres,
    puis cette combinaison est évaluée sur les folds temporels.
    """
    
    # espace de recherche des hyperparamètres
    params = {
        "n_estimators": 2000,
        "learning_rate": trial.suggest_float("learning_rate", 0.005, 0.1, log=True),
    
        "num_leaves": trial.suggest_int("num_leaves", 31, 128),
        "max_depth": trial.suggest_int("max_depth", 4, 10),
    
        "min_child_samples": trial.suggest_int("min_child_samples", 20, 100),
    
        "subsample": trial.suggest_float("subsample", 0.7, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.7, 1.0),
    
        "reg_alpha": trial.suggest_float("reg_alpha", 1e-3, 5.0, log=True),
        "reg_lambda": trial.suggest_float("reg_lambda", 1e-3, 5.0, log=True),
    
        "random_state": 42,
        "n_jobs": 1,
        "verbosity": -1
    }

    # Évaluation des paramètres proposés sur les folds temporels
    return evaluate_params(
        params,
        X_dev,
        y_dev,
        trial=trial
    )


#----------------------------------------
# Création et lancement de l'étude Optuna
#----------------------------------------
study_lgbm = optuna.create_study(
    study_name="study_lgbm_new",
    storage=f"sqlite:///{filepath_output}study_lgbm_new.db",
    load_if_exists=True,
    directions=["minimize", "minimize"],
    sampler=optuna.samplers.TPESampler(
        n_startup_trials=150,
        seed=42
    )
)

# lancement de l'optimisation
# n_trials=300 signifie 300 combinaisons testées par Optuna
study_lgbm.optimize(
    objective_lgbm,
    n_trials=300,
    n_jobs=-1
)
# Out:
# [I 2026-04-26 15:33:43,909] A new study created in RDB with name: study_lgbm_new
# [I 2026-04-26 15:34:01,257] Trial 7 finished with values: [0.4802907659697787, 0.08487760168354183] and parameters: {'learning_rate': 0.09673076010733318, 'num_leaves': 86, 'max_depth': 4, 'min_child_samples': 98, 'subsample': 0.9835987595396125, 'colsample_bytree': 0.8480147908475961, 'reg_alpha': 0.7833177129923361, 'reg_lambda': 0.03846501950107067}.
# [I 2026-04-26 15:34:02,283] Trial 1 finished with values: [0.4634913061139167, 0.09081458534573149] and parameters: {'learning_rate': 0.055528145443294284, 'num_leaves': 52, 'max_depth': 7, 'min_child_samples': 79, 'subsample': 0.8705660971435647, 'colsample_bytree': 0.7493076569232109, 'reg_alpha': 0.08094416133204597, 'reg_lambda': 1.3577372483867727}.
# [I 2026-04-26 15:34:07,026] Trial 0 finished with values: [0.4607965867422564, 0.1188976225746998] and parameters: {'learning_rate': 0.07645938733079988, 'num_leaves': 123, 'max_depth': 9, 'min_child_samples': 76, 'subsample': 0.7844631872760099, 'colsample_bytree': 0.892718157454184, 'reg_alpha': 0.8811643099341809, 'reg_lambda': 0.8546020096844607}.
# [I 2026-04-26 15:34:09,992] Trial 5 finished with values: [0.46017997913710007, 0.1113921494789988] and parameters: {'learning_rate': 0.05710448134206623, 'num_leaves': 113, 'max_depth': 10, 'min_child_samples': 85, 'subsample': 0.9277832794101657, 'colsample_bytree': 0.8956448020251659, 'reg_alpha': 0.35923469969499466, 'reg_lambda': 0.13620952655483265}.
# [I 2026-04-26 15:34:14,405] Trial 8 finished with values: [0.45739191805326024, 0.11342750185576342] and parameters: {'learning_rate': 0.02936957199672204, 'num_leaves': 107, 'max_depth': 7, 'min_child_samples': 25, 'subsample': 0.8096524178369435, 'colsample_bytree': 0.7362962489847872, 'reg_alpha': 0.10778346774836131, 'reg_lambda': 0.0032524391823479425}.
# [I 2026-04-26 15:34:17,147] Trial 17 finished with values: [0.4619403076095722, 0.13618721791850932] and parameters: {'learning_rate': 0.08683833751009244, 'num_leaves': 112, 'max_depth': 10, 'min_child_samples': 40, 'subsample': 0.7596825930287067, 'colsample_bytree': 0.7446858845804278, 'reg_alpha': 0.005254289565609764, 'reg_lambda': 0.017851236490577797}.
# [I 2026-04-26 15:34:29,192] Trial 3 finished with values: [0.462855272384482, 0.13110253353326137] and parameters: {'learning_rate': 0.0356348107179265, 'num_leaves': 82, 'max_depth': 8, 'min_child_samples': 35, 'subsample': 0.7317700284458529, 'colsample_bytree': 0.9776676641483162, 'reg_alpha': 3.235947398604152, 'reg_lambda': 0.3382929660793797}.
# [I 2026-04-26 15:39:16,975] Trial 72 finished with values: [0.46360446953878987, 0.08792349223960327] and parameters: {'learning_rate': 0.034495453307148635, 'num_leaves': 74, 'max_depth': 6, 'min_child_samples': 76, 'subsample': 0.94149992404741, 'colsample_bytree': 0.9954208752424978, 'reg_alpha': 0.0097608986656418, 'reg_lambda': 0.08772234957780718}.
# [I 2026-04-26 15:39:19,772] Trial 77 finished with values: [0.4617601465693853, 0.10703555263632449] and parameters: {'learning_rate': 0.05994986762261797, 'num_leaves': 62, 'max_depth': 6, 'min_child_samples': 25, 'subsample': 0.9600681348677299, 'colsample_bytree': 0.7549248411821975, 'reg_alpha': 0.0023145658688495776, 'reg_lambda': 0.5726770534799386}.
# [I 2026-04-26 15:39:25,361] Trial 50 finished with values: [0.47192789820623654, 0.06482362989401654] and parameters: {'learning_rate': 0.006384539907687434, 'num_leaves': 45, 'max_depth': 5, 'min_child_samples': 70, 'subsample': 0.9976014298783875, 'colsample_bytree': 0.8259384533088776, 'reg_alpha': 3.1606261985473503, 'reg_lambda': 0.8833896495296946}.
# [I 2026-04-26 15:39:31,115] Trial 70 finished with values: [0.4620385167978359, 0.08868788669084746] and parameters: {'learning_rate': 0.022881489203306477, 'num_leaves': 41, 'max_depth': 6, 'min_child_samples': 56, 'subsample': 0.8246803637601205, 'colsample_bytree': 0.7222497578732411, 'reg_alpha': 0.03115501365082816, 'reg_lambda': 0.8218100641529772}.
# [I 2026-04-26 15:39:32,882] Trial 78 finished with values: [0.4610716089536682, 0.11676186362318385] and parameters: {'learning_rate': 0.03560997491695524, 'num_leaves': 125, 'max_depth': 7, 'min_child_samples': 30, 'subsample': 0.7165321322399982, 'colsample_bytree': 0.9514108310014739, 'reg_alpha': 0.02672082848528811, 'reg_lambda': 0.7294692866151256}.
# [I 2026-04-26 15:39:35,025] Trial 81 finished with values: [0.46492663369229525, 0.08224687347550513] and parameters: {'learning_rate': 0.06627777141923497, 'num_leaves': 117, 'max_depth': 6, 'min_child_samples': 93, 'subsample': 0.9566396556361325, 'colsample_bytree': 0.8938553944200098, 'reg_alpha': 0.2360740921600161, 'reg_lambda': 0.10930694450810886}.
# [I 2026-04-26 15:39:41,902] Trial 58 finished with values: [0.45493409255999934, 0.12540541230229985] and parameters: {'learning_rate': 0.010463934738866046, 'num_leaves': 117, 'max_depth': 8, 'min_child_samples': 33, 'subsample': 0.8008530892566017, 'colsample_bytree': 0.7476657982637407, 'reg_alpha': 0.04461097478305752, 'reg_lambda': 0.31024710466094485}.
# [I 2026-04-26 15:39:46,455] Trial 74 finished with values: [0.4791694195667648, 0.07815945114189607] and parameters: {'learning_rate': 0.03306692971088588, 'num_leaves': 85, 'max_depth': 4, 'min_child_samples': 80, 'subsample': 0.7944376799794751, 'colsample_bytree': 0.9374971706166638, 'reg_alpha': 0.6367847585894778, 'reg_lambda': 3.9486088948162976}.
# [I 2026-04-26 15:39:49,689] Trial 82 finished with values: [0.46002000388748693, 0.12285001210985809] and parameters: {'learning_rate': 0.04500107126446857, 'num_leaves': 99, 'max_depth': 9, 'min_child_samples': 58, 'subsample': 0.7844274005041931, 'colsample_bytree': 0.83885832020151, 'reg_alpha': 0.004894048798480763, 'reg_lambda': 0.07169215395912325}.
# [I 2026-04-26 15:40:45,706] Trial 89 finished with values: [0.46493097113799836, 0.09125755358564178] and parameters: {'learning_rate': 0.023976301718302742, 'num_leaves': 45, 'max_depth': 7, 'min_child_samples': 77, 'subsample': 0.7177293522459192, 'colsample_bytree': 0.9311465466351597, 'reg_alpha': 0.10888891362608161, 'reg_lambda': 1.211199374795201}.
# [I 2026-04-26 15:40:47,160] Trial 94 finished with values: [0.4595087545587702, 0.11374003050212189] and parameters: {'learning_rate': 0.039002673467089945, 'num_leaves': 126, 'max_depth': 10, 'min_child_samples': 93, 'subsample': 0.7365751760110676, 'colsample_bytree': 0.8686457136401975, 'reg_alpha': 0.3591387102356372, 'reg_lambda': 4.577467503122422}.
# [I 2026-04-26 15:40:49,565] Trial 95 finished with values: [0.4796138725783431, 0.08556979936703543] and parameters: {'learning_rate': 0.057577986825621284, 'num_leaves': 55, 'max_depth': 4, 'min_child_samples': 50, 'subsample': 0.8894226469095984, 'colsample_bytree': 0.7494611555608388, 'reg_alpha': 0.005832935627784963, 'reg_lambda': 0.05400775223895498}.
# [I 2026-04-26 15:40:53,581] Trial 79 finished with values: [0.4625556679888313, 0.14192406871249358] and parameters: {'learning_rate': 0.014911512764481846, 'num_leaves': 79, 'max_depth': 9, 'min_child_samples': 23, 'subsample': 0.9151033386610729, 'colsample_bytree': 0.9891189193218791, 'reg_alpha': 2.420844429177513, 'reg_lambda': 0.038632095335250825}.
# [I 2026-04-26 15:40:59,119] Trial 86 finished with values: [0.46951352591111223, 0.08156398656238725] and parameters: {'learning_rate': 0.01889340147077803, 'num_leaves': 67, 'max_depth': 5, 'min_child_samples': 86, 'subsample': 0.7842993210982715, 'colsample_bytree': 0.9234153326530404, 'reg_alpha': 1.3499936250890059, 'reg_lambda': 0.36574142612871224}.
# [I 2026-04-26 15:41:04,766] Trial 97 finished with values: [0.46359659029890277, 0.1169333369880373] and parameters: {'learning_rate': 0.04091335580970114, 'num_leaves': 56, 'max_depth': 8, 'min_child_samples': 35, 'subsample': 0.7733734817404501, 'colsample_bytree': 0.8671054881976399, 'reg_alpha': 0.18478643271659753, 'reg_lambda': 0.13751319471032786}.
# [I 2026-04-26 15:41:19,928] Trial 75 finished with values: [0.4609097727645854, 0.11090503996523599] and parameters: {'learning_rate': 0.009890821870892241, 'num_leaves': 84, 'max_depth': 7, 'min_child_samples': 31, 'subsample': 0.7399497282808597, 'colsample_bytree': 0.9163963639887824, 'reg_alpha': 0.0013354402850443148, 'reg_lambda': 1.240459411984725}.
# [I 2026-04-26 15:41:21,607] Trial 98 finished with values: [0.4601490783110777, 0.11852764464222722] and parameters: {'learning_rate': 0.025751321681857276, 'num_leaves': 67, 'max_depth': 9, 'min_child_samples': 30, 'subsample': 0.8091246608463981, 'colsample_bytree': 0.7278306500699815, 'reg_alpha': 0.8302052834679198, 'reg_lambda': 0.03696938660274032}.
# [I 2026-04-26 15:41:22,391] Trial 91 finished with values: [0.47703162878771804, 0.07915745568103505] and parameters: {'learning_rate': 0.03222449240600321, 'num_leaves': 61, 'max_depth': 4, 'min_child_samples': 66, 'subsample': 0.8038318910445763, 'colsample_bytree': 0.8931169997313472, 'reg_alpha': 2.6352481071477403, 'reg_lambda': 2.407227134164559}.
# [I 2026-04-26 15:41:27,641] Trial 99 finished with values: [0.4655412130577271, 0.08726901909130776] and parameters: {'learning_rate': 0.05263966256851278, 'num_leaves': 31, 'max_depth': 6, 'min_child_samples': 94, 'subsample': 0.7603507257342597, 'colsample_bytree': 0.7437322604791484, 'reg_alpha': 0.002141502452964612, 'reg_lambda': 0.027937942254853472}.
# [I 2026-04-26 15:41:37,680] Trial 104 finished with values: [0.46877737246988954, 0.08225713442447781] and parameters: {'learning_rate': 0.06389848665315959, 'num_leaves': 64, 'max_depth': 5, 'min_child_samples': 83, 'subsample': 0.7135757163681843, 'colsample_bytree': 0.7032873271052359, 'reg_alpha': 0.337359245644906, 'reg_lambda': 0.2105641245114239}.
# [I 2026-04-26 15:41:44,980] Trial 65 finished with values: [0.4629304431228152, 0.0785447724103503] and parameters: {'learning_rate': 0.0057643425437355535, 'num_leaves': 104, 'max_depth': 6, 'min_child_samples': 56, 'subsample': 0.9675315670987521, 'colsample_bytree': 0.812046051951438, 'reg_alpha': 0.008372887383397499, 'reg_lambda': 0.00954772211839596}.
# [I 2026-04-26 15:42:04,470] Trial 92 finished with values: [0.46634700035223753, 0.09284269031874305] and parameters: {'learning_rate': 0.01090401486804357, 'num_leaves': 67, 'max_depth': 9, 'min_child_samples': 83, 'subsample': 0.9977596494105332, 'colsample_bytree': 0.9773566133044704, 'reg_alpha': 0.0028565362771462554, 'reg_lambda': 0.19450827129885934}.
# [I 2026-04-26 15:42:13,665] Trial 102 finished with values: [0.45730488513035567, 0.10831435974923634] and parameters: {'learning_rate': 0.019559718540443624, 'num_leaves': 121, 'max_depth': 10, 'min_child_samples': 93, 'subsample': 0.8828664838499257, 'colsample_bytree': 0.8342466123681425, 'reg_alpha': 0.0010601251000859585, 'reg_lambda': 0.005439582595829275}.
# [I 2026-04-26 15:42:23,830] Trial 109 finished with values: [0.46371451564782945, 0.10998420375288609] and parameters: {'learning_rate': 0.03342461238917659, 'num_leaves': 44, 'max_depth': 7, 'min_child_samples': 20, 'subsample': 0.9230575738825332, 'colsample_bytree': 0.7761881654854034, 'reg_alpha': 0.0011953876292273753, 'reg_lambda': 0.07080262856169402}.
# [I 2026-04-26 15:42:24,524] Trial 100 finished with values: [0.46383863476283366, 0.07843350255217856] and parameters: {'learning_rate': 0.011999973495678619, 'num_leaves': 57, 'max_depth': 6, 'min_child_samples': 65, 'subsample': 0.9596523506844457, 'colsample_bytree': 0.8444965695717526, 'reg_alpha': 0.4630337291424945, 'reg_lambda': 0.11283425643422432}.
# [I 2026-04-26 15:42:30,483] Trial 108 finished with values: [0.4596086535973952, 0.11508764092103341] and parameters: {'learning_rate': 0.025341949485367447, 'num_leaves': 106, 'max_depth': 10, 'min_child_samples': 73, 'subsample': 0.9741844608617846, 'colsample_bytree': 0.8533493659098461, 'reg_alpha': 0.7218861556797654, 'reg_lambda': 0.005330448280834709}.
# [I 2026-04-26 15:43:15,068] Trial 107 finished with values: [0.4570848715556633, 0.09980713184485979] and parameters: {'learning_rate': 0.012421079508649659, 'num_leaves': 111, 'max_depth': 8, 'min_child_samples': 78, 'subsample': 0.9883416505580668, 'colsample_bytree': 0.7227853577339519, 'reg_alpha': 3.645493537219762, 'reg_lambda': 0.0017884259045857142}.
# [I 2026-04-26 15:43:22,897] Trial 119 finished with values: [0.4711318303165969, 0.09875530401372185] and parameters: {'learning_rate': 0.09276625974703118, 'num_leaves': 117, 'max_depth': 5, 'min_child_samples': 58, 'subsample': 0.8959372100866141, 'colsample_bytree': 0.7534810794884186, 'reg_alpha': 0.03134353418313146, 'reg_lambda': 0.1841833701794952}.
# [I 2026-04-26 15:43:30,472] Trial 123 finished with values: [0.4645383070466866, 0.11018409741681212] and parameters: {'learning_rate': 0.07625353395428827, 'num_leaves': 70, 'max_depth': 7, 'min_child_samples': 47, 'subsample': 0.9139137785544197, 'colsample_bytree': 0.9914478309592798, 'reg_alpha': 0.005040449252511962, 'reg_lambda': 0.0025444395751282683}.
# [I 2026-04-26 15:43:31,150] Trial 93 finished with values: [0.46540690872392537, 0.09033436709110801] and parameters: {'learning_rate': 0.00735232295425996, 'num_leaves': 36, 'max_depth': 7, 'min_child_samples': 43, 'subsample': 0.8909179805564861, 'colsample_bytree': 0.8452449579605638, 'reg_alpha': 0.34954093252883417, 'reg_lambda': 0.8154042783299642}.
# [I 2026-04-26 15:43:37,416] Trial 124 finished with values: [0.4660900155892728, 0.10879635659997658] and parameters: {'learning_rate': 0.0977449183568587, 'num_leaves': 62, 'max_depth': 9, 'min_child_samples': 71, 'subsample': 0.9001595893788702, 'colsample_bytree': 0.935113200418558, 'reg_alpha': 0.1317958967814274, 'reg_lambda': 0.011100300287082613}.
# [I 2026-04-26 15:43:42,900] Trial 114 finished with values: [0.4614244564726279, 0.09792124273765482] and parameters: {'learning_rate': 0.019921182465872937, 'num_leaves': 63, 'max_depth': 7, 'min_child_samples': 51, 'subsample': 0.8693641293566763, 'colsample_bytree': 0.8613921950525047, 'reg_alpha': 0.17285283797334347, 'reg_lambda': 0.00553725842055644}.
# [I 2026-04-26 15:43:48,226] Trial 105 finished with values: [0.48443733870558425, 0.058232086449859166] and parameters: {'learning_rate': 0.009625476252831191, 'num_leaves': 64, 'max_depth': 4, 'min_child_samples': 95, 'subsample': 0.9028257549821778, 'colsample_bytree': 0.9149574502078459, 'reg_alpha': 0.13576387101499546, 'reg_lambda': 0.0013369926404275684}.
# [I 2026-04-26 15:43:48,587] Trial 84 finished with values: [0.46600543637868347, 0.08216956305928462] and parameters: {'learning_rate': 0.005533096570372279, 'num_leaves': 39, 'max_depth': 10, 'min_child_samples': 98, 'subsample': 0.9387492778623528, 'colsample_bytree': 0.8885607344235547, 'reg_alpha': 0.002747156820145972, 'reg_lambda': 0.012346375924660228}.
# [I 2026-04-26 15:44:58,346] Trial 139 finished with values: [0.47774616976016754, 0.07695179309204721] and parameters: {'learning_rate': 0.04713468961996775, 'num_leaves': 92, 'max_depth': 4, 'min_child_samples': 59, 'subsample': 0.8703158592535991, 'colsample_bytree': 0.7105239338826033, 'reg_alpha': 0.0018181593161572338, 'reg_lambda': 0.04578608360622748}.
# [I 2026-04-26 15:45:27,970] Trial 127 finished with values: [0.46308998518725064, 0.10866878682706947] and parameters: {'learning_rate': 0.013490906006143949, 'num_leaves': 52, 'max_depth': 9, 'min_child_samples': 43, 'subsample': 0.9327300119973874, 'colsample_bytree': 0.8943778517204974, 'reg_alpha': 1.283851590832037, 'reg_lambda': 4.151815563035419}.
# [I 2026-04-26 15:45:48,350] Trial 116 finished with values: [0.45861436503955383, 0.10324919843742182] and parameters: {'learning_rate': 0.007635933721732676, 'num_leaves': 119, 'max_depth': 8, 'min_child_samples': 60, 'subsample': 0.705700326957944, 'colsample_bytree': 0.8543303957554301, 'reg_alpha': 0.0017940549600097646, 'reg_lambda': 1.016847077033404}.
# [I 2026-04-26 15:45:56,599] Trial 131 finished with values: [0.4777121750592585, 0.08108277457517815] and parameters: {'learning_rate': 0.02259808755723003, 'num_leaves': 106, 'max_depth': 4, 'min_child_samples': 66, 'subsample': 0.9203602692101718, 'colsample_bytree': 0.8276199678690274, 'reg_alpha': 0.0034946901906544934, 'reg_lambda': 0.004342291609597698}.
# [I 2026-04-26 15:45:58,701] Trial 142 finished with values: [0.46267077591191763, 0.10239163325641099] and parameters: {'learning_rate': 0.02475552058392738, 'num_leaves': 104, 'max_depth': 6, 'min_child_samples': 28, 'subsample': 0.8735640793989746, 'colsample_bytree': 0.9050046183437794, 'reg_alpha': 0.16621114706755047, 'reg_lambda': 0.0010724385507662841}.
# [I 2026-04-26 15:46:04,693] Trial 133 finished with values: [0.48002885613543517, 0.07700288238411429] and parameters: {'learning_rate': 0.020709200217012048, 'num_leaves': 77, 'max_depth': 4, 'min_child_samples': 51, 'subsample': 0.8025874869286845, 'colsample_bytree': 0.8927421097601613, 'reg_alpha': 1.8059047771377212, 'reg_lambda': 0.011365604409016348}.
# [I 2026-04-26 15:46:11,607] Trial 136 finished with values: [0.48006036893467724, 0.08008202058049343] and parameters: {'learning_rate': 0.019818779124059008, 'num_leaves': 89, 'max_depth': 4, 'min_child_samples': 28, 'subsample': 0.7696120674260698, 'colsample_bytree': 0.7977250112250963, 'reg_alpha': 0.029414385831780628, 'reg_lambda': 0.008323560844045966}.
# ...
# [I 2026-04-26 16:10:25,029] Trial 256 finished with values: [0.46031576610863373, 0.07893692572669148] and parameters: {'learning_rate': 0.010609592388268405, 'num_leaves': 103, 'max_depth': 6, 'min_child_samples': 94, 'subsample': 0.760328227198981, 'colsample_bytree': 0.7082513544351347, 'reg_alpha': 0.0052930001004366945, 'reg_lambda': 0.0014930191512006568}.
 'max_depth': 4, 'min_child_samples': 95, 'subsample': 0.9507524368427464, 'colsample_bytree': 0.728424781064122, 'reg_alpha': 0.007979978288777036, 'reg_lambda': 0.017198901334099542}.
# [I 2026-04-26 16:17:21,261] Trial 293 finished with values: [0.48660582138895214, 0.04550689117450131] and parameters: {'learning_rate': 0.0057207123129138565, 'num_leaves': 97, 'max_depth': 4, 'min_child_samples': 95, 'subsample': 0.747642477044738, 'colsample_bytree': 0.7052023202613703, 'reg_alpha': 0.017769276020873755, 'reg_lambda': 0.0010505652198185163}.
# [I 2026-04-26 16:17:21,404] Trial 296 finished with values: [0.4796617302692089, 0.06588682477335073] and parameters: {'learning_rate': 0.012267332303427725, 'num_leaves': 121, 'max_depth': 4, 'min_child_samples': 96, 'subsample': 0.7398690548400935, 'colsample_bytree': 0.7057516943480387, 'reg_alpha': 0.008402905732554812, 'reg_lambda': 1.5764541323522296}.
# [I 2026-04-26 16:17:22,186] Trial 299 finished with values: [0.4566807391478369, 0.10475920987977724] and parameters: {'learning_rate': 0.012754886504821763, 'num_leaves': 96, 'max_depth': 9, 'min_child_samples': 82, 'subsample': 0.950899452133109, 'colsample_bytree': 0.7271756109118358, 'reg_alpha': 0.0025320000121754494, 'reg_lambda': 1.7251281118530257}.
# [I 2026-04-26 16:17:23,726] Trial 295 finished with values: [0.4862495469947584, 0.04566703427313769] and parameters: {'learning_rate': 0.00578228581462281, 'num_leaves': 121, 'max_depth': 4, 'min_child_samples': 96, 'subsample': 0.7416512322348352, 'colsample_bytree': 0.726080456225521, 'reg_alpha': 0.00878971684427067, 'reg_lambda': 0.0022930876956061942}.
# [I 2026-04-26 16:17:30,870] Trial 297 finished with values: [0.48642289995984, 0.04585204165678426] and parameters: {'learning_rate': 0.005810201710164934, 'num_leaves': 121, 'max_depth': 4, 'min_child_samples': 96, 'subsample': 0.9501135910824511, 'colsample_bytree': 0.7273541935974228, 'reg_alpha': 0.00886514985202338, 'reg_lambda': 0.9985290898055785}.

# %% [markdown]
# #### 6.1.2 Sélection du meilleur essai Optuna et entraînement final
#
# Après l'optimisation, Optuna fournit plusieurs essais candidats, car l'étude minimise deux objectifs : la MAE moyenne de validation et le gap train/validation.
#
# Ces essais appartiennent au **front de Pareto**.
# Dans une optimisation multi-objective, le front de Pareto regroupe les solutions pour lesquelles il n'existe pas d'autre essai meilleur sur tous les objectifs à la fois. Autrement dit, un essai peut avoir une MAE plus faible mais un gap plus élevé, tandis qu'un autre peut être plus robuste mais légèrement moins performant.
#
# Dans cette étape, on recharge l'étude Optuna sauvegardée, puis on sélectionne un essai parmi ces meilleurs compromis.
# Le choix privilégie une faible MAE, tout en pénalisant les modèles présentant un gap trop important entre l'entraînement et la validation.
#
# Les hyperparamètres du meilleur essai sont ensuite récupérés.
# Le nombre d'arbres `n_estimators` est remplacé par la meilleure itération déterminée grâce à l'early stopping pendant la validation croisée temporelle.
#
# Enfin, le modèle LightGBM sélectionné est réentraîné sur l'ensemble `train`, puis évalué sur les ensembles `train` et `valid` afin de comparer ses performances avec les modèles précédents.

# %%
# =================================================================
# Chargement de l'étude Optuna et entraînement du meilleur LightGBM
# =================================================================

# Copie des données utilisées pour LightGBM
X_train_lgbm = X_train.copy()
X_valid_lgbm = X_valid.copy()

# Chargement de l'étude Optuna déjà optimisée
study_lgbm = optuna.load_study(
    study_name="study_lgbm_new",
    storage=f"sqlite:///{filepath_output}study_lgbm_new.db"
)

# =========================================================
# Sélection du meilleur essai parmi les meilleurs compromis
# =========================================================

# Dans une optimisation multi-objective, Optuna retourne plusieurs meilleurs essais
# correspondant au front de Pareto.
lgbm_trials = study_lgbm.best_trials

# Choix d'un compromis :
# - priorité à une faible MAE ;
# - pénalité si le gap relatif dépasse 4 %.
best_trial_lgbm = min(
    lgbm_trials,
    key=lambda t: t.values[0] + 50 * max(0, (t.values[1] / t.values[0]) - 0.04)
)

print("Selected trial:")
print(f"Meilleur MAE = {best_trial_lgbm.values[0]}")
print(f"Meilleur GAP = {best_trial_lgbm.values[1]}")


# ==========================================
# Récupération des meilleurs hyperparamètres
# ==========================================

# On copie les paramètres pour éviter de modifier directement l'objet trial
best_params_lgbm = best_trial_lgbm.params.copy()

# On remplace n_estimators par la meilleure itération médiane obtenue avec early stopping
best_params_lgbm["n_estimators"] = best_trial_lgbm.user_attrs["best_iteration"]

print("Best_params_lgbm:", best_params_lgbm)


# ========================================
# Entraînement du meilleur modèle LightGBM
# ========================================

best_model_lgbm = LGBMRegressor(
    verbosity=-1,
    random_state=42,
    n_jobs=-1,
    **best_params_lgbm
)

# Entraînement final sur l'ensemble train
best_model_lgbm.fit(X_train_lgbm, y_train)


# ==================================
# Évaluation sur train et validation
# ==================================

# Prédictions
y_pred_train_lgbm = best_model_lgbm.predict(X_train_lgbm)
y_pred_valid_lgbm = best_model_lgbm.predict(X_valid_lgbm)

# Métriques train
mae_train_lgbm = mean_absolute_error(y_train, y_pred_train_lgbm)
rmse_train_lgbm = np.sqrt(mean_squared_error(y_train, y_pred_train_lgbm))
r2_train_lgbm = r2_score(y_train, y_pred_train_lgbm)
nmae_train_lgbm = calculer_nmae(y_train, y_pred_train_lgbm)

# Métriques validation
mae_valid_lgbm = mean_absolute_error(y_valid, y_pred_valid_lgbm)
rmse_valid_lgbm = np.sqrt(mean_squared_error(y_valid, y_pred_valid_lgbm))
r2_valid_lgbm = r2_score(y_valid, y_pred_valid_lgbm)
nmae_valid_lgbm = calculer_nmae(y_valid, y_pred_valid_lgbm)

# Pourcentage d'overfitting sur l'évaluation finale train/validation
overfit_pct_lgbm = (
    100 * max(0, mae_valid_lgbm - mae_train_lgbm) / mae_valid_lgbm
    if mae_valid_lgbm != 0 else np.nan
)


# =======================
# Affichage des résultats
# =======================

print("\n--- Résultats LGBMRegressor ---")

print(f"MAE valid_lgbm      : {mae_valid_lgbm}")
print(f"MAE train_lgbm      : {mae_train_lgbm}")

print(f"NMAE valid_lgbm     : {nmae_valid_lgbm:.3f} %")
print(f"NMAE train_lgbm     : {nmae_train_lgbm:.3f} %")

print(f"RMSE valid_lgbm     : {rmse_valid_lgbm}")
print(f"RMSE train_lgbm     : {rmse_train_lgbm}")

print(f"R² valid_lgbm       : {r2_valid_lgbm}")
print(f"R² train_lgbm       : {r2_train_lgbm}")

print(f"Overfitting CV      : {best_trial_lgbm.user_attrs['overfit_gap_pct']:.2f} %")
print(f"Overfitting final   : {overfit_pct_lgbm:.2f} %")

# MAE moyenne obtenue pendant la validation croisée temporelle
MAE_CV_moyenne_lgbm = best_trial_lgbm.user_attrs["mean_mae_valid"]

print("MAE_CV_moyenne_lgbm:", MAE_CV_moyenne_lgbm)


# =====================================
# Ajout au tableau global des résultats
# =====================================

# Ajout des métriques du meilleur LightGBM
resultats.append(
    calculer_metriques(
        y_train,
        y_pred_train_lgbm,
        y_valid,
        y_pred_valid_lgbm,
        nom_modele="LGBMRegressor",
        MAE_CV_moyenne=MAE_CV_moyenne_lgbm
    )
)

# Affichage du tableau comparatif
resultats_df = pd.DataFrame(resultats).sort_values("MAE_valid")
display(resultats_df)
# Out:
# Selected trial:
# Meilleur MAE = 0.48827067194278095
# Meilleur GAP = 0.042476462395805784
# Best_params_lgbm: {'learning_rate': 0.00500506602458601, 'num_leaves': 122, 'max_depth': 4, 'min_child_samples': 96, 'subsample': 0.7536176371507638, 'colsample_bytree': 0.7059471341507862, 'reg_alpha': 0.009870716017689346, 'reg_lambda': 0.0019045973808220768, 'n_estimators': 1999}
#
# --- Résultats LGBMRegressor ---
# MAE valid_lgbm      : 0.5197435446750469
# MAE train_lgbm      : 0.4531539364015658
# NMAE valid_lgbm     : 21.591 %
# NMAE train_lgbm     : 18.562 %
# RMSE valid_lgbm     : 1.1353956623500627
# RMSE train_lgbm     : 0.936690921303588
# R² valid_lgbm       : 0.8803698738023867
# R² train_lgbm       : 0.919903744188931
# Overfitting CV      : 8.70 %
# Overfitting final   : 12.81 %
# MAE_CV_moyenne_lgbm: 0.48827067194278095
#                             Modèle  MAE_train  NMAE_train (%)  RMSE_train  \
# 5                    LGBMRegressor       0.45           18.56        0.94
# 4                            Lasso       0.72           29.44        1.21
# 3                            Ridge       0.72           29.42        1.20
# 2  Régression linéaire multivariée       0.72           29.62        1.18
# 0                             Naïf       0.95           38.84        1.66
# 1       Régression linéaire simple       1.05           43.05        1.88
#
#    R2_train  MAE_valid  NMAE_valid (%)  RMSE_valid  R2_valid  MAE_CV_moyenne  \
# 5      0.92       0.52           21.59        1.14      0.88            0.49
# 4      0.87       0.76           31.41        1.34      0.83            0.73
# 3      0.87       0.76           31.53        1.34      0.83            0.73
# 2      0.87       0.76           31.75        1.33      0.84             NaN
# 0      0.75       0.98           40.69        1.78      0.71             NaN
# 1      0.68       1.11           45.96        2.00      0.63             NaN
#
#    Gap_MAE_valid_train  Gap_R2_train_valid
# 5                 0.07                0.04
# 4                 0.04                0.03
# 3                 0.04                0.04
# 2                 0.04                0.04
# 0                 0.03                0.04
# 1                 0.06                0.05

# %%
# ============================================================
# Sauvegarde et rechargement du meilleur modèle LightGBM
# ============================================================

# Chemin du dossier où sauvegarder les meilleurs modèles
best_models_path = filepath_output + "Best_Models/"

# Chemin complet du fichier de sauvegarde
model_path_lgbm = best_models_path + "best_model_lgbm.joblib"

# Sauvegarde du meilleur modèle LightGBM entraîné
joblib.dump(best_model_lgbm, model_path_lgbm)

# Rechargement du modèle sauvegardé
best_model_lgbm = joblib.load(model_path_lgbm)

# %% [markdown]
# #### 6.1.3 Visualisation des prédictions LightGBM
#
# Après l'entraînement et l'évaluation numérique du modèle LightGBM, on visualise maintenant la qualité des prédictions sur l'ensemble de validation.
#
# Le graphique suivant compare les valeurs réelles de la cible aux valeurs prédites par le modèle.
# La ligne diagonale représente une prédiction parfaite : plus les points sont proches de cette ligne, plus les prédictions sont précises.
#
# Cette visualisation permet de vérifier rapidement si le modèle suit correctement la tendance générale des données, et si certaines zones présentent des erreurs plus importantes.

# %%
# ============================================================
# Visualisation : valeurs réelles vs valeurs prédites LightGBM
# ============================================================

# Cette cellule compare les valeurs réelles de la cible avec les prédictions
# du modèle LightGBM sur l'ensemble de validation.

plt.figure(figsize=(6, 6))

# Nuage de points :
# chaque point représente une observation de validation
# axe x : valeur réelle
# axe y : valeur prédite
plt.scatter(y_valid, y_pred_valid_lgbm, alpha=0.5)

# Ligne idéale y = x
# Si les prédictions étaient parfaites, tous les points seraient sur cette ligne
min_val = min(y_valid.min(), y_pred_valid_lgbm.min())
max_val = max(y_valid.max(), y_pred_valid_lgbm.max())

plt.plot(
    [min_val, max_val],
    [min_val, max_val],
    "r--",
    label="Prédiction parfaite"
)

# Titres et labels
plt.xlabel("Valeurs réelles")
plt.ylabel("Valeurs prédites")
plt.title("LightGBM - Valeurs réelles vs valeurs prédites sur validation")

# Affichage de la légende
plt.legend()

# Affichage du graphique
plt.show()

# %% [markdown]
# Après l'optimisation et l'évaluation de LightGBM, on applique maintenant la même démarche à d'autres modèles identifiés comme prometteurs lors de l'étape exploratoire avec LazyPredict.
#
# Pour les modèles suivants, on conserve la même stratégie d'optimisation : Optuna est utilisé avec les folds temporels définis manuellement, et les modèles sont comparés principalement à partir de la MAE moyenne de validation croisée temporelle et du gap train/validation.
#
# L'objectif est de comparer plusieurs modèles avancés dans des conditions similaires : mêmes ensembles de données, mêmes folds temporels, même métrique principale et même attention portée au surapprentissage.
#
# On commence par **XGBoost**, afin de le comparer directement à LightGBM.
#
# ### 6.2 XGBoost
#
# XGBoost est un algorithme de gradient boosting très utilisé pour les données tabulaires.
#
# Comme LightGBM, il construit progressivement plusieurs arbres de décision, où chaque nouvel arbre cherche à corriger les erreurs des arbres précédents.
# Il permet de modéliser des relations non linéaires ainsi que des interactions complexes entre les variables explicatives.
#
# Dans cette section, XGBoost est optimisé avec la même méthodologie que LightGBM, puis évalué sur l'ensemble de validation.
#
# L'objectif est de vérifier s'il apporte un gain de performance par rapport à LightGBM et aux modèles de référence déjà testés.

# %% [markdown]
# Les principaux hyperparamètres optimisés pour XGBoost sont résumés ci-dessous.
#
# | Paramètre | Explication |
# |---|---|
# | `n_estimators` | Nombre maximal d'arbres de boosting construits successivement. Une grande valeur peut améliorer les performances, mais augmente le temps de calcul et le risque de surapprentissage. Avec l'early stopping, le nombre effectif d'arbres peut être plus faible. |
# | `learning_rate` | Taux d'apprentissage appliqué à la contribution de chaque arbre. Une petite valeur rend l'apprentissage plus progressif, mais nécessite souvent plus d'arbres. |
# | `max_depth` | Profondeur maximale de chaque arbre. Des arbres plus profonds peuvent capturer des relations plus complexes, mais peuvent aussi surajuster les données. |
# | `min_child_weight` | Poids minimal requis dans un nœud feuille pour autoriser une nouvelle division. Une valeur élevée rend le modèle plus conservateur. |
# | `subsample` | Fraction des observations utilisée pour construire chaque arbre. Une valeur inférieure à 1 introduit de l'aléatoire et peut aider à réduire le surapprentissage. |
# | `colsample_bytree` | Fraction des variables utilisée pour construire chaque arbre. Cela permet de diversifier les arbres et de limiter le surapprentissage. |
# | `gamma` | Gain minimal requis pour effectuer une nouvelle division dans un arbre. Plus `gamma` est grand, plus le modèle devient prudent dans la création de nouvelles divisions. |
# | `reg_alpha` | Régularisation L1 appliquée aux poids du modèle. Elle peut rendre le modèle plus parcimonieux. |
# | `reg_lambda` | Régularisation L2 appliquée aux poids du modèle. Elle pénalise les poids trop grands et aide à stabiliser le modèle. |
# | `tree_method` | Méthode de construction des arbres. Ici, `hist` utilise une méthode basée sur des histogrammes, généralement plus rapide sur des jeux de données tabulaires. |
# | `max_bin` | Nombre maximal d'intervalles utilisés pour discrétiser les variables continues avec `tree_method="hist"`. Une valeur plus grande peut améliorer la précision, mais augmente le temps de calcul. |
#
# Comme pour LightGBM, l'optimisation est réalisée avec **Optuna**.
# À chaque essai, Optuna propose une combinaison d'hyperparamètres, qui est évaluée sur les folds temporels définis manuellement.
#
# L'objectif est de minimiser principalement la MAE moyenne de validation, tout en surveillant le gap train/validation afin de limiter le surapprentissage.
#
# Quelques règles pratiques permettent d'interpréter les effets des hyperparamètres :
#
# - si le modèle surapprend : augmenter `gamma`, `min_child_weight` ou `reg_lambda`, réduire `max_depth` ou `subsample` ;
# - si le modèle sous-apprend : réduire `gamma` ou `min_child_weight`, augmenter `max_depth` ou réduire la régularisation ;
# - si l'apprentissage est instable : réduire `learning_rate` et augmenter `n_estimators`.

# %% [markdown]
# #### 6.2.1 Optimisation des hyperparamètres XGBoost avec Optuna
#
# L'optimisation de XGBoost suit la même logique que celle appliquée à LightGBM.
#
# Les hyperparamètres sont optimisés avec **Optuna**, en utilisant les folds temporels définis manuellement.
# Pour chaque essai, Optuna propose une combinaison d'hyperparamètres, puis le modèle est entraîné sur une période passée et validé sur une période future.
#
# L'évaluation repose principalement sur :
#
# - la **MAE moyenne de validation croisée temporelle**, utilisée comme métrique principale ;
# - le **gap train/validation**, utilisé comme indicateur de surapprentissage ;
# - l'**early stopping**, qui permet d'arrêter l'entraînement lorsque la performance sur le fold de validation ne s'améliore plus.
#
# L'objectif est de sélectionner une configuration performante et robuste, capable de généraliser correctement sur des périodes futures.

# %%
# ============================================================
# XGBoost : optimisation avec Optuna et folds temporels manuels
# ============================================================

# Copie des ensembles utilisés pour XGBoost
X_train_xgb = X_train.copy()
X_valid_xgb = X_valid.copy()


# ============================================================
# Évaluation d'une combinaison d'hyperparamètres XGBoost
# ============================================================

def evaluate_params_xgb(params, X, y, trial=None):
    """
    Évalue une combinaison d'hyperparamètres XGBoost
    sur les folds temporels définis manuellement.

    La fonction retourne deux objectifs :
    - la MAE moyenne sur validation ;
    - le gap moyen entre train et validation.
    """

    # Listes pour stocker les métriques de chaque fold
    maes_valid = []; maes_train = []
    rmses_valid = []; rmses_train = []
    r2_trains = []; r2_valids = []
    gaps = []; best_iterations = []

    folds = get_folds(X, y)

    for step, (X_tr, X_v, y_tr, y_v) in enumerate(folds):

        model = XGBRegressor(
            **params,
            eval_metric="mae",
            early_stopping_rounds = 50
        )
        
        model.fit(
            X_tr,
            y_tr,
            eval_set=[(X_v, y_v)],
            verbose=False
        )
        
        best_iter = model.best_iteration + 1
        best_iterations.append(best_iter)

        pred_train = model.predict(X_tr, iteration_range=(0, best_iter))
        pred_valid = model.predict(X_v, iteration_range=(0, best_iter))

        # métriques
        mae_train = mean_absolute_error(y_tr, pred_train)
        mae_valid = mean_absolute_error(y_v, pred_valid)

        rmse_train = np.sqrt(mean_squared_error(y_tr, pred_train))
        rmse_valid = np.sqrt(mean_squared_error(y_v, pred_valid))

        r2_train = r2_score(y_tr, pred_train)
        r2_valid = r2_score(y_v, pred_valid)

        gap = max(0, mae_valid - mae_train)

        maes_valid.append(mae_valid)
        maes_train.append(mae_train)
        rmses_valid.append(rmse_valid)
        rmses_train.append(rmse_train)
        r2_trains.append(r2_train)
        r2_valids.append(r2_valid)
        gaps.append(gap)

    median_best_iteration = int(np.median(best_iterations))

    mean_mae_valid = np.mean(maes_valid)
    mean_mae_train = np.mean(maes_train)
    std_mae_valid = np.std(maes_valid)
    std_mae_train = np.std(maes_train)

    mean_r2_train = np.mean(r2_trains)
    mean_r2_valid = np.mean(r2_valids)

    mean_rmse_valid = np.mean(rmses_valid)
    mean_rmse_train = np.mean(rmses_train)

    mean_gap = np.mean(gaps)
    gap_pct = 100 * max(0, mean_mae_valid - mean_mae_train) / mean_mae_valid

    
    if trial is not None:
        trial.set_user_attr("best_iteration", median_best_iteration)

        trial.set_user_attr("mean_mae_valid", mean_mae_valid)
        trial.set_user_attr("mean_mae_train", mean_mae_train)

        trial.set_user_attr("std_mae_valid", std_mae_valid)
        trial.set_user_attr("std_mae_train", std_mae_train)

        trial.set_user_attr("mean_rmse_valid", mean_rmse_valid)
        trial.set_user_attr("mean_rmse_train", mean_rmse_train)

        trial.set_user_attr("mean_r2_valid", mean_r2_valid)
        trial.set_user_attr("mean_r2_train", mean_r2_train)

        trial.set_user_attr("mean_gap", mean_gap)
        trial.set_user_attr("std_gap", np.std(gaps))
        trial.set_user_attr("max_gap", np.max(gaps))
        trial.set_user_attr("overfit_gap_pct", gap_pct)

    return mean_mae_valid, mean_gap

def objective_xgb(trial):

    max_depth = trial.suggest_int("max_depth", 3, 7)

    # Interaction entre max_depth et min_child_weight :
    # si les arbres sont profonds, on impose un min_child_weight plus élevé
    # pour limiter le surapprentissage.
    if max_depth >= 7:
        min_child_weight = trial.suggest_int("min_child_weight", 10, 30)
    else:
        min_child_weight = trial.suggest_int("min_child_weight", 1, 30)

    params = {
        "n_estimators": 2000,
        "learning_rate": trial.suggest_float("learning_rate", 0.005, 0.1, log=True),

        "max_depth": max_depth,
        "min_child_weight": min_child_weight,

        "subsample": trial.suggest_float("subsample", 0.6, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.6, 1.0),

        "reg_alpha": trial.suggest_float("reg_alpha", 1e-4, 20.0, log=True),
        "reg_lambda": trial.suggest_float("reg_lambda", 1e-4, 20.0, log=True),

        "gamma": trial.suggest_float("gamma", 1e-8, 1.0, log=True),

        "random_state": 42,
        "n_jobs": 1,
        "verbosity": 0
    }

    return evaluate_params_xgb(
        params,
        X_dev,
        y_dev,
        trial=trial
    )

# ====================================================
# Création et lancement de l'étude Optuna pour XGBoost
# ====================================================

study_xgb = optuna.create_study(
    study_name="study_xgb",
    storage=f"sqlite:///{filepath_output}study_xgb.db",
    load_if_exists=True,
    directions=["minimize", "minimize"],
    sampler=optuna.samplers.TPESampler(
        n_startup_trials=100,
        seed=42
    )
)

# Lancement de l'optimisation
study_xgb.optimize(
    objective_xgb,
    n_trials=200,
    n_jobs=-1
)
# Out:
# [I 2026-04-26 13:41:30,699] A new study created in RDB with name: study_xgb
# [I 2026-04-26 13:42:11,795] Trial 15 finished with values: [0.45784811346480453, 0.12162906002405369] and parameters: {'max_depth': 7, 'min_child_weight': 23, 'learning_rate': 0.054465788425935524, 'subsample': 0.6451305440930974, 'colsample_bytree': 0.612356771725593, 'reg_alpha': 0.00048474344575777107, 'reg_lambda': 0.00011775829568446288, 'gamma': 5.207728910035324e-07}.
# [I 2026-04-26 13:42:29,293] Trial 1 finished with values: [0.4596128206406733, 0.17352710479361297] and parameters: {'max_depth': 7, 'min_child_weight': 16, 'learning_rate': 0.06028794412850894, 'subsample': 0.6725258852867247, 'colsample_bytree': 0.9305135285048662, 'reg_alpha': 4.905029809375589, 'reg_lambda': 0.03558372027566485, 'gamma': 7.360161791584381e-07}.
# [I 2026-04-26 13:42:41,991] Trial 4 finished with values: [0.455948310815532, 0.15344195035121522] and parameters: {'max_depth': 7, 'min_child_weight': 24, 'learning_rate': 0.03738466008888073, 'subsample': 0.8978654180886427, 'colsample_bytree': 0.8768423074894559, 'reg_alpha': 0.0008335282315865379, 'reg_lambda': 0.03174608970290354, 'gamma': 9.242406016912928e-05}.
# [I 2026-04-26 13:42:44,515] Trial 3 finished with values: [0.4968338945086877, 0.08861618685102608] and parameters: {'max_depth': 3, 'min_child_weight': 3, 'learning_rate': 0.07537158362709138, 'subsample': 0.6228501162147647, 'colsample_bytree': 0.8794148927119625, 'reg_alpha': 0.12752752060396855, 'reg_lambda': 0.001955416440894189, 'gamma': 0.0024336247916755963}.
# [I 2026-04-26 13:42:51,935] Trial 6 finished with values: [0.46671168035574295, 0.11178961353676052] and parameters: {'max_depth': 5, 'min_child_weight': 3, 'learning_rate': 0.03133752539974678, 'subsample': 0.8199846677763759, 'colsample_bytree': 0.8242669367516833, 'reg_alpha': 0.14909001040802058, 'reg_lambda': 0.04752140444007236, 'gamma': 0.15816165299110202}.
# [I 2026-04-26 13:43:17,811] Trial 14 finished with values: [0.4949487672524116, 0.07157617063994244] and parameters: {'max_depth': 3, 'min_child_weight': 19, 'learning_rate': 0.040117596353494614, 'subsample': 0.6330654235881538, 'colsample_bytree': 0.9940887194283157, 'reg_alpha': 0.4295560637737028, 'reg_lambda': 0.07200003330081713, 'gamma': 0.04418216029910428}.
# [I 2026-04-26 14:09:54,835] Trial 156 finished with values: [0.4682633555655854, 0.06116661346334927] and parameters: {'max_depth': 5, 'min_child_weight': 23, 'learning_rate': 0.005448641229056536, 'subsample': 0.6426462270480506, 'colsample_bytree': 0.6171356622227011, 'reg_alpha': 0.00030166567820825914, 'reg_lambda': 10.159233693068089, 'gamma': 0.0029908773499331357}.
# [I 2026-04-26 14:10:26,448] Trial 161 finished with values: [0.5073200898580841, 0.034284443993284605] and parameters: {'max_depth': 3, 'min_child_weight': 22, 'learning_rate': 0.006736828878294248, 'subsample': 0.6990117907823032, 'colsample_bytree': 0.6112872056502602, 'reg_alpha': 0.00020694005318169111, 'reg_lambda': 9.820746993948124, 'gamma': 0.002167686417226318}.
# [I 2026-04-26 14:10:38,393] Trial 162 finished with values: [0.5081787037918883, 0.034720997338645476] and parameters: {'max_depth': 3, 'min_child_weight': 22, 'learning_rate': 0.0067100065089705585, 'subsample': 0.7495277247778963, 'colsample_bytree': 0.6511975919363279, 'reg_alpha': 0.0002663302842501956, 'reg_lambda': 9.285326104499989, 'gamma': 0.002667922575226977}.
# [I 2026-04-26 14:10:48,431] Trial 164 finished with values: [0.5069086931059356, 0.03425600101813417] and parameters: {'max_depth': 3, 'min_child_weight': 26, 'learning_rate': 0.00687045249138587, 'subsample': 0.6969873320822191, 'colsample_bytree': 0.648165890986341, 'reg_alpha': 0.0002863753757948664, 'reg_lambda': 9.219150031830168, 'gamma': 0.0023123645833199938}.
# [I 2026-04-26 14:10:49,044] Trial 163 finished with values: [0.5055922719016398, 0.03704695035363571] and parameters: {'max_depth': 3, 'min_child_weight': 26, 'learning_rate': 0.007713946978789423, 'subsample': 0.7513616436080948, 'colsample_bytree': 0.6487230703710607, 'reg_alpha': 0.0003084346447715952, 'reg_lambda': 9.92561723395561, 'gamma': 1.1961258144748478e-08}.
# [I 2026-04-26 14:11:16,210] Trial 169 finished with values: [0.5060409116362978, 0.03360262437230639] and parameters: {'max_depth': 3, 'min_child_weight': 22, 'learning_rate': 0.006782839068070456, 'subsample': 0.7508151704982673, 'colsample_bytree': 0.6492236950034567, 'reg_alpha': 13.282224719245747, 'reg_lambda': 9.089188455574302, 'gamma': 5.163015418398936e-08}.
# [I 2026-04-26 14:11:26,931] Trial 170 finished with values: [0.5064687207751863, 0.03307515890894547] and parameters: {'max_depth': 3, 'min_child_weight': 26, 'learning_rate': 0.006565174997109536, 'subsample': 0.7570226643593442, 'colsample_bytree': 0.6428678205415789, 'reg_alpha': 13.095777145278138, 'reg_lambda': 5.9336028693225895, 'gamma': 1.0751211498546807e-08}.
# [I 2026-04-26 14:11:27,643] Trial 171 finished with values: [0.5060042354824125, 0.03461242904697631] and parameters: {'max_depth': 3, 'min_child_weight': 22, 'learning_rate': 0.006868205520466945, 'subsample': 0.754858241687387, 'colsample_bytree': 0.6480467266333344, 'reg_alpha': 11.623991798788396, 'reg_lambda': 5.460186173351176, 'gamma': 0.08536857198337709}.
# [I 2026-04-26 14:11:38,015] Trial 168 finished with values: [0.5063512631630673, 0.033220157223678354] and parameters: {'max_depth': 3, 'min_child_weight': 22, 'learning_rate': 0.006614068061159508, 'subsample': 0.7529128841705678, 'colsample_bytree': 0.6395520210590904, 'reg_alpha': 11.16219647157772, 'reg_lambda': 9.073113550868623, 'gamma': 1.0597813956936316e-08}.
# [I 2026-04-26 14:11:42,743] Trial 174 finished with values: [0.5065624440570016, 0.03207259772872485] and parameters: {'max_depth': 3, 'min_child_weight': 22, 'learning_rate': 0.006472309102134528, 'subsample': 0.7053542195245103, 'colsample_bytree': 0.6492260728603849, 'reg_alpha': 16.18367738971921, 'reg_lambda': 7.679762291849486, 'gamma': 0.08621139453403734}.
# [I 2026-04-26 14:11:58,070] Trial 172 finished with values: [0.5096184137134985, 0.030028417835836402] and parameters: {'max_depth': 3, 'min_child_weight': 22, 'learning_rate': 0.005552483756443358, 'subsample': 0.7544012255508947, 'colsample_bytree': 0.6492915322582585, 'reg_alpha': 12.598274675349593, 'reg_lambda': 8.03858823328583, 'gamma': 6.38821327674149e-08}.
# [I 2026-04-26 14:12:07,525] Trial 175 finished with values: [0.5054118721932549, 0.03373566496271288] and parameters: {'max_depth': 3, 'min_child_weight': 22, 'learning_rate': 0.006863523093686252, 'subsample': 0.679810748597936, 'colsample_bytree': 0.6380140535838392, 'reg_alpha': 13.260880756983683, 'reg_lambda': 7.051330905416546, 'gamma': 0.009834875972232234}.
# [I 2026-04-26 14:12:08,579] Trial 165 finished with values: [0.46415874067252827, 0.07745051192235365] and parameters: {'max_depth': 5, 'min_child_weight': 22, 'learning_rate': 0.00750786170034743, 'subsample': 0.6380290733157701, 'colsample_bytree': 0.6495371974676611, 'reg_alpha': 6.959897281081548, 'reg_lambda': 9.028814851553294, 'gamma': 0.08134041862013713}.
# [I 2026-04-26 14:12:09,049] Trial 173 finished with values: [0.5076485132398684, 0.035028956930609256] and parameters: {'max_depth': 3, 'min_child_weight': 22, 'learning_rate': 0.006812798262766063, 'subsample': 0.6820315191789278, 'colsample_bytree': 0.648950343957582, 'reg_alpha': 1.170712140025392, 'reg_lambda': 4.987702043304451, 'gamma': 0.008952731784766953}.
# [I 2026-04-26 14:12:27,212] Trial 166 finished with values: [0.46391965526225754, 0.07375434016936219] and parameters: {'max_depth': 5, 'min_child_weight': 22, 'learning_rate': 0.006782926666824774, 'subsample': 0.7505339951160469, 'colsample_bytree': 0.6411248994153308, 'reg_alpha': 12.047301698091166, 'reg_lambda': 8.320126375332572, 'gamma': 0.005291944607356346}.
# [I 2026-04-26 14:12:34,629] Trial 167 finished with values: [0.4635114224592453, 0.07587481965532214] and parameters: {'max_depth': 5, 'min_child_weight': 22, 'learning_rate': 0.007033159415834349, 'subsample': 0.7529383267897533, 'colsample_bytree': 0.6466317625954927, 'reg_alpha': 13.465702783350443, 'reg_lambda': 5.506779806186317, 'gamma': 0.015824253157646923}.
# [I 2026-04-26 14:14:01,724] Trial 176 finished with values: [0.4666976796826385, 0.07184645671562075] and parameters: {'max_depth': 5, 'min_child_weight': 22, 'learning_rate': 0.006751685811765628, 'subsample': 0.6517598411624423, 'colsample_bytree': 0.6456447256328106, 'reg_alpha': 0.02224536401463034, 'reg_lambda': 5.2327173064342904, 'gamma': 0.010402794673291433}.
# [I 2026-04-26 14:17:36,525] Trial 193 finished with values: [0.46878711507709286, 0.06473703699920627] and parameters: {'max_depth': 5, 'min_child_weight': 25, 'learning_rate': 0.005545377760864658, 'subsample': 0.6220802148395527, 'colsample_bytree': 0.7287442998713379, 'reg_alpha': 0.020603110604947728, 'reg_lambda': 6.610101261456859, 'gamma': 0.005249291829899191}.
# [I 2026-04-26 14:17:39,412] Trial 196 finished with values: [0.4673727733124174, 0.06747028344494065] and parameters: {'max_depth': 5, 'min_child_weight': 20, 'learning_rate': 0.005611445253499693, 'subsample': 0.6261566748165244, 'colsample_bytree': 0.6072033644388729, 'reg_alpha': 0.026036675830398637, 'reg_lambda': 0.00021205764153933612, 'gamma': 0.01877952557522848}.
# [I 2026-04-26 14:18:09,633] Trial 195 finished with values: [0.4569645463028825, 0.0909219768818161] and parameters: {'max_depth': 6, 'min_child_weight': 20, 'learning_rate': 0.005544245630142388, 'subsample': 0.6150833982158452, 'colsample_bytree': 0.6064890627542098, 'reg_alpha': 0.0007167783032969531, 'reg_lambda': 0.00023905366964769873, 'gamma': 0.015678908596498994}.
# [I 2026-04-26 14:18:24,810] Trial 197 finished with values: [0.45736988248986565, 0.09079208324628316] and parameters: {'max_depth': 6, 'min_child_weight': 20, 'learning_rate': 0.005516304645686691, 'subsample': 0.6223963184069833, 'colsample_bytree': 0.6095821655793783, 'reg_alpha': 0.0007090939587545231, 'reg_lambda': 0.3106482360665057, 'gamma': 0.016039341053517106}.
# [I 2026-04-26 14:18:26,615] Trial 198 finished with values: [0.45739300644288766, 0.08702830127683732] and parameters: {'max_depth': 6, 'min_child_weight': 25, 'learning_rate': 0.005619350991911099, 'subsample': 0.6161535104783458, 'colsample_bytree': 0.6065166610872237, 'reg_alpha': 0.0007654776345788166, 'reg_lambda': 0.3220287919834021, 'gamma': 0.015346036989446171}.
# [I 2026-04-26 14:18:36,191] Trial 199 finished with values: [0.45725064674116184, 0.09164666154523257] and parameters: {'max_depth': 6, 'min_child_weight': 20, 'learning_rate': 0.005573273666565971, 'subsample': 0.6185975012796695, 'colsample_bytree': 0.6094298696965164, 'reg_alpha': 0.0006867623407371732, 'reg_lambda': 0.25511258454257757, 'gamma': 0.017651632683548135}.
# [I 2026-04-26 14:18:42,751] Trial 194 finished with values: [0.4593058245019872, 0.08576475229380119] and parameters: {'max_depth': 6, 'min_child_weight': 20, 'learning_rate': 0.005481531911121065, 'subsample': 0.6165302300387223, 'colsample_bytree': 0.7357348021587806, 'reg_alpha': 18.730731130535386, 'reg_lambda': 0.0002085866017670811, 'gamma': 0.017223169428774658}.

# %% [markdown]
# #### 6.2.2 Sélection du meilleur essai Optuna et évaluation du modèle XGBoost
#
# Après l'optimisation des hyperparamètres, l'étude Optuna est rechargée afin de récupérer les meilleurs essais obtenus.
#
# Comme l'optimisation est multi-objective, plusieurs essais peuvent appartenir au front de Pareto.
# On sélectionne donc un compromis entre deux critères :
#
# - une faible MAE moyenne en validation croisée temporelle ;
# - un gap train/validation limité, afin de réduire le risque de surapprentissage.
#
# Le meilleur essai est ensuite utilisé pour construire le modèle XGBoost final.
# Le nombre d'arbres `n_estimators` est remplacé par la meilleure itération obtenue avec l'early stopping pendant la validation croisée.
#
# Le modèle sélectionné est ensuite entraîné sur l'ensemble `train`, puis évalué sur les ensembles `train` et `valid`.
# Les métriques obtenues sont finalement ajoutées au tableau global des résultats afin de comparer XGBoost aux autres modèles.

# %%
# ========================================================
# Sélection du meilleur essai Optuna et évaluation XGBoost
# ========================================================

# Copie des ensembles utilisés pour XGBoost
X_train_xgb = X_train.copy()
X_valid_xgb = X_valid.copy()

# Chargement de l'étude Optuna déjà optimisée
study_xgb = optuna.load_study(
    study_name="study_xgb",
    storage=f"sqlite:///{filepath_output}study_xgb.db"
)

# ==============================================
# Sélection du meilleur essai du front de Pareto
# ==============================================

# Optuna retourne plusieurs meilleurs essais car l'étude est multi-objective
xgb_trials = study_xgb.best_trials

# Choix d'un compromis :
# - faible MAE moyenne en validation croisée temporelle
# - pénalité si le gap relatif dépasse 4 %
best_trial_xgb = min(
    xgb_trials,
    key=lambda t: t.values[0] + 50 * max(0, (t.values[1] / t.values[0]) - 0.04)
)

print("Selected trial:")
print(f"MAE = {best_trial_xgb.values[0]}")
print(f"GAP = {best_trial_xgb.values[1]}")


# ==========================================
# Récupération des meilleurs hyperparamètres
# ==========================================

# Copie des paramètres pour éviter de modifier directement l'objet Optuna
best_params_xgb = best_trial_xgb.params.copy()

# Remplacement de n_estimators par la meilleure itération obtenue avec early stopping
best_params_xgb["n_estimators"] = best_trial_xgb.user_attrs["best_iteration"]

print("Best_params_xgb:", best_params_xgb)

# ====================================
# Entraînement du modèle XGBoost final
# ====================================

best_model_xgb = XGBRegressor(
    verbosity=0,
    random_state=42,
    n_jobs=-1,
    **best_params_xgb
)

# Entraînement sur l'ensemble train
best_model_xgb.fit(X_train_xgb, y_train)


# ==================================
# Évaluation sur train et validation
# ==================================

# Prédictions
y_pred_train_xgb = best_model_xgb.predict(X_train_xgb)
y_pred_valid_xgb = best_model_xgb.predict(X_valid_xgb)

# Métriques train
mae_train_xgb = mean_absolute_error(y_train, y_pred_train_xgb)
rmse_train_xgb = np.sqrt(mean_squared_error(y_train, y_pred_train_xgb))
r2_train_xgb = r2_score(y_train, y_pred_train_xgb)
nmae_train_xgb = calculer_nmae(y_train, y_pred_train_xgb)

# Métriques validation
mae_valid_xgb = mean_absolute_error(y_valid, y_pred_valid_xgb)
rmse_valid_xgb = np.sqrt(mean_squared_error(y_valid, y_pred_valid_xgb))
r2_valid_xgb = r2_score(y_valid, y_pred_valid_xgb)
nmae_valid_xgb = calculer_nmae(y_valid, y_pred_valid_xgb)

# Pourcentage d'overfitting final
overfit_pct_xgb = (
    100 * max(0, mae_valid_xgb - mae_train_xgb) / mae_valid_xgb
    if mae_valid_xgb != 0 else np.nan
)


# =======================
# Affichage des résultats
# =======================

print("\n--- Résultats XGBRegressor ---")

print(f"MAE valid_xgb      : {mae_valid_xgb}")
print(f"MAE train_xgb      : {mae_train_xgb}")

print(f"NMAE valid_xgb     : {nmae_valid_xgb:.3f} %")
print(f"NMAE train_xgb     : {nmae_train_xgb:.3f} %")

print(f"RMSE valid_xgb     : {rmse_valid_xgb}")
print(f"RMSE train_xgb     : {rmse_train_xgb}")

print(f"R² valid_xgb       : {r2_valid_xgb}")
print(f"R² train_xgb       : {r2_train_xgb}")

print(f"Overfitting CV     : {best_trial_xgb.user_attrs['overfit_gap_pct']:.2f} %")
print(f"Overfitting final  : {overfit_pct_xgb:.2f} %")

# MAE moyenne obtenue pendant la validation croisée temporelle
MAE_CV_moyenne_xgb = best_trial_xgb.user_attrs["mean_mae_valid"]

print("MAE_CV_moyenne_xgb:", MAE_CV_moyenne_xgb)


# =====================================
# Ajout au tableau global des résultats
# =====================================

# Ajout du modèle XGBoost au tableau global
resultats.append(
    calculer_metriques(
        y_train,
        y_pred_train_xgb,
        y_valid,
        y_pred_valid_xgb,
        nom_modele="XGBRegressor",
        MAE_CV_moyenne=MAE_CV_moyenne_xgb
    )
)

# Tableau comparatif final, trié par performance sur validation
resultats_df = pd.DataFrame(resultats).sort_values("MAE_valid")

display(resultats_df)
# Out:
# Selected trial:
# MAE = 0.5123288530333205
# GAP = 0.028348244696542693
# Best_params_xgb: {'max_depth': 3, 'min_child_weight': 25, 'learning_rate': 0.005021832648534782, 'subsample': 0.7165236031933135, 'colsample_bytree': 0.6314677891528471, 'reg_alpha': 0.0003960709268170266, 'reg_lambda': 19.93861869281122, 'gamma': 0.005385444325599382, 'n_estimators': 1999}
#
# --- Résultats XGBRegressor ---
# MAE valid_xgb      : 0.5456713586144329
# MAE train_xgb      : 0.4885701071559466
# NMAE valid_xgb     : 22.668 %
# NMAE train_xgb     : 20.013 %
# RMSE valid_xgb     : 1.1567690678354134
# RMSE train_xgb     : 0.9849846002958476
# R² valid_xgb       : 0.8758234946644508
# R² train_xgb       : 0.9114316662531257
# Overfitting CV     : 5.53 %
# Overfitting final  : 10.46 %
# MAE_CV_moyenne_xgb: 0.5123288530333205
#                             Modèle  MAE_train  NMAE_train (%)  RMSE_train  \
# 5                    LGBMRegressor       0.45           18.56        0.94
# 6                     XGBRegressor       0.49           20.01        0.98
# 4                            Lasso       0.72           29.44        1.21
# 3                            Ridge       0.72           29.42        1.20
# 2  Régression linéaire multivariée       0.72           29.62        1.18
# 0                             Naïf       0.95           38.84        1.66
# 1       Régression linéaire simple       1.05           43.05        1.88
#
#    R2_train  MAE_valid  NMAE_valid (%)  RMSE_valid  R2_valid  MAE_CV_moyenne  \
# 5      0.92       0.52           21.59        1.14      0.88            0.49
# 6      0.91       0.55           22.67        1.16      0.88            0.51
# 4      0.87       0.76           31.41        1.34      0.83            0.73
# 3      0.87       0.76           31.53        1.34      0.83            0.73
# 2      0.87       0.76           31.75        1.33      0.84             NaN
# 0      0.75       0.98           40.69        1.78      0.71             NaN
# 1      0.68       1.11           45.96        2.00      0.63             NaN
#
#    Gap_MAE_valid_train  Gap_R2_train_valid
# 5                 0.07                0.04
# 6                 0.06                0.04
# 4                 0.04                0.03
# 3                 0.04                0.04
# 2                 0.04                0.04
# 0                 0.03                0.04
# 1                 0.06                0.05

# %%
# =====================================================
# Sauvegarde et rechargement du meilleur modèle XGBoost
# =====================================================

# Chemin complet du fichier de sauvegarde
model_path_xgb = best_models_path + "best_model_xgb.joblib"

# Sauvegarde du meilleur modèle XGBoost entraîné
joblib.dump(best_model_xgb, model_path_xgb)

# Rechargement du modèle sauvegardé
best_model_xgb = joblib.load(model_path_xgb)

# %% [markdown]
# #### 6.2.3 Visualisation des prédictions XGBoost

# %%
# ============================================================
# Visualisation : valeurs réelles vs valeurs prédites XGBoost
# ============================================================

# Cette cellule compare les valeurs réelles de la cible avec les prédictions
# du modèle XGBoost sur l'ensemble de validation.

plt.figure(figsize=(6, 6))

# Nuage de points :
# axe x : valeurs réelles
# axe y : valeurs prédites par XGBoost
plt.scatter(y_valid, y_pred_valid_xgb, alpha=0.5)

# Ligne idéale y = x
# Si les prédictions étaient parfaites, tous les points seraient sur cette ligne
min_val = min(y_valid.min(), y_pred_valid_xgb.min())
max_val = max(y_valid.max(), y_pred_valid_xgb.max())

plt.plot(
    [min_val, max_val],
    [min_val, max_val],
    "r--",
    label="Prédiction parfaite"
)

# Titres et labels
plt.xlabel("Valeurs réelles")
plt.ylabel("Valeurs prédites")
plt.title("XGBoost - Valeurs réelles vs valeurs prédites sur validation")

# Légende
plt.legend()

# Affichage
plt.show()

# %% [markdown]
# ### 6.3 ExtraTreesRegressor
#
# ExtraTreesRegressor est un modèle d'ensemble basé sur plusieurs arbres de décision très aléatorisés.
#
# Contrairement à un arbre unique, il combine les prédictions de nombreux arbres afin d'obtenir une prédiction plus stable et plus robuste.
# L'aléa introduit dans la construction des arbres permet aussi de réduire la variance du modèle et de limiter le risque de surapprentissage.
#
# Ce modèle est intéressant dans ce contexte, car il peut capturer des relations non linéaires et des interactions complexes entre les variables météorologiques, temporelles et régionales.
#
# ExtraTreesRegressor est optimisé avec la même stratégie que les modèles précédents, puis évalué sur l'ensemble de validation.
#
# L'objectif est de vérifier s'il constitue une alternative performante aux modèles de boosting comme LightGBM et XGBoost, ainsi qu'aux modèles de référence déjà testés.

# %%
importance_etr = variables_importantes(ExtraTreesRegressor, X_train, y_train)

importance_etr = importance_etr.sort_values(ascending=False)

cum_importance_etr = importance_etr.cumsum() / importance_etr.sum()

selected_features_etr = cum_importance_etr[cum_importance_etr <= 0.95].index

plt.figure(figsize=(12,8))
plt.plot(cum_importance_etr.index, cum_importance_etr)
plt.axhline(0.95, color='red', linestyle='--')
plt.xticks(rotation=90)
plt.ylabel("Cumulative importance")
plt.xlabel("Features")
plt.title("Cumulative importance - ExtraTreesRegressor")
plt.show()

plt.figure(figsize=(8,12))
plt.barh(selected_features_etr, importance_etr[selected_features_etr] / importance_etr.sum())
plt.gca().invert_yaxis()
plt.title("Feature importance 'ExtraTreesRegressor'")
plt.show()

# %% [markdown]
# #### 6.3.1 Optimisation des hyperparamètres ExtraTreesRegressor avec Optuna
#
# ExtraTreesRegressor est optimisé avec Optuna en utilisant les folds temporels définis manuellement.
#
# Comme pour les modèles précédents, la sélection repose sur la MAE moyenne de validation croisée temporelle et sur le contrôle du gap train/validation.

# %%
# Copie des ensembles utilisés pour ExtraTreesRegressor
X_train_etr = X_train.copy()
X_valid_etr = X_valid.copy()


# =========================================================
# Évaluation d'une combinaison d'hyperparamètres ExtraTrees
# =========================================================

def evaluate_params_etr(params, X, y, trial=None):

    # Listes pour stocker les métriques de chaque fold
    maes_valid = []
    maes_train = []

    rmses_valid = []
    rmses_train = []

    r2_trains = []
    r2_valids = []

    gaps = []

    # Génération des folds temporels manuels
    folds = get_folds(X, y)

    # Boucle sur les folds
    for step, (X_tr, X_v, y_tr, y_v) in enumerate(folds):

        # Création du modèle avec les paramètres proposés par Optuna
        model = ExtraTreesRegressor(**params)

        # Entraînement sur la période passée du fold
        model.fit(X_tr, y_tr)

        # Prédictions sur train et validation du fold
        pred_train = model.predict(X_tr)
        pred_valid = model.predict(X_v)

        # MAE train et validation
        mae_train = mean_absolute_error(y_tr, pred_train)
        mae_valid = mean_absolute_error(y_v, pred_valid)

        # RMSE train et validation
        rmse_train = np.sqrt(mean_squared_error(y_tr, pred_train))
        rmse_valid = np.sqrt(mean_squared_error(y_v, pred_valid))

        # R² train et validation
        r2_train = r2_score(y_tr, pred_train)
        r2_valid = r2_score(y_v, pred_valid)

        # Gap train-validation
        gap = max(0, mae_valid - mae_train)

        # Stockage des métriques
        maes_train.append(mae_train)
        maes_valid.append(mae_valid)

        rmses_train.append(rmse_train)
        rmses_valid.append(rmse_valid)

        r2_trains.append(r2_train)
        r2_valids.append(r2_valid)

        gaps.append(gap)

    # Moyennes des métriques sur tous les folds
    mean_mae_valid = np.mean(maes_valid)
    mean_mae_train = np.mean(maes_train)

    std_mae_valid = np.std(maes_valid)
    std_mae_train = np.std(maes_train)

    mean_rmse_valid = np.mean(rmses_valid)
    mean_rmse_train = np.mean(rmses_train)

    mean_r2_valid = np.mean(r2_valids)
    mean_r2_train = np.mean(r2_trains)

    mean_gap = np.mean(gaps)

    # Pourcentage d'overfitting
    gap_pct = (
        100 * max(0, mean_mae_valid - mean_mae_train) / mean_mae_valid
        if mean_mae_valid != 0 else np.nan
    )

    # Sauvegarde des informations utiles dans Optuna
    if trial is not None:
        trial.set_user_attr("mean_mae_valid", mean_mae_valid)
        trial.set_user_attr("mean_mae_train", mean_mae_train)

        trial.set_user_attr("std_mae_valid", std_mae_valid)
        trial.set_user_attr("std_mae_train", std_mae_train)

        trial.set_user_attr("mean_rmse_valid", mean_rmse_valid)
        trial.set_user_attr("mean_rmse_train", mean_rmse_train)

        trial.set_user_attr("mean_r2_valid", mean_r2_valid)
        trial.set_user_attr("mean_r2_train", mean_r2_train)

        trial.set_user_attr("mean_gap", mean_gap)
        trial.set_user_attr("std_gap", np.std(gaps))
        trial.set_user_attr("max_gap", np.max(gaps))
        trial.set_user_attr("overfit_gap_pct", gap_pct)

    # Optuna minimise ces deux objectifs
    return mean_mae_valid, mean_gap

# ==================================================
# Fonction objective Optuna pour ExtraTreesRegressor
# ==================================================

def objective_etr(trial):
    
    params = {
        # Nombre d'arbres dans la forêt
        "n_estimators": trial.suggest_int("n_estimators", 50, 400),

        # Profondeur maximale des arbres
        "max_depth": trial.suggest_int("max_depth", 5, 40),

        # Nombre minimum d'échantillons nécessaires pour diviser un nœud
        "min_samples_split": trial.suggest_int("min_samples_split", 10, 60),

        # Nombre minimum d'échantillons dans une feuille
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 5, 60),

        # Fraction des variables utilisées à chaque division
        "max_features": trial.suggest_float("max_features", 0.3, 1.0),

        # Utilisation ou non du bootstrap
        "bootstrap": trial.suggest_categorical("bootstrap", [False, True]),

        "random_state": 42,
        "n_jobs": 1
    }

    return evaluate_params_etr(
        params=params,
        X=X_dev,
        y=y_dev,
        trial=trial
    )

# =======================================================
# Création et lancement de l'étude Optuna pour ExtraTrees
# =======================================================

study_etr = optuna.create_study(
    study_name="study_etr",
    storage=f"sqlite:///{filepath_output}study_etr.db",
    load_if_exists=True,
    directions=["minimize", "minimize"],
    sampler=optuna.samplers.TPESampler(
        n_startup_trials=60,
        seed=42
    )
)

# Lancement de l'optimisation
study_etr.optimize(
    objective_etr,
    n_trials=300,
    n_jobs=-1
)
# Out:
# [I 2026-04-27 04:47:00,682] A new study created in RDB with name: study_etr
# [I 2026-04-27 04:47:35,002] Trial 8 finished with values: [0.4790711970532771, 0.04772026561724291] and parameters: {'n_estimators': 84, 'max_depth': 32, 'min_samples_split': 47, 'min_samples_leaf': 20, 'max_features': 0.4670227104185136, 'bootstrap': True}.
# [I 2026-04-27 04:47:41,539] Trial 2 finished with values: [0.46227631369845246, 0.09303345823848962] and parameters: {'n_estimators': 94, 'max_depth': 29, 'min_samples_split': 22, 'min_samples_leaf': 5, 'max_features': 0.4087195523965252, 'bootstrap': True}.
# [I 2026-04-27 04:47:48,668] Trial 14 finished with values: [0.4784261920705877, 0.05145627107154453] and parameters: {'n_estimators': 113, 'max_depth': 40, 'min_samples_split': 56, 'min_samples_leaf': 8, 'max_features': 0.34069153706654975, 'bootstrap': True}.
# [I 2026-04-27 04:48:27,780] Trial 5 finished with values: [0.46184346855039404, 0.0856348481542782] and parameters: {'n_estimators': 132, 'max_depth': 27, 'min_samples_split': 10, 'min_samples_leaf': 9, 'max_features': 0.5175025775723587, 'bootstrap': True}.
# [I 2026-04-27 04:48:29,280] Trial 12 finished with values: [0.47868029867566736, 0.046787923693854885] and parameters: {'n_estimators': 177, 'max_depth': 29, 'min_samples_split': 16, 'min_samples_leaf': 21, 'max_features': 0.4258517209753906, 'bootstrap': True}.
# [I 2026-04-27 04:48:37,619] Trial 0 finished with values: [0.6023942998220391, 0.024361389375152892] and parameters: {'n_estimators': 299, 'max_depth': 6, 'min_samples_split': 42, 'min_samples_leaf': 50, 'max_features': 0.5910760741278053, 'bootstrap': False}.
# [I 2026-04-27 04:48:52,274] Trial 13 finished with values: [0.5153254663060924, 0.03229781217582264] and parameters: {'n_estimators': 295, 'max_depth': 9, 'min_samples_split': 32, 'min_samples_leaf': 31, 'max_features': 0.48633487272590836, 'bootstrap': True}.
# [I 2026-04-27 04:49:10,352] Trial 6 finished with values: [0.5129889069395421, 0.02970566659748522] and parameters: {'n_estimators': 264, 'max_depth': 10, 'min_samples_split': 31, 'min_samples_leaf': 52, 'max_features': 0.5893464263991011, 'bootstrap': True}.
# [I 2026-04-27 04:49:11,121] Trial 10 finished with values: [0.4684423987822629, 0.05889634896572253] and parameters: {'n_estimators': 118, 'max_depth': 17, 'min_samples_split': 36, 'min_samples_leaf': 28, 'max_features': 0.9580486791730987, 'bootstrap': False}.
# [I 2026-04-27 04:49:21,382] Trial 7 finished with values: [0.6507422138151744, 0.021406753524033484] and parameters: {'n_estimators': 340, 'max_depth': 5, 'min_samples_split': 17, 'min_samples_leaf': 27, 'max_features': 0.9750585092522361, 'bootstrap': True}.
# [I 2026-04-27 04:49:32,331] Trial 1 finished with values: [0.5164042035015834, 0.03057088512224375] and parameters: {'n_estimators': 400, 'max_depth': 26, 'min_samples_split': 26, 'min_samples_leaf': 54, 'max_features': 0.3593558274239542, 'bootstrap': True}.
# [I 2026-04-27 04:49:40,517] Trial 9 finished with values: [0.4992530677626431, 0.030567361705038057] and parameters: {'n_estimators': 233, 'max_depth': 37, 'min_samples_split': 42, 'min_samples_leaf': 55, 'max_features': 0.9157155039601601, 'bootstrap': True}.
# [I 2026-04-27 04:49:49,186] Trial 11 finished with values: [0.4908630570834978, 0.037310768829948326] and parameters: {'n_estimators': 283, 'max_depth': 38, 'min_samples_split': 40, 'min_samples_leaf': 54, 'max_features': 0.5298739488997697, 'bootstrap': False}.
# [I 2026-04-27 04:50:01,470] Trial 4 finished with values: [0.4702170026142186, 0.05969321487467913] and parameters: {'n_estimators': 323, 'max_depth': 39, 'min_samples_split': 44, 'min_samples_leaf': 9, 'max_features': 0.4716458464098774, 'bootstrap': True}.
# [I 2026-04-27 04:50:06,121] Trial 20 finished with values: [0.457026826317519, 0.10379944672639205] and parameters: {'n_estimators': 89, 'max_depth': 38, 'min_samples_split': 19, 'min_samples_leaf': 12, 'max_features': 0.6942693088308363, 'bootstrap': False}.
# [I 2026-04-27 04:50:08,292] Trial 18 finished with values: [0.4660035149381492, 0.06651732087513355] and parameters: {'n_estimators': 171, 'max_depth': 14, 'min_samples_split': 14, 'min_samples_leaf': 13, 'max_features': 0.8101528672648803, 'bootstrap': True}.
# [I 2026-04-27 04:50:11,234] Trial 3 finished with values: [0.5489826326264569, 0.025580204874117246] and parameters: {'n_estimators': 365, 'max_depth': 7, 'min_samples_split': 15, 'min_samples_leaf': 35, 'max_features': 0.9061739139083851, 'bootstrap': True}.
# [I 2026-04-27 04:50:19,993] Trial 21 finished with values: [0.48010390920674073, 0.045823731987595206] and parameters: {'n_estimators': 215, 'max_depth': 26, 'min_samples_split': 39, 'min_samples_leaf': 23, 'max_features': 0.4903061972871827, 'bootstrap': True}.
# [I 2026-04-27 04:50:28,594] Trial 22 finished with values: [0.5636814932055999, 0.024426902424997732] and parameters: {'n_estimators': 277, 'max_depth': 7, 'min_samples_split': 57, 'min_samples_leaf': 55, 'max_features': 0.6001928504951947, 'bootstrap': True}.
# [I 2026-04-27 04:50:31,720] Trial 27 finished with values: [0.46994736026576794, 0.06825684055728073] and parameters: {'n_estimators': 109, 'max_depth': 17, 'min_samples_split': 45, 'min_samples_leaf': 12, 'max_features': 0.30383151893792076, 'bootstrap': False}.
# [I 2026-04-27 04:50:44,276] Trial 17 finished with values: [0.4755965815675225, 0.048934371797724044] and parameters: {'n_estimators': 380, 'max_depth': 22, 'min_samples_split': 39, 'min_samples_leaf': 20, 'max_features': 0.4918093533618879, 'bootstrap': True}.
# [I 2026-04-27 04:51:13,593] Trial 24 finished with values: [0.4964653501234413, 0.03446295986028099] and parameters: {'n_estimators': 260, 'max_depth': 16, 'min_samples_split': 48, 'min_samples_leaf': 41, 'max_features': 0.5448541694856199, 'bootstrap': True}.
# [I 2026-04-27 04:51:14,036] Trial 28 finished with values: [0.5218178190972915, 0.036142606266742205] and parameters: {'n_estimators': 169, 'max_depth': 8, 'min_samples_split': 38, 'min_samples_leaf': 12, 'max_features': 0.6153711991852087, 'bootstrap': False}.
# [I 2026-04-27 04:51:18,614] Trial 23 finished with values: [0.4986489488077474, 0.03535263895754576] and parameters: {'n_estimators': 239, 'max_depth': 12, 'min_samples_split': 10, 'min_samples_leaf': 54, 'max_features': 0.4146259458294594, 'bootstrap': False}.
# [I 2026-04-27 04:51:20,016] Trial 31 finished with values: [0.4656956802796062, 0.07361162533736204] and parameters: {'n_estimators': 98, 'max_depth': 35, 'min_samples_split': 43, 'min_samples_leaf': 14, 'max_features': 0.44678197840204614, 'bootstrap': False}.
# [I 2026-04-27 04:51:37,774] Trial 25 finished with values: [0.506886519376599, 0.03372266121571531] and parameters: {'n_estimators': 357, 'max_depth': 27, 'min_samples_split': 26, 'min_samples_leaf': 40, 'max_features': 0.307278458976012, 'bootstrap': True}.
# [I 2026-04-27 04:51:49,755] Trial 35 finished with values: [0.4736183259091287, 0.05142044131173214] and parameters: {'n_estimators': 94, 'max_depth': 14, 'min_samples_split': 58, 'min_samples_leaf': 14, 'max_features': 0.9815578256951727, 'bootstrap': True}.
# [I 2026-04-27 04:51:59,265] Trial 40 finished with values: [0.4893619472749855, 0.0428222783290961] and parameters: {'n_estimators': 99, 'max_depth': 24, 'min_samples_split': 59, 'min_samples_leaf': 21, 'max_features': 0.31470050868845395, 'bootstrap': True}.
# [I 2026-04-27 04:52:17,882] Trial 15 finished with values: [0.4799637203234571, 0.04281467687783988] and parameters: {'n_estimators': 319, 'max_depth': 37, 'min_samples_split': 54, 'min_samples_leaf': 44, 'max_features': 0.7388896881249588, 'bootstrap': False}.
# [I 2026-04-27 04:52:31,294] Trial 16 finished with values: [0.47080259387721435, 0.052638204976125424] and parameters: {'n_estimators': 250, 'max_depth': 29, 'min_samples_split': 58, 'min_samples_leaf': 33, 'max_features': 0.9812433195461079, 'bootstrap': False}.
# [I 2026-04-27 04:52:44,478] Trial 36 finished with values: [0.4768873026023679, 0.04603403947417242] and parameters: {'n_estimators': 114, 'max_depth': 40, 'min_samples_split': 42, 'min_samples_leaf': 41, 'max_features': 0.9186892447038917, 'bootstrap': False}.
# [I 2026-04-27 04:52:44,909] Trial 19 finished with values: [0.46955592900025855, 0.058409107137327776] and parameters: {'n_estimators': 296, 'max_depth': 20, 'min_samples_split': 56, 'min_samples_leaf': 8, 'max_features': 0.8573277405438988, 'bootstrap': True}.
# [I 2026-04-27 04:52:49,578] Trial 38 finished with values: [0.4906731485003147, 0.040458901815145484] and parameters: {'n_estimators': 239, 'max_depth': 13, 'min_samples_split': 41, 'min_samples_leaf': 37, 'max_features': 0.3189923819166195, 'bootstrap': False}.
# [I 2026-04-27 04:52:57,238] Trial 26 finished with values: [0.48576131658552574, 0.03856465578901504] and parameters: {'n_estimators': 282, 'max_depth': 40, 'min_samples_split': 46, 'min_samples_leaf': 34, 'max_features': 0.7209988124214963, 'bootstrap': True}.
# [I 2026-04-27 04:53:05,854] Trial 32 finished with values: [0.4947006258214921, 0.03255114514079872] and parameters: {'n_estimators': 209, 'max_depth': 14, 'min_samples_split': 11, 'min_samples_leaf': 49, 'max_features': 0.9565716747921977, 'bootstrap': True}.
# [I 2026-04-27 04:53:20,893] Trial 29 finished with values: [0.4780309791758419, 0.04658785187246117] and parameters: {'n_estimators': 348, 'max_depth': 27, 'min_samples_split': 35, 'min_samples_leaf': 22, 'max_features': 0.5000695803658466, 'bootstrap': True}.
# [I 2026-04-27 04:53:37,216] Trial 46 finished with values: [0.47101023910610323, 0.06566427881319474] and parameters: {'n_estimators': 77, 'max_depth': 15, 'min_samples_split': 38, 'min_samples_leaf': 5, 'max_features': 0.39982065484840446, 'bootstrap': True}.
# [I 2026-04-27 04:54:02,501] Trial 47 finished with values: [0.4925981989883528, 0.03667505762093541] and parameters: {'n_estimators': 113, 'max_depth': 16, 'min_samples_split': 15, 'min_samples_leaf': 36, 'max_features': 0.5266881712076555, 'bootstrap': True}.
# [I 2026-04-27 04:54:06,151] Trial 37 finished with values: [0.5547149640558786, 0.028008786844316014] and parameters: {'n_estimators': 392, 'max_depth': 7, 'min_samples_split': 18, 'min_samples_leaf': 18, 'max_features': 0.6067140402919662, 'bootstrap': True}.
# [I 2026-04-27 04:54:39,784] Trial 30 finished with values: [0.48305934076902385, 0.04252027049839238] and parameters: {'n_estimators': 359, 'max_depth': 22, 'min_samples_split': 56, 'min_samples_leaf': 41, 'max_features': 0.5110315203778133, 'bootstrap': False}.
# [I 2026-04-27 04:54:42,833] Trial 33 finished with values: [0.5006644616236751, 0.030923557633254356] and parameters: {'n_estimators': 331, 'max_depth': 18, 'min_samples_split': 40, 'min_samples_leaf': 54, 'max_features': 0.7764113997189064, 'bootstrap': True}.
# [I 2026-04-27 04:54:45,653] Trial 49 finished with values: [0.4746127761887535, 0.05242874195545996] and parameters: {'n_estimators': 131, 'max_depth': 32, 'min_samples_split': 22, 'min_samples_leaf': 18, 'max_features': 0.47180593486802624, 'bootstrap': True}.
# [I 2026-04-27 04:54:58,502] Trial 39 finished with values: [0.46539591262848246, 0.06964842055325027] and parameters: {'n_estimators': 206, 'max_depth': 14, 'min_samples_split': 49, 'min_samples_leaf': 13, 'max_features': 0.6605107536544923, 'bootstrap': False}.
# [I 2026-04-27 04:55:00,694] Trial 48 finished with values: [0.4923640190963947, 0.038333705410879854] and parameters: {'n_estimators': 112, 'max_depth': 12, 'min_samples_split': 56, 'min_samples_leaf': 46, 'max_features': 0.48684804069535015, 'bootstrap': False}.
# [I 2026-04-27 04:55:36,121] Trial 44 finished with values: [0.5130691229519828, 0.03676575990842043] and parameters: {'n_estimators': 189, 'max_depth': 8, 'min_samples_split': 25, 'min_samples_leaf': 13, 'max_features': 0.9942328359583845, 'bootstrap': False}.
# [I 2026-04-27 04:55:40,927] Trial 42 finished with values: [0.4705326179705658, 0.0607369269195506] and parameters: {'n_estimators': 369, 'max_depth': 27, 'min_samples_split': 17, 'min_samples_leaf': 13, 'max_features': 0.35671082297843654, 'bootstrap': True}.
# [I 2026-04-27 04:55:58,379] Trial 34 finished with values: [0.47442743871482507, 0.04901907961846558] and parameters: {'n_estimators': 333, 'max_depth': 28, 'min_samples_split': 28, 'min_samples_leaf': 33, 'max_features': 0.6203324263938963, 'bootstrap': False}.
# [I 2026-04-27 04:56:23,514] Trial 43 finished with values: [0.48682788521389886, 0.03860764614538198] and parameters: {'n_estimators': 350, 'max_depth': 25, 'min_samples_split': 37, 'min_samples_leaf': 32, 'max_features': 0.560719067342393, 'bootstrap': True}.
# [I 2026-04-27 04:56:35,477] Trial 41 finished with values: [0.4768156649606127, 0.04889014425924357] and parameters: {'n_estimators': 330, 'max_depth': 32, 'min_samples_split': 47, 'min_samples_leaf': 32, 'max_features': 0.48541262383411793, 'bootstrap': False}.
# [I 2026-04-27 04:57:24,615] Trial 55 finished with values: [0.5195735960211707, 0.029835619181031975] and parameters: {'n_estimators': 295, 'max_depth': 20, 'min_samples_split': 47, 'min_samples_leaf': 59, 'max_features': 0.37843821078306034, 'bootstrap': True}.
# [I 2026-04-27 04:58:23,276] Trial 51 finished with values: [0.48923548859070026, 0.03808092991971833] and parameters: {'n_estimators': 300, 'max_depth': 22, 'min_samples_split': 28, 'min_samples_leaf': 51, 'max_features': 0.5042422522049391, 'bootstrap': False}.
# [I 2026-04-27 04:58:33,554] Trial 53 finished with values: [0.4769497291804937, 0.048199279336460815] and parameters: {'n_estimators': 322, 'max_depth': 16, 'min_samples_split': 57, 'min_samples_leaf': 15, 'max_features': 0.5201296300462551, 'bootstrap': True}.
# [I 2026-04-27 04:58:40,245] Trial 65 finished with values: [0.5081291757288192, 0.03566551826190291] and parameters: {'n_estimators': 147, 'max_depth': 10, 'min_samples_split': 22, 'min_samples_leaf': 26, 'max_features': 0.35893220276080257, 'bootstrap': True}.
# [I 2026-04-27 04:58:50,074] Trial 52 finished with values: [0.5267201234902857, 0.0271636421493905] and parameters: {'n_estimators': 324, 'max_depth': 8, 'min_samples_split': 24, 'min_samples_leaf': 49, 'max_features': 0.9459773723093228, 'bootstrap': True}.
# [I 2026-04-27 04:58:54,948] Trial 56 finished with values: [0.48382521319771843, 0.045399223718607884] and parameters: {'n_estimators': 301, 'max_depth': 26, 'min_samples_split': 60, 'min_samples_leaf': 14, 'max_features': 0.3048149715246115, 'bootstrap': True}.
# [I 2026-04-27 04:59:00,802] Trial 54 finished with values: [0.4830610283910793, 0.04186268516813536] and parameters: {'n_estimators': 161, 'max_depth': 13, 'min_samples_split': 37, 'min_samples_leaf': 43, 'max_features': 0.6792438177554336, 'bootstrap': False}.
# [I 2026-04-27 04:59:02,256] Trial 66 finished with values: [0.4778544949850312, 0.05279130301698505] and parameters: {'n_estimators': 55, 'max_depth': 34, 'min_samples_split': 22, 'min_samples_leaf': 16, 'max_features': 0.3465100902242906, 'bootstrap': True}.
# [I 2026-04-27 04:59:17,876] Trial 64 finished with values: [0.4519054895215934, 0.1679091840028441] and parameters: {'n_estimators': 70, 'max_depth': 34, 'min_samples_split': 18, 'min_samples_leaf': 6, 'max_features': 0.947871632507336, 'bootstrap': False}.
# [I 2026-04-27 04:59:32,369] Trial 50 finished with values: [0.4844291982976975, 0.03884736843065746] and parameters: {'n_estimators': 236, 'max_depth': 28, 'min_samples_split': 30, 'min_samples_leaf': 54, 'max_features': 0.8365333191233468, 'bootstrap': False}.
# [I 2026-04-27 05:00:04,355] Trial 59 finished with values: [0.5954951093131837, 0.024808505793711966] and parameters: {'n_estimators': 306, 'max_depth': 6, 'min_samples_split': 50, 'min_samples_leaf': 6, 'max_features': 0.6953685523757231, 'bootstrap': False}.
# [I 2026-04-27 05:00:29,280] Trial 71 finished with values: [0.4734633331495146, 0.05689846011182455] and parameters: {'n_estimators': 52, 'max_depth': 16, 'min_samples_split': 38, 'min_samples_leaf': 16, 'max_features': 0.6168095806759617, 'bootstrap': True}.
# [I 2026-04-27 05:00:32,142] Trial 57 finished with values: [0.4878937350909414, 0.045363058529274955] and parameters: {'n_estimators': 306, 'max_depth': 10, 'min_samples_split': 16, 'min_samples_leaf': 22, 'max_features': 0.6381088455729693, 'bootstrap': False}.
# [I 2026-04-27 05:00:43,776] Trial 45 finished with values: [0.5480448012236407, 0.027523238631799757] and parameters: {'n_estimators': 380, 'max_depth': 7, 'min_samples_split': 56, 'min_samples_leaf': 29, 'max_features': 0.8280247630803397, 'bootstrap': False}.
# [I 2026-04-27 05:01:03,114] Trial 58 finished with values: [0.4826695027235932, 0.03988896749140726] and parameters: {'n_estimators': 311, 'max_depth': 32, 'min_samples_split': 59, 'min_samples_leaf': 33, 'max_features': 0.8728570298936984, 'bootstrap': True}.
# [I 2026-04-27 05:01:08,512] Trial 73 finished with values: [0.6039362934480456, 0.02458125129174557] and parameters: {'n_estimators': 258, 'max_depth': 6, 'min_samples_split': 46, 'min_samples_leaf': 11, 'max_features': 0.5375352920241999, 'bootstrap': True}.
# [I 2026-04-27 05:01:45,341] Trial 68 finished with values: [0.4834818679147266, 0.04199447662353804] and parameters: {'n_estimators': 194, 'max_depth': 21, 'min_samples_split': 10, 'min_samples_leaf': 28, 'max_features': 0.5625609883120343, 'bootstrap': True}.
# [I 2026-04-27 05:01:46,378] Trial 72 finished with values: [0.4787030525994609, 0.0466369821156775] and parameters: {'n_estimators': 134, 'max_depth': 38, 'min_samples_split': 36, 'min_samples_leaf': 35, 'max_features': 0.5171388824523803, 'bootstrap': False}.
# [I 2026-04-27 05:01:56,306] Trial 67 finished with values: [0.5159143962339068, 0.03346281778467593] and parameters: {'n_estimators': 378, 'max_depth': 9, 'min_samples_split': 38, 'min_samples_leaf': 25, 'max_features': 0.41654816209518275, 'bootstrap': True}.
# [I 2026-04-27 05:02:35,938] Trial 60 finished with values: [0.46252021572723, 0.07944459103865885] and parameters: {'n_estimators': 369, 'max_depth': 20, 'min_samples_split': 15, 'min_samples_leaf': 15, 'max_features': 0.4651756449140864, 'bootstrap': False}.
# [I 2026-04-27 05:02:48,345] Trial 61 finished with values: [0.46921910093575714, 0.05628240287884753] and parameters: {'n_estimators': 298, 'max_depth': 25, 'min_samples_split': 42, 'min_samples_leaf': 17, 'max_features': 0.8320968886328337, 'bootstrap': True}.
# [I 2026-04-27 05:02:48,841] Trial 62 finished with values: [0.45779398297576457, 0.09195664174585466] and parameters: {'n_estimators': 184, 'max_depth': 32, 'min_samples_split': 37, 'min_samples_leaf': 13, 'max_features': 0.9628554585599851, 'bootstrap': False}.
# [I 2026-04-27 05:03:03,673] Trial 74 finished with values: [0.4652550793683505, 0.0656345300033577] and parameters: {'n_estimators': 110, 'max_depth': 17, 'min_samples_split': 59, 'min_samples_leaf': 18, 'max_features': 0.8403816201377399, 'bootstrap': False}.
# [I 2026-04-27 05:03:26,832] Trial 80 finished with values: [0.6524031044027107, 0.021123882238189368] and parameters: {'n_estimators': 270, 'max_depth': 5, 'min_samples_split': 53, 'min_samples_leaf': 25, 'max_features': 0.8816820611350715, 'bootstrap': True}.
# [I 2026-04-27 05:04:22,192] Trial 82 finished with values: [0.6516115210612939, 0.02114569119262588] and parameters: {'n_estimators': 283, 'max_depth': 5, 'min_samples_split': 52, 'min_samples_leaf': 24, 'max_features': 0.8913824099442638, 'bootstrap': True}.
# [I 2026-04-27 05:04:25,500] Trial 69 finished with values: [0.4722170426100667, 0.052012377255992545] and parameters: {'n_estimators': 264, 'max_depth': 16, 'min_samples_split': 54, 'min_samples_leaf': 14, 'max_features': 0.7279460202007294, 'bootstrap': True}.
# [I 2026-04-27 05:04:54,315] Trial 63 finished with values: [0.48324319512419567, 0.03961092542704041] and parameters: {'n_estimators': 289, 'max_depth': 20, 'min_samples_split': 26, 'min_samples_leaf': 53, 'max_features': 0.8997767721023058, 'bootstrap': False}.
# [I 2026-04-27 05:04:55,129] Trial 81 finished with values: [0.6549203077463001, 0.021888926605582615] and parameters: {'n_estimators': 280, 'max_depth': 5, 'min_samples_split': 34, 'min_samples_leaf': 57, 'max_features': 0.8894100048727368, 'bootstrap': False}.
# [I 2026-04-27 05:04:58,661] Trial 70 finished with values: [0.4979189425719746, 0.03329250186860752] and parameters: {'n_estimators': 275, 'max_depth': 37, 'min_samples_split': 28, 'min_samples_leaf': 45, 'max_features': 0.5897651499976606, 'bootstrap': True}.
# [I 2026-04-27 05:05:05,263] Trial 83 finished with values: [0.6530462371777638, 0.021709819399371943] and parameters: {'n_estimators': 278, 'max_depth': 5, 'min_samples_split': 53, 'min_samples_leaf': 30, 'max_features': 0.8818406691859463, 'bootstrap': False}.
# [I 2026-04-27 05:05:46,299] Trial 87 finished with values: [0.6547420651178617, 0.021473824074938086] and parameters: {'n_estimators': 277, 'max_depth': 5, 'min_samples_split': 54, 'min_samples_leaf': 57, 'max_features': 0.8828050280929354, 'bootstrap': True}.
# [I 2026-04-27 05:05:49,703] Trial 88 finished with values: [0.6550873340407731, 0.021492565662532215] and parameters: {'n_estimators': 274, 'max_depth': 5, 'min_samples_split': 52, 'min_samples_leaf': 58, 'max_features': 0.8829751876700528, 'bootstrap': True}.
# [I 2026-04-27 05:06:43,007] Trial 77 finished with values: [0.47938132712367787, 0.04295929680772122] and parameters: {'n_estimators': 257, 'max_depth': 30, 'min_samples_split': 13, 'min_samples_leaf': 29, 'max_features': 0.8801343903952239, 'bootstrap': True}.
# [I 2026-04-27 05:06:56,393] Trial 79 finished with values: [0.4765267388347484, 0.04409765694952893] and parameters: {'n_estimators': 278, 'max_depth': 38, 'min_samples_split': 34, 'min_samples_leaf': 27, 'max_features': 0.8792044827460802, 'bootstrap': True}.
# [I 2026-04-27 05:08:27,691] Trial 78 finished with values: [0.5024056646158747, 0.030377303343641263] and parameters: {'n_estimators': 262, 'max_depth': 30, 'min_samples_split': 11, 'min_samples_leaf': 58, 'max_features': 0.8924366144153187, 'bootstrap': True}.
# [I 2026-04-27 05:08:43,830] Trial 86 finished with values: [0.5019853420793452, 0.03006272730219138] and parameters: {'n_estimators': 284, 'max_depth': 36, 'min_samples_split': 34, 'min_samples_leaf': 58, 'max_features': 0.9034684702160617, 'bootstrap': True}.
# [I 2026-04-27 05:08:53,010] Trial 76 finished with values: [0.47938328281466513, 0.04294429697875987] and parameters: {'n_estimators': 253, 'max_depth': 30, 'min_samples_split': 12, 'min_samples_leaf': 29, 'max_features': 0.8846060934601037, 'bootstrap': True}.
# [I 2026-04-27 05:10:12,811] Trial 84 finished with values: [0.48661586682809166, 0.03736514508408942] and parameters: {'n_estimators': 284, 'max_depth': 36, 'min_samples_split': 53, 'min_samples_leaf': 59, 'max_features': 0.883904688808193, 'bootstrap': False}.
# [I 2026-04-27 05:10:16,626] Trial 89 finished with values: [0.502608460748069, 0.029257756803904536] and parameters: {'n_estimators': 279, 'max_depth': 30, 'min_samples_split': 52, 'min_samples_leaf': 60, 'max_features': 0.9124959288807181, 'bootstrap': True}.
# [I 2026-04-27 05:10:28,218] Trial 92 finished with values: [0.49451156371168864, 0.03316217618612416] and parameters: {'n_estimators': 248, 'max_depth': 36, 'min_samples_split': 52, 'min_samples_leaf': 48, 'max_features': 0.9249410889905212, 'bootstrap': True}.
# [I 2026-04-27 05:10:43,868] Trial 90 finished with values: [0.5010871546308997, 0.030374498524418356] and parameters: {'n_estimators': 280, 'max_depth': 34, 'min_samples_split': 51, 'min_samples_leaf': 57, 'max_features': 0.9138140727498133, 'bootstrap': True}.
# [I 2026-04-27 05:10:50,901] Trial 91 finished with values: [0.5017046360387266, 0.02983815316339182] and parameters: {'n_estimators': 276, 'max_depth': 30, 'min_samples_split': 53, 'min_samples_leaf': 58, 'max_features': 0.9324387901573186, 'bootstrap': True}.
# [I 2026-04-27 05:10:59,201] Trial 75 finished with values: [0.4857954159741919, 0.037943059402106113] and parameters: {'n_estimators': 252, 'max_depth': 30, 'min_samples_split': 52, 'min_samples_leaf': 57, 'max_features': 0.8853346741918748, 'bootstrap': False}.
# [I 2026-04-27 05:11:13,232] Trial 96 finished with values: [0.4626849580021117, 0.07250126850209264] and parameters: {'n_estimators': 222, 'max_depth': 35, 'min_samples_split': 34, 'min_samples_leaf': 10, 'max_features': 0.9408841080837694, 'bootstrap': True}.
# [I 2026-04-27 05:11:28,458] Trial 85 finished with values: [0.48641499514931863, 0.03779752548119214] and parameters: {'n_estimators': 278, 'max_depth': 31, 'min_samples_split': 53, 'min_samples_leaf': 58, 'max_features': 0.9206574932443011, 'bootstrap': False}.
# [I 2026-04-27 05:11:39,037] Trial 95 finished with values: [0.49453657546346674, 0.03317311646625003] and parameters: {'n_estimators': 250, 'max_depth': 31, 'min_samples_split': 60, 'min_samples_leaf': 48, 'max_features': 0.9302542995316068, 'bootstrap': True}.
# [I 2026-04-27 05:11:55,578] Trial 94 finished with values: [0.5014801272269251, 0.030573791239771442] and parameters: {'n_estimators': 314, 'max_depth': 30, 'min_samples_split': 60, 'min_samples_leaf': 57, 'max_features': 0.9297590618944287, 'bootstrap': True}.
# [I 2026-04-27 05:13:00,555] Trial 97 finished with values: [0.4681266160451348, 0.058101637255353444] and parameters: {'n_estimators': 227, 'max_depth': 35, 'min_samples_split': 33, 'min_samples_leaf': 18, 'max_features': 0.9329949907554734, 'bootstrap': True}.
# [I 2026-04-27 05:13:10,851] Trial 98 finished with values: [0.4813863109677815, 0.041793214596493] and parameters: {'n_estimators': 223, 'max_depth': 35, 'min_samples_split': 43, 'min_samples_leaf': 49, 'max_features': 0.9203915983133978, 'bootstrap': False}.
# [I 2026-04-27 05:13:23,795] Trial 106 finished with values: [0.465329759486342, 0.0672065050633447] and parameters: {'n_estimators': 68, 'max_depth': 33, 'min_samples_split': 58, 'min_samples_leaf': 19, 'max_features': 0.9495507959295418, 'bootstrap': False}.
# [I 2026-04-27 05:13:53,333] Trial 108 finished with values: [0.45242326151673606, 0.13980804534134095] and parameters: {'n_estimators': 70, 'max_depth': 39, 'min_samples_split': 18, 'min_samples_leaf': 9, 'max_features': 0.9416778340089108, 'bootstrap': False}.
# [I 2026-04-27 05:14:35,197] Trial 109 finished with values: [0.4553891416714175, 0.12971529516900504] and parameters: {'n_estimators': 69, 'max_depth': 34, 'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': 0.9463119543261074, 'bootstrap': False}.
# [I 2026-04-27 05:14:42,754] Trial 93 finished with values: [0.5014801272269251, 0.030573791239771442] and parameters: {'n_estimators': 314, 'max_depth': 31, 'min_samples_split': 51, 'min_samples_leaf': 57, 'max_features': 0.9249488809659268, 'bootstrap': True}.
# [I 2026-04-27 05:15:15,137] Trial 113 finished with values: [0.4548761888540302, 0.12431485876510216] and parameters: {'n_estimators': 66, 'max_depth': 39, 'min_samples_split': 18, 'min_samples_leaf': 10, 'max_features': 0.7894521088223412, 'bootstrap': False}.
# [I 2026-04-27 05:15:50,723] Trial 112 finished with values: [0.45475787365179765, 0.12491525728459946] and parameters: {'n_estimators': 73, 'max_depth': 39, 'min_samples_split': 19, 'min_samples_leaf': 10, 'max_features': 0.8051147200850961, 'bootstrap': False}.
# [I 2026-04-27 05:17:02,228] Trial 114 finished with values: [0.4538579662492256, 0.13859466983107846] and parameters: {'n_estimators': 80, 'max_depth': 39, 'min_samples_split': 20, 'min_samples_leaf': 9, 'max_features': 0.9950892656647163, 'bootstrap': False}.
# [I 2026-04-27 05:17:13,129] Trial 102 finished with values: [0.4803158105817629, 0.04222464134681632] and parameters: {'n_estimators': 245, 'max_depth': 36, 'min_samples_split': 20, 'min_samples_leaf': 48, 'max_features': 0.943702083115736, 'bootstrap': False}.
# [I 2026-04-27 05:17:26,980] Trial 103 finished with values: [0.48711348031047463, 0.03709844242859667] and parameters: {'n_estimators': 226, 'max_depth': 34, 'min_samples_split': 50, 'min_samples_leaf': 60, 'max_features': 0.9282676180165175, 'bootstrap': False}.
# [I 2026-04-27 05:17:45,109] Trial 104 finished with values: [0.48517199784196674, 0.03867105062301954] and parameters: {'n_estimators': 227, 'max_depth': 34, 'min_samples_split': 44, 'min_samples_leaf': 56, 'max_features': 0.9360378958918572, 'bootstrap': False}.
# [I 2026-04-27 05:18:19,696] Trial 105 finished with values: [0.4871667311227774, 0.037461953292653824] and parameters: {'n_estimators': 225, 'max_depth': 33, 'min_samples_split': 58, 'min_samples_leaf': 60, 'max_features': 0.9674837358766878, 'bootstrap': False}.
# [I 2026-04-27 05:19:29,174] Trial 101 finished with values: [0.4802974531952154, 0.04230424894687364] and parameters: {'n_estimators': 224, 'max_depth': 34, 'min_samples_split': 44, 'min_samples_leaf': 48, 'max_features': 0.94175438356835, 'bootstrap': False}.
# [I 2026-04-27 05:19:33,279] Trial 115 finished with values: [0.5025513368780975, 0.029720101788975703] and parameters: {'n_estimators': 289, 'max_depth': 39, 'min_samples_split': 49, 'min_samples_leaf': 60, 'max_features': 0.970974708150538, 'bootstrap': True}.
# [I 2026-04-27 05:19:33,858] Trial 111 finished with values: [0.4562486810436252, 0.10305055382261098] and parameters: {'n_estimators': 226, 'max_depth': 39, 'min_samples_split': 32, 'min_samples_leaf': 10, 'max_features': 0.785500500152389, 'bootstrap': False}.
# [I 2026-04-27 05:19:55,389] Trial 110 finished with values: [0.4530009277694593, 0.13392997962242587] and parameters: {'n_estimators': 219, 'max_depth': 39, 'min_samples_split': 19, 'min_samples_leaf': 9, 'max_features': 0.7862995917171944, 'bootstrap': False}.
# [I 2026-04-27 05:20:06,377] Trial 100 finished with values: [0.4641454065035881, 0.06702694264194242] and parameters: {'n_estimators': 316, 'max_depth': 33, 'min_samples_split': 58, 'min_samples_leaf': 19, 'max_features': 0.9478040276304299, 'bootstrap': False}.
# [I 2026-04-27 05:20:29,385] Trial 117 finished with values: [0.5304973565568356, 0.025994403029993826] and parameters: {'n_estimators': 244, 'max_depth': 8, 'min_samples_split': 32, 'min_samples_leaf': 60, 'max_features': 0.9710416536871103, 'bootstrap': True}.
# [I 2026-04-27 05:20:35,663] Trial 119 finished with values: [0.5160656913446994, 0.027123471355168058] and parameters: {'n_estimators': 247, 'max_depth': 9, 'min_samples_split': 56, 'min_samples_leaf': 60, 'max_features': 0.9969224831976794, 'bootstrap': True}.
# [I 2026-04-27 05:20:49,018] Trial 122 finished with values: [0.556437933674105, 0.02465028142081893] and parameters: {'n_estimators': 268, 'max_depth': 7, 'min_samples_split': 55, 'min_samples_leaf': 55, 'max_features': 0.8556453796398461, 'bootstrap': True}.
# [I 2026-04-27 05:20:59,700] Trial 118 finished with values: [0.5025513368780975, 0.029720101788975703] and parameters: {'n_estimators': 289, 'max_depth': 39, 'min_samples_split': 31, 'min_samples_leaf': 60, 'max_features': 0.9743296587907824, 'bootstrap': True}.
# [I 2026-04-27 05:21:02,351] Trial 99 finished with values: [0.4585227806808375, 0.09064210596317274] and parameters: {'n_estimators': 225, 'max_depth': 34, 'min_samples_split': 44, 'min_samples_leaf': 10, 'max_features': 0.9497835803784804, 'bootstrap': False}.
# [I 2026-04-27 05:21:05,300] Trial 120 finished with values: [0.5540559557152704, 0.023965049671498012] and parameters: {'n_estimators': 289, 'max_depth': 7, 'min_samples_split': 55, 'min_samples_leaf': 60, 'max_features': 0.9687389536216314, 'bootstrap': True}.
# [I 2026-04-27 05:21:17,721] Trial 107 finished with values: [0.4870342514358108, 0.037443722214337616] and parameters: {'n_estimators': 228, 'max_depth': 33, 'min_samples_split': 58, 'min_samples_leaf': 60, 'max_features': 0.9526839262873061, 'bootstrap': False}.
# [I 2026-04-27 05:21:18,867] Trial 116 finished with values: [0.5022445682075973, 0.02967104926395915] and parameters: {'n_estimators': 291, 'max_depth': 39, 'min_samples_split': 30, 'min_samples_leaf': 60, 'max_features': 0.9691072256902905, 'bootstrap': True}.
# [I 2026-04-27 05:21:28,517] Trial 121 finished with values: [0.5151643848563321, 0.027881752728142556] and parameters: {'n_estimators': 290, 'max_depth': 9, 'min_samples_split': 30, 'min_samples_leaf': 52, 'max_features': 0.8587393763038222, 'bootstrap': True}.
# [I 2026-04-27 05:22:28,701] Trial 123 finished with values: [0.5177591116639146, 0.03135959174012484] and parameters: {'n_estimators': 289, 'max_depth': 8, 'min_samples_split': 55, 'min_samples_leaf': 23, 'max_features': 0.975150295027423, 'bootstrap': True}.
# [I 2026-04-27 05:22:45,522] Trial 124 finished with values: [0.5254905644637752, 0.02826127073830484] and parameters: {'n_estimators': 290, 'max_depth': 8, 'min_samples_split': 55, 'min_samples_leaf': 39, 'max_features': 0.8585988003185064, 'bootstrap': True}.
# [I 2026-04-27 05:23:00,902] Trial 133 finished with values: [0.5910797656594639, 0.023569936628853344] and parameters: {'n_estimators': 198, 'max_depth': 6, 'min_samples_split': 33, 'min_samples_leaf': 23, 'max_features': 0.8536436943263956, 'bootstrap': True}.
# [I 2026-04-27 05:23:08,513] Trial 126 finished with values: [0.5300225781057364, 0.026978970326623636] and parameters: {'n_estimators': 266, 'max_depth': 8, 'min_samples_split': 32, 'min_samples_leaf': 52, 'max_features': 0.8597847093858343, 'bootstrap': True}.
# [I 2026-04-27 05:23:25,266] Trial 128 finished with values: [0.5211914008837899, 0.027928626900582287] and parameters: {'n_estimators': 269, 'max_depth': 9, 'min_samples_split': 34, 'min_samples_leaf': 55, 'max_features': 0.6422717994768834, 'bootstrap': True}.
# [I 2026-04-27 05:23:36,432] Trial 127 finished with values: [0.5307826512409577, 0.02617517368250348] and parameters: {'n_estimators': 289, 'max_depth': 8, 'min_samples_split': 31, 'min_samples_leaf': 55, 'max_features': 0.8486417478233665, 'bootstrap': True}.
# [I 2026-04-27 05:23:58,210] Trial 138 finished with values: [0.5860672536803978, 0.022831855314240285] and parameters: {'n_estimators': 212, 'max_depth': 6, 'min_samples_split': 34, 'min_samples_leaf': 22, 'max_features': 0.9995909926895663, 'bootstrap': True}.
# [I 2026-04-27 05:24:10,376] Trial 129 finished with values: [0.5304294142625151, 0.0264698575514382] and parameters: {'n_estimators': 291, 'max_depth': 8, 'min_samples_split': 32, 'min_samples_leaf': 54, 'max_features': 0.8567358185157062, 'bootstrap': True}.
# [I 2026-04-27 05:24:13,845] Trial 131 finished with values: [0.5563051054720374, 0.024645171517799463] and parameters: {'n_estimators': 270, 'max_depth': 7, 'min_samples_split': 32, 'min_samples_leaf': 55, 'max_features': 0.8522820254781531, 'bootstrap': True}.
# [I 2026-04-27 05:24:39,048] Trial 130 finished with values: [0.5917427538355038, 0.02373064892470042] and parameters: {'n_estimators': 267, 'max_depth': 6, 'min_samples_split': 30, 'min_samples_leaf': 23, 'max_features': 0.861220241429808, 'bootstrap': True}.
# [I 2026-04-27 05:25:23,993] Trial 140 finished with values: [0.5876569481820242, 0.023363033395297744] and parameters: {'n_estimators': 194, 'max_depth': 6, 'min_samples_split': 33, 'min_samples_leaf': 24, 'max_features': 0.9996693202896162, 'bootstrap': True}.
# [I 2026-04-27 05:25:35,632] Trial 135 finished with values: [0.4911030633277427, 0.03483076654140836] and parameters: {'n_estimators': 210, 'max_depth': 11, 'min_samples_split': 57, 'min_samples_leaf': 38, 'max_features': 0.9863159892443957, 'bootstrap': True}.
# [I 2026-04-27 05:25:36,298] Trial 125 finished with values: [0.529859650963399, 0.026838049615242443] and parameters: {'n_estimators': 290, 'max_depth': 8, 'min_samples_split': 55, 'min_samples_leaf': 52, 'max_features': 0.860840272061258, 'bootstrap': True}.
# [I 2026-04-27 05:26:13,922] Trial 143 finished with values: [0.5876521574643947, 0.022537918605005813] and parameters: {'n_estimators': 211, 'max_depth': 6, 'min_samples_split': 57, 'min_samples_leaf': 26, 'max_features': 0.9892430467660196, 'bootstrap': True}.
# [I 2026-04-27 05:26:14,459] Trial 137 finished with values: [0.48296892591812685, 0.04226104563883164] and parameters: {'n_estimators': 212, 'max_depth': 11, 'min_samples_split': 56, 'min_samples_leaf': 24, 'max_features': 0.9855441778473165, 'bootstrap': True}.
# [I 2026-04-27 05:26:31,342] Trial 139 finished with values: [0.49172021408755173, 0.03468171251459093] and parameters: {'n_estimators': 185, 'max_depth': 11, 'min_samples_split': 33, 'min_samples_leaf': 39, 'max_features': 0.9944527452031213, 'bootstrap': True}.
# [I 2026-04-27 05:27:10,351] Trial 132 finished with values: [0.48805849293409254, 0.036500543812411426] and parameters: {'n_estimators': 289, 'max_depth': 37, 'min_samples_split': 30, 'min_samples_leaf': 39, 'max_features': 0.8661486827082701, 'bootstrap': True}.
# [I 2026-04-27 05:27:30,030] Trial 141 finished with values: [0.47728485747776705, 0.04540978004679298] and parameters: {'n_estimators': 202, 'max_depth': 37, 'min_samples_split': 57, 'min_samples_leaf': 27, 'max_features': 0.9932239284842566, 'bootstrap': True}.
# [I 2026-04-27 05:27:59,450] Trial 136 finished with values: [0.482151613632628, 0.04262468659054314] and parameters: {'n_estimators': 209, 'max_depth': 11, 'min_samples_split': 55, 'min_samples_leaf': 23, 'max_features': 0.9986867165129087, 'bootstrap': True}.
# [I 2026-04-27 05:28:16,632] Trial 134 finished with values: [0.4743805207573009, 0.0477933673338158] and parameters: {'n_estimators': 208, 'max_depth': 37, 'min_samples_split': 33, 'min_samples_leaf': 24, 'max_features': 0.9080506599031812, 'bootstrap': True}.
# [I 2026-04-27 05:28:38,426] Trial 144 finished with values: [0.48421809219659984, 0.040736727558575714] and parameters: {'n_estimators': 215, 'max_depth': 11, 'min_samples_split': 36, 'min_samples_leaf': 27, 'max_features': 0.9987388284913625, 'bootstrap': True}.
# [I 2026-04-27 05:28:44,610] Trial 145 finished with values: [0.4736640496827407, 0.04676427816243532] and parameters: {'n_estimators': 211, 'max_depth': 38, 'min_samples_split': 36, 'min_samples_leaf': 25, 'max_features': 0.9993594303297436, 'bootstrap': True}.
# [I 2026-04-27 05:29:17,490] Trial 142 finished with values: [0.47515921490957214, 0.05650995636237133] and parameters: {'n_estimators': 306, 'max_depth': 11, 'min_samples_split': 36, 'min_samples_leaf': 7, 'max_features': 0.9839175130065945, 'bootstrap': True}.
# [I 2026-04-27 05:30:02,022] Trial 146 finished with values: [0.4752158869175386, 0.04575795007924509] and parameters: {'n_estimators': 211, 'max_depth': 37, 'min_samples_split': 35, 'min_samples_leaf': 26, 'max_features': 0.992928166939784, 'bootstrap': True}.
# [I 2026-04-27 05:30:56,021] Trial 147 finished with values: [0.4619870963970366, 0.07754217201354767] and parameters: {'n_estimators': 215, 'max_depth': 37, 'min_samples_split': 36, 'min_samples_leaf': 7, 'max_features': 0.996468183139757, 'bootstrap': True}.
# [I 2026-04-27 05:31:20,023] Trial 149 finished with values: [0.47662331723794366, 0.04532592658398234] and parameters: {'n_estimators': 209, 'max_depth': 37, 'min_samples_split': 35, 'min_samples_leaf': 27, 'max_features': 0.989317681500362, 'bootstrap': True}.
# [I 2026-04-27 05:31:50,575] Trial 154 finished with values: [0.4785901382235732, 0.0435661187466293] and parameters: {'n_estimators': 237, 'max_depth': 37, 'min_samples_split': 36, 'min_samples_leaf': 27, 'max_features': 0.7584946150855473, 'bootstrap': True}.
# [I 2026-04-27 05:32:13,723] Trial 153 finished with values: [0.46176229064767643, 0.07734141917398776] and parameters: {'n_estimators': 201, 'max_depth': 37, 'min_samples_split': 35, 'min_samples_leaf': 7, 'max_features': 0.9056400253289884, 'bootstrap': True}.
# [I 2026-04-27 05:32:23,942] Trial 151 finished with values: [0.4770597402069504, 0.04502226086999514] and parameters: {'n_estimators': 183, 'max_depth': 37, 'min_samples_split': 36, 'min_samples_leaf': 27, 'max_features': 0.9030914901227011, 'bootstrap': True}.
# [I 2026-04-27 05:32:34,570] Trial 156 finished with values: [0.4622904640690196, 0.07483740381136363] and parameters: {'n_estimators': 235, 'max_depth': 38, 'min_samples_split': 35, 'min_samples_leaf': 7, 'max_features': 0.7567519954876868, 'bootstrap': True}.
# [I 2026-04-27 05:33:00,238] Trial 150 finished with values: [0.46197374853188417, 0.07757265856578734] and parameters: {'n_estimators': 240, 'max_depth': 37, 'min_samples_split': 36, 'min_samples_leaf': 7, 'max_features': 0.9857941272883757, 'bootstrap': True}.
# [I 2026-04-27 05:33:10,895] Trial 155 finished with values: [0.4761143087038393, 0.045706953320090976] and parameters: {'n_estimators': 233, 'max_depth': 38, 'min_samples_split': 35, 'min_samples_leaf': 26, 'max_features': 0.9066177091963347, 'bootstrap': True}.
# [I 2026-04-27 05:33:15,064] Trial 152 finished with values: [0.46166568109869555, 0.07607150241781273] and parameters: {'n_estimators': 240, 'max_depth': 37, 'min_samples_split': 36, 'min_samples_leaf': 7, 'max_features': 0.9085624819465841, 'bootstrap': True}.
# [I 2026-04-27 05:34:07,596] Trial 148 finished with values: [0.4618274649796979, 0.07485176918098327] and parameters: {'n_estimators': 209, 'max_depth': 37, 'min_samples_split': 36, 'min_samples_leaf': 8, 'max_features': 0.9955586593770327, 'bootstrap': True}.
# [I 2026-04-27 05:35:02,626] Trial 160 finished with values: [0.46384587599452193, 0.06974574173727638] and parameters: {'n_estimators': 241, 'max_depth': 36, 'min_samples_split': 41, 'min_samples_leaf': 8, 'max_features': 0.9621748128521093, 'bootstrap': True}.
# [I 2026-04-27 05:35:44,035] Trial 161 finished with values: [0.4620268929403001, 0.07593798585866349] and parameters: {'n_estimators': 243, 'max_depth': 36, 'min_samples_split': 35, 'min_samples_leaf': 8, 'max_features': 0.9612978441339314, 'bootstrap': True}.
# [I 2026-04-27 05:35:51,868] Trial 159 finished with values: [0.4633860504010401, 0.06807891271658699] and parameters: {'n_estimators': 241, 'max_depth': 38, 'min_samples_split': 35, 'min_samples_leaf': 12, 'max_features': 0.9586106010036761, 'bootstrap': True}.
# [I 2026-04-27 05:37:04,551] Trial 158 finished with values: [0.4655427416183425, 0.06500255501095287] and parameters: {'n_estimators': 244, 'max_depth': 38, 'min_samples_split': 36, 'min_samples_leaf': 12, 'max_features': 0.752295611363784, 'bootstrap': True}.
# [I 2026-04-27 05:37:24,711] Trial 162 finished with values: [0.4630286079858813, 0.07155618993422526] and parameters: {'n_estimators': 242, 'max_depth': 36, 'min_samples_split': 39, 'min_samples_leaf': 8, 'max_features': 0.9602510593174353, 'bootstrap': True}.
# [I 2026-04-27 05:38:14,819] Trial 163 finished with values: [0.4652959583049651, 0.0647761487434258] and parameters: {'n_estimators': 243, 'max_depth': 36, 'min_samples_split': 40, 'min_samples_leaf': 12, 'max_features': 0.9593842280297437, 'bootstrap': True}.
# [I 2026-04-27 05:38:17,269] Trial 157 finished with values: [0.4621892704686727, 0.07489761614528245] and parameters: {'n_estimators': 240, 'max_depth': 38, 'min_samples_split': 35, 'min_samples_leaf': 8, 'max_features': 0.9045275317819728, 'bootstrap': True}.
# [I 2026-04-27 05:38:44,970] Trial 168 finished with values: [0.46529922604116286, 0.06479301948812334] and parameters: {'n_estimators': 245, 'max_depth': 35, 'min_samples_split': 40, 'min_samples_leaf': 12, 'max_features': 0.9598007994210958, 'bootstrap': True}.
# [I 2026-04-27 05:38:46,785] Trial 165 finished with values: [0.46442314790179506, 0.06504998711311166] and parameters: {'n_estimators': 233, 'max_depth': 35, 'min_samples_split': 39, 'min_samples_leaf': 12, 'max_features': 0.9624725262134134, 'bootstrap': True}.
# [I 2026-04-27 05:39:05,139] Trial 164 finished with values: [0.45963376426990876, 0.08257528057162346] and parameters: {'n_estimators': 237, 'max_depth': 36, 'min_samples_split': 13, 'min_samples_leaf': 11, 'max_features': 0.9616040765568611, 'bootstrap': True}.
# [I 2026-04-27 05:39:41,765] Trial 177 finished with values: [0.6496473046935304, 0.021214050697110742] and parameters: {'n_estimators': 168, 'max_depth': 5, 'min_samples_split': 24, 'min_samples_leaf': 21, 'max_features': 0.9687823236569106, 'bootstrap': False}.
# [I 2026-04-27 05:39:45,317] Trial 166 finished with values: [0.4652768631403039, 0.06476426797858552] and parameters: {'n_estimators': 246, 'max_depth': 35, 'min_samples_split': 40, 'min_samples_leaf': 12, 'max_features': 0.9610589681404718, 'bootstrap': True}.
# [I 2026-04-27 05:40:46,499] Trial 169 finished with values: [0.45967955500776586, 0.0826531996467144] and parameters: {'n_estimators': 246, 'max_depth': 36, 'min_samples_split': 14, 'min_samples_leaf': 11, 'max_features': 0.9618467804347534, 'bootstrap': True}.
# [I 2026-04-27 05:41:00,748] Trial 173 finished with values: [0.4610398388544609, 0.07798785827957151] and parameters: {'n_estimators': 174, 'max_depth': 36, 'min_samples_split': 24, 'min_samples_leaf': 19, 'max_features': 0.9583339059873139, 'bootstrap': False}.
# [I 2026-04-27 05:41:36,333] Trial 176 finished with values: [0.6506161949904088, 0.021421176308291795] and parameters: {'n_estimators': 231, 'max_depth': 5, 'min_samples_split': 39, 'min_samples_leaf': 21, 'max_features': 0.9627275901056563, 'bootstrap': False}.
# [I 2026-04-27 05:41:38,452] Trial 174 finished with values: [0.46154157940577895, 0.07472102116339298] and parameters: {'n_estimators': 175, 'max_depth': 35, 'min_samples_split': 24, 'min_samples_leaf': 20, 'max_features': 0.9606218783715932, 'bootstrap': False}.
# [I 2026-04-27 05:42:42,411] Trial 167 finished with values: [0.46068376523419613, 0.07803137091562738] and parameters: {'n_estimators': 234, 'max_depth': 35, 'min_samples_split': 27, 'min_samples_leaf': 11, 'max_features': 0.959127917633836, 'bootstrap': True}.
# [I 2026-04-27 05:42:58,194] Trial 180 finished with values: [0.549272328558286, 0.025849819764769494] and parameters: {'n_estimators': 256, 'max_depth': 7, 'min_samples_split': 24, 'min_samples_leaf': 59, 'max_features': 0.9710692513227608, 'bootstrap': False}.
# [I 2026-04-27 05:43:19,350] Trial 175 finished with values: [0.45722276284600005, 0.09425301157436765] and parameters: {'n_estimators': 172, 'max_depth': 40, 'min_samples_split': 39, 'min_samples_leaf': 11, 'max_features': 0.9554387499061564, 'bootstrap': False}.
# [I 2026-04-27 05:43:30,210] Trial 171 finished with values: [0.4615052509275739, 0.07467696895826284] and parameters: {'n_estimators': 245, 'max_depth': 40, 'min_samples_split': 40, 'min_samples_leaf': 20, 'max_features': 0.9633211875376595, 'bootstrap': False}.
# [I 2026-04-27 05:44:28,234] Trial 170 finished with values: [0.4539056605281466, 0.11902038195880975] and parameters: {'n_estimators': 243, 'max_depth': 35, 'min_samples_split': 23, 'min_samples_leaf': 11, 'max_features': 0.971418464953208, 'bootstrap': False}.
# [I 2026-04-27 05:44:39,527] Trial 172 finished with values: [0.46146149826927163, 0.07468339224643342] and parameters: {'n_estimators': 178, 'max_depth': 36, 'min_samples_split': 14, 'min_samples_leaf': 20, 'max_features': 0.9622059000685631, 'bootstrap': False}.
# [I 2026-04-27 05:44:51,553] Trial 186 finished with values: [0.4872203971230328, 0.03713123128049191] and parameters: {'n_estimators': 167, 'max_depth': 40, 'min_samples_split': 26, 'min_samples_leaf': 59, 'max_features': 0.81968441506657, 'bootstrap': False}.
# [I 2026-04-27 05:45:42,140] Trial 178 finished with values: [0.46185116295966794, 0.07496868130740998] and parameters: {'n_estimators': 174, 'max_depth': 40, 'min_samples_split': 24, 'min_samples_leaf': 20, 'max_features': 0.9732430141310828, 'bootstrap': False}.
# [I 2026-04-27 05:46:58,031] Trial 188 finished with values: [0.4699119915984129, 0.0555736106832377] and parameters: {'n_estimators': 181, 'max_depth': 40, 'min_samples_split': 23, 'min_samples_leaf': 31, 'max_features': 0.9766560452100657, 'bootstrap': False}.
# [I 2026-04-27 05:47:03,581] Trial 181 finished with values: [0.46226460918136497, 0.07216458662859727] and parameters: {'n_estimators': 190, 'max_depth': 40, 'min_samples_split': 16, 'min_samples_leaf': 21, 'max_features': 0.975090737006316, 'bootstrap': False}.
# ...
# [I 2026-04-27 06:03:27,677] Trial 242 finished with values: [0.4704034977456217, 0.06060625225830861] and parameters: {'n_estimators': 216, 'max_depth': 39, 'min_samples_split': 54, 'min_samples_leaf': 5, 'max_features': 0.5618107499497751, 'bootstrap': True}.
# [I 2026-04-27 06:03:31,627] Trial 244 finished with values: [0.47889818176843935, 0.044562322939935645] and parameters: {'n_estimators': 214, 'max_depth': 39, 'min_samples_split': 54, 'min_samples_leaf': 26, 'max_features': 0.7003051351809307, 'bootstrap': True}.
# [I 2026-04-27 06:03:49,759] Trial 241 finished with values: [0.49120047060544053, 0.038439950395444886] and parameters: {'n_estimators': 217, 'max_depth': 10, 'min_samples_split': 54, 'min_samples_leaf': 26, 'max_features': 0.9251038698613135, 'bootstrap': True}.
# [I 2026-04-27 06:03:54,258] Trial 239 finished with values: [0.4761573538887369, 0.04575041007961968] and parameters: {'n_estimators': 228, 'max_depth': 39, 'min_samples_split': 55, 'min_samples_leaf': 26, 'max_features': 0.9468457104202941, 'bootstrap': True}.
# [I 2026-04-27 06:04:29,147] Trial 251 finished with values: [0.5162992363021175, 0.029565339532862583] and parameters: {'n_estimators': 214, 'max_depth': 31, 'min_samples_split': 59, 'min_samples_leaf': 57, 'max_features': 0.3890154945873291, 'bootstrap': True}.
# [I 2026-04-27 06:04:38,199] Trial 218 finished with values: [0.46632627905980667, 0.061926423988485885] and parameters: {'n_estimators': 219, 'max_depth': 19, 'min_samples_split': 56, 'min_samples_leaf': 25, 'max_features': 0.9538079762507652, 'bootstrap': False}.
# [I 2026-04-27 06:04:51,494] Trial 252 finished with values: [0.5920322135285686, 0.02293699920380332] and parameters: {'n_estimators': 219, 'max_depth': 6, 'min_samples_split': 59, 'min_samples_leaf': 58, 'max_features': 0.9314370827029167, 'bootstrap': True}.
# [I 2026-04-27 06:05:05,439] Trial 258 finished with values: [0.6159117818967598, 0.025756464651165573] and parameters: {'n_estimators': 206, 'max_depth': 6, 'min_samples_split': 59, 'min_samples_leaf': 13, 'max_features': 0.39000161472485256, 'bootstrap': True}.
# [I 2026-04-27 06:05:15,383] Trial 248 finished with values: [0.4869776387989513, 0.04121965512791073] and parameters: {'n_estimators': 214, 'max_depth': 32, 'min_samples_split': 55, 'min_samples_leaf': 26, 'max_features': 0.3964339813753704, 'bootstrap': True}.
# [I 2026-04-27 06:05:23,283] Trial 253 finished with values: [0.5863071850267763, 0.0229356287701247] and parameters: {'n_estimators': 219, 'max_depth': 6, 'min_samples_split': 59, 'min_samples_leaf': 10, 'max_features': 0.9987946204119329, 'bootstrap': True}.
# [I 2026-04-27 06:05:45,771] Trial 237 finished with values: [0.4764169357586354, 0.04558062392595036] and parameters: {'n_estimators': 229, 'max_depth': 39, 'min_samples_split': 56, 'min_samples_leaf': 26, 'max_features': 0.9179207223358985, 'bootstrap': True}.
# [I 2026-04-27 06:06:02,897] Trial 262 finished with values: [0.6257551537789883, 0.027130051280840284] and parameters: {'n_estimators': 249, 'max_depth': 6, 'min_samples_split': 18, 'min_samples_leaf': 10, 'max_features': 0.3328952529840631, 'bootstrap': True}.
# [I 2026-04-27 06:06:20,979] Trial 259 finished with values: [0.5880320797009905, 0.022793265550102] and parameters: {'n_estimators': 209, 'max_depth': 6, 'min_samples_split': 59, 'min_samples_leaf': 14, 'max_features': 0.9657662193646388, 'bootstrap': True}.
# [I 2026-04-27 06:06:35,281] Trial 256 finished with values: [0.587965729701538, 0.02294667780099227] and parameters: {'n_estimators': 250, 'max_depth': 6, 'min_samples_split': 58, 'min_samples_leaf': 10, 'max_features': 0.9637220488709396, 'bootstrap': True}.
# [I 2026-04-27 06:06:50,218] Trial 257 finished with values: [0.6496055650745131, 0.021278200880361503] and parameters: {'n_estimators': 349, 'max_depth': 5, 'min_samples_split': 59, 'min_samples_leaf': 11, 'max_features': 0.9669038697259633, 'bootstrap': True}.
# [I 2026-04-27 06:07:01,702] Trial 249 finished with values: [0.47566009229275663, 0.0466070208143706] and parameters: {'n_estimators': 217, 'max_depth': 28, 'min_samples_split': 59, 'min_samples_leaf': 24, 'max_features': 0.9952602871087735, 'bootstrap': True}.
# [I 2026-04-27 06:07:07,133] Trial 260 finished with values: [0.5880477846030031, 0.02359013395379697] and parameters: {'n_estimators': 207, 'max_depth': 6, 'min_samples_split': 18, 'min_samples_leaf': 10, 'max_features': 0.9655140141694466, 'bootstrap': True}.
# [I 2026-04-27 06:07:37,920] Trial 250 finished with values: [0.4692171246512398, 0.058190646518889375] and parameters: {'n_estimators': 214, 'max_depth': 27, 'min_samples_split': 55, 'min_samples_leaf': 10, 'max_features': 0.9964269080146138, 'bootstrap': True}.
# [I 2026-04-27 06:07:39,563] Trial 265 finished with values: [0.6499003165049309, 0.021569023687271982] and parameters: {'n_estimators': 250, 'max_depth': 5, 'min_samples_split': 19, 'min_samples_leaf': 23, 'max_features': 0.963719684090563, 'bootstrap': True}.
# [I 2026-04-27 06:07:41,294] Trial 263 finished with values: [0.6503584551140872, 0.021491376606725926] and parameters: {'n_estimators': 250, 'max_depth': 5, 'min_samples_split': 18, 'min_samples_leaf': 24, 'max_features': 0.9691339071797744, 'bootstrap': True}.
# [I 2026-04-27 06:08:20,587] Trial 245 finished with values: [0.4698762163861555, 0.06209361279817423] and parameters: {'n_estimators': 390, 'max_depth': 39, 'min_samples_split': 55, 'min_samples_leaf': 5, 'max_features': 0.691728356731682, 'bootstrap': True}.
# [I 2026-04-27 06:08:36,934] Trial 255 finished with values: [0.47126285051155575, 0.05264773012755203] and parameters: {'n_estimators': 210, 'max_depth': 32, 'min_samples_split': 58, 'min_samples_leaf': 14, 'max_features': 0.963290123288644, 'bootstrap': True}.
# [I 2026-04-27 06:08:47,511] Trial 267 finished with values: [0.6505441419420308, 0.021507649942635126] and parameters: {'n_estimators': 272, 'max_depth': 5, 'min_samples_split': 58, 'min_samples_leaf': 11, 'max_features': 0.9662819481070151, 'bootstrap': True}.
# [I 2026-04-27 06:09:08,018] Trial 264 finished with values: [0.6489934905105004, 0.021267718463316904] and parameters: {'n_estimators': 250, 'max_depth': 5, 'min_samples_split': 18, 'min_samples_leaf': 11, 'max_features': 0.9666568923484121, 'bootstrap': True}.
# [I 2026-04-27 06:09:58,671] Trial 247 finished with values: [0.4762812195034773, 0.045283051900747495] and parameters: {'n_estimators': 348, 'max_depth': 26, 'min_samples_split': 59, 'min_samples_leaf': 26, 'max_features': 0.9983873926305267, 'bootstrap': True}.
# [I 2026-04-27 06:10:24,531] Trial 254 finished with values: [0.48596095846954634, 0.03763233900173556] and parameters: {'n_estimators': 214, 'max_depth': 32, 'min_samples_split': 59, 'min_samples_leaf': 37, 'max_features': 0.966127132109947, 'bootstrap': True}.
# [I 2026-04-27 06:11:05,944] Trial 266 finished with values: [0.6489502117284562, 0.021470322488224308] and parameters: {'n_estimators': 345, 'max_depth': 5, 'min_samples_split': 29, 'min_samples_leaf': 23, 'max_features': 0.9639613441314561, 'bootstrap': True}.
# [I 2026-04-27 06:11:33,503] Trial 275 finished with values: [0.5387792095828634, 0.026107253661436416] and parameters: {'n_estimators': 329, 'max_depth': 8, 'min_samples_split': 57, 'min_samples_leaf': 58, 'max_features': 0.6259623713053433, 'bootstrap': True}.
# [I 2026-04-27 06:11:36,129] Trial 271 finished with values: [0.517583994254829, 0.031016418947831692] and parameters: {'n_estimators': 273, 'max_depth': 8, 'min_samples_split': 19, 'min_samples_leaf': 23, 'max_features': 0.9680666925673745, 'bootstrap': True}.
# [I 2026-04-27 06:11:53,913] Trial 277 finished with values: [0.5413126722597753, 0.026268971612600528] and parameters: {'n_estimators': 312, 'max_depth': 8, 'min_samples_split': 45, 'min_samples_leaf': 58, 'max_features': 0.5825510613549578, 'bootstrap': True}.
# [I 2026-04-27 06:12:05,800] Trial 272 finished with values: [0.5182417654322407, 0.031046618619088556] and parameters: {'n_estimators': 276, 'max_depth': 8, 'min_samples_split': 58, 'min_samples_leaf': 22, 'max_features': 0.9898930320391385, 'bootstrap': True}.
# [I 2026-04-27 06:12:22,220] Trial 268 finished with values: [0.5013750380067203, 0.03045136117068009] and parameters: {'n_estimators': 309, 'max_depth': 28, 'min_samples_split': 57, 'min_samples_leaf': 58, 'max_features': 0.9636712698419218, 'bootstrap': True}.
# [I 2026-04-27 06:12:38,671] Trial 274 finished with values: [0.5219379869218527, 0.028684607411080337] and parameters: {'n_estimators': 330, 'max_depth': 8, 'min_samples_split': 58, 'min_samples_leaf': 37, 'max_features': 0.988357120472772, 'bootstrap': True}.
# [I 2026-04-27 06:12:52,117] Trial 270 finished with values: [0.5008133332452538, 0.030211131859994453] and parameters: {'n_estimators': 308, 'max_depth': 14, 'min_samples_split': 18, 'min_samples_leaf': 58, 'max_features': 0.9997387282323055, 'bootstrap': True}.
# [I 2026-04-27 06:13:38,985] Trial 269 finished with values: [0.4733316200508935, 0.048839620470305975] and parameters: {'n_estimators': 273, 'max_depth': 15, 'min_samples_split': 19, 'min_samples_leaf': 23, 'max_features': 0.9684946617383933, 'bootstrap': True}.
# [I 2026-04-27 06:13:42,729] Trial 278 finished with values: [0.5308167333104258, 0.02615657362763972] and parameters: {'n_estimators': 311, 'max_depth': 8, 'min_samples_split': 29, 'min_samples_leaf': 58, 'max_features': 0.9337219556910954, 'bootstrap': True}.
# [I 2026-04-27 06:14:24,346] Trial 276 finished with values: [0.5017393728343229, 0.029917365214061603] and parameters: {'n_estimators': 268, 'max_depth': 34, 'min_samples_split': 46, 'min_samples_leaf': 58, 'max_features': 0.938356406062016, 'bootstrap': True}.
# [I 2026-04-27 06:15:06,186] Trial 273 finished with values: [0.5008542768765377, 0.03047227498139113] and parameters: {'n_estimators': 326, 'max_depth': 21, 'min_samples_split': 57, 'min_samples_leaf': 58, 'max_features': 0.9879936628021515, 'bootstrap': True}.
# [I 2026-04-27 06:15:32,223] Trial 281 finished with values: [0.5275744401027757, 0.031107703936832307] and parameters: {'n_estimators': 326, 'max_depth': 8, 'min_samples_split': 47, 'min_samples_leaf': 22, 'max_features': 0.5792628094542197, 'bootstrap': True}.
# [I 2026-04-27 06:16:21,487] Trial 279 finished with values: [0.5308167333104258, 0.02615657362763972] and parameters: {'n_estimators': 311, 'max_depth': 8, 'min_samples_split': 47, 'min_samples_leaf': 58, 'max_features': 0.9347884380879632, 'bootstrap': True}.
# [I 2026-04-27 06:16:31,934] Trial 280 finished with values: [0.5014076050501718, 0.030546604608472486] and parameters: {'n_estimators': 298, 'max_depth': 34, 'min_samples_split': 29, 'min_samples_leaf': 57, 'max_features': 0.9324893406647587, 'bootstrap': True}.
# [I 2026-04-27 06:16:51,472] Trial 282 finished with values: [0.5068119560715977, 0.029833790180346986] and parameters: {'n_estimators': 263, 'max_depth': 21, 'min_samples_split': 56, 'min_samples_leaf': 58, 'max_features': 0.6320255418294998, 'bootstrap': True}.
# [I 2026-04-27 06:17:36,169] Trial 283 finished with values: [0.5303669645014626, 0.026011345938526886] and parameters: {'n_estimators': 361, 'max_depth': 8, 'min_samples_split': 46, 'min_samples_leaf': 58, 'max_features': 0.9357180453002238, 'bootstrap': True}.
# [I 2026-04-27 06:18:03,520] Trial 261 finished with values: [0.47017760630777344, 0.05629598348419518] and parameters: {'n_estimators': 350, 'max_depth': 27, 'min_samples_split': 58, 'min_samples_leaf': 10, 'max_features': 0.9673823519035187, 'bootstrap': True}.
# [I 2026-04-27 06:19:40,193] Trial 284 finished with values: [0.48679844926791604, 0.03738497668895968] and parameters: {'n_estimators': 263, 'max_depth': 14, 'min_samples_split': 56, 'min_samples_leaf': 59, 'max_features': 0.9341064885118922, 'bootstrap': False}.
# [I 2026-04-27 06:20:38,127] Trial 296 finished with values: [0.4936271613904776, 0.036515449083669674] and parameters: {'n_estimators': 224, 'max_depth': 38, 'min_samples_split': 56, 'min_samples_leaf': 56, 'max_features': 0.47187077032136926, 'bootstrap': False}.
# [I 2026-04-27 06:20:42,826] Trial 289 finished with values: [0.481490711860644, 0.04104860373915993] and parameters: {'n_estimators': 283, 'max_depth': 34, 'min_samples_split': 52, 'min_samples_leaf': 50, 'max_features': 0.9307369284065076, 'bootstrap': False}.
# [I 2026-04-27 06:20:52,387] Trial 286 finished with values: [0.4814023186117039, 0.04096600867938084] and parameters: {'n_estimators': 265, 'max_depth': 21, 'min_samples_split': 56, 'min_samples_leaf': 50, 'max_features': 0.9347522791715952, 'bootstrap': False}.
# [I 2026-04-27 06:20:57,153] Trial 288 finished with values: [0.4702638921639665, 0.05330686068973167] and parameters: {'n_estimators': 282, 'max_depth': 21, 'min_samples_split': 52, 'min_samples_leaf': 32, 'max_features': 0.938871882411301, 'bootstrap': False}.
# [I 2026-04-27 06:20:59,664] Trial 287 finished with values: [0.4672281514523481, 0.06019614138861183] and parameters: {'n_estimators': 284, 'max_depth': 35, 'min_samples_split': 48, 'min_samples_leaf': 27, 'max_features': 0.9349578403842436, 'bootstrap': False}.
# [I 2026-04-27 06:21:09,636] Trial 285 finished with values: [0.4650823690068619, 0.06498957433209979] and parameters: {'n_estimators': 264, 'max_depth': 33, 'min_samples_split': 56, 'min_samples_leaf': 22, 'max_features': 0.9344348279059203, 'bootstrap': False}.
# [I 2026-04-27 06:21:38,067] Trial 293 finished with values: [0.4822204027469461, 0.040997239756653314] and parameters: {'n_estimators': 222, 'max_depth': 33, 'min_samples_split': 56, 'min_samples_leaf': 50, 'max_features': 0.8986397233619472, 'bootstrap': False}.
# [I 2026-04-27 06:21:44,210] Trial 291 finished with values: [0.48153062923440637, 0.04109016218844787] and parameters: {'n_estimators': 265, 'max_depth': 34, 'min_samples_split': 56, 'min_samples_leaf': 50, 'max_features': 0.9392472974037119, 'bootstrap': False}.
# [I 2026-04-27 06:21:54,382] Trial 297 finished with values: [0.47504360917848404, 0.05232443492931818] and parameters: {'n_estimators': 224, 'max_depth': 38, 'min_samples_split': 53, 'min_samples_leaf': 28, 'max_features': 0.46647125684595026, 'bootstrap': False}.
# [I 2026-04-27 06:22:43,461] Trial 290 finished with values: [0.4677493224325258, 0.05847938932142194] and parameters: {'n_estimators': 296, 'max_depth': 38, 'min_samples_split': 56, 'min_samples_leaf': 28, 'max_features': 0.9387409748307332, 'bootstrap': False}.
# [I 2026-04-27 06:22:46,875] Trial 292 finished with values: [0.4705961696714399, 0.05372341493247974] and parameters: {'n_estimators': 282, 'max_depth': 21, 'min_samples_split': 56, 'min_samples_leaf': 32, 'max_features': 0.9453820290688207, 'bootstrap': False}.
# [I 2026-04-27 06:23:40,052] Trial 298 finished with values: [0.460425954631718, 0.08508725533080208] and parameters: {'n_estimators': 236, 'max_depth': 38, 'min_samples_split': 52, 'min_samples_leaf': 9, 'max_features': 0.9502980995052902, 'bootstrap': False}.
# [I 2026-04-27 06:23:46,810] Trial 294 finished with values: [0.46777722188652093, 0.05806038633533277] and parameters: {'n_estimators': 283, 'max_depth': 33, 'min_samples_split': 52, 'min_samples_leaf': 28, 'max_features': 0.8980517793721767, 'bootstrap': False}.
# [I 2026-04-27 06:24:06,061] Trial 295 finished with values: [0.4677507256177717, 0.05870419103598208] and parameters: {'n_estimators': 283, 'max_depth': 33, 'min_samples_split': 51, 'min_samples_leaf': 28, 'max_features': 0.947631683931081, 'bootstrap': False}.
# [I 2026-04-27 06:24:10,462] Trial 299 finished with values: [0.46006506480345044, 0.08387493105068539] and parameters: {'n_estimators': 238, 'max_depth': 38, 'min_samples_split': 53, 'min_samples_leaf': 9, 'max_features': 0.9482983726113774, 'bootstrap': False}.

# %% [markdown]
# #### 6.3.2 Sélection du meilleur essai Optuna et évaluation du modèle ExtraTreesRegressor
#
# Après l'optimisation, l'étude Optuna est rechargée afin de sélectionner le meilleur compromis parmi les essais du front de Pareto.
#
# Le modèle ExtraTreesRegressor retenu est ensuite entraîné sur l'ensemble `train`, puis évalué sur les ensembles `train` et `valid`.
#
# Les métriques obtenues sont ajoutées au tableau global des résultats afin de comparer ExtraTreesRegressor aux modèles précédents.

# %%
# ===========================================================
# Sélection du meilleur essai Optuna et évaluation ExtraTrees
# ===========================================================

# Copie des ensembles utilisés pour ExtraTreesRegressor
X_train_etr = X_train.copy()
X_valid_etr = X_valid.copy()

# Chargement de l'étude Optuna déjà optimisée
study_etr = optuna.load_study(
    study_name="study_etr",
    storage=f"sqlite:///{filepath_output}study_etr.db"
)


# ==============================================
# Sélection du meilleur essai du front de Pareto
# ==============================================

# Optuna retourne plusieurs meilleurs essais car l'étude est multi-objective
etr_trials = study_etr.best_trials

# Choix d'un compromis :
# - faible MAE moyenne en validation croisée temporelle
# - pénalité si le gap relatif dépasse 4 %
best_trial_etr = min(
    etr_trials,
    key=lambda t: t.values[0] + 50 * max(0, (t.values[1] / t.values[0]) - 0.04)
)

print("Selected trial:")
print(f"MAE = {best_trial_etr.values[0]}")
print(f"GAP = {best_trial_etr.values[1]}")


# ==========================================
# Récupération des meilleurs hyperparamètres
# ==========================================

# Copie des paramètres pour éviter de modifier directement l'objet Optuna
best_params_etr = best_trial_etr.params.copy()

best_params_etr = {'n_estimators': 50, 'max_depth': None, 'min_samples_split': 2, 
 'min_samples_leaf': 150, 'max_features': 1.0, 'bootstrap': False}
# min_samples_leaf réduit l'overfitting quand il est grand

print("Best_params_etr:", best_params_etr)

# =======================================
# Entraînement du modèle ExtraTrees final
# =======================================

best_model_etr = ExtraTreesRegressor(
    random_state=42,
    n_jobs=-1,
    **best_params_etr
)

# Entraînement sur l'ensemble train
best_model_etr.fit(X_train_etr, y_train)


# ==================================
# Évaluation sur train et validation
# ==================================

# Prédictions
y_pred_train_etr = best_model_etr.predict(X_train_etr)
y_pred_valid_etr = best_model_etr.predict(X_valid_etr)

# Métriques train
mae_train_etr = mean_absolute_error(y_train, y_pred_train_etr)
rmse_train_etr = np.sqrt(mean_squared_error(y_train, y_pred_train_etr))
r2_train_etr = r2_score(y_train, y_pred_train_etr)
nmae_train_etr = calculer_nmae(y_train, y_pred_train_etr)

# Métriques validation
mae_valid_etr = mean_absolute_error(y_valid, y_pred_valid_etr)
rmse_valid_etr = np.sqrt(mean_squared_error(y_valid, y_pred_valid_etr))
r2_valid_etr = r2_score(y_valid, y_pred_valid_etr)
nmae_valid_etr = calculer_nmae(y_valid, y_pred_valid_etr)

# Pourcentage d'overfitting final
overfit_pct_etr = (
    100 * max(0, mae_valid_etr - mae_train_etr) / mae_valid_etr
    if mae_valid_etr != 0 else np.nan
)


# =======================
# Affichage des résultats
# =======================

print("\n--- Résultats ExtraTreesRegressor ---")

print(f"MAE valid_etr      : {mae_valid_etr}")
print(f"MAE train_etr      : {mae_train_etr}")

print(f"NMAE valid_etr     : {nmae_valid_etr:.3f} %")
print(f"NMAE train_etr     : {nmae_train_etr:.3f} %")

print(f"RMSE valid_etr     : {rmse_valid_etr}")
print(f"RMSE train_etr     : {rmse_train_etr}")

print(f"R² valid_etr       : {r2_valid_etr}")
print(f"R² train_etr       : {r2_train_etr}")

print(f"Overfitting CV     : {best_trial_etr.user_attrs['overfit_gap_pct']:.2f} %")
print(f"Overfitting final  : {overfit_pct_etr:.2f} %")

# MAE moyenne obtenue pendant la validation croisée temporelle
MAE_CV_moyenne_etr = best_trial_etr.user_attrs["mean_mae_valid"]

print("MAE_CV_moyenne_etr:", MAE_CV_moyenne_etr)


# =====================================
# Ajout au tableau global des résultats
# =====================================

# Supprimer une ancienne ligne ExtraTrees si elle existe déjà
resultats = [
    r for r in resultats
    if r["Modèle"] != "ExtraTreesRegressor"
]

# Ajout du modèle ExtraTrees au tableau global
resultats.append(
    calculer_metriques(
        y_train,
        y_pred_train_etr,
        y_valid,
        y_pred_valid_etr,
        nom_modele="ExtraTreesRegressor",
        MAE_CV_moyenne=MAE_CV_moyenne_etr
    )
)

# Tableau comparatif final, trié par performance sur validation
resultats_df = pd.DataFrame(resultats).sort_values("MAE_valid")

display(resultats_df)
# Out:
# Selected trial:
# MAE = 0.5860672536803978
# GAP = 0.022831855314240285
# Best_params_etr: {'n_estimators': 212, 'max_depth': 6, 'min_samples_split': 34, 'min_samples_leaf': 22, 'max_features': 0.9995909926895663, 'bootstrap': True}
#
# --- Résultats ExtraTreesRegressor ---
# MAE valid_etr      : 0.5285991369767822
# MAE train_etr      : 0.46846633530406057
# NMAE valid_etr     : 21.959 %
# NMAE train_etr     : 19.189 %
# RMSE valid_etr     : 1.1453712629471795
# RMSE train_etr     : 0.980194970977033
# R² valid_etr       : 0.8782584954797525
# R² train_etr       : 0.9122909245564013
# Overfitting CV     : 3.87 %
# Overfitting final  : 11.38 %
# MAE_CV_moyenne_etr: 0.5860672536803978
#                             Modèle  MAE_train  NMAE_train (%)  RMSE_train  \
# 5                    LGBMRegressor       0.45           18.56        0.94
# 7              ExtraTreesRegressor       0.47           19.19        0.98
# 6                     XGBRegressor       0.49           20.01        0.98
# 4                            Lasso       0.72           29.44        1.21
# 3                            Ridge       0.72           29.42        1.20
# 2  Régression linéaire multivariée       0.72           29.62        1.18
# 0                             Naïf       0.95           38.84        1.66
# 1       Régression linéaire simple       1.05           43.05        1.88
#
#    R2_train  MAE_valid  NMAE_valid (%)  RMSE_valid  R2_valid  MAE_CV_moyenne  \
# 5      0.92       0.52           21.59        1.14      0.88            0.49
# 7      0.91       0.53           21.96        1.15      0.88            0.59
# 6      0.91       0.55           22.67        1.16      0.88            0.51
# 4      0.87       0.76           31.41        1.34      0.83            0.73
# 3      0.87       0.76           31.53        1.34      0.83            0.73
# 2      0.87       0.76           31.75        1.33      0.84             NaN
# 0      0.75       0.98           40.69        1.78      0.71             NaN
# 1      0.68       1.11           45.96        2.00      0.63             NaN
#
#    Gap_MAE_valid_train  Gap_R2_train_valid
# 5                 0.07                0.04
# 7                 0.06                0.03
# 6                 0.06                0.04
# 4                 0.04                0.03
# 3                 0.04                0.04
# 2                 0.04                0.04
# 0                 0.03                0.04
# 1                 0.06                0.05

# %%
# =========================================================
# Sauvegarde et rechargement du meilleur modèle ExtraTrees
# =========================================================

# Chemin complet du fichier de sauvegarde
model_path_etr = best_models_path + "best_model_etr.joblib"

# Sauvegarde du meilleur modèle ExtraTrees entraîné
joblib.dump(best_model_etr, model_path_etr)

print("Modèle ExtraTrees sauvegardé dans :", model_path_etr)

# Rechargement du modèle sauvegardé
best_model_etr = joblib.load(model_path_etr)

print("Modèle ExtraTrees rechargé avec succès.")
# Out:
# Modèle ExtraTrees sauvegardé dans : /Users/mibrahim/Desktop/Varaiability/data/local_data/05_Modelisation/output/output_jour_nuit/Best_Models/best_model_etr.joblib
# Modèle ExtraTrees rechargé avec succès.

# %% [markdown]
# #### 6.3.3 Visualisation des prédictions Extratrees

# %%
# ==============================================================
# Visualisation : valeurs réelles vs valeurs prédites Extratrees
# ==============================================================

# Cette cellule compare les valeurs réelles de la cible avec les prédictions
# du modèle Extratrees sur l'ensemble de validation.

plt.figure(figsize=(6, 6))

# Nuage de points :
# axe x : valeurs réelles
# axe y : valeurs prédites par Extratrees
plt.scatter(y_valid, y_pred_valid_etr, alpha=0.5)

# Ligne idéale y = x
# Si les prédictions étaient parfaites, tous les points seraient sur cette ligne
min_val = min(y_valid.min(), y_pred_valid_etr.min())
max_val = max(y_valid.max(), y_pred_valid_etr.max())

plt.plot(
    [min_val, max_val],
    [min_val, max_val],
    "r--",
    label="Prédiction parfaite"
)

# Titres et labels
plt.xlabel("Valeurs réelles")
plt.ylabel("Valeurs prédites")
plt.title("ExtraTrees - Valeurs réelles vs valeurs prédites sur validation")

# Légende
plt.legend()

# Affichage
plt.show()

# %% [markdown]
# Le modèle `ExtraTreesRegressor` final présente un bon compromis entre performance et généralisation.
#
# Après régularisation et optimisation des hyperparamètres avec Optuna :
#
# - l'overfitting a été significativement réduit (écart train / validation plus faible),
# - la performance en validation reste stable (R² ≈ 0.885),
# - le modèle est désormais plus robuste et moins sensible aux variations des données.
#
# Le modèle final est donc fiable pour la prédiction, avec une bonne capacité de généralisation sans sur-apprentissage excessif.

# %% [markdown]
# ### 6.4 RandomForestRegressor
#
# RandomForestRegressor est un modèle d'ensemble basé sur plusieurs arbres de décision.
#
# Contrairement à ExtraTreesRegressor, les arbres d'une forêt aléatoire sont construits à partir de sous-échantillons des données, avec une sélection aléatoire de variables à chaque division.
# Cette diversité entre les arbres permet de réduire la variance et d'obtenir un modèle généralement robuste.
#
# Ce modèle est intéressant dans ce contexte, car il peut capturer des relations non linéaires et des interactions entre les variables météorologiques, temporelles et régionales.
#
# Cependant, RandomForestRegressor peut surapprendre si les arbres sont trop profonds ou si les paramètres de régularisation, comme `min_samples_leaf`, `min_samples_split` ou `max_depth`, ne sont pas suffisamment contrôlés.
#
# L'objectif est donc de vérifier si RandomForestRegressor constitue une alternative robuste aux modèles précédents, notamment ExtraTreesRegressor, LightGBM et XGBoost.

# %% [markdown]
# #### 6.4.1 Optimisation des hyperparamètres RandomForestRegressor avec Optuna
#
# RandomForestRegressor est optimisé avec Optuna en utilisant les folds temporels définis manuellement.
#
# Comme pour les modèles précédents, la sélection repose sur la MAE moyenne de validation croisée temporelle et sur le contrôle du gap train/validation.

# %%
# =============
# RANDOM FOREST
# =============

# Copie des ensembles utilisés pour RandomForestRegressor
X_train_rf = X_train.copy()
X_valid_rf = X_valid.copy()


# ===========================================================
# Évaluation d'une combinaison d'hyperparamètres RandomForest
# ===========================================================

def evaluate_params_rf(params, X, y, trial=None):

    # Listes pour stocker les métriques de chaque fold
    maes_valid = []
    maes_train = []

    rmses_valid = []
    rmses_train = []

    r2_trains = []
    r2_valids = []

    gaps = []

    # Génération des folds temporels manuels
    folds = get_folds(X, y)

    # Boucle sur les folds
    for step, (X_tr, X_v, y_tr, y_v) in enumerate(folds):

        # Création du modèle avec les paramètres proposés par Optuna
        model = RandomForestRegressor(**params)

        # Entraînement sur la période passée du fold
        model.fit(X_tr, y_tr)

        # Prédictions sur train et validation du fold
        pred_train = model.predict(X_tr)
        pred_valid = model.predict(X_v)

        # MAE train et validation
        mae_train = mean_absolute_error(y_tr, pred_train)
        mae_valid = mean_absolute_error(y_v, pred_valid)

        # RMSE train et validation
        rmse_train = np.sqrt(mean_squared_error(y_tr, pred_train))
        rmse_valid = np.sqrt(mean_squared_error(y_v, pred_valid))

        # R² train et validation
        r2_train = r2_score(y_tr, pred_train)
        r2_valid = r2_score(y_v, pred_valid)

        # Gap train-validation
        # Un grand gap peut indiquer un surapprentissage
        gap = max(0, mae_valid - mae_train)

        # Stockage des métriques
        maes_train.append(mae_train)
        maes_valid.append(mae_valid)

        rmses_train.append(rmse_train)
        rmses_valid.append(rmse_valid)

        r2_trains.append(r2_train)
        r2_valids.append(r2_valid)

        gaps.append(gap)

    # Moyennes des métriques sur tous les folds
    mean_mae_valid = np.mean(maes_valid)
    mean_mae_train = np.mean(maes_train)

    std_mae_valid = np.std(maes_valid)
    std_mae_train = np.std(maes_train)

    mean_rmse_valid = np.mean(rmses_valid)
    mean_rmse_train = np.mean(rmses_train)

    mean_r2_valid = np.mean(r2_valids)
    mean_r2_train = np.mean(r2_trains)

    mean_gap = np.mean(gaps)

    # Pourcentage d'overfitting
    gap_pct = (
        100 * max(0, mean_mae_valid - mean_mae_train) / mean_mae_valid
        if mean_mae_valid != 0 else np.nan
    )

    # Sauvegarde des informations utiles dans Optuna
    if trial is not None:
        trial.set_user_attr("mean_mae_valid", mean_mae_valid)
        trial.set_user_attr("mean_mae_train", mean_mae_train)

        trial.set_user_attr("std_mae_valid", std_mae_valid)
        trial.set_user_attr("std_mae_train", std_mae_train)

        trial.set_user_attr("mean_rmse_valid", mean_rmse_valid)
        trial.set_user_attr("mean_rmse_train", mean_rmse_train)

        trial.set_user_attr("mean_r2_valid", mean_r2_valid)
        trial.set_user_attr("mean_r2_train", mean_r2_train)

        trial.set_user_attr("mean_gap", mean_gap)
        trial.set_user_attr("std_gap", np.std(gaps))
        trial.set_user_attr("max_gap", np.max(gaps))
        trial.set_user_attr("overfit_gap_pct", gap_pct)

    # Optuna minimise ces deux objectifs
    return mean_mae_valid, mean_gap

# ====================================================
# Fonction objective Optuna pour RandomForestRegressor
# ====================================================

def objective_rf(trial):

    params = {
        # Nombre d'arbres dans la forêt
        "n_estimators": trial.suggest_int("n_estimators", 100, 400),

        # Profondeur maximale des arbres
        "max_depth": trial.suggest_int("max_depth", 5, 30),

        # Nombre minimum d'échantillons nécessaires pour diviser un nœud
        "min_samples_split": trial.suggest_int("min_samples_split", 10, 30),

        # Nombre minimum d'échantillons dans une feuille
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 5, 50),

        # Fraction des variables utilisées à chaque division
        "max_features": trial.suggest_float("max_features", 0.2, 0.7),

        # RandomForest utilise ici le bootstrap
        "bootstrap": True,

        # Fraction des observations utilisées dans chaque échantillon bootstrap
        "max_samples": trial.suggest_float("max_samples", 0.5, 1.0),

        "random_state": 42,
        "n_jobs": 1
    }

    return evaluate_params_rf(
        params=params,
        X=X_dev,
        y=y_dev,
        trial=trial
    )

# =========================================================
# Création et lancement de l'étude Optuna pour RandomForest
# =========================================================

study_rf = optuna.create_study(
    study_name="study_rf_new",
    storage=f"sqlite:///{filepath_output}study_rf_new.db",
    load_if_exists=True,
    directions=["minimize", "minimize"],
    sampler=optuna.samplers.TPESampler(
        n_startup_trials=60,
        seed=42
    )
)

# Lancement de l'optimisation
study_rf.optimize(
    objective_rf,
    n_trials=300,
    n_jobs=-1
)
# Out:
# [I 2026-04-27 14:07:18,524] A new study created in RDB with name: study_rf_new
# [I 2026-04-27 14:10:14,402] Trial 3 finished with values: [0.6094337897911345, 0.025306006760483335] and parameters: {'n_estimators': 124, 'max_depth': 5, 'min_samples_split': 16, 'min_samples_leaf': 33, 'max_features': 0.4140163772912422, 'max_samples': 0.8956068466531935}.
# [I 2026-04-27 14:10:43,852] Trial 7 finished with values: [0.4974493595023902, 0.04034375560988791] and parameters: {'n_estimators': 179, 'max_depth': 27, 'min_samples_split': 17, 'min_samples_leaf': 47, 'max_features': 0.21180971504704016, 'max_samples': 0.5468237702740466}.
# [I 2026-04-27 14:10:44,571] Trial 9 finished with values: [0.5391266860696373, 0.03552253184575213] and parameters: {'n_estimators': 230, 'max_depth': 7, 'min_samples_split': 22, 'min_samples_leaf': 41, 'max_features': 0.20035948356304562, 'max_samples': 0.752650523346265}.
# [I 2026-04-27 14:13:22,883] Trial 13 finished with values: [0.508086289388113, 0.04367951700004477] and parameters: {'n_estimators': 364, 'max_depth': 8, 'min_samples_split': 17, 'min_samples_leaf': 16, 'max_features': 0.2569829864739816, 'max_samples': 0.5371910296243919}.
# [I 2026-04-27 14:13:40,469] Trial 10 finished with values: [0.6133213886362582, 0.024967381906763897] and parameters: {'n_estimators': 376, 'max_depth': 5, 'min_samples_split': 13, 'min_samples_leaf': 48, 'max_features': 0.2974493691806377, 'max_samples': 0.520059576671201}.
# [I 2026-04-27 14:14:16,379] Trial 2 finished with values: [0.465184433853869, 0.09024812253332287] and parameters: {'n_estimators': 108, 'max_depth': 14, 'min_samples_split': 30, 'min_samples_leaf': 12, 'max_features': 0.6186701217473198, 'max_samples': 0.6632235182954237}.
# [I 2026-04-27 14:14:22,336] Trial 1 finished with values: [0.48201164362756943, 0.05399328208857265] and parameters: {'n_estimators': 120, 'max_depth': 20, 'min_samples_split': 22, 'min_samples_leaf': 40, 'max_features': 0.5535161484047099, 'max_samples': 0.809397981478857}.
# [I 2026-04-27 14:14:24,210] Trial 11 finished with values: [0.48032779554724747, 0.053354271151979715] and parameters: {'n_estimators': 134, 'max_depth': 21, 'min_samples_split': 17, 'min_samples_leaf': 34, 'max_features': 0.3796288881206371, 'max_samples': 0.669178282554762}.
# [I 2026-04-27 14:14:44,933] Trial 18 finished with values: [0.477325907515119, 0.05592282492880882] and parameters: {'n_estimators': 118, 'max_depth': 27, 'min_samples_split': 10, 'min_samples_leaf': 27, 'max_features': 0.31229657035699127, 'max_samples': 0.5870618947339331}.
# [I 2026-04-27 14:15:08,209] Trial 16 finished with values: [0.4900606834444251, 0.04414466938840084] and parameters: {'n_estimators': 280, 'max_depth': 23, 'min_samples_split': 16, 'min_samples_leaf': 37, 'max_features': 0.2416703566401004, 'max_samples': 0.5114799620228166}.
# [I 2026-04-27 14:16:38,536] Trial 5 finished with values: [0.4572045853574139, 0.13451930227558875] and parameters: {'n_estimators': 252, 'max_depth': 16, 'min_samples_split': 17, 'min_samples_leaf': 5, 'max_features': 0.2526923576887023, 'max_samples': 0.7895475262045049}.
# [I 2026-04-27 14:17:31,072] Trial 15 finished with values: [0.4688050436227331, 0.07231323609856806] and parameters: {'n_estimators': 164, 'max_depth': 21, 'min_samples_split': 19, 'min_samples_leaf': 16, 'max_features': 0.47257040547272583, 'max_samples': 0.5061312661489303}.
# [I 2026-04-27 14:19:14,115] Trial 19 finished with values: [0.48692409144330845, 0.04807730536817123] and parameters: {'n_estimators': 207, 'max_depth': 27, 'min_samples_split': 14, 'min_samples_leaf': 44, 'max_features': 0.21021756734411357, 'max_samples': 0.79128546292629}.
# [I 2026-04-27 14:20:01,344] Trial 4 finished with values: [0.46123888106827526, 0.1022456851889973] and parameters: {'n_estimators': 265, 'max_depth': 26, 'min_samples_split': 23, 'min_samples_leaf': 8, 'max_features': 0.4981926529453298, 'max_samples': 0.5572458815607145}.
# [I 2026-04-27 14:20:14,362] Trial 17 finished with values: [0.5048843762820969, 0.04416570684181752] and parameters: {'n_estimators': 164, 'max_depth': 8, 'min_samples_split': 16, 'min_samples_leaf': 22, 'max_features': 0.4294691276903282, 'max_samples': 0.7083234942915702}.
# [I 2026-04-27 14:21:22,665] Trial 6 finished with values: [0.4652238983853445, 0.09236844989891084] and parameters: {'n_estimators': 255, 'max_depth': 12, 'min_samples_split': 25, 'min_samples_leaf': 7, 'max_features': 0.31133153646598094, 'max_samples': 0.786272295897039}.
# [I 2026-04-27 14:22:15,959] Trial 26 finished with values: [0.4738251780822403, 0.06194419331389328] and parameters: {'n_estimators': 166, 'max_depth': 15, 'min_samples_split': 27, 'min_samples_leaf': 25, 'max_features': 0.23465884632852163, 'max_samples': 0.7155260438108255}.
# [I 2026-04-27 14:22:28,696] Trial 12 finished with values: [0.5027983106335054, 0.049410371526876204] and parameters: {'n_estimators': 299, 'max_depth': 8, 'min_samples_split': 14, 'min_samples_leaf': 15, 'max_features': 0.5649412382566799, 'max_samples': 0.869533541746117}.
# [I 2026-04-27 14:22:49,729] Trial 21 finished with values: [0.47760977609925814, 0.05655543012425018] and parameters: {'n_estimators': 284, 'max_depth': 25, 'min_samples_split': 21, 'min_samples_leaf': 32, 'max_features': 0.2655831430483202, 'max_samples': 0.7546289893824268}.
# [I 2026-04-27 14:23:22,956] Trial 0 finished with values: [0.47740472924644795, 0.0558953117373881] and parameters: {'n_estimators': 222, 'max_depth': 24, 'min_samples_split': 24, 'min_samples_leaf': 30, 'max_features': 0.4764566110815953, 'max_samples': 0.6333191792748569}.
# [I 2026-04-27 14:29:08,196] Trial 22 finished with values: [0.49023662415629143, 0.0441148733202172] and parameters: {'n_estimators': 316, 'max_depth': 14, 'min_samples_split': 14, 'min_samples_leaf': 49, 'max_features': 0.47597124417665543, 'max_samples': 0.6801881968526746}.
# [I 2026-04-27 14:30:05,584] Trial 34 finished with values: [0.4904749517746126, 0.044718879348693494] and parameters: {'n_estimators': 241, 'max_depth': 23, 'min_samples_split': 23, 'min_samples_leaf': 49, 'max_features': 0.27437299870809373, 'max_samples': 0.7129783360291162}.
# [I 2026-04-27 14:30:11,209] Trial 14 finished with values: [0.46706773698461806, 0.07531079155271286] and parameters: {'n_estimators': 292, 'max_depth': 13, 'min_samples_split': 14, 'min_samples_leaf': 20, 'max_features': 0.4027148026326617, 'max_samples': 0.8295526618829643}.
# [I 2026-04-27 14:30:47,635] Trial 29 finished with values: [0.4594463582178966, 0.1272722270950993] and parameters: {'n_estimators': 127, 'max_depth': 30, 'min_samples_split': 10, 'min_samples_leaf': 10, 'max_features': 0.6070074065439128, 'max_samples': 0.8056817952403974}.
# [I 2026-04-27 14:32:33,839] Trial 31 finished with values: [0.4796839116747265, 0.05370385579153128] and parameters: {'n_estimators': 139, 'max_depth': 23, 'min_samples_split': 28, 'min_samples_leaf': 35, 'max_features': 0.4277650790503038, 'max_samples': 0.7109324128477275}.
# [I 2026-04-27 14:35:19,481] Trial 38 finished with values: [0.48885771242520776, 0.04596376918518491] and parameters: {'n_estimators': 130, 'max_depth': 19, 'min_samples_split': 21, 'min_samples_leaf': 41, 'max_features': 0.23507837630287792, 'max_samples': 0.639937183028251}.
# [I 2026-04-27 14:36:38,282] Trial 28 finished with values: [0.4959821601926827, 0.042901963663757134] and parameters: {'n_estimators': 319, 'max_depth': 9, 'min_samples_split': 18, 'min_samples_leaf': 38, 'max_features': 0.5175130878376897, 'max_samples': 0.6632410365254302}.
# [I 2026-04-27 14:36:48,732] Trial 27 finished with values: [0.46641628241443905, 0.08150964734807005] and parameters: {'n_estimators': 203, 'max_depth': 29, 'min_samples_split': 14, 'min_samples_leaf': 14, 'max_features': 0.589239285832446, 'max_samples': 0.5275598021492075}.
# [I 2026-04-27 14:37:23,814] Trial 25 finished with values: [0.472093688600161, 0.06569898574170495] and parameters: {'n_estimators': 319, 'max_depth': 29, 'min_samples_split': 10, 'min_samples_leaf': 30, 'max_features': 0.5201740219587112, 'max_samples': 0.8938733454856818}.
# [I 2026-04-27 14:37:25,363] Trial 36 finished with values: [0.4632894493796555, 0.09188648446338236] and parameters: {'n_estimators': 158, 'max_depth': 23, 'min_samples_split': 17, 'min_samples_leaf': 13, 'max_features': 0.4751169919370911, 'max_samples': 0.6210079254078851}.
# [I 2026-04-27 14:37:31,262] Trial 35 finished with values: [0.47088293642391654, 0.07261888652215594] and parameters: {'n_estimators': 103, 'max_depth': 27, 'min_samples_split': 25, 'min_samples_leaf': 27, 'max_features': 0.5760496918780715, 'max_samples': 0.937094864771619}.
# [I 2026-04-27 14:38:50,657] Trial 39 finished with values: [0.5119813067372422, 0.03751657564366627] and parameters: {'n_estimators': 184, 'max_depth': 8, 'min_samples_split': 23, 'min_samples_leaf': 45, 'max_features': 0.5787746672843319, 'max_samples': 0.6446931194009331}.
# [I 2026-04-27 14:39:15,563] Trial 8 finished with values: [0.47177705752359267, 0.06516797813145268] and parameters: {'n_estimators': 367, 'max_depth': 26, 'min_samples_split': 30, 'min_samples_leaf': 28, 'max_features': 0.42536499286382157, 'max_samples': 0.8207207857407188}.
# [I 2026-04-27 14:40:40,737] Trial 24 finished with values: [0.4782801811670739, 0.05651240952158046] and parameters: {'n_estimators': 370, 'max_depth': 29, 'min_samples_split': 27, 'min_samples_leaf': 26, 'max_features': 0.648917670996884, 'max_samples': 0.5221758222476722}.
# [I 2026-04-27 14:40:47,056] Trial 40 finished with values: [0.5122383271918358, 0.03661855101367105] and parameters: {'n_estimators': 102, 'max_depth': 8, 'min_samples_split': 28, 'min_samples_leaf': 47, 'max_features': 0.5926296700980453, 'max_samples': 0.6855352751804438}.
# [I 2026-04-27 14:42:56,302] Trial 20 finished with values: [0.4655923537776511, 0.07927954234788967] and parameters: {'n_estimators': 314, 'max_depth': 29, 'min_samples_split': 18, 'min_samples_leaf': 22, 'max_features': 0.38089224510432396, 'max_samples': 0.9314226381553877}.
# [I 2026-04-27 14:44:21,643] Trial 44 finished with values: [0.4765158139992162, 0.056442988279794215] and parameters: {'n_estimators': 316, 'max_depth': 28, 'min_samples_split': 17, 'min_samples_leaf': 24, 'max_features': 0.23417901792124007, 'max_samples': 0.5500954346176536}.
# [I 2026-04-27 14:44:47,292] Trial 43 finished with values: [0.4867570677311238, 0.04763037742286817] and parameters: {'n_estimators': 105, 'max_depth': 11, 'min_samples_split': 12, 'min_samples_leaf': 31, 'max_features': 0.5763797083661868, 'max_samples': 0.5060747494900912}.
# [I 2026-04-27 14:46:02,242] Trial 23 finished with values: [0.4688448128181595, 0.07723041312559709] and parameters: {'n_estimators': 207, 'max_depth': 30, 'min_samples_split': 28, 'min_samples_leaf': 25, 'max_features': 0.6427411392203376, 'max_samples': 0.9514420955230315}.
# [I 2026-04-27 14:47:00,126] Trial 48 finished with values: [0.559761138499246, 0.029918785628232192] and parameters: {'n_estimators': 143, 'max_depth': 6, 'min_samples_split': 11, 'min_samples_leaf': 42, 'max_features': 0.4106073001150409, 'max_samples': 0.9471953079610155}.
# [I 2026-04-27 14:47:43,813] Trial 42 finished with values: [0.45862015369768244, 0.11778891126166148] and parameters: {'n_estimators': 346, 'max_depth': 17, 'min_samples_split': 19, 'min_samples_leaf': 5, 'max_features': 0.20021232624323365, 'max_samples': 0.653185952842312}.
# [I 2026-04-27 14:49:40,318] Trial 37 finished with values: [0.4796100993682304, 0.05409389022352948] and parameters: {'n_estimators': 377, 'max_depth': 14, 'min_samples_split': 16, 'min_samples_leaf': 41, 'max_features': 0.41249919193253803, 'max_samples': 0.9083659186427588}.
# [I 2026-04-27 14:50:20,085] Trial 33 finished with values: [0.4864323016324793, 0.05004561389469457] and parameters: {'n_estimators': 377, 'max_depth': 11, 'min_samples_split': 14, 'min_samples_leaf': 48, 'max_features': 0.6216989989352673, 'max_samples': 0.9612494876153788}.
# [I 2026-04-27 14:50:21,339] Trial 47 finished with values: [0.4548866546512022, 0.16482614003446974] and parameters: {'n_estimators': 181, 'max_depth': 19, 'min_samples_split': 15, 'min_samples_leaf': 6, 'max_features': 0.3912758148207669, 'max_samples': 0.9663847198166062}.
# [I 2026-04-27 14:52:18,696] Trial 46 finished with values: [0.48278432079162953, 0.05352519175388322] and parameters: {'n_estimators': 118, 'max_depth': 18, 'min_samples_split': 26, 'min_samples_leaf': 38, 'max_features': 0.6798376819264185, 'max_samples': 0.7349011119242734}.
# [I 2026-04-27 14:52:20,992] Trial 30 finished with values: [0.4751657529847364, 0.05843801170167898] and parameters: {'n_estimators': 400, 'max_depth': 20, 'min_samples_split': 25, 'min_samples_leaf': 27, 'max_features': 0.4725947715183829, 'max_samples': 0.6117445902845233}.
# [I 2026-04-27 14:52:43,658] Trial 32 finished with values: [0.46907436705067435, 0.07061558001110803] and parameters: {'n_estimators': 383, 'max_depth': 27, 'min_samples_split': 12, 'min_samples_leaf': 27, 'max_features': 0.46655990871465985, 'max_samples': 0.931417940058149}.
# [I 2026-04-27 14:53:56,661] Trial 45 finished with values: [0.48617359970650315, 0.04935179028648708] and parameters: {'n_estimators': 242, 'max_depth': 12, 'min_samples_split': 23, 'min_samples_leaf': 42, 'max_features': 0.6600286172803704, 'max_samples': 0.7289617285696974}.
# [I 2026-04-27 14:55:54,307] Trial 56 finished with values: [0.5313639262844088, 0.034833067948834465] and parameters: {'n_estimators': 107, 'max_depth': 7, 'min_samples_split': 30, 'min_samples_leaf': 50, 'max_features': 0.6387036608455461, 'max_samples': 0.9851095146925164}.
# [I 2026-04-27 14:58:03,331] Trial 53 finished with values: [0.4745415616310731, 0.06192918907831821] and parameters: {'n_estimators': 161, 'max_depth': 22, 'min_samples_split': 20, 'min_samples_leaf': 25, 'max_features': 0.4861015267142233, 'max_samples': 0.6146773974250871}.
# [I 2026-04-27 14:58:48,092] Trial 57 finished with values: [0.5601281946505255, 0.031096391152400815] and parameters: {'n_estimators': 188, 'max_depth': 6, 'min_samples_split': 16, 'min_samples_leaf': 10, 'max_features': 0.629511630509122, 'max_samples': 0.9383881897474249}.
# [I 2026-04-27 14:59:30,491] Trial 58 finished with values: [0.48453653610372865, 0.04909361395405967] and parameters: {'n_estimators': 197, 'max_depth': 17, 'min_samples_split': 24, 'min_samples_leaf': 47, 'max_features': 0.3911007895439488, 'max_samples': 0.8428168513393655}.
# [I 2026-04-27 14:59:31,555] Trial 54 finished with values: [0.6074346350095539, 0.02430459682818656] and parameters: {'n_estimators': 341, 'max_depth': 5, 'min_samples_split': 13, 'min_samples_leaf': 41, 'max_features': 0.4482798956766151, 'max_samples': 0.6762284538290775}.
# [I 2026-04-27 14:59:31,802] Trial 63 finished with values: [0.45958373807493663, 0.11391367387105471] and parameters: {'n_estimators': 143, 'max_depth': 16, 'min_samples_split': 27, 'min_samples_leaf': 7, 'max_features': 0.27009486555309775, 'max_samples': 0.8787892290544924}.
# [I 2026-04-27 15:00:24,879] Trial 50 finished with values: [0.5124615568964034, 0.0364249830381323] and parameters: {'n_estimators': 272, 'max_depth': 8, 'min_samples_split': 23, 'min_samples_leaf': 47, 'max_features': 0.5784737858070172, 'max_samples': 0.6250378615346233}.
# [I 2026-04-27 15:01:54,124] Trial 41 finished with values: [0.45531371708582125, 0.15673172921806627] and parameters: {'n_estimators': 251, 'max_depth': 16, 'min_samples_split': 10, 'min_samples_leaf': 5, 'max_features': 0.4743487678951199, 'max_samples': 0.7094367635470304}.
# [I 2026-04-27 15:02:03,944] Trial 59 finished with values: [0.4695514216247444, 0.06768545057072811] and parameters: {'n_estimators': 325, 'max_depth': 21, 'min_samples_split': 20, 'min_samples_leaf': 22, 'max_features': 0.3077733050719104, 'max_samples': 0.6950051124178347}.
# [I 2026-04-27 15:02:57,259] Trial 52 finished with values: [0.4646064767676627, 0.08575250726214723] and parameters: {'n_estimators': 270, 'max_depth': 13, 'min_samples_split': 13, 'min_samples_leaf': 17, 'max_features': 0.5277345623461098, 'max_samples': 0.8731806751894287}.
# [I 2026-04-27 15:08:10,168] Trial 69 finished with values: [0.4826694094817968, 0.048990126208021983] and parameters: {'n_estimators': 350, 'max_depth': 17, 'min_samples_split': 14, 'min_samples_leaf': 31, 'max_features': 0.275305206597584, 'max_samples': 0.5290312084227686}.
# [I 2026-04-27 15:08:30,125] Trial 73 finished with values: [0.5124308318839816, 0.03781782485467046] and parameters: {'n_estimators': 124, 'max_depth': 8, 'min_samples_split': 13, 'min_samples_leaf': 50, 'max_features': 0.5348235273265027, 'max_samples': 0.7459975332164133}.
# [I 2026-04-27 15:08:35,277] Trial 51 finished with values: [0.4764033428139248, 0.05899582249016806] and parameters: {'n_estimators': 247, 'max_depth': 18, 'min_samples_split': 18, 'min_samples_leaf': 26, 'max_features': 0.6567957360548622, 'max_samples': 0.571317974948752}.
# [I 2026-04-27 15:08:39,604] Trial 49 finished with values: [0.48945364916445755, 0.045226998352703066] and parameters: {'n_estimators': 378, 'max_depth': 30, 'min_samples_split': 23, 'min_samples_leaf': 45, 'max_features': 0.6266487914935404, 'max_samples': 0.6363745357167458}.
# [I 2026-04-27 15:09:19,216] Trial 64 finished with values: [0.5573571634573976, 0.030087453873288178] and parameters: {'n_estimators': 358, 'max_depth': 6, 'min_samples_split': 25, 'min_samples_leaf': 7, 'max_features': 0.5437523092377041, 'max_samples': 0.6278087515172854}.
# [I 2026-04-27 15:09:24,562] Trial 70 finished with values: [0.47752297114867404, 0.05708805149312696] and parameters: {'n_estimators': 112, 'max_depth': 25, 'min_samples_split': 15, 'min_samples_leaf': 32, 'max_features': 0.4517297308105027, 'max_samples': 0.7205061013337624}.
# [I 2026-04-27 15:09:38,957] Trial 67 finished with values: [0.4700563695344633, 0.07434034248885754] and parameters: {'n_estimators': 138, 'max_depth': 14, 'min_samples_split': 12, 'min_samples_leaf': 22, 'max_features': 0.6288583182226527, 'max_samples': 0.7628370926055268}.
# [I 2026-04-27 15:10:49,062] Trial 72 finished with values: [0.467876854886182, 0.07275735532663474] and parameters: {'n_estimators': 241, 'max_depth': 29, 'min_samples_split': 22, 'min_samples_leaf': 19, 'max_features': 0.3326961363555849, 'max_samples': 0.6630723082798128}.
# [I 2026-04-27 15:13:46,114] Trial 66 finished with values: [0.5584860734293855, 0.030424170198097372] and parameters: {'n_estimators': 349, 'max_depth': 6, 'min_samples_split': 20, 'min_samples_leaf': 22, 'max_features': 0.5613879868524334, 'max_samples': 0.898968209838375}.
# [I 2026-04-27 15:14:18,283] Trial 75 finished with values: [0.6097510734257923, 0.02399531156166837] and parameters: {'n_estimators': 345, 'max_depth': 5, 'min_samples_split': 11, 'min_samples_leaf': 45, 'max_features': 0.3495982654009452, 'max_samples': 0.5720274469792443}.
# [I 2026-04-27 15:14:36,121] Trial 68 finished with values: [0.4780928016404436, 0.05316019149600533] and parameters: {'n_estimators': 291, 'max_depth': 24, 'min_samples_split': 17, 'min_samples_leaf': 27, 'max_features': 0.34979004672328107, 'max_samples': 0.5265820337557763}.
# [I 2026-04-27 15:15:59,732] Trial 55 finished with values: [0.45751197683128486, 0.11412199660168287] and parameters: {'n_estimators': 375, 'max_depth': 24, 'min_samples_split': 17, 'min_samples_leaf': 12, 'max_features': 0.29481862728403835, 'max_samples': 0.9611015849788502}.
# [I 2026-04-27 15:16:13,050] Trial 77 finished with values: [0.6095009960799185, 0.025075068589973687] and parameters: {'n_estimators': 356, 'max_depth': 5, 'min_samples_split': 11, 'min_samples_leaf': 29, 'max_features': 0.3482087842326648, 'max_samples': 0.5940459080163505}.
# [I 2026-04-27 15:16:38,097] Trial 78 finished with values: [0.6095586759765496, 0.025154263869208687] and parameters: {'n_estimators': 350, 'max_depth': 5, 'min_samples_split': 25, 'min_samples_leaf': 19, 'max_features': 0.34277591538856345, 'max_samples': 0.5886808727628485}.
# [I 2026-04-27 15:17:54,790] Trial 60 finished with values: [0.4591630023243033, 0.10544656137741519] and parameters: {'n_estimators': 389, 'max_depth': 17, 'min_samples_split': 21, 'min_samples_leaf': 12, 'max_features': 0.2876506303650369, 'max_samples': 0.8440713018939567}.
# [I 2026-04-27 15:18:23,414] Trial 65 finished with values: [0.48082453970979405, 0.053720823767674314] and parameters: {'n_estimators': 193, 'max_depth': 19, 'min_samples_split': 22, 'min_samples_leaf': 45, 'max_features': 0.48377531471689883, 'max_samples': 0.9781357622620817}.
# [I 2026-04-27 15:18:42,744] Trial 76 finished with values: [0.6095048700398288, 0.024476241291777362] and parameters: {'n_estimators': 350, 'max_depth': 5, 'min_samples_split': 11, 'min_samples_leaf': 45, 'max_features': 0.3537063048482642, 'max_samples': 0.5967802082204414}.
# [I 2026-04-27 15:19:36,602] Trial 79 finished with values: [0.6087166268098756, 0.024421289611715385] and parameters: {'n_estimators': 359, 'max_depth': 5, 'min_samples_split': 25, 'min_samples_leaf': 29, 'max_features': 0.34990052009605954, 'max_samples': 0.5821714308739353}.
# [I 2026-04-27 15:19:38,009] Trial 74 finished with values: [0.509821162083218, 0.03912171762751991] and parameters: {'n_estimators': 327, 'max_depth': 8, 'min_samples_split': 18, 'min_samples_leaf': 38, 'max_features': 0.4668271187235009, 'max_samples': 0.639199025866618}.
# [I 2026-04-27 15:19:40,631] Trial 82 finished with values: [0.6088068985840688, 0.024846122432881868] and parameters: {'n_estimators': 341, 'max_depth': 5, 'min_samples_split': 24, 'min_samples_leaf': 36, 'max_features': 0.3575589246917809, 'max_samples': 0.6071656848223422}.
# [I 2026-04-27 15:21:38,035] Trial 81 finished with values: [0.6056508969496286, 0.023987538382418988] and parameters: {'n_estimators': 398, 'max_depth': 5, 'min_samples_split': 24, 'min_samples_leaf': 29, 'max_features': 0.5553860516175266, 'max_samples': 0.6096321764491037}.
# [I 2026-04-27 15:22:18,301] Trial 80 finished with values: [0.5572943491170265, 0.029532740616990155] and parameters: {'n_estimators': 398, 'max_depth': 6, 'min_samples_split': 25, 'min_samples_leaf': 19, 'max_features': 0.5461252231051761, 'max_samples': 0.5984857606786113}.
# [I 2026-04-27 15:26:49,483] Trial 83 finished with values: [0.47805793256638945, 0.06572391245099339] and parameters: {'n_estimators': 398, 'max_depth': 10, 'min_samples_split': 24, 'min_samples_leaf': 11, 'max_features': 0.3634894109269635, 'max_samples': 0.5891449987343267}.
# [I 2026-04-27 15:27:35,261] Trial 85 finished with values: [0.6082300818731173, 0.02449752755193635] and parameters: {'n_estimators': 393, 'max_depth': 5, 'min_samples_split': 25, 'min_samples_leaf': 29, 'max_features': 0.35153217428933514, 'max_samples': 0.5904064170807938}.
# [I 2026-04-27 15:29:14,979] Trial 71 finished with values: [0.48847188085178006, 0.054344454176865176] and parameters: {'n_estimators': 369, 'max_depth': 9, 'min_samples_split': 28, 'min_samples_leaf': 20, 'max_features': 0.4527707775959979, 'max_samples': 0.8032126630390117}.
# [I 2026-04-27 15:30:18,729] Trial 61 finished with values: [0.4582483054785149, 0.13175951421417564] and parameters: {'n_estimators': 247, 'max_depth': 30, 'min_samples_split': 21, 'min_samples_leaf': 8, 'max_features': 0.6606523730836581, 'max_samples': 0.7888270683030973}.
# [I 2026-04-27 15:31:14,924] Trial 87 finished with values: [0.4886928444770135, 0.05692516144910846] and parameters: {'n_estimators': 398, 'max_depth': 9, 'min_samples_split': 24, 'min_samples_leaf': 9, 'max_features': 0.35878640636729636, 'max_samples': 0.5599244586771418}.
# [I 2026-04-27 15:32:07,407] Trial 93 finished with values: [0.46127693492861965, 0.09115076678220017] and parameters: {'n_estimators': 392, 'max_depth': 21, 'min_samples_split': 20, 'min_samples_leaf': 11, 'max_features': 0.2946103162158147, 'max_samples': 0.5618715802241693}.
# [I 2026-04-27 15:32:13,412] Trial 92 finished with values: [0.4603768138673803, 0.0984695384976922] and parameters: {'n_estimators': 393, 'max_depth': 21, 'min_samples_split': 21, 'min_samples_leaf': 9, 'max_features': 0.2943214071277777, 'max_samples': 0.5625477618366973}.
# [I 2026-04-27 15:32:27,533] Trial 91 finished with values: [0.4891648871898301, 0.05642757259699925] and parameters: {'n_estimators': 331, 'max_depth': 9, 'min_samples_split': 21, 'min_samples_leaf': 9, 'max_features': 0.29364818646192903, 'max_samples': 0.5492329986364908}.
# [I 2026-04-27 15:33:00,257] Trial 86 finished with values: [0.4775490247270354, 0.06705654173187853] and parameters: {'n_estimators': 394, 'max_depth': 10, 'min_samples_split': 25, 'min_samples_leaf': 8, 'max_features': 0.3701945404245145, 'max_samples': 0.5817247702246179}.
# [I 2026-04-27 15:33:03,657] Trial 62 finished with values: [0.4630162984239401, 0.09498841190832091] and parameters: {'n_estimators': 353, 'max_depth': 26, 'min_samples_split': 17, 'min_samples_leaf': 17, 'max_features': 0.6556155606360872, 'max_samples': 0.8730583486380782}.
# [I 2026-04-27 15:33:25,999] Trial 95 finished with values: [0.4683731019191615, 0.06917887626602885] and parameters: {'n_estimators': 399, 'max_depth': 20, 'min_samples_split': 21, 'min_samples_leaf': 17, 'max_features': 0.2876370312061718, 'max_samples': 0.5458250031825529}.
# [I 2026-04-27 15:34:31,713] Trial 88 finished with values: [0.4628478207016, 0.08700629531356646] and parameters: {'n_estimators': 334, 'max_depth': 21, 'min_samples_split': 21, 'min_samples_leaf': 12, 'max_features': 0.2865345797267926, 'max_samples': 0.5691367670194262}.
# [I 2026-04-27 15:35:31,406] Trial 84 finished with values: [0.48621236035033377, 0.048612547805567854] and parameters: {'n_estimators': 396, 'max_depth': 10, 'min_samples_split': 24, 'min_samples_leaf': 29, 'max_features': 0.36764244360625614, 'max_samples': 0.5964024815027004}.
# [I 2026-04-27 15:35:43,684] Trial 89 finished with values: [0.46185367646941966, 0.09162906016136657] and parameters: {'n_estimators': 329, 'max_depth': 21, 'min_samples_split': 24, 'min_samples_leaf': 10, 'max_features': 0.29913982765033154, 'max_samples': 0.5634356933766316}.
# [I 2026-04-27 15:36:11,288] Trial 94 finished with values: [0.45893594413804983, 0.10679964048366672] and parameters: {'n_estimators': 392, 'max_depth': 21, 'min_samples_split': 21, 'min_samples_leaf': 10, 'max_features': 0.29563485708318554, 'max_samples': 0.6897099906613423}.
# [I 2026-04-27 15:36:15,031] Trial 96 finished with values: [0.49326603685138853, 0.04633275452718533] and parameters: {'n_estimators': 391, 'max_depth': 9, 'min_samples_split': 21, 'min_samples_leaf': 23, 'max_features': 0.31141096159935366, 'max_samples': 0.5453750679343694}.
# [I 2026-04-27 15:37:14,542] Trial 90 finished with values: [0.4607698010224041, 0.0962461786936531] and parameters: {'n_estimators': 337, 'max_depth': 21, 'min_samples_split': 21, 'min_samples_leaf': 10, 'max_features': 0.3068157621914068, 'max_samples': 0.5658127363701227}.
# [I 2026-04-27 15:38:41,605] Trial 97 finished with values: [0.5307505776638658, 0.036168903859630785] and parameters: {'n_estimators': 389, 'max_depth': 7, 'min_samples_split': 26, 'min_samples_leaf': 23, 'max_features': 0.28582593452526295, 'max_samples': 0.5524429985820027}.
# [I 2026-04-27 15:40:31,108] Trial 100 finished with values: [0.5301655656456956, 0.036366506205565086] and parameters: {'n_estimators': 384, 'max_depth': 7, 'min_samples_split': 19, 'min_samples_leaf': 23, 'max_features': 0.2950751141270117, 'max_samples': 0.5424613415900009}.
# [I 2026-04-27 15:42:05,208] Trial 99 finished with values: [0.5295084926428627, 0.0361256306252693] and parameters: {'n_estimators': 390, 'max_depth': 7, 'min_samples_split': 26, 'min_samples_leaf': 23, 'max_features': 0.29963997573014156, 'max_samples': 0.5494683392846381}.
# [I 2026-04-27 15:42:52,991] Trial 105 finished with values: [0.5281654473186027, 0.034343112335255374] and parameters: {'n_estimators': 225, 'max_depth': 7, 'min_samples_split': 26, 'min_samples_leaf': 33, 'max_features': 0.5046185567144489, 'max_samples': 0.6027085791805002}.
# [I 2026-04-27 15:48:51,834] Trial 111 finished with values: [0.5252954393495033, 0.03714434632430583] and parameters: {'n_estimators': 384, 'max_depth': 7, 'min_samples_split': 26, 'min_samples_leaf': 17, 'max_features': 0.49913331570914127, 'max_samples': 0.6073920850533575}.
# [I 2026-04-27 15:50:03,282] Trial 101 finished with values: [0.4750021105785846, 0.05939921868412945] and parameters: {'n_estimators': 386, 'max_depth': 22, 'min_samples_split': 29, 'min_samples_leaf': 24, 'max_features': 0.5033974657866683, 'max_samples': 0.5410290011162003}.
# [I 2026-04-27 15:50:29,226] Trial 110 finished with values: [0.5241367396511318, 0.037131500362423506] and parameters: {'n_estimators': 384, 'max_depth': 7, 'min_samples_split': 26, 'min_samples_leaf': 15, 'max_features': 0.6070832906967075, 'max_samples': 0.543008214427851}.
# [I 2026-04-27 15:51:37,883] Trial 109 finished with values: [0.4659568082037613, 0.07661273346681359] and parameters: {'n_estimators': 381, 'max_depth': 20, 'min_samples_split': 26, 'min_samples_leaf': 14, 'max_features': 0.256938586162583, 'max_samples': 0.5451873372253777}.
# [I 2026-04-27 15:52:11,068] Trial 103 finished with values: [0.4682613214700635, 0.06977967752552587] and parameters: {'n_estimators': 385, 'max_depth': 20, 'min_samples_split': 26, 'min_samples_leaf': 17, 'max_features': 0.32023676376663346, 'max_samples': 0.5408045959273082}.
# [I 2026-04-27 15:52:11,910] Trial 114 finished with values: [0.46836186297183696, 0.07167575846333835] and parameters: {'n_estimators': 380, 'max_depth': 20, 'min_samples_split': 26, 'min_samples_leaf': 17, 'max_features': 0.21903669774335113, 'max_samples': 0.6079192094184235}.
# [I 2026-04-27 15:53:08,850] Trial 117 finished with values: [0.4867164468855026, 0.04738468084632094] and parameters: {'n_estimators': 217, 'max_depth': 20, 'min_samples_split': 23, 'min_samples_leaf': 33, 'max_features': 0.22023485474758606, 'max_samples': 0.5310096003096499}.
# [I 2026-04-27 15:53:12,874] Trial 98 finished with values: [0.527987356489187, 0.03376590138582394] and parameters: {'n_estimators': 390, 'max_depth': 7, 'min_samples_split': 26, 'min_samples_leaf': 34, 'max_features': 0.6019800863620554, 'max_samples': 0.5652510832812074}.
# [I 2026-04-27 15:54:10,440] Trial 106 finished with values: [0.4653658464151412, 0.08033904192294744] and parameters: {'n_estimators': 384, 'max_depth': 20, 'min_samples_split': 26, 'min_samples_leaf': 16, 'max_features': 0.5093880635272651, 'max_samples': 0.611806550102499}.
# [I 2026-04-27 15:54:28,467] Trial 102 finished with values: [0.46651765278223783, 0.078877319743975] and parameters: {'n_estimators': 387, 'max_depth': 20, 'min_samples_split': 26, 'min_samples_leaf': 15, 'max_features': 0.5999599951338337, 'max_samples': 0.5364423786351473}.
# [I 2026-04-27 15:54:55,202] Trial 119 finished with values: [0.48765025038673393, 0.045773367061399756] and parameters: {'n_estimators': 223, 'max_depth': 20, 'min_samples_split': 23, 'min_samples_leaf': 34, 'max_features': 0.22456901642599963, 'max_samples': 0.5172806935332408}.
# [I 2026-04-27 15:55:26,842] Trial 108 finished with values: [0.5251621351063915, 0.037085789910806494] and parameters: {'n_estimators': 385, 'max_depth': 7, 'min_samples_split': 26, 'min_samples_leaf': 14, 'max_features': 0.5026693914262466, 'max_samples': 0.5473744051204623}.
# [I 2026-04-27 15:55:45,197] Trial 118 finished with values: [0.48288576244020615, 0.05005344822460682] and parameters: {'n_estimators': 223, 'max_depth': 20, 'min_samples_split': 23, 'min_samples_leaf': 34, 'max_features': 0.24604753801241502, 'max_samples': 0.6182246931534342}.
# [I 2026-04-27 15:56:09,790] Trial 107 finished with values: [0.5253246076093401, 0.037539273617565885] and parameters: {'n_estimators': 385, 'max_depth': 7, 'min_samples_split': 26, 'min_samples_leaf': 15, 'max_features': 0.5046717933431628, 'max_samples': 0.6085989169808665}.
# [I 2026-04-27 15:58:57,135] Trial 112 finished with values: [0.52574890538857, 0.038061593817380196] and parameters: {'n_estimators': 386, 'max_depth': 7, 'min_samples_split': 26, 'min_samples_leaf': 15, 'max_features': 0.5039252401346175, 'max_samples': 0.6095142927339795}.
# [I 2026-04-27 15:59:10,419] Trial 121 finished with values: [0.48595528643748137, 0.04792112348844833] and parameters: {'n_estimators': 226, 'max_depth': 25, 'min_samples_split': 23, 'min_samples_leaf': 31, 'max_features': 0.21864006843187267, 'max_samples': 0.5008908546940237}.
# [I 2026-04-27 15:59:22,027] Trial 104 finished with values: [0.466771909076962, 0.07722369982051437] and parameters: {'n_estimators': 381, 'max_depth': 20, 'min_samples_split': 26, 'min_samples_leaf': 17, 'max_features': 0.5079368918637585, 'max_samples': 0.6052665632401887}.
# [I 2026-04-27 15:59:23,373] Trial 116 finished with values: [0.46409157684169894, 0.08776751446856779] and parameters: {'n_estimators': 214, 'max_depth': 20, 'min_samples_split': 23, 'min_samples_leaf': 14, 'max_features': 0.5543573931467388, 'max_samples': 0.6096631315366008}.
# [I 2026-04-27 16:00:58,291] Trial 126 finished with values: [0.4800123343643875, 0.052229857940053415] and parameters: {'n_estimators': 261, 'max_depth': 22, 'min_samples_split': 15, 'min_samples_leaf': 31, 'max_features': 0.24488308146526855, 'max_samples': 0.6245309440148799}.
# [I 2026-04-27 16:02:26,658] Trial 115 finished with values: [0.46427987254319797, 0.08840422458765797] and parameters: {'n_estimators': 221, 'max_depth': 22, 'min_samples_split': 22, 'min_samples_leaf': 14, 'max_features': 0.5020106704346468, 'max_samples': 0.6191974117057574}.
# [I 2026-04-27 16:03:21,327] Trial 120 finished with values: [0.48627744020712127, 0.04654488499309099] and parameters: {'n_estimators': 374, 'max_depth': 24, 'min_samples_split': 23, 'min_samples_leaf': 33, 'max_features': 0.2151944498912136, 'max_samples': 0.5153922480396662}.
# [I 2026-04-27 16:07:49,644] Trial 129 finished with values: [0.5585658289602271, 0.028845050256363247] and parameters: {'n_estimators': 370, 'max_depth': 6, 'min_samples_split': 16, 'min_samples_leaf': 32, 'max_features': 0.5469234194205572, 'max_samples': 0.6243913253206943}.
# [I 2026-04-27 16:11:49,243] Trial 135 finished with values: [0.5575951152738733, 0.030220475760924903] and parameters: {'n_estimators': 372, 'max_depth': 6, 'min_samples_split': 19, 'min_samples_leaf': 5, 'max_features': 0.5687418349565967, 'max_samples': 0.5154140235232549}.
# [I 2026-04-27 16:14:00,946] Trial 123 finished with values: [0.47799740506013116, 0.05664820486189702] and parameters: {'n_estimators': 373, 'max_depth': 24, 'min_samples_split': 15, 'min_samples_leaf': 30, 'max_features': 0.5600491687106226, 'max_samples': 0.6259039062364206}.
# [I 2026-04-27 16:15:03,323] Trial 125 finished with values: [0.47884340774622536, 0.055292897426477444] and parameters: {'n_estimators': 365, 'max_depth': 24, 'min_samples_split': 15, 'min_samples_leaf': 31, 'max_features': 0.5608932012220312, 'max_samples': 0.6208351272190534}.
# [I 2026-04-27 16:15:23,052] Trial 127 finished with values: [0.47935026202862774, 0.05413534753618918] and parameters: {'n_estimators': 371, 'max_depth': 24, 'min_samples_split': 16, 'min_samples_leaf': 32, 'max_features': 0.5492937872594378, 'max_samples': 0.6241528884071504}.
# [I 2026-04-27 16:16:11,894] Trial 113 finished with values: [0.46685480326940126, 0.07928398257539197] and parameters: {'n_estimators': 383, 'max_depth': 20, 'min_samples_split': 26, 'min_samples_leaf': 15, 'max_features': 0.6062532792125628, 'max_samples': 0.537688600432196}.
# [I 2026-04-27 16:18:08,949] Trial 122 finished with values: [0.47976261775766255, 0.05463143547056826] and parameters: {'n_estimators': 371, 'max_depth': 25, 'min_samples_split': 23, 'min_samples_leaf': 33, 'max_features': 0.5484710809324077, 'max_samples': 0.6532869786141692}.
# [I 2026-04-27 16:19:55,665] Trial 142 finished with values: [0.5665298624367209, 0.03027228509416946] and parameters: {'n_estimators': 272, 'max_depth': 6, 'min_samples_split': 16, 'min_samples_leaf': 36, 'max_features': 0.26176494393789557, 'max_samples': 0.6504007256165109}.
# [I 2026-04-27 16:20:14,889] Trial 132 finished with values: [0.5587564457691241, 0.029244487944467185] and parameters: {'n_estimators': 374, 'max_depth': 6, 'min_samples_split': 16, 'min_samples_leaf': 31, 'max_features': 0.5542524020948921, 'max_samples': 0.6495882088265583}.
# [I 2026-04-27 16:20:48,128] Trial 138 finished with values: [0.5592229755439797, 0.028854130458528304] and parameters: {'n_estimators': 370, 'max_depth': 6, 'min_samples_split': 16, 'min_samples_leaf': 36, 'max_features': 0.5679395395932313, 'max_samples': 0.6483690594823036}.
# [I 2026-04-27 16:21:27,940] Trial 134 finished with values: [0.4815797431156728, 0.05143643105761156] and parameters: {'n_estimators': 371, 'max_depth': 22, 'min_samples_split': 22, 'min_samples_leaf': 30, 'max_features': 0.5687887897666942, 'max_samples': 0.5163015607850472}.
# [I 2026-04-27 16:22:36,480] Trial 136 finished with values: [0.5575700481844956, 0.029052985240332535] and parameters: {'n_estimators': 371, 'max_depth': 6, 'min_samples_split': 19, 'min_samples_leaf': 28, 'max_features': 0.5400167807604698, 'max_samples': 0.649923519414921}.
# [I 2026-04-27 16:23:51,012] Trial 137 finished with values: [0.5589623397794783, 0.02947252280622617] and parameters: {'n_estimators': 363, 'max_depth': 6, 'min_samples_split': 19, 'min_samples_leaf': 28, 'max_features': 0.5654030025133356, 'max_samples': 0.6472953469679472}.
# [I 2026-04-27 16:23:55,143] Trial 140 finished with values: [0.48184145565838893, 0.049692865925226926] and parameters: {'n_estimators': 364, 'max_depth': 16, 'min_samples_split': 16, 'min_samples_leaf': 35, 'max_features': 0.2590161180162428, 'max_samples': 0.6465352183677964}.
# [I 2026-04-27 16:26:30,537] Trial 133 finished with values: [0.4786845336659338, 0.05575225674921144] and parameters: {'n_estimators': 372, 'max_depth': 22, 'min_samples_split': 16, 'min_samples_leaf': 31, 'max_features': 0.5823373088026007, 'max_samples': 0.6302396051979067}.
# [I 2026-04-27 16:27:08,919] Trial 124 finished with values: [0.4786935459210289, 0.05518283799412506] and parameters: {'n_estimators': 372, 'max_depth': 24, 'min_samples_split': 15, 'min_samples_leaf': 31, 'max_features': 0.5536109984995711, 'max_samples': 0.6236158360241886}.
# [I 2026-04-27 16:27:28,969] Trial 144 finished with values: [0.48556994399806275, 0.04720120179318754] and parameters: {'n_estimators': 303, 'max_depth': 16, 'min_samples_split': 16, 'min_samples_leaf': 36, 'max_features': 0.26266385540708165, 'max_samples': 0.5759867605543487}.
# [I 2026-04-27 16:29:21,223] Trial 128 finished with values: [0.4786749701649677, 0.055330413915175874] and parameters: {'n_estimators': 371, 'max_depth': 24, 'min_samples_split': 22, 'min_samples_leaf': 31, 'max_features': 0.5546800270061684, 'max_samples': 0.625031291379666}.
# [I 2026-04-27 16:29:22,642] Trial 130 finished with values: [0.48271452069906495, 0.05076094024455623] and parameters: {'n_estimators': 372, 'max_depth': 24, 'min_samples_split': 22, 'min_samples_leaf': 36, 'max_features': 0.5598204906724428, 'max_samples': 0.6226586698873445}.
# [I 2026-04-27 16:30:29,307] Trial 139 finished with values: [0.47559808600744646, 0.0598799746602751] and parameters: {'n_estimators': 304, 'max_depth': 16, 'min_samples_split': 16, 'min_samples_leaf': 28, 'max_features': 0.5870279393405033, 'max_samples': 0.6492098133149751}.
# [I 2026-04-27 16:34:04,678] Trial 131 finished with values: [0.47467311701717185, 0.06148238022621004] and parameters: {'n_estimators': 373, 'max_depth': 24, 'min_samples_split': 16, 'min_samples_leaf': 26, 'max_features': 0.5537797518491154, 'max_samples': 0.6255789111120317}.
# [I 2026-04-27 16:36:15,243] Trial 141 finished with values: [0.4821882157146754, 0.051878571380298735] and parameters: {'n_estimators': 361, 'max_depth': 15, 'min_samples_split': 16, 'min_samples_leaf': 36, 'max_features': 0.5848706255913537, 'max_samples': 0.6480051763370667}.
# [I 2026-04-27 16:36:50,315] Trial 147 finished with values: [0.47722521908881516, 0.056570830595386215] and parameters: {'n_estimators': 292, 'max_depth': 18, 'min_samples_split': 17, 'min_samples_leaf': 28, 'max_features': 0.5800871518348818, 'max_samples': 0.577908643184103}.
# [I 2026-04-27 16:38:14,954] Trial 151 finished with values: [0.4757399660850492, 0.05856611567438527] and parameters: {'n_estimators': 282, 'max_depth': 23, 'min_samples_split': 17, 'min_samples_leaf': 26, 'max_features': 0.5274721150221724, 'max_samples': 0.5791281462244361}.
# [I 2026-04-27 16:44:28,738] Trial 145 finished with values: [0.47784758414315526, 0.057020577938493855] and parameters: {'n_estimators': 366, 'max_depth': 16, 'min_samples_split': 18, 'min_samples_leaf': 28, 'max_features': 0.6993552028619622, 'max_samples': 0.5783718253360032}.
# [I 2026-04-27 16:44:37,480] Trial 143 finished with values: [0.47438431712084494, 0.06247464875516537] and parameters: {'n_estimators': 280, 'max_depth': 16, 'min_samples_split': 16, 'min_samples_leaf': 26, 'max_features': 0.5823265710085844, 'max_samples': 0.648576740414162}.
# [I 2026-04-27 16:44:47,185] Trial 157 finished with values: [0.47565877141513146, 0.05857787968948021] and parameters: {'n_estimators': 285, 'max_depth': 18, 'min_samples_split': 18, 'min_samples_leaf': 26, 'max_features': 0.5211800719503852, 'max_samples': 0.578761470094366}.
# [I 2026-04-27 16:46:41,066] Trial 148 finished with values: [0.4704733555694619, 0.06983116833104727] and parameters: {'n_estimators': 280, 'max_depth': 23, 'min_samples_split': 18, 'min_samples_leaf': 28, 'max_features': 0.5365556440407517, 'max_samples': 0.9179447741075968}.
# [I 2026-04-27 16:47:10,576] Trial 160 finished with values: [0.5058656779412779, 0.048730659540459104] and parameters: {'n_estimators': 399, 'max_depth': 8, 'min_samples_split': 18, 'min_samples_leaf': 12, 'max_features': 0.2803202774365661, 'max_samples': 0.7754044485979911}.
# [I 2026-04-27 16:47:23,958] Trial 146 finished with values: [0.47610395231924363, 0.05894861071551119] and parameters: {'n_estimators': 301, 'max_depth': 23, 'min_samples_split': 17, 'min_samples_leaf': 28, 'max_features': 0.5226895259889908, 'max_samples': 0.6362395934569055}.
# [I 2026-04-27 16:47:33,112] Trial 149 finished with values: [0.4754668880255018, 0.058225927442178346] and parameters: {'n_estimators': 303, 'max_depth': 23, 'min_samples_split': 17, 'min_samples_leaf': 26, 'max_features': 0.5289986971733442, 'max_samples': 0.574926838316725}.
# [I 2026-04-27 16:48:00,738] Trial 156 finished with values: [0.604966887748508, 0.02384573954217581] and parameters: {'n_estimators': 400, 'max_depth': 5, 'min_samples_split': 17, 'min_samples_leaf': 27, 'max_features': 0.5315257524249205, 'max_samples': 0.6636295515427523}.
# [I 2026-04-27 16:48:16,603] Trial 161 finished with values: [0.46251344118828075, 0.0915160233702645] and parameters: {'n_estimators': 399, 'max_depth': 28, 'min_samples_split': 18, 'min_samples_leaf': 12, 'max_features': 0.2036392521229087, 'max_samples': 0.663885862502069}.
# [I 2026-04-27 16:48:30,725] Trial 152 finished with values: [0.4713019211722614, 0.06724288373692092] and parameters: {'n_estimators': 296, 'max_depth': 23, 'min_samples_split': 17, 'min_samples_leaf': 26, 'max_features': 0.5237501979138098, 'max_samples': 0.7660018723714485}.
# [I 2026-04-27 16:50:03,748] Trial 150 finished with values: [0.47711656615004566, 0.05773202184701562] and parameters: {'n_estimators': 285, 'max_depth': 16, 'min_samples_split': 17, 'min_samples_leaf': 27, 'max_features': 0.5864021836680505, 'max_samples': 0.5788870512114306}.
# [I 2026-04-27 16:50:34,815] Trial 162 finished with values: [0.6133707540812654, 0.026143429749025476] and parameters: {'n_estimators': 399, 'max_depth': 5, 'min_samples_split': 27, 'min_samples_leaf': 12, 'max_features': 0.2802998218709022, 'max_samples': 0.668929662226195}.
# [I 2026-04-27 16:51:18,170] Trial 166 finished with values: [0.6073053735182226, 0.024998131845859944] and parameters: {'n_estimators': 154, 'max_depth': 5, 'min_samples_split': 24, 'min_samples_leaf': 30, 'max_features': 0.42508909106700604, 'max_samples': 0.8324580187163357}.
# [I 2026-04-27 16:51:26,871] Trial 153 finished with values: [0.47733813429703287, 0.05621411797041101] and parameters: {'n_estimators': 294, 'max_depth': 23, 'min_samples_split': 17, 'min_samples_leaf': 28, 'max_features': 0.5269283056423495, 'max_samples': 0.5802073781934178}.
# [I 2026-04-27 16:52:34,757] Trial 165 finished with values: [0.6076033470535713, 0.02455695468383079] and parameters: {'n_estimators': 171, 'max_depth': 5, 'min_samples_split': 27, 'min_samples_leaf': 12, 'max_features': 0.4848265857893732, 'max_samples': 0.8325704356474815}.
# [I 2026-04-27 16:53:05,763] Trial 154 finished with values: [0.4832657804755837, 0.051718504582791716] and parameters: {'n_estimators': 283, 'max_depth': 23, 'min_samples_split': 17, 'min_samples_leaf': 47, 'max_features': 0.5846215717248153, 'max_samples': 0.9195724819573443}.
# [I 2026-04-27 16:54:07,051] Trial 171 finished with values: [0.6090088069207169, 0.02429713623781607] and parameters: {'n_estimators': 173, 'max_depth': 5, 'min_samples_split': 14, 'min_samples_leaf': 48, 'max_features': 0.4447484335841409, 'max_samples': 0.8400590164873627}.
# [I 2026-04-27 16:54:20,828] Trial 159 finished with values: [0.46119016272411417, 0.10100630185544177] and parameters: {'n_estimators': 278, 'max_depth': 28, 'min_samples_split': 17, 'min_samples_leaf': 12, 'max_features': 0.5238224653926102, 'max_samples': 0.6689761881982459}.
# [I 2026-04-27 16:55:20,173] Trial 173 finished with values: [0.6072063761141713, 0.024490856854925663] and parameters: {'n_estimators': 152, 'max_depth': 5, 'min_samples_split': 14, 'min_samples_leaf': 48, 'max_features': 0.4857123934089819, 'max_samples': 0.8517738430706012}.
# [I 2026-04-27 16:55:43,839] Trial 163 finished with values: [0.6137170655335836, 0.025513312134785082] and parameters: {'n_estimators': 399, 'max_depth': 5, 'min_samples_split': 27, 'min_samples_leaf': 39, 'max_features': 0.2795328217364983, 'max_samples': 0.8345444238524632}.
# [I 2026-04-27 16:57:47,798] Trial 170 finished with values: [0.4692885916100487, 0.07080714881179648] and parameters: {'n_estimators': 170, 'max_depth': 27, 'min_samples_split': 17, 'min_samples_leaf': 25, 'max_features': 0.4322858559413435, 'max_samples': 0.845656527577319}.
# [I 2026-04-27 16:59:43,898] Trial 164 finished with values: [0.47775006607997755, 0.0600588880860638] and parameters: {'n_estimators': 175, 'max_depth': 26, 'min_samples_split': 27, 'min_samples_leaf': 39, 'max_features': 0.6170519883831067, 'max_samples': 0.999197880927625}.
# [I 2026-04-27 17:00:27,878] Trial 174 finished with values: [0.48291437960923667, 0.050790982743885896] and parameters: {'n_estimators': 175, 'max_depth': 27, 'min_samples_split': 20, 'min_samples_leaf': 39, 'max_features': 0.487300141721093, 'max_samples': 0.7018682486080458}.
# [I 2026-04-27 17:00:34,178] Trial 155 finished with values: [0.47716744490492036, 0.05580471065412332] and parameters: {'n_estimators': 399, 'max_depth': 26, 'min_samples_split': 17, 'min_samples_leaf': 26, 'max_features': 0.5189684421924834, 'max_samples': 0.5266335517614122}.
# [I 2026-04-27 17:00:55,798] Trial 158 finished with values: [0.4896557031532447, 0.04502199287597525] and parameters: {'n_estimators': 282, 'max_depth': 18, 'min_samples_split': 27, 'min_samples_leaf': 39, 'max_features': 0.687658329084363, 'max_samples': 0.527143678233764}.
# [I 2026-04-27 17:02:20,049] Trial 169 finished with values: [0.4709381170418823, 0.06693244756613309] and parameters: {'n_estimators': 151, 'max_depth': 28, 'min_samples_split': 14, 'min_samples_leaf': 27, 'max_features': 0.4397905297551188, 'max_samples': 0.8265146469259282}.
# ...
# [I 2026-04-27 18:24:25,292] Trial 226 finished with values: [0.4851327517063504, 0.04910250744023996] and parameters: {'n_estimators': 362, 'max_depth': 15, 'min_samples_split': 16, 'min_samples_leaf': 35, 'max_features': 0.6839776763132792, 'max_samples': 0.5557482286751732}.
# [I 2026-04-27 18:25:34,659] Trial 241 finished with values: [0.47297011637478387, 0.06460787154517911] and parameters: {'n_estimators': 310, 'max_depth': 21, 'min_samples_split': 16, 'min_samples_leaf': 21, 'max_features': 0.6932545968070346, 'max_samples': 0.5329563601229932}.
# [I 2026-04-27 18:25:40,509] Trial 230 finished with values: [0.496837611928479, 0.04087681641221472] and parameters: {'n_estimators': 341, 'max_depth': 25, 'min_samples_split': 16, 'min_samples_leaf': 50, 'max_features': 0.6694880386611882, 'max_samples': 0.5639335699571025}.
# [I 2026-04-27 18:26:09,090] Trial 247 finished with values: [0.4720215581237379, 0.06660806490646168] and parameters: {'n_estimators': 247, 'max_depth': 21, 'min_samples_split': 28, 'min_samples_leaf': 20, 'max_features': 0.696344338915466, 'max_samples': 0.534724181101477}.
# [I 2026-04-27 18:26:36,979] Trial 234 finished with values: [0.47537385935839493, 0.061852621709550526] and parameters: {'n_estimators': 274, 'max_depth': 17, 'min_samples_split': 16, 'min_samples_leaf': 24, 'max_features': 0.6895768037576975, 'max_samples': 0.566863638136448}.
# [I 2026-04-27 18:29:02,527] Trial 250 finished with values: [0.6066636126760416, 0.023176499329269462] and parameters: {'n_estimators': 249, 'max_depth': 5, 'min_samples_split': 29, 'min_samples_leaf': 18, 'max_features': 0.6973342299546953, 'max_samples': 0.5343522209870701}.
# [I 2026-04-27 18:29:18,093] Trial 246 finished with values: [0.47359429087417343, 0.06310148171045066] and parameters: {'n_estimators': 276, 'max_depth': 21, 'min_samples_split': 29, 'min_samples_leaf': 22, 'max_features': 0.689180087816145, 'max_samples': 0.5389436613273646}.
# [I 2026-04-27 18:29:35,501] Trial 249 finished with values: [0.4731107945066721, 0.06504267265228057] and parameters: {'n_estimators': 263, 'max_depth': 21, 'min_samples_split': 29, 'min_samples_leaf': 21, 'max_features': 0.6914073879853144, 'max_samples': 0.5359664129472949}.
# [I 2026-04-27 18:30:42,249] Trial 258 finished with values: [0.6060793539434985, 0.022928880830868636] and parameters: {'n_estimators': 288, 'max_depth': 5, 'min_samples_split': 15, 'min_samples_leaf': 23, 'max_features': 0.6923026466311052, 'max_samples': 0.5142103684396312}.
# [I 2026-04-27 18:33:59,203] Trial 262 finished with values: [0.605500119905357, 0.023570852977666007] and parameters: {'n_estimators': 261, 'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 23, 'max_features': 0.6524608025305665, 'max_samples': 0.5282109377538542}.
# [I 2026-04-27 18:34:24,786] Trial 260 finished with values: [0.6068533497423367, 0.023175898548511348] and parameters: {'n_estimators': 289, 'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 23, 'max_features': 0.6973453311119095, 'max_samples': 0.511709495197618}.
# [I 2026-04-27 18:34:53,588] Trial 257 finished with values: [0.6066066985717019, 0.02309338042591816] and parameters: {'n_estimators': 262, 'max_depth': 5, 'min_samples_split': 28, 'min_samples_leaf': 23, 'max_features': 0.6979277143909335, 'max_samples': 0.5179601289252437}.
# [I 2026-04-27 18:36:33,177] Trial 244 finished with values: [0.47546445613220245, 0.06151220888582991] and parameters: {'n_estimators': 274, 'max_depth': 21, 'min_samples_split': 16, 'min_samples_leaf': 23, 'max_features': 0.6980495658537721, 'max_samples': 0.5329621524355986}.
# [I 2026-04-27 18:36:48,777] Trial 267 finished with values: [0.5082425135305528, 0.040605657266297] and parameters: {'n_estimators': 289, 'max_depth': 8, 'min_samples_split': 13, 'min_samples_leaf': 23, 'max_features': 0.30747780896606614, 'max_samples': 0.5126364786121362}.
# [I 2026-04-27 18:37:35,463] Trial 261 finished with values: [0.6050229059996942, 0.023222678934908675] and parameters: {'n_estimators': 261, 'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 23, 'max_features': 0.6487727980575093, 'max_samples': 0.5175753042285194}.
# [I 2026-04-27 18:38:00,299] Trial 266 finished with values: [0.6044663377385839, 0.023010632656288832] and parameters: {'n_estimators': 291, 'max_depth': 5, 'min_samples_split': 15, 'min_samples_leaf': 23, 'max_features': 0.6496229809015139, 'max_samples': 0.5150523053334359}.
# [I 2026-04-27 18:38:12,403] Trial 265 finished with values: [0.6051316395033656, 0.022939107732117492] and parameters: {'n_estimators': 260, 'max_depth': 5, 'min_samples_split': 10, 'min_samples_leaf': 23, 'max_features': 0.6506799403997655, 'max_samples': 0.5136472858923575}.
# [I 2026-04-27 18:38:17,829] Trial 256 finished with values: [0.4684396386432327, 0.07764321572386028] and parameters: {'n_estimators': 114, 'max_depth': 25, 'min_samples_split': 11, 'min_samples_leaf': 23, 'max_features': 0.6960346677682523, 'max_samples': 0.8612309785346077}.
# [I 2026-04-27 18:38:51,432] Trial 253 finished with values: [0.47110772795472755, 0.06977914359785946] and parameters: {'n_estimators': 249, 'max_depth': 21, 'min_samples_split': 15, 'min_samples_leaf': 19, 'max_features': 0.6961560905302042, 'max_samples': 0.5433321508289826}.
# [I 2026-04-27 18:39:47,335] Trial 263 finished with values: [0.6052218366872114, 0.02335505260749013] and parameters: {'n_estimators': 288, 'max_depth': 5, 'min_samples_split': 15, 'min_samples_leaf': 23, 'max_features': 0.6530446191578911, 'max_samples': 0.5082609367963771}.
# [I 2026-04-27 18:39:57,985] Trial 268 finished with values: [0.5059474375386679, 0.04507798096576936] and parameters: {'n_estimators': 287, 'max_depth': 8, 'min_samples_split': 15, 'min_samples_leaf': 13, 'max_features': 0.30139435151901023, 'max_samples': 0.5126211598253977}.
# [I 2026-04-27 18:40:37,538] Trial 264 finished with values: [0.6049550132749297, 0.02288140554120019] and parameters: {'n_estimators': 261, 'max_depth': 5, 'min_samples_split': 15, 'min_samples_leaf': 23, 'max_features': 0.6487119729960831, 'max_samples': 0.5133829768603584}.
# [I 2026-04-27 18:40:48,122] Trial 269 finished with values: [0.4636092112941449, 0.08609786285040363] and parameters: {'n_estimators': 211, 'max_depth': 18, 'min_samples_split': 15, 'min_samples_leaf': 11, 'max_features': 0.30467641137721074, 'max_samples': 0.501046726546274}.
# [I 2026-04-27 18:41:20,726] Trial 255 finished with values: [0.47629934049184663, 0.06000193886358733] and parameters: {'n_estimators': 289, 'max_depth': 21, 'min_samples_split': 10, 'min_samples_leaf': 23, 'max_features': 0.6946853936005435, 'max_samples': 0.5082435250697548}.
# [I 2026-04-27 18:42:01,011] Trial 274 finished with values: [0.46428706022103683, 0.08634258907064397] and parameters: {'n_estimators': 128, 'max_depth': 18, 'min_samples_split': 21, 'min_samples_leaf': 11, 'max_features': 0.30416545378028365, 'max_samples': 0.5066334233551284}.
# [I 2026-04-27 18:44:02,272] Trial 273 finished with values: [0.45830739595808795, 0.12182951936981963] and parameters: {'n_estimators': 131, 'max_depth': 25, 'min_samples_split': 11, 'min_samples_leaf': 6, 'max_features': 0.29967526479372203, 'max_samples': 0.5085279250307352}.
# [I 2026-04-27 18:45:03,948] Trial 282 finished with values: [0.5597070326304794, 0.030165508082573733] and parameters: {'n_estimators': 100, 'max_depth': 6, 'min_samples_split': 14, 'min_samples_leaf': 5, 'max_features': 0.6338747933996526, 'max_samples': 0.5233989410459579}.
# [I 2026-04-27 18:45:57,855] Trial 272 finished with values: [0.46323508037952976, 0.0856287879332808] and parameters: {'n_estimators': 317, 'max_depth': 25, 'min_samples_split': 15, 'min_samples_leaf': 11, 'max_features': 0.2905103463982346, 'max_samples': 0.5016472012725959}.
# [I 2026-04-27 18:46:16,126] Trial 251 finished with values: [0.4650770189415885, 0.08823249630549201] and parameters: {'n_estimators': 311, 'max_depth': 25, 'min_samples_split': 21, 'min_samples_leaf': 19, 'max_features': 0.6914897825030039, 'max_samples': 0.8598282322329279}.
# [I 2026-04-27 18:47:32,371] Trial 280 finished with values: [0.5597936615459518, 0.02894628518154857] and parameters: {'n_estimators': 132, 'max_depth': 6, 'min_samples_split': 14, 'min_samples_leaf': 16, 'max_features': 0.632285034584352, 'max_samples': 0.5055053736313381}.
# [I 2026-04-27 18:47:53,204] Trial 270 finished with values: [0.46556167688409655, 0.07821898532328452] and parameters: {'n_estimators': 289, 'max_depth': 18, 'min_samples_split': 15, 'min_samples_leaf': 13, 'max_features': 0.30218888476651673, 'max_samples': 0.5084755349722838}.
# [I 2026-04-27 18:48:14,984] Trial 275 finished with values: [0.5576026891070629, 0.029033157956920824] and parameters: {'n_estimators': 251, 'max_depth': 6, 'min_samples_split': 11, 'min_samples_leaf': 16, 'max_features': 0.6434990059799993, 'max_samples': 0.5069833595357379}.
# [I 2026-04-27 18:48:23,878] Trial 279 finished with values: [0.5581994362675202, 0.029168977952018837] and parameters: {'n_estimators': 252, 'max_depth': 6, 'min_samples_split': 11, 'min_samples_leaf': 16, 'max_features': 0.6434944898940167, 'max_samples': 0.5028131269464623}.
# [I 2026-04-27 18:48:52,885] Trial 254 finished with values: [0.4722676445524514, 0.06736041794391132] and parameters: {'n_estimators': 288, 'max_depth': 25, 'min_samples_split': 11, 'min_samples_leaf': 19, 'max_features': 0.6989681128586831, 'max_samples': 0.509095748097008}.
# [I 2026-04-27 18:48:58,952] Trial 277 finished with values: [0.5577582752728301, 0.02907161177946621] and parameters: {'n_estimators': 253, 'max_depth': 6, 'min_samples_split': 11, 'min_samples_leaf': 16, 'max_features': 0.6422399079971456, 'max_samples': 0.5044229802272879}.
# [I 2026-04-27 18:50:28,059] Trial 283 finished with values: [0.557164626894584, 0.02975193959187658] and parameters: {'n_estimators': 251, 'max_depth': 6, 'min_samples_split': 14, 'min_samples_leaf': 9, 'max_features': 0.6329619990031484, 'max_samples': 0.5248674653613257}.
# [I 2026-04-27 18:51:27,462] Trial 271 finished with values: [0.4596967375241334, 0.10492031353325455] and parameters: {'n_estimators': 291, 'max_depth': 25, 'min_samples_split': 15, 'min_samples_leaf': 8, 'max_features': 0.3071369466116605, 'max_samples': 0.5110772347452036}.
# [I 2026-04-27 18:53:04,549] Trial 259 finished with values: [0.47664589061418905, 0.057997814261527614] and parameters: {'n_estimators': 309, 'max_depth': 25, 'min_samples_split': 10, 'min_samples_leaf': 24, 'max_features': 0.6494800531956829, 'max_samples': 0.5083981051872796}.
# [I 2026-04-27 18:53:29,754] Trial 278 finished with values: [0.5578866351320227, 0.02905910917109747] and parameters: {'n_estimators': 253, 'max_depth': 6, 'min_samples_split': 11, 'min_samples_leaf': 16, 'max_features': 0.6426722875157107, 'max_samples': 0.5016847865768718}.
# [I 2026-04-27 18:54:16,514] Trial 287 finished with values: [0.5580680564854786, 0.02953996355789862] and parameters: {'n_estimators': 240, 'max_depth': 6, 'min_samples_split': 15, 'min_samples_leaf': 13, 'max_features': 0.6435488524449694, 'max_samples': 0.5224206435177171}.
# [I 2026-04-27 18:54:39,008] Trial 286 finished with values: [0.5576599233881223, 0.02904895294845697] and parameters: {'n_estimators': 253, 'max_depth': 6, 'min_samples_split': 15, 'min_samples_leaf': 16, 'max_features': 0.6424001829908433, 'max_samples': 0.5251154491365365}.
# [I 2026-04-27 18:56:30,517] Trial 281 finished with values: [0.48076419937398196, 0.05718983561917999] and parameters: {'n_estimators': 320, 'max_depth': 10, 'min_samples_split': 14, 'min_samples_leaf': 18, 'max_features': 0.6317147254304396, 'max_samples': 0.5223327147914072}.
# [I 2026-04-27 18:57:59,486] Trial 291 finished with values: [0.5252615127271751, 0.03869466026923575] and parameters: {'n_estimators': 242, 'max_depth': 7, 'min_samples_split': 15, 'min_samples_leaf': 8, 'max_features': 0.6626504841627421, 'max_samples': 0.5249175369025441}.
# [I 2026-04-27 18:58:43,789] Trial 285 finished with values: [0.5576264970340828, 0.029218487826799228] and parameters: {'n_estimators': 319, 'max_depth': 6, 'min_samples_split': 14, 'min_samples_leaf': 16, 'max_features': 0.6434115558354422, 'max_samples': 0.5247842874157859}.
# [I 2026-04-27 19:00:54,930] Trial 276 finished with values: [0.4638175426617758, 0.09245566159665677] and parameters: {'n_estimators': 240, 'max_depth': 30, 'min_samples_split': 11, 'min_samples_leaf': 11, 'max_features': 0.6394846309512103, 'max_samples': 0.5045138069197849}.
# [I 2026-04-27 19:01:52,345] Trial 289 finished with values: [0.5249709280931524, 0.03594012330715461] and parameters: {'n_estimators': 253, 'max_depth': 7, 'min_samples_split': 15, 'min_samples_leaf': 18, 'max_features': 0.6611323193127405, 'max_samples': 0.5012236289607717}.
# [I 2026-04-27 19:04:52,697] Trial 288 finished with values: [0.5252140709584814, 0.038604770657540005] and parameters: {'n_estimators': 319, 'max_depth': 7, 'min_samples_split': 15, 'min_samples_leaf': 9, 'max_features': 0.6449846287284762, 'max_samples': 0.5240943419767599}.
# [I 2026-04-27 19:07:15,659] Trial 294 finished with values: [0.48633172925662843, 0.04932629895847994] and parameters: {'n_estimators': 324, 'max_depth': 10, 'min_samples_split': 15, 'min_samples_leaf': 27, 'max_features': 0.6586123381594164, 'max_samples': 0.5265173158964279}.
# [I 2026-04-27 19:07:29,086] Trial 298 finished with values: [0.529285824294796, 0.03272000055117029] and parameters: {'n_estimators': 326, 'max_depth': 7, 'min_samples_split': 15, 'min_samples_leaf': 37, 'max_features': 0.655301678044997, 'max_samples': 0.5240092580461959}.
# [I 2026-04-27 19:08:02,032] Trial 292 finished with values: [0.4795148565094459, 0.05539597406674411] and parameters: {'n_estimators': 258, 'max_depth': 30, 'min_samples_split': 15, 'min_samples_leaf': 27, 'max_features': 0.6608841266597911, 'max_samples': 0.5233458025512094}.
# [I 2026-04-27 19:08:31,391] Trial 299 finished with values: [0.5281456804085292, 0.03632098744849141] and parameters: {'n_estimators': 228, 'max_depth': 7, 'min_samples_split': 15, 'min_samples_leaf': 37, 'max_features': 0.6638813986118902, 'max_samples': 0.9393582570834529}.
# [I 2026-04-27 19:09:05,046] Trial 284 finished with values: [0.4682103218074628, 0.07543297455449349] and parameters: {'n_estimators': 319, 'max_depth': 30, 'min_samples_split': 14, 'min_samples_leaf': 16, 'max_features': 0.6339409298716442, 'max_samples': 0.5239771038556353}.
# [I 2026-04-27 19:09:41,961] Trial 293 finished with values: [0.5262205851669549, 0.03701741669891105] and parameters: {'n_estimators': 321, 'max_depth': 7, 'min_samples_split': 15, 'min_samples_leaf': 27, 'max_features': 0.6613280838612919, 'max_samples': 0.8905621723877571}.
# [I 2026-04-27 19:11:35,385] Trial 290 finished with values: [0.46022611053001805, 0.113765868587802] and parameters: {'n_estimators': 320, 'max_depth': 30, 'min_samples_split': 15, 'min_samples_leaf': 8, 'max_features': 0.6581790102921918, 'max_samples': 0.5242546666472404}.
# [I 2026-04-27 19:11:47,260] Trial 295 finished with values: [0.4809546088679849, 0.05880184929507633] and parameters: {'n_estimators': 239, 'max_depth': 10, 'min_samples_split': 15, 'min_samples_leaf': 27, 'max_features': 0.6581399941773948, 'max_samples': 0.886739325453179}.
# [I 2026-04-27 19:13:50,241] Trial 296 finished with values: [0.4705158403510087, 0.07022211682845472] and parameters: {'n_estimators': 321, 'max_depth': 30, 'min_samples_split': 15, 'min_samples_leaf': 18, 'max_features': 0.6637041764414281, 'max_samples': 0.5238312128737315}.
# [I 2026-04-27 19:13:54,115] Trial 297 finished with values: [0.4782114163923852, 0.059472309213230795] and parameters: {'n_estimators': 227, 'max_depth': 29, 'min_samples_split': 15, 'min_samples_leaf': 37, 'max_features': 0.6619113757885257, 'max_samples': 0.8958309478045339}.

# %% [markdown]
# #### 6.4.2 Sélection du meilleur essai Optuna et évaluation du modèle RandomForestRegressor
#
# Après l'optimisation, l'étude Optuna est rechargée afin de sélectionner le meilleur compromis parmi les essais du front de Pareto.
#
# Le modèle RandomForestRegressor retenu est ensuite entraîné sur l'ensemble `train`, puis évalué sur les ensembles `train` et `valid`.
#
# Les métriques obtenues sont ajoutées au tableau global des résultats afin de comparer RandomForestRegressor aux modèles précédents.

# %%
# =============================================================
# Sélection du meilleur essai Optuna et évaluation RandomForest
# =============================================================

# Copie des ensembles utilisés pour RandomForestRegressor
X_train_rf = X_train.copy()
X_valid_rf = X_valid.copy()

# Chargement de l'étude Optuna déjà optimisée
study_rf = optuna.load_study(
    study_name="study_rf_new",
    storage=f"sqlite:///{filepath_output}study_rf_new.db"
)


# ==============================================
# Sélection du meilleur essai du front de Pareto
# ==============================================

# Optuna retourne plusieurs meilleurs essais car l'étude est multi-objective
rf_trials = study_rf.best_trials

# Choix d'un compromis :
# - faible MAE moyenne en validation croisée temporelle
# - pénalité si le gap relatif dépasse 5 %
best_trial_rf = min(
    rf_trials,
    key=lambda t: t.values[0] + 50 * max(0, (t.values[1] / t.values[0]) - 0.05)
)

print("Selected trial:")
print(f"MAE = {best_trial_rf.values[0]}")
print(f"GAP = {best_trial_rf.values[1]}")


# ==========================================
# Récupération des meilleurs hyperparamètres
# ==========================================

# Copie des paramètres pour éviter de modifier directement l'objet Optuna
best_params_rf = best_trial_rf.params.copy()

print("Best_params_rf:", best_params_rf)


# =========================================
# Entraînement du modèle RandomForest final
# =========================================

best_model_rf = RandomForestRegressor(
    random_state=42,
    n_jobs=-1,
    **best_params_rf
)

# Entraînement sur l'ensemble train
best_model_rf.fit(X_train_rf, y_train)


# ==================================
# Évaluation sur train et validation
# ==================================

# Prédictions
y_pred_train_rf = best_model_rf.predict(X_train_rf)
y_pred_valid_rf = best_model_rf.predict(X_valid_rf)

# Métriques train
mae_train_rf = mean_absolute_error(y_train, y_pred_train_rf)
rmse_train_rf = np.sqrt(mean_squared_error(y_train, y_pred_train_rf))
r2_train_rf = r2_score(y_train, y_pred_train_rf)
nmae_train_rf = calculer_nmae(y_train, y_pred_train_rf)

# Métriques validation
mae_valid_rf = mean_absolute_error(y_valid, y_pred_valid_rf)
rmse_valid_rf = np.sqrt(mean_squared_error(y_valid, y_pred_valid_rf))
r2_valid_rf = r2_score(y_valid, y_pred_valid_rf)
nmae_valid_rf = calculer_nmae(y_valid, y_pred_valid_rf)

# Pourcentage d'overfitting final
overfit_pct_rf = (
    100 * max(0, mae_valid_rf - mae_train_rf) / mae_valid_rf
    if mae_valid_rf != 0 else np.nan
)


# =======================
# Affichage des résultats
# =======================

print("\n--- Résultats RandomForestRegressor ---")

print(f"MAE valid_rf      : {mae_valid_rf}")
print(f"MAE train_rf      : {mae_train_rf}")

print(f"NMAE valid_rf     : {nmae_valid_rf:.3f} %")
print(f"NMAE train_rf     : {nmae_train_rf:.3f} %")

print(f"RMSE valid_rf     : {rmse_valid_rf}")
print(f"RMSE train_rf     : {rmse_train_rf}")

print(f"R² valid_rf       : {r2_valid_rf}")
print(f"R² train_rf       : {r2_train_rf}")

print(f"Overfitting CV    : {best_trial_rf.user_attrs['overfit_gap_pct']:.2f} %")
print(f"Overfitting final : {overfit_pct_rf:.2f} %")

# MAE moyenne obtenue pendant la validation croisée temporelle
MAE_CV_moyenne_rf = best_trial_rf.user_attrs["mean_mae_valid"]

print("MAE_CV_moyenne_rf:", MAE_CV_moyenne_rf)


# =====================================
# Ajout au tableau global des résultats
# =====================================

# Supprimer une ancienne ligne RandomForest si elle existe déjà
resultats = [
    r for r in resultats
    if r["Modèle"] != "RandomForestRegressor"
]

# Ajout du modèle RandomForest au tableau global
resultats.append(
    calculer_metriques(
        y_train,
        y_pred_train_rf,
        y_valid,
        y_pred_valid_rf,
        nom_modele="RandomForestRegressor",
        MAE_CV_moyenne=MAE_CV_moyenne_rf
    )
)

# Tableau comparatif final, trié par performance sur validation
resultats_df = pd.DataFrame(resultats).sort_values("MAE_valid")

display(resultats_df)
# Out:
# Selected trial:
# MAE = 0.5579337742049324
# GAP = 0.02829186739127665
# Best_params_rf: {'n_estimators': 247, 'max_depth': 6, 'min_samples_split': 16, 'min_samples_leaf': 24, 'max_features': 0.6825494585336842, 'max_samples': 0.5335843729474861}
#
# --- Résultats RandomForestRegressor ---
# MAE valid_rf      : 0.5923803215707527
# MAE train_rf      : 0.5342817995725402
# NMAE valid_rf     : 24.608 %
# NMAE train_rf     : 21.885 %
# RMSE valid_rf     : 1.2174492167492743
# RMSE train_rf     : 1.058951334102703
# R² valid_rf       : 0.8624540495511098
# R² train_rf       : 0.8976302608235173
# Overfitting CV    : 5.07 %
# Overfitting final : 9.81 %
# MAE_CV_moyenne_rf: 0.5579337742049324
#                             Modèle  MAE_train  NMAE_train (%)  RMSE_train  \
# 5                    LGBMRegressor       0.45           18.56        0.94
# 7              ExtraTreesRegressor       0.47           19.19        0.98
# 6                     XGBRegressor       0.49           20.01        0.98
# 8            RandomForestRegressor       0.53           21.89        1.06
# 4                            Lasso       0.72           29.44        1.21
# 3                            Ridge       0.72           29.42        1.20
# 2  Régression linéaire multivariée       0.72           29.62        1.18
# 0                             Naïf       0.95           38.84        1.66
# 1       Régression linéaire simple       1.05           43.05        1.88
#
#    R2_train  MAE_valid  NMAE_valid (%)  RMSE_valid  R2_valid  MAE_CV_moyenne  \
# 5      0.92       0.52           21.59        1.14      0.88            0.49
# 7      0.91       0.53           21.96        1.15      0.88            0.59
# 6      0.91       0.55           22.67        1.16      0.88            0.51
# 8      0.90       0.59           24.61        1.22      0.86            0.56
# 4      0.87       0.76           31.41        1.34      0.83            0.73
# 3      0.87       0.76           31.53        1.34      0.83            0.73
# 2      0.87       0.76           31.75        1.33      0.84             NaN
# 0      0.75       0.98           40.69        1.78      0.71             NaN
# 1      0.68       1.11           45.96        2.00      0.63             NaN
#
#    Gap_MAE_valid_train  Gap_R2_train_valid
# 5                 0.07                0.04
# 7                 0.06                0.03
# 6                 0.06                0.04
# 8                 0.06                0.04
# 4                 0.04                0.03
# 3                 0.04                0.04
# 2                 0.04                0.04
# 0                 0.03                0.04
# 1                 0.06                0.05

# %%
# ===========================================================
# Sauvegarde et rechargement du meilleur modèle RandomForest
# ===========================================================

# Chemin complet du fichier de sauvegarde
model_path_rf = best_models_path + "best_model_rf.joblib"

# Sauvegarde du meilleur modèle RandomForest entraîné
joblib.dump(best_model_rf, model_path_rf)

print("Modèle RandomForest sauvegardé dans :", model_path_rf)

# Rechargement du modèle sauvegardé
best_model_rf = joblib.load(model_path_rf)

print("Modèle RandomForest rechargé avec succès.")
# Out:
# Modèle RandomForest sauvegardé dans : /Users/mibrahim/Desktop/Varaiability/data/local_data/05_Modelisation/output/output_jour_nuit/Best_Models/best_model_rf.joblib
# Modèle RandomForest rechargé avec succès.

# %% [markdown]
# #### 6.4.3 Visualisation des prédictions RandomForest

# %%
# ================================================================
# Visualisation : valeurs réelles vs valeurs prédites RandomForest
# ================================================================

# Cette cellule compare les valeurs réelles de la cible avec les prédictions
# du modèle RandomForest sur l'ensemble de validation.

plt.figure(figsize=(6, 6))

# Nuage de points :
# axe x : valeurs réelles
# axe y : valeurs prédites par RandomForest
plt.scatter(y_valid, y_pred_valid_rf, alpha=0.5)

# Ligne idéale y = x
# Si les prédictions étaient parfaites, tous les points seraient sur cette ligne
min_val = min(y_valid.min(), y_pred_valid_rf.min())
max_val = max(y_valid.max(), y_pred_valid_rf.max())

plt.plot(
    [min_val, max_val],
    [min_val, max_val],
    "r--",
    label="Prédiction parfaite"
)

# Titres et labels
plt.xlabel("Valeurs réelles")
plt.ylabel("Valeurs prédites")
plt.title("RandomForest - Valeurs réelles vs valeurs prédites sur validation")

# Légende
plt.legend()

# Affichage
plt.show()

# %% [markdown]
# ### 6.5 HistGradientBoosting
#
# HistGradientBoostingRegressor est une implémentation efficace du gradient boosting proposée par scikit-learn.
#
# Comme les autres modèles de boosting, il construit progressivement plusieurs arbres afin de corriger les erreurs des modèles précédents.
# Il utilise une approche basée sur des histogrammes, ce qui permet d'accélérer l'entraînement sur des données tabulaires.
#
# Ce modèle est intéressant ici comme alternative supplémentaire à LightGBM et XGBoost.
# Il permet de comparer plusieurs approches d'arbres boostés dans les mêmes conditions expérimentales.
#
# L'objectif est donc d'évaluer si HistGradientBoostingRegressor peut offrir une performance compétitive par rapport aux autres modèles avancés déjà testés.

# %% [markdown]
# #### 6.5.1 Optimisation des hyperparamètres HistGradientBoostingRegressor avec Optuna
#
# HistGradientBoostingRegressor est optimisé avec Optuna en utilisant les folds temporels définis manuellement.
#
# Comme pour les modèles précédents, la sélection repose sur la MAE moyenne de validation croisée temporelle et sur le contrôle du gap train/validation.

# %%
# ===============================
# HIST GRADIENT BOOSTING REGRESSOR
# ===============================

from sklearn.ensemble import HistGradientBoostingRegressor

# Copie des ensembles utilisés pour HistGradientBoostingRegressor
X_train_hgb = X_train.copy()
X_valid_hgb = X_valid.copy()


# ===================================================================
# Évaluation d'une combinaison d'hyperparamètres HistGradientBoosting
# ===================================================================

def evaluate_params_hgb(params, X, y, trial=None):

    # Listes pour stocker les métriques de chaque fold
    maes_valid = []
    maes_train = []

    rmses_valid = []
    rmses_train = []

    r2_trains = []
    r2_valids = []

    gaps = []

    # Génération des folds temporels manuels
    folds = get_folds(X, y)

    # Boucle sur les folds
    for step, (X_tr, X_v, y_tr, y_v) in enumerate(folds):

        # Création du modèle avec les paramètres proposés par Optuna
        model = HistGradientBoostingRegressor(**params)

        # Entraînement sur la période passée du fold
        model.fit(X_tr, y_tr)

        # Prédictions sur train et validation du fold
        pred_train = model.predict(X_tr)
        pred_valid = model.predict(X_v)

        # MAE train et validation
        mae_train = mean_absolute_error(y_tr, pred_train)
        mae_valid = mean_absolute_error(y_v, pred_valid)

        # RMSE train et validation
        rmse_train = np.sqrt(mean_squared_error(y_tr, pred_train))
        rmse_valid = np.sqrt(mean_squared_error(y_v, pred_valid))

        # R² train et validation
        r2_train = r2_score(y_tr, pred_train)
        r2_valid = r2_score(y_v, pred_valid)

        # Gap train-validation
        gap = max(0, mae_valid - mae_train)

        # Stockage des métriques du fold
        maes_train.append(mae_train)
        maes_valid.append(mae_valid)

        rmses_train.append(rmse_train)
        rmses_valid.append(rmse_valid)

        r2_trains.append(r2_train)
        r2_valids.append(r2_valid)

        gaps.append(gap)

    # Moyennes des métriques sur tous les folds
    mean_mae_valid = np.mean(maes_valid)
    mean_mae_train = np.mean(maes_train)

    std_mae_valid = np.std(maes_valid)
    std_mae_train = np.std(maes_train)

    mean_rmse_valid = np.mean(rmses_valid)
    mean_rmse_train = np.mean(rmses_train)

    mean_r2_valid = np.mean(r2_valids)
    mean_r2_train = np.mean(r2_trains)

    mean_gap = np.mean(gaps)

    # Pourcentage d'overfitting
    gap_pct = (
        100 * max(0, mean_mae_valid - mean_mae_train) / mean_mae_valid
        if mean_mae_valid != 0 else np.nan
    )

    # Sauvegarde des informations utiles dans Optuna
    if trial is not None:
        trial.set_user_attr("mean_mae_valid", mean_mae_valid)
        trial.set_user_attr("mean_mae_train", mean_mae_train)

        trial.set_user_attr("std_mae_valid", std_mae_valid)
        trial.set_user_attr("std_mae_train", std_mae_train)

        trial.set_user_attr("mean_rmse_valid", mean_rmse_valid)
        trial.set_user_attr("mean_rmse_train", mean_rmse_train)

        trial.set_user_attr("mean_r2_valid", mean_r2_valid)
        trial.set_user_attr("mean_r2_train", mean_r2_train)

        trial.set_user_attr("mean_gap", mean_gap)
        trial.set_user_attr("std_gap", np.std(gaps))
        trial.set_user_attr("max_gap", np.max(gaps))
        trial.set_user_attr("overfit_gap_pct", gap_pct)

    # Optuna minimise ces deux objectifs
    return mean_mae_valid, mean_gap

# ============================================================
# Fonction objective Optuna pour HistGradientBoostingRegressor
# ============================================================

def objective_hgb(trial):
    
    params = {
        # Fonction de perte adaptée à la MAE
        "loss": "absolute_error",

        # Taux d'apprentissage
        "learning_rate": trial.suggest_float(
            "learning_rate", 0.01, 0.2, log=True
        ),

        # Nombre d'itérations de boosting
        "max_iter": trial.suggest_int(
            "max_iter", 100, 600
        ),

        # Complexité des arbres
        "max_leaf_nodes": trial.suggest_int(
            "max_leaf_nodes", 15, 63
        ),

        "max_depth": trial.suggest_int(
            "max_depth", 3, 12
        ),

        # Régularisation et contrôle du surapprentissage
        "min_samples_leaf": trial.suggest_int(
            "min_samples_leaf", 10, 100
        ),

        "l2_regularization": trial.suggest_float(
            "l2_regularization", 0.0, 5.0
        ),

        # Nombre de bins pour la discrétisation des variables continues
        "max_bins": trial.suggest_int(
            "max_bins", 64, 255
        ),

        "random_state": 42,
        "verbose": 0
    }

    return evaluate_params_hgb(
        params=params,
        X=X_dev,
        y=y_dev,
        trial=trial
    )

# =================================================================
# Création et lancement de l'étude Optuna pour HistGradientBoosting
# =================================================================

study_hgb = optuna.create_study(
    study_name="study_hgb_new",
    storage=f"sqlite:///{filepath_output}study_hgb_new.db",
    load_if_exists=True,
    directions=["minimize", "minimize"],
    sampler=optuna.samplers.TPESampler(
        n_startup_trials=60,
        seed=42
    )
)

# Lancement de l'optimisation
study_hgb.optimize(
    objective_hgb,
    n_trials=150,
    n_jobs=-1
)
# Out:
# [I 2026-04-27 21:36:37,052] A new study created in RDB with name: study_hgb_new
# [I 2026-04-27 21:37:10,263] Trial 8 finished with values: [0.5822330752624879, 0.021174438153010927] and parameters: {'learning_rate': 0.018458846946140264, 'max_iter': 257, 'max_leaf_nodes': 38, 'max_depth': 3, 'min_samples_leaf': 58, 'l2_regularization': 0.9437707051501593, 'max_bins': 135}.
# [I 2026-04-27 21:37:11,455] Trial 0 finished with values: [0.5584203459267982, 0.02658144421367717] and parameters: {'learning_rate': 0.024101076539928552, 'max_iter': 149, 'max_leaf_nodes': 26, 'max_depth': 4, 'min_samples_leaf': 22, 'l2_regularization': 1.3369363518526278, 'max_bins': 110}.
# [I 2026-04-27 21:37:16,608] Trial 7 finished with values: [0.4981129444896892, 0.025105619669050352] and parameters: {'learning_rate': 0.09446304445060125, 'max_iter': 316, 'max_leaf_nodes': 53, 'max_depth': 3, 'min_samples_leaf': 27, 'l2_regularization': 4.1593063283434635, 'max_bins': 107}.
# [I 2026-04-27 21:37:20,963] Trial 3 finished with values: [0.5111282483383672, 0.022062347096476337] and parameters: {'learning_rate': 0.052617721141628764, 'max_iter': 366, 'max_leaf_nodes': 53, 'max_depth': 3, 'min_samples_leaf': 48, 'l2_regularization': 0.8520052041704235, 'max_bins': 193}.
# [I 2026-04-27 21:37:27,226] Trial 9 finished with values: [0.5184957405382945, 0.03409636930934237] and parameters: {'learning_rate': 0.026163661466479884, 'max_iter': 127, 'max_leaf_nodes': 23, 'max_depth': 7, 'min_samples_leaf': 57, 'l2_regularization': 4.5922719302386135, 'max_bins': 212}.
# [I 2026-04-27 21:37:30,100] Trial 6 finished with values: [0.4839036823398279, 0.0322303604659349] and parameters: {'learning_rate': 0.13677508808598826, 'max_iter': 439, 'max_leaf_nodes': 46, 'max_depth': 3, 'min_samples_leaf': 58, 'l2_regularization': 2.8187163355406235, 'max_bins': 158}.
# [I 2026-04-27 21:37:42,252] Trial 11 finished with values: [0.4763602248894949, 0.035077728706791225] and parameters: {'learning_rate': 0.041617035652307045, 'max_iter': 204, 'max_leaf_nodes': 40, 'max_depth': 5, 'min_samples_leaf': 64, 'l2_regularization': 4.640384019299651, 'max_bins': 113}.
# [I 2026-04-27 21:37:52,486] Trial 16 finished with values: [0.4990570116181793, 0.02314970657266581] and parameters: {'learning_rate': 0.06506942242571923, 'max_iter': 372, 'max_leaf_nodes': 38, 'max_depth': 3, 'min_samples_leaf': 24, 'l2_regularization': 0.7677740114654841, 'max_bins': 106}.
# [I 2026-04-27 21:38:21,366] Trial 13 finished with values: [0.4573682946670349, 0.051660484816362054] and parameters: {'learning_rate': 0.049961016434075904, 'max_iter': 175, 'max_leaf_nodes': 34, 'max_depth': 11, 'min_samples_leaf': 50, 'l2_regularization': 1.5361143258945424, 'max_bins': 154}.
# [I 2026-04-27 21:38:48,331] Trial 15 finished with values: [0.5397199490952811, 0.037480412927885356] and parameters: {'learning_rate': 0.011332503008664485, 'max_iter': 255, 'max_leaf_nodes': 28, 'max_depth': 11, 'min_samples_leaf': 27, 'l2_regularization': 0.6307270008586857, 'max_bins': 164}.
# [I 2026-04-27 21:38:49,174] Trial 2 finished with values: [0.5069462817805203, 0.041187329352167595] and parameters: {'learning_rate': 0.016320154534806352, 'max_iter': 209, 'max_leaf_nodes': 61, 'max_depth': 7, 'min_samples_leaf': 99, 'l2_regularization': 2.461460596481959, 'max_bins': 79}.
# [I 2026-04-27 21:38:49,538] Trial 10 finished with values: [0.4612781519189896, 0.07612614512587842] and parameters: {'learning_rate': 0.13849746383057537, 'max_iter': 390, 'max_leaf_nodes': 23, 'max_depth': 6, 'min_samples_leaf': 52, 'l2_regularization': 0.7054692982214872, 'max_bins': 69}.
# [I 2026-04-27 21:38:55,577] Trial 20 finished with values: [0.5214254066022557, 0.024350269637645652] and parameters: {'learning_rate': 0.011155998416459334, 'max_iter': 454, 'max_leaf_nodes': 39, 'max_depth': 4, 'min_samples_leaf': 84, 'l2_regularization': 4.113807301257606, 'max_bins': 78}.
# [I 2026-04-27 21:39:05,290] Trial 12 finished with values: [0.45471535667047336, 0.0776542016404698] and parameters: {'learning_rate': 0.0692846988210166, 'max_iter': 205, 'max_leaf_nodes': 46, 'max_depth': 12, 'min_samples_leaf': 76, 'l2_regularization': 0.3466300612041284, 'max_bins': 74}.
# [I 2026-04-27 21:39:17,133] Trial 28 finished with values: [0.7161158146842802, 0.033829320034113375] and parameters: {'learning_rate': 0.020514788154079023, 'max_iter': 100, 'max_leaf_nodes': 58, 'max_depth': 4, 'min_samples_leaf': 50, 'l2_regularization': 0.4069558470344131, 'max_bins': 227}.
# [I 2026-04-27 21:39:36,680] Trial 18 finished with values: [0.45952960047507285, 0.09966536952387875] and parameters: {'learning_rate': 0.1520326277517847, 'max_iter': 321, 'max_leaf_nodes': 39, 'max_depth': 7, 'min_samples_leaf': 73, 'l2_regularization': 3.072147555785209, 'max_bins': 232}.
# [I 2026-04-27 21:39:47,250] Trial 1 finished with values: [0.46024669924996525, 0.04279253669153758] and parameters: {'learning_rate': 0.02299768454572729, 'max_iter': 544, 'max_leaf_nodes': 20, 'max_depth': 12, 'min_samples_leaf': 98, 'l2_regularization': 1.344458909947999, 'max_bins': 161}.
# [I 2026-04-27 21:39:54,107] Trial 5 finished with values: [0.45932142739525167, 0.1277483774623956] and parameters: {'learning_rate': 0.16403690750751584, 'max_iter': 332, 'max_leaf_nodes': 54, 'max_depth': 8, 'min_samples_leaf': 65, 'l2_regularization': 2.1910460089264734, 'max_bins': 82}.
# [I 2026-04-27 21:40:00,629] Trial 24 finished with values: [0.4597806382319989, 0.058037714311379426] and parameters: {'learning_rate': 0.08110320663685638, 'max_iter': 280, 'max_leaf_nodes': 25, 'max_depth': 6, 'min_samples_leaf': 74, 'l2_regularization': 4.0609714349424255, 'max_bins': 133}.
# [I 2026-04-27 21:40:05,922] Trial 25 finished with values: [0.6508577918008696, 0.04051313825602554] and parameters: {'learning_rate': 0.01373031042838296, 'max_iter': 149, 'max_leaf_nodes': 31, 'max_depth': 9, 'min_samples_leaf': 69, 'l2_regularization': 4.939870473471414, 'max_bins': 72}.
# [I 2026-04-27 21:40:11,945] Trial 21 finished with values: [0.4881326694494519, 0.0367481539161085] and parameters: {'learning_rate': 0.013311782321292513, 'max_iter': 298, 'max_leaf_nodes': 30, 'max_depth': 11, 'min_samples_leaf': 28, 'l2_regularization': 4.244485033468951, 'max_bins': 69}.
# [I 2026-04-27 21:40:14,359] Trial 19 finished with values: [0.45613043867878744, 0.10732758393905838] and parameters: {'learning_rate': 0.1589145184038369, 'max_iter': 477, 'max_leaf_nodes': 24, 'max_depth': 11, 'min_samples_leaf': 92, 'l2_regularization': 1.9452983378183597, 'max_bins': 170}.
# [I 2026-04-27 21:40:40,115] Trial 14 finished with values: [0.46425643636952696, 0.04029110795103383] and parameters: {'learning_rate': 0.01277430959769544, 'max_iter': 575, 'max_leaf_nodes': 27, 'max_depth': 7, 'min_samples_leaf': 49, 'l2_regularization': 3.241318961416794, 'max_bins': 189}.
# [I 2026-04-27 21:40:44,390] Trial 33 finished with values: [0.6789788870099829, 0.03751157617157114] and parameters: {'learning_rate': 0.015351158990577936, 'max_iter': 127, 'max_leaf_nodes': 22, 'max_depth': 9, 'min_samples_leaf': 70, 'l2_regularization': 3.846841798631149, 'max_bins': 112}.
# [I 2026-04-27 21:41:19,470] Trial 17 finished with values: [0.4526055808253345, 0.1029596364795081] and parameters: {'learning_rate': 0.08753440285747925, 'max_iter': 574, 'max_leaf_nodes': 27, 'max_depth': 12, 'min_samples_leaf': 42, 'l2_regularization': 3.5029032707693593, 'max_bins': 158}.
# [I 2026-04-27 21:41:20,157] Trial 27 finished with values: [0.45776537239371495, 0.04856303316481708] and parameters: {'learning_rate': 0.03350678518608116, 'max_iter': 352, 'max_leaf_nodes': 31, 'max_depth': 7, 'min_samples_leaf': 94, 'l2_regularization': 1.1802784979285281, 'max_bins': 246}.
# [I 2026-04-27 21:41:42,694] Trial 34 finished with values: [0.4560756850940375, 0.06885555794826419] and parameters: {'learning_rate': 0.10755244458680405, 'max_iter': 268, 'max_leaf_nodes': 24, 'max_depth': 8, 'min_samples_leaf': 86, 'l2_regularization': 2.846666239468714, 'max_bins': 100}.
# [I 2026-04-27 21:41:59,189] Trial 22 finished with values: [0.45757601336092363, 0.05244271045805357] and parameters: {'learning_rate': 0.02505046305774174, 'max_iter': 526, 'max_leaf_nodes': 29, 'max_depth': 11, 'min_samples_leaf': 17, 'l2_regularization': 1.6233271989099092, 'max_bins': 66}.
# [I 2026-04-27 21:41:59,875] Trial 35 finished with values: [0.4814929634132573, 0.030903581111051015] and parameters: {'learning_rate': 0.015330045186246748, 'max_iter': 348, 'max_leaf_nodes': 20, 'max_depth': 6, 'min_samples_leaf': 47, 'l2_regularization': 1.41280724161152, 'max_bins': 240}.
# [I 2026-04-27 21:42:06,015] Trial 4 finished with values: [0.4642339777410307, 0.04702083199826727] and parameters: {'learning_rate': 0.010450214617701, 'max_iter': 506, 'max_leaf_nodes': 40, 'max_depth': 10, 'min_samples_leaf': 97, 'l2_regularization': 3.8675938547147886, 'max_bins': 139}.
# [I 2026-04-27 21:42:15,665] Trial 37 finished with values: [0.4582624192623912, 0.07907505610068764] and parameters: {'learning_rate': 0.17096798828898185, 'max_iter': 400, 'max_leaf_nodes': 19, 'max_depth': 9, 'min_samples_leaf': 74, 'l2_regularization': 2.068401150790109, 'max_bins': 119}.
# [I 2026-04-27 21:42:34,191] Trial 31 finished with values: [0.4548013161718427, 0.06344704601763997] and parameters: {'learning_rate': 0.05166991345832749, 'max_iter': 386, 'max_leaf_nodes': 29, 'max_depth': 8, 'min_samples_leaf': 38, 'l2_regularization': 4.063780601417502, 'max_bins': 69}.
# [I 2026-04-27 21:42:39,977] Trial 38 finished with values: [0.4721969834555567, 0.031542382378115574] and parameters: {'learning_rate': 0.01988296494854028, 'max_iter': 395, 'max_leaf_nodes': 17, 'max_depth': 7, 'min_samples_leaf': 11, 'l2_regularization': 0.34276561287506835, 'max_bins': 112}.
# [I 2026-04-27 21:42:45,817] Trial 29 finished with values: [0.4528570162755942, 0.11174294385873926] and parameters: {'learning_rate': 0.08380222330405335, 'max_iter': 297, 'max_leaf_nodes': 57, 'max_depth': 11, 'min_samples_leaf': 79, 'l2_regularization': 2.5928918439380344, 'max_bins': 147}.
# [I 2026-04-27 21:43:16,938] Trial 26 finished with values: [0.46423231511997914, 0.14367656191749922] and parameters: {'learning_rate': 0.19586763863520976, 'max_iter': 464, 'max_leaf_nodes': 48, 'max_depth': 7, 'min_samples_leaf': 26, 'l2_regularization': 4.161674204464733, 'max_bins': 195}.
# [I 2026-04-27 21:43:17,346] Trial 30 finished with values: [0.44854598658620026, 0.09601192728444675] and parameters: {'learning_rate': 0.05829949128147674, 'max_iter': 345, 'max_leaf_nodes': 51, 'max_depth': 12, 'min_samples_leaf': 94, 'l2_regularization': 3.0950097600538804, 'max_bins': 248}.
# [I 2026-04-27 21:43:23,458] Trial 40 finished with values: [0.46383554928003656, 0.03868969693793507] and parameters: {'learning_rate': 0.025877682224456494, 'max_iter': 303, 'max_leaf_nodes': 23, 'max_depth': 11, 'min_samples_leaf': 65, 'l2_regularization': 3.0917316656868903, 'max_bins': 136}.
# [I 2026-04-27 21:43:24,587] Trial 45 finished with values: [0.46565439707525164, 0.07207892930695997] and parameters: {'learning_rate': 0.15090539314655968, 'max_iter': 205, 'max_leaf_nodes': 26, 'max_depth': 6, 'min_samples_leaf': 15, 'l2_regularization': 1.1407556244710515, 'max_bins': 206}.
# [I 2026-04-27 21:43:54,154] Trial 41 finished with values: [0.45699819980832584, 0.09156119792255973] and parameters: {'learning_rate': 0.10275517911808202, 'max_iter': 272, 'max_leaf_nodes': 49, 'max_depth': 8, 'min_samples_leaf': 99, 'l2_regularization': 2.746056812806702, 'max_bins': 68}.
# [I 2026-04-27 21:43:55,077] Trial 43 finished with values: [0.45523440394875275, 0.06408829642309567] and parameters: {'learning_rate': 0.08349874315034221, 'max_iter': 318, 'max_leaf_nodes': 23, 'max_depth': 10, 'min_samples_leaf': 91, 'l2_regularization': 0.9413712522567091, 'max_bins': 235}.
# [I 2026-04-27 21:43:58,655] Trial 36 finished with values: [0.45187849483237996, 0.11030820271426457] and parameters: {'learning_rate': 0.09693996729715643, 'max_iter': 415, 'max_leaf_nodes': 37, 'max_depth': 9, 'min_samples_leaf': 44, 'l2_regularization': 0.8691575396776752, 'max_bins': 145}.
# [I 2026-04-27 21:44:13,259] Trial 39 finished with values: [0.47658764282821614, 0.03793959330806519] and parameters: {'learning_rate': 0.01113540120159168, 'max_iter': 427, 'max_leaf_nodes': 32, 'max_depth': 7, 'min_samples_leaf': 78, 'l2_regularization': 1.6185457642497387, 'max_bins': 143}.
# [I 2026-04-27 21:45:36,019] Trial 46 finished with values: [0.4561876320076018, 0.1046393499833078] and parameters: {'learning_rate': 0.12284170907718972, 'max_iter': 439, 'max_leaf_nodes': 41, 'max_depth': 6, 'min_samples_leaf': 30, 'l2_regularization': 3.3816149187999534, 'max_bins': 174}.
# [I 2026-04-27 21:45:36,907] Trial 23 finished with values: [0.4511280789974813, 0.07892039632648692] and parameters: {'learning_rate': 0.017607031089559137, 'max_iter': 514, 'max_leaf_nodes': 63, 'max_depth': 10, 'min_samples_leaf': 51, 'l2_regularization': 2.611938527449321, 'max_bins': 174}.
# [I 2026-04-27 21:45:53,232] Trial 48 finished with values: [0.45211975139034066, 0.0906269161107248] and parameters: {'learning_rate': 0.08079434702100209, 'max_iter': 353, 'max_leaf_nodes': 38, 'max_depth': 9, 'min_samples_leaf': 75, 'l2_regularization': 0.6503136759473771, 'max_bins': 124}.
# [I 2026-04-27 21:46:07,619] Trial 56 finished with values: [0.45914440388547084, 0.05952479515263444] and parameters: {'learning_rate': 0.08808384345860396, 'max_iter': 498, 'max_leaf_nodes': 17, 'max_depth': 5, 'min_samples_leaf': 85, 'l2_regularization': 0.22824919672541466, 'max_bins': 123}.
# [I 2026-04-27 21:46:22,360] Trial 58 finished with values: [0.5276874028948605, 0.030843270248310115] and parameters: {'learning_rate': 0.02810581961970832, 'max_iter': 133, 'max_leaf_nodes': 52, 'max_depth': 5, 'min_samples_leaf': 64, 'l2_regularization': 0.3648237886418604, 'max_bins': 66}.
# [I 2026-04-27 21:46:28,122] Trial 50 finished with values: [0.48909381130424967, 0.0517264420513457] and parameters: {'learning_rate': 0.017266780297874814, 'max_iter': 206, 'max_leaf_nodes': 56, 'max_depth': 11, 'min_samples_leaf': 38, 'l2_regularization': 0.07139288817494371, 'max_bins': 194}.
# [I 2026-04-27 21:46:31,119] Trial 53 finished with values: [0.4728325489867163, 0.03249290004291858] and parameters: {'learning_rate': 0.011655592809906261, 'max_iter': 578, 'max_leaf_nodes': 18, 'max_depth': 7, 'min_samples_leaf': 72, 'l2_regularization': 0.7918488164305593, 'max_bins': 228}.
# [I 2026-04-27 21:46:35,291] Trial 54 finished with values: [0.6243522099303367, 0.04632635003240748] and parameters: {'learning_rate': 0.01060843908992348, 'max_iter': 201, 'max_leaf_nodes': 46, 'max_depth': 12, 'min_samples_leaf': 49, 'l2_regularization': 1.2274682279541733, 'max_bins': 228}.
# [I 2026-04-27 21:46:40,158] Trial 49 finished with values: [0.4513119407535894, 0.10020150647886793] and parameters: {'learning_rate': 0.06526072569263085, 'max_iter': 303, 'max_leaf_nodes': 51, 'max_depth': 11, 'min_samples_leaf': 52, 'l2_regularization': 4.485191604371096, 'max_bins': 106}.
# [I 2026-04-27 21:46:53,770] Trial 52 finished with values: [0.45876498057837445, 0.11693011013664434] and parameters: {'learning_rate': 0.18231737143505147, 'max_iter': 591, 'max_leaf_nodes': 22, 'max_depth': 11, 'min_samples_leaf': 78, 'l2_regularization': 2.1428117881203117, 'max_bins': 115}.
# [I 2026-04-27 21:47:12,649] Trial 44 finished with values: [0.45092656538386855, 0.13632467874732326] and parameters: {'learning_rate': 0.09134665098503957, 'max_iter': 372, 'max_leaf_nodes': 62, 'max_depth': 12, 'min_samples_leaf': 62, 'l2_regularization': 4.16736533174377, 'max_bins': 173}.
# [I 2026-04-27 21:47:22,742] Trial 32 finished with values: [0.4522402266840734, 0.14439800719342563] and parameters: {'learning_rate': 0.08515454916159154, 'max_iter': 589, 'max_leaf_nodes': 51, 'max_depth': 10, 'min_samples_leaf': 12, 'l2_regularization': 4.6363922421923025, 'max_bins': 214}.
# [I 2026-04-27 21:47:33,203] Trial 63 finished with values: [0.5531972973557404, 0.020243117425157553] and parameters: {'learning_rate': 0.011879801165916828, 'max_iter': 541, 'max_leaf_nodes': 56, 'max_depth': 3, 'min_samples_leaf': 91, 'l2_regularization': 4.385757289799117, 'max_bins': 179}.
# [I 2026-04-27 21:48:13,967] Trial 69 finished with values: [0.48448880921144466, 0.031296934762798045] and parameters: {'learning_rate': 0.15570805511587202, 'max_iter': 420, 'max_leaf_nodes': 48, 'max_depth': 3, 'min_samples_leaf': 68, 'l2_regularization': 1.921430143814622, 'max_bins': 114}.
# [I 2026-04-27 21:48:21,247] Trial 51 finished with values: [0.4508356729741363, 0.11193710261140288] and parameters: {'learning_rate': 0.08056016004838897, 'max_iter': 592, 'max_leaf_nodes': 34, 'max_depth': 11, 'min_samples_leaf': 61, 'l2_regularization': 1.982085449824083, 'max_bins': 109}.
# [I 2026-04-27 21:48:28,899] Trial 55 finished with values: [0.4606443638238255, 0.05472152906728464] and parameters: {'learning_rate': 0.021818561729561668, 'max_iter': 511, 'max_leaf_nodes': 43, 'max_depth': 6, 'min_samples_leaf': 13, 'l2_regularization': 3.67690279191883, 'max_bins': 245}.
# [I 2026-04-27 21:48:39,909] Trial 42 finished with values: [0.45825074724123965, 0.06337748215061535] and parameters: {'learning_rate': 0.017716042529313147, 'max_iter': 541, 'max_leaf_nodes': 58, 'max_depth': 7, 'min_samples_leaf': 18, 'l2_regularization': 0.8122863940693525, 'max_bins': 97}.
# [I 2026-04-27 21:48:47,536] Trial 72 finished with values: [0.537773772110513, 0.019844878938745786] and parameters: {'learning_rate': 0.04142689942780793, 'max_iter': 200, 'max_leaf_nodes': 62, 'max_depth': 3, 'min_samples_leaf': 74, 'l2_regularization': 2.1861141012623158, 'max_bins': 248}.
# [I 2026-04-27 21:48:50,179] Trial 47 finished with values: [0.4526931083028771, 0.09585368359804512] and parameters: {'learning_rate': 0.04393174642003137, 'max_iter': 547, 'max_leaf_nodes': 50, 'max_depth': 8, 'min_samples_leaf': 46, 'l2_regularization': 2.6033655081311697, 'max_bins': 70}.
# [I 2026-04-27 21:48:58,485] Trial 65 finished with values: [0.45766555731368286, 0.07352413611516112] and parameters: {'learning_rate': 0.09336666291402103, 'max_iter': 278, 'max_leaf_nodes': 30, 'max_depth': 12, 'min_samples_leaf': 35, 'l2_regularization': 2.367015669702165, 'max_bins': 70}.
# [I 2026-04-27 21:49:00,060] Trial 59 finished with values: [0.4534421642219681, 0.07066453313570335] and parameters: {'learning_rate': 0.06675879315949668, 'max_iter': 535, 'max_leaf_nodes': 22, 'max_depth': 11, 'min_samples_leaf': 42, 'l2_regularization': 4.291128723293305, 'max_bins': 221}.
# [I 2026-04-27 21:49:12,946] Trial 73 finished with values: [0.6124485931785211, 0.021334399956713407] and parameters: {'learning_rate': 0.010883535698706228, 'max_iter': 350, 'max_leaf_nodes': 29, 'max_depth': 3, 'min_samples_leaf': 65, 'l2_regularization': 1.1965125881858996, 'max_bins': 250}.
# [I 2026-04-27 21:49:18,001] Trial 66 finished with values: [0.454667078272234, 0.06108900350857918] and parameters: {'learning_rate': 0.06777795497516578, 'max_iter': 373, 'max_leaf_nodes': 26, 'max_depth': 7, 'min_samples_leaf': 31, 'l2_regularization': 0.5999860958480951, 'max_bins': 142}.
# [I 2026-04-27 21:49:29,697] Trial 64 finished with values: [0.467955599500207, 0.04524846075521255] and parameters: {'learning_rate': 0.023186931003965745, 'max_iter': 275, 'max_leaf_nodes': 47, 'max_depth': 7, 'min_samples_leaf': 69, 'l2_regularization': 0.29378645927207125, 'max_bins': 65}.
# [I 2026-04-27 21:49:44,548] Trial 60 finished with values: [0.4537992235679064, 0.07255937310164504] and parameters: {'learning_rate': 0.04042461092641798, 'max_iter': 346, 'max_leaf_nodes': 40, 'max_depth': 11, 'min_samples_leaf': 48, 'l2_regularization': 3.14823582912771, 'max_bins': 79}.
# [I 2026-04-27 21:49:44,829] Trial 75 finished with values: [0.48883648110375744, 0.025209580424120567] and parameters: {'learning_rate': 0.039127302451539475, 'max_iter': 251, 'max_leaf_nodes': 36, 'max_depth': 4, 'min_samples_leaf': 33, 'l2_regularization': 2.393703549577871, 'max_bins': 89}.
# [I 2026-04-27 21:49:46,445] Trial 74 finished with values: [0.4632571296390182, 0.05199398026596408] and parameters: {'learning_rate': 0.132192822942026, 'max_iter': 234, 'max_leaf_nodes': 16, 'max_depth': 6, 'min_samples_leaf': 92, 'l2_regularization': 2.7597946663092414, 'max_bins': 230}.
# [I 2026-04-27 21:49:55,595] Trial 77 finished with values: [0.4926206497365466, 0.025736984550144892] and parameters: {'learning_rate': 0.0380050038409004, 'max_iter': 237, 'max_leaf_nodes': 15, 'max_depth': 4, 'min_samples_leaf': 21, 'l2_regularization': 0.5309082736099531, 'max_bins': 131}.
# [I 2026-04-27 21:49:57,922] Trial 68 finished with values: [0.46103013872801296, 0.044535838794305824] and parameters: {'learning_rate': 0.032104722524421155, 'max_iter': 328, 'max_leaf_nodes': 27, 'max_depth': 9, 'min_samples_leaf': 13, 'l2_regularization': 1.2244965769423777, 'max_bins': 131}.
# [I 2026-04-27 21:50:17,954] Trial 76 finished with values: [0.48625995146537854, 0.025551570033940277] and parameters: {'learning_rate': 0.03201356941838576, 'max_iter': 379, 'max_leaf_nodes': 15, 'max_depth': 4, 'min_samples_leaf': 35, 'l2_regularization': 2.295028860747655, 'max_bins': 95}.
# [I 2026-04-27 21:50:18,845] Trial 80 finished with values: [0.49207247538076204, 0.023364241702935454] and parameters: {'learning_rate': 0.0365442372934189, 'max_iter': 236, 'max_leaf_nodes': 35, 'max_depth': 4, 'min_samples_leaf': 23, 'l2_regularization': 0.4744445741439031, 'max_bins': 92}.
# [I 2026-04-27 21:50:24,414] Trial 86 finished with values: [0.5543349778972038, 0.020385601847217105] and parameters: {'learning_rate': 0.03524910341995137, 'max_iter': 181, 'max_leaf_nodes': 35, 'max_depth': 3, 'min_samples_leaf': 10, 'l2_regularization': 1.8009061494119079, 'max_bins': 255}.
# [I 2026-04-27 21:50:29,734] Trial 81 finished with values: [0.4908526316064265, 0.02492391939705467] and parameters: {'learning_rate': 0.03793753349863643, 'max_iter': 238, 'max_leaf_nodes': 15, 'max_depth': 4, 'min_samples_leaf': 23, 'l2_regularization': 0.5436453657040692, 'max_bins': 97}.
# [I 2026-04-27 21:50:30,622] Trial 78 finished with values: [0.48115953019420876, 0.029074045544221994] and parameters: {'learning_rate': 0.037083921485741946, 'max_iter': 372, 'max_leaf_nodes': 34, 'max_depth': 4, 'min_samples_leaf': 23, 'l2_regularization': 1.0457960480382613, 'max_bins': 254}.
# [I 2026-04-27 21:50:33,422] Trial 57 finished with values: [0.45258525962653817, 0.12334471532490943] and parameters: {'learning_rate': 0.0885803194000147, 'max_iter': 595, 'max_leaf_nodes': 58, 'max_depth': 8, 'min_samples_leaf': 57, 'l2_regularization': 4.756931233883771, 'max_bins': 118}.
# [I 2026-04-27 21:50:37,911] Trial 85 finished with values: [0.5138742102562327, 0.024735540269571546] and parameters: {'learning_rate': 0.033500238805050986, 'max_iter': 163, 'max_leaf_nodes': 34, 'max_depth': 4, 'min_samples_leaf': 55, 'l2_regularization': 1.820238779151527, 'max_bins': 255}.
# [I 2026-04-27 21:50:41,772] Trial 83 finished with values: [0.49786453876893844, 0.024490751088455887] and parameters: {'learning_rate': 0.031460059564941585, 'max_iter': 242, 'max_leaf_nodes': 15, 'max_depth': 4, 'min_samples_leaf': 96, 'l2_regularization': 2.366580048256945, 'max_bins': 255}.
# [I 2026-04-27 21:50:43,142] Trial 84 finished with values: [0.49579725849239564, 0.023779586836291666] and parameters: {'learning_rate': 0.03491010230843042, 'max_iter': 234, 'max_leaf_nodes': 36, 'max_depth': 4, 'min_samples_leaf': 81, 'l2_regularization': 1.806814987831771, 'max_bins': 86}.
# [I 2026-04-27 21:50:45,375] Trial 79 finished with values: [0.4821807843317794, 0.027478828027612437] and parameters: {'learning_rate': 0.03731684709196478, 'max_iter': 383, 'max_leaf_nodes': 35, 'max_depth': 4, 'min_samples_leaf': 22, 'l2_regularization': 0.5513857587638779, 'max_bins': 91}.
# [I 2026-04-27 21:50:47,270] Trial 62 finished with values: [0.46172084714815026, 0.05031394872020861] and parameters: {'learning_rate': 0.022264718979283924, 'max_iter': 501, 'max_leaf_nodes': 44, 'max_depth': 6, 'min_samples_leaf': 41, 'l2_regularization': 0.5604331429667525, 'max_bins': 222}.
# [I 2026-04-27 21:51:05,247] Trial 88 finished with values: [0.5067347341265441, 0.024599268466819993] and parameters: {'learning_rate': 0.03389805774558072, 'max_iter': 181, 'max_leaf_nodes': 33, 'max_depth': 4, 'min_samples_leaf': 22, 'l2_regularization': 0.03618058253453865, 'max_bins': 253}.
# [I 2026-04-27 21:51:09,050] Trial 89 finished with values: [0.5215900169510611, 0.02351362762439463] and parameters: {'learning_rate': 0.028827156711524814, 'max_iter': 174, 'max_leaf_nodes': 33, 'max_depth': 4, 'min_samples_leaf': 21, 'l2_regularization': 0.010115510146945006, 'max_bins': 96}.
# [I 2026-04-27 21:51:10,335] Trial 87 finished with values: [0.5224899929559167, 0.020463720992830864] and parameters: {'learning_rate': 0.03339656555653221, 'max_iter': 372, 'max_leaf_nodes': 44, 'max_depth': 3, 'min_samples_leaf': 24, 'l2_regularization': 0.09594500252189692, 'max_bins': 89}.
# [I 2026-04-27 21:51:15,534] Trial 96 finished with values: [0.526042206173191, 0.0200216899155915] and parameters: {'learning_rate': 0.04894807054477897, 'max_iter': 220, 'max_leaf_nodes': 62, 'max_depth': 3, 'min_samples_leaf': 17, 'l2_regularization': 0.06997052490279498, 'max_bins': 155}.
# [I 2026-04-27 21:51:16,040] Trial 82 finished with values: [0.4819075469480845, 0.02733807398077745] and parameters: {'learning_rate': 0.03548282502058835, 'max_iter': 372, 'max_leaf_nodes': 15, 'max_depth': 4, 'min_samples_leaf': 22, 'l2_regularization': 0.5699983757173572, 'max_bins': 89}.
# [I 2026-04-27 21:51:18,757] Trial 70 finished with values: [0.45672112695524314, 0.11534576564724693] and parameters: {'learning_rate': 0.16487544894043824, 'max_iter': 428, 'max_leaf_nodes': 49, 'max_depth': 7, 'min_samples_leaf': 80, 'l2_regularization': 0.47699537507220335, 'max_bins': 170}.
# [I 2026-04-27 21:51:27,044] Trial 61 finished with values: [0.45681575318025514, 0.05247135337555514] and parameters: {'learning_rate': 0.015782557343790717, 'max_iter': 491, 'max_leaf_nodes': 35, 'max_depth': 12, 'min_samples_leaf': 59, 'l2_regularization': 4.778744937006557, 'max_bins': 164}.
# [I 2026-04-27 21:51:44,143] Trial 91 finished with values: [0.4965536848498969, 0.031018411484798197] and parameters: {'learning_rate': 0.028564856300733615, 'max_iter': 177, 'max_leaf_nodes': 60, 'max_depth': 5, 'min_samples_leaf': 56, 'l2_regularization': 0.06483839517096612, 'max_bins': 152}.
# [I 2026-04-27 21:51:48,010] Trial 90 finished with values: [0.4670570987518301, 0.03569430734498143] and parameters: {'learning_rate': 0.047545164657427495, 'max_iter': 187, 'max_leaf_nodes': 20, 'max_depth': 10, 'min_samples_leaf': 55, 'l2_regularization': 0.08380218636772241, 'max_bins': 88}.
# [I 2026-04-27 21:52:00,964] Trial 93 finished with values: [0.49527242661488424, 0.03308134803405105] and parameters: {'learning_rate': 0.027541488016022218, 'max_iter': 186, 'max_leaf_nodes': 63, 'max_depth': 5, 'min_samples_leaf': 18, 'l2_regularization': 0.09140381517484791, 'max_bins': 240}.
# [I 2026-04-27 21:52:03,389] Trial 95 finished with values: [0.4728906781110155, 0.03626199868229309] and parameters: {'learning_rate': 0.05864093210790216, 'max_iter': 183, 'max_leaf_nodes': 60, 'max_depth': 5, 'min_samples_leaf': 20, 'l2_regularization': 0.08334673272074594, 'max_bins': 150}.
# [I 2026-04-27 21:52:17,492] Trial 94 finished with values: [0.4846395603428294, 0.031632783674919215] and parameters: {'learning_rate': 0.02826955158641773, 'max_iter': 223, 'max_leaf_nodes': 60, 'max_depth': 5, 'min_samples_leaf': 19, 'l2_regularization': 0.05700843748286527, 'max_bins': 91}.
# [I 2026-04-27 21:52:29,941] Trial 92 finished with values: [0.4659628657710657, 0.04350159828739805] and parameters: {'learning_rate': 0.030327669695383797, 'max_iter': 187, 'max_leaf_nodes': 32, 'max_depth': 10, 'min_samples_leaf': 81, 'l2_regularization': 0.06488652492302455, 'max_bins': 238}.
# [I 2026-04-27 21:52:32,160] Trial 107 finished with values: [0.523519805572384, 0.020867099609648082] and parameters: {'learning_rate': 0.05344171777367592, 'max_iter': 222, 'max_leaf_nodes': 54, 'max_depth': 3, 'min_samples_leaf': 16, 'l2_regularization': 0.26814109476715103, 'max_bins': 151}.
# [I 2026-04-27 21:52:34,398] Trial 108 finished with values: [0.5222631601659565, 0.019881914378376844] and parameters: {'learning_rate': 0.054327316493568166, 'max_iter': 219, 'max_leaf_nodes': 54, 'max_depth': 3, 'min_samples_leaf': 16, 'l2_regularization': 0.25091629977791424, 'max_bins': 138}.
# [I 2026-04-27 21:52:46,782] Trial 101 finished with values: [0.470281876222098, 0.04081175832845976] and parameters: {'learning_rate': 0.055909800229384445, 'max_iter': 223, 'max_leaf_nodes': 60, 'max_depth': 5, 'min_samples_leaf': 18, 'l2_regularization': 0.2129248117008398, 'max_bins': 155}.
# [I 2026-04-27 21:52:46,828] Trial 109 finished with values: [0.5200662026270677, 0.02089172251771884] and parameters: {'learning_rate': 0.05802632888348357, 'max_iter': 218, 'max_leaf_nodes': 54, 'max_depth': 3, 'min_samples_leaf': 16, 'l2_regularization': 0.22975742295601587, 'max_bins': 138}.
# [I 2026-04-27 21:52:48,869] Trial 102 finished with values: [0.470419599832044, 0.03856054276037549] and parameters: {'learning_rate': 0.058070229533004364, 'max_iter': 221, 'max_leaf_nodes': 60, 'max_depth': 5, 'min_samples_leaf': 16, 'l2_regularization': 0.20673554020329354, 'max_bins': 152}.
# [I 2026-04-27 21:52:49,501] Trial 103 finished with values: [0.4744604793421022, 0.036606730754884576] and parameters: {'learning_rate': 0.04620595541065137, 'max_iter': 216, 'max_leaf_nodes': 61, 'max_depth': 5, 'min_samples_leaf': 17, 'l2_regularization': 0.2065588058866473, 'max_bins': 153}.
# [I 2026-04-27 21:52:59,094] Trial 110 finished with values: [0.5205826117026369, 0.020394063232395288] and parameters: {'learning_rate': 0.055593817781787465, 'max_iter': 216, 'max_leaf_nodes': 55, 'max_depth': 3, 'min_samples_leaf': 16, 'l2_regularization': 0.23885337312451616, 'max_bins': 141}.
# [I 2026-04-27 21:52:59,961] Trial 104 finished with values: [0.4724745697420817, 0.038653866060513326] and parameters: {'learning_rate': 0.05728932607285035, 'max_iter': 219, 'max_leaf_nodes': 63, 'max_depth': 5, 'min_samples_leaf': 17, 'l2_regularization': 0.1891792239889148, 'max_bins': 149}.
# [I 2026-04-27 21:53:11,724] Trial 105 finished with values: [0.46662551515692385, 0.039873418113587675] and parameters: {'learning_rate': 0.04877379796887908, 'max_iter': 216, 'max_leaf_nodes': 20, 'max_depth': 10, 'min_samples_leaf': 18, 'l2_regularization': 0.20898715152411337, 'max_bins': 137}.
# [I 2026-04-27 21:53:17,372] Trial 67 finished with values: [0.4499217642264438, 0.12819284292452243] and parameters: {'learning_rate': 0.0850507911562228, 'max_iter': 543, 'max_leaf_nodes': 48, 'max_depth': 12, 'min_samples_leaf': 92, 'l2_regularization': 4.012464426592378, 'max_bins': 230}.
# [I 2026-04-27 21:53:25,368] Trial 71 finished with values: [0.45108959763111617, 0.08677765278817548] and parameters: {'learning_rate': 0.04876241445468979, 'max_iter': 511, 'max_leaf_nodes': 61, 'max_depth': 7, 'min_samples_leaf': 60, 'l2_regularization': 3.68297008809113, 'max_bins': 238}.
# [I 2026-04-27 21:53:32,980] Trial 97 finished with values: [0.4703745931295536, 0.03711166592006174] and parameters: {'learning_rate': 0.027541345599414364, 'max_iter': 401, 'max_leaf_nodes': 60, 'max_depth': 5, 'min_samples_leaf': 17, 'l2_regularization': 0.0723897250229878, 'max_bins': 239}.
# [I 2026-04-27 21:53:50,608] Trial 98 finished with values: [0.4634045000567809, 0.04695703642856919] and parameters: {'learning_rate': 0.05127556410604439, 'max_iter': 405, 'max_leaf_nodes': 60, 'max_depth': 5, 'min_samples_leaf': 17, 'l2_regularization': 0.21904099729797105, 'max_bins': 150}.
# [I 2026-04-27 21:53:56,540] Trial 100 finished with values: [0.47326756760469, 0.03685329131535213] and parameters: {'learning_rate': 0.024797017223632062, 'max_iter': 409, 'max_leaf_nodes': 61, 'max_depth': 5, 'min_samples_leaf': 29, 'l2_regularization': 0.2198676120227697, 'max_bins': 152}.
# [I 2026-04-27 21:54:27,325] Trial 106 finished with values: [0.4623432720820347, 0.056148177194310506] and parameters: {'learning_rate': 0.05645172763385879, 'max_iter': 400, 'max_leaf_nodes': 60, 'max_depth': 5, 'min_samples_leaf': 18, 'l2_regularization': 0.1678471525242713, 'max_bins': 139}.
# [I 2026-04-27 21:54:34,438] Trial 113 finished with values: [0.46308189950707374, 0.0428276314414215] and parameters: {'learning_rate': 0.07465579693922024, 'max_iter': 312, 'max_leaf_nodes': 19, 'max_depth': 8, 'min_samples_leaf': 10, 'l2_regularization': 0.7105031168042053, 'max_bins': 141}.
# [I 2026-04-27 21:54:41,968] Trial 116 finished with values: [0.4733309077937919, 0.03356340522309145] and parameters: {'learning_rate': 0.019764228319220044, 'max_iter': 293, 'max_leaf_nodes': 21, 'max_depth': 8, 'min_samples_leaf': 28, 'l2_regularization': 0.38616826318155995, 'max_bins': 127}.
# [I 2026-04-27 21:54:46,480] Trial 111 finished with values: [0.45913346193951077, 0.04735327341809714] and parameters: {'learning_rate': 0.05657919771267329, 'max_iter': 399, 'max_leaf_nodes': 18, 'max_depth': 8, 'min_samples_leaf': 26, 'l2_regularization': 2.9772256490086937, 'max_bins': 158}.
# [I 2026-04-27 21:54:58,560] Trial 115 finished with values: [0.45948004825125477, 0.05358333331966193] and parameters: {'learning_rate': 0.07475354669977666, 'max_iter': 404, 'max_leaf_nodes': 18, 'max_depth': 8, 'min_samples_leaf': 29, 'l2_regularization': 0.6942096154206205, 'max_bins': 140}.
# [I 2026-04-27 21:55:03,394] Trial 114 finished with values: [0.46865966148517807, 0.032116342772956136] and parameters: {'learning_rate': 0.01978175858090805, 'max_iter': 404, 'max_leaf_nodes': 18, 'max_depth': 8, 'min_samples_leaf': 27, 'l2_regularization': 0.689032272215149, 'max_bins': 102}.
# [I 2026-04-27 21:55:04,188] Trial 117 finished with values: [0.4619594637364645, 0.03855982736707225] and parameters: {'learning_rate': 0.04682990826494541, 'max_iter': 394, 'max_leaf_nodes': 17, 'max_depth': 8, 'min_samples_leaf': 29, 'l2_regularization': 0.6670569632089758, 'max_bins': 126}.
# [I 2026-04-27 21:55:05,178] Trial 120 finished with values: [0.46237805357912964, 0.04842418549290951] and parameters: {'learning_rate': 0.07416699180763818, 'max_iter': 339, 'max_leaf_nodes': 18, 'max_depth': 7, 'min_samples_leaf': 29, 'l2_regularization': 0.7128032515985203, 'max_bins': 103}.
# [I 2026-04-27 21:55:20,367] Trial 118 finished with values: [0.45716010043089034, 0.053733094935208045] and parameters: {'learning_rate': 0.07229972365726259, 'max_iter': 404, 'max_leaf_nodes': 19, 'max_depth': 10, 'min_samples_leaf': 29, 'l2_regularization': 0.4327281007941568, 'max_bins': 128}.
# [I 2026-04-27 21:55:25,454] Trial 119 finished with values: [0.4604715119254639, 0.0497602970720524] and parameters: {'learning_rate': 0.07363157947298185, 'max_iter': 407, 'max_leaf_nodes': 18, 'max_depth': 8, 'min_samples_leaf': 12, 'l2_regularization': 0.6527147680294433, 'max_bins': 126}.
# [I 2026-04-27 21:56:34,575] Trial 128 finished with values: [0.46165857226370105, 0.04415654297279718] and parameters: {'learning_rate': 0.061864928212606904, 'max_iter': 339, 'max_leaf_nodes': 17, 'max_depth': 10, 'min_samples_leaf': 54, 'l2_regularization': 1.0089551075054968, 'max_bins': 104}.
# [I 2026-04-27 21:57:04,698] Trial 123 finished with values: [0.45206620929141916, 0.084051485798233] and parameters: {'learning_rate': 0.07671081248563849, 'max_iter': 308, 'max_leaf_nodes': 41, 'max_depth': 8, 'min_samples_leaf': 29, 'l2_regularization': 0.707345025316665, 'max_bins': 126}.
# [I 2026-04-27 21:57:08,885] Trial 122 finished with values: [0.453166118645159, 0.08824356943444624] and parameters: {'learning_rate': 0.07196867812544443, 'max_iter': 359, 'max_leaf_nodes': 41, 'max_depth': 8, 'min_samples_leaf': 29, 'l2_regularization': 0.6870551780377709, 'max_bins': 103}.
# [I 2026-04-27 21:57:25,837] Trial 126 finished with values: [0.4589284937526952, 0.04755173095515772] and parameters: {'learning_rate': 0.04406397295437812, 'max_iter': 563, 'max_leaf_nodes': 17, 'max_depth': 10, 'min_samples_leaf': 52, 'l2_regularization': 0.41037725708998385, 'max_bins': 104}.
# [I 2026-04-27 21:57:35,397] Trial 127 finished with values: [0.4564184384385574, 0.054703804130307065] and parameters: {'learning_rate': 0.06205493972607204, 'max_iter': 562, 'max_leaf_nodes': 17, 'max_depth': 10, 'min_samples_leaf': 26, 'l2_regularization': 3.018555776015763, 'max_bins': 104}.
# [I 2026-04-27 21:57:48,536] Trial 99 finished with values: [0.44989667118485566, 0.11539798546207672] and parameters: {'learning_rate': 0.05039357458535179, 'max_iter': 399, 'max_leaf_nodes': 63, 'max_depth': 10, 'min_samples_leaf': 19, 'l2_regularization': 0.2118120755543071, 'max_bins': 161}.
# [I 2026-04-27 21:57:56,037] Trial 125 finished with values: [0.46354873650160816, 0.04813675015814363] and parameters: {'learning_rate': 0.019198432897818665, 'max_iter': 300, 'max_leaf_nodes': 41, 'max_depth': 8, 'min_samples_leaf': 26, 'l2_regularization': 2.933346986926111, 'max_bins': 126}.
# [I 2026-04-27 21:57:56,332] Trial 121 finished with values: [0.45950615489506597, 0.0550971408975838] and parameters: {'learning_rate': 0.019618026683572754, 'max_iter': 396, 'max_leaf_nodes': 41, 'max_depth': 8, 'min_samples_leaf': 26, 'l2_regularization': 0.4137961707125533, 'max_bins': 103}.
# [I 2026-04-27 21:57:57,344] Trial 124 finished with values: [0.4619352284699989, 0.05095254497030477] and parameters: {'learning_rate': 0.01895281057359758, 'max_iter': 337, 'max_leaf_nodes': 42, 'max_depth': 8, 'min_samples_leaf': 10, 'l2_regularization': 0.7242293952218913, 'max_bins': 127}.
# [I 2026-04-27 21:58:06,269] Trial 112 finished with values: [0.4564282452061017, 0.06453696200849099] and parameters: {'learning_rate': 0.019790596311082678, 'max_iter': 403, 'max_leaf_nodes': 54, 'max_depth': 8, 'min_samples_leaf': 26, 'l2_regularization': 2.9584394242786574, 'max_bins': 140}.
# [I 2026-04-27 21:59:30,792] Trial 129 finished with values: [0.4517564865548329, 0.09837230171137906] and parameters: {'learning_rate': 0.061476620076833806, 'max_iter': 341, 'max_leaf_nodes': 52, 'max_depth': 10, 'min_samples_leaf': 53, 'l2_regularization': 0.9096537163705544, 'max_bins': 103}.
# [I 2026-04-27 21:59:37,402] Trial 136 finished with values: [0.4725274168278928, 0.03148906724772889] and parameters: {'learning_rate': 0.01574668860033667, 'max_iter': 475, 'max_leaf_nodes': 16, 'max_depth': 12, 'min_samples_leaf': 26, 'l2_regularization': 0.8963422712132483, 'max_bins': 164}.
# [I 2026-04-27 21:59:50,553] Trial 138 finished with values: [0.4701714722526596, 0.033164777103622214] and parameters: {'learning_rate': 0.017447656042213516, 'max_iter': 476, 'max_leaf_nodes': 16, 'max_depth': 12, 'min_samples_leaf': 32, 'l2_regularization': 4.831828925079542, 'max_bins': 164}.
# [I 2026-04-27 22:01:21,473] Trial 132 finished with values: [0.4548119862125813, 0.05763190383079585] and parameters: {'learning_rate': 0.016328928234696078, 'max_iter': 477, 'max_leaf_nodes': 42, 'max_depth': 12, 'min_samples_leaf': 32, 'l2_regularization': 0.9292625803620379, 'max_bins': 184}.
# [I 2026-04-27 22:01:38,706] Trial 144 finished with values: [0.4657153300430868, 0.03800560333620999] and parameters: {'learning_rate': 0.014672288302157725, 'max_iter': 450, 'max_leaf_nodes': 24, 'max_depth': 12, 'min_samples_leaf': 33, 'l2_regularization': 0.873523374219309, 'max_bins': 177}.
# [I 2026-04-27 22:01:38,926] Trial 133 finished with values: [0.455767911500004, 0.0589215687084091] and parameters: {'learning_rate': 0.016120494571293234, 'max_iter': 490, 'max_leaf_nodes': 42, 'max_depth': 12, 'min_samples_leaf': 34, 'l2_regularization': 0.8945807356943039, 'max_bins': 166}.
# [I 2026-04-27 22:02:30,694] Trial 131 finished with values: [0.45301111870353056, 0.0672450852266111] and parameters: {'learning_rate': 0.015903601758712357, 'max_iter': 485, 'max_leaf_nodes': 52, 'max_depth': 12, 'min_samples_leaf': 32, 'l2_regularization': 1.41429486443925, 'max_bins': 182}.
# [I 2026-04-27 22:02:35,685] Trial 135 finished with values: [0.45696119115401684, 0.0578304100267867] and parameters: {'learning_rate': 0.015658147005238165, 'max_iter': 470, 'max_leaf_nodes': 42, 'max_depth': 12, 'min_samples_leaf': 31, 'l2_regularization': 0.8979381616690689, 'max_bins': 164}.
# [I 2026-04-27 22:02:36,352] Trial 130 finished with values: [0.45237900188829017, 0.06981373715756187] and parameters: {'learning_rate': 0.01598972840179479, 'max_iter': 521, 'max_leaf_nodes': 52, 'max_depth': 12, 'min_samples_leaf': 33, 'l2_regularization': 0.9079063490636055, 'max_bins': 164}.
# [I 2026-04-27 22:02:52,366] Trial 134 finished with values: [0.4531538509899363, 0.06639476711805346] and parameters: {'learning_rate': 0.015342326158636531, 'max_iter': 483, 'max_leaf_nodes': 52, 'max_depth': 12, 'min_samples_leaf': 32, 'l2_regularization': 0.9844050619249842, 'max_bins': 184}.
# [I 2026-04-27 22:02:56,483] Trial 146 finished with values: [0.46566459006278316, 0.037880227230108504] and parameters: {'learning_rate': 0.014741204581079177, 'max_iter': 451, 'max_leaf_nodes': 24, 'max_depth': 9, 'min_samples_leaf': 34, 'l2_regularization': 1.4721083468964344, 'max_bins': 185}.
# [I 2026-04-27 22:03:06,527] Trial 143 finished with values: [0.4500341217575697, 0.10795071480343942] and parameters: {'learning_rate': 0.0666539639234997, 'max_iter': 463, 'max_leaf_nodes': 45, 'max_depth': 9, 'min_samples_leaf': 33, 'l2_regularization': 1.413291360441828, 'max_bins': 186}.
# [I 2026-04-27 22:03:08,213] Trial 145 finished with values: [0.46202323001896395, 0.04119238042863971] and parameters: {'learning_rate': 0.0159533825028196, 'max_iter': 492, 'max_leaf_nodes': 24, 'max_depth': 12, 'min_samples_leaf': 33, 'l2_regularization': 4.914021902252673, 'max_bins': 188}.
# [I 2026-04-27 22:03:33,796] Trial 137 finished with values: [0.4532952372663879, 0.06651723445244678] and parameters: {'learning_rate': 0.0156413829126565, 'max_iter': 481, 'max_leaf_nodes': 52, 'max_depth': 12, 'min_samples_leaf': 36, 'l2_regularization': 0.8565215457001233, 'max_bins': 182}.
# [I 2026-04-27 22:03:45,129] Trial 139 finished with values: [0.4547575317225495, 0.0680037188786277] and parameters: {'learning_rate': 0.015562001859935884, 'max_iter': 484, 'max_leaf_nodes': 52, 'max_depth': 12, 'min_samples_leaf': 32, 'l2_regularization': 0.9041284362500667, 'max_bins': 163}.
# [I 2026-04-27 22:03:48,825] Trial 141 finished with values: [0.45512159976506095, 0.06210546751410981] and parameters: {'learning_rate': 0.015325270695847748, 'max_iter': 455, 'max_leaf_nodes': 51, 'max_depth': 12, 'min_samples_leaf': 32, 'l2_regularization': 4.906906202544462, 'max_bins': 75}.
# [I 2026-04-27 22:03:55,947] Trial 142 finished with values: [0.4531746548806997, 0.0689542373241228] and parameters: {'learning_rate': 0.016923488156570278, 'max_iter': 472, 'max_leaf_nodes': 52, 'max_depth': 12, 'min_samples_leaf': 32, 'l2_regularization': 4.984241720734194, 'max_bins': 165}.
# [I 2026-04-27 22:03:56,474] Trial 149 finished with values: [0.4727277152093716, 0.04768489758217305] and parameters: {'learning_rate': 0.016388763171915465, 'max_iter': 261, 'max_leaf_nodes': 45, 'max_depth': 12, 'min_samples_leaf': 36, 'l2_regularization': 1.4392225921575554, 'max_bins': 182}.
# [I 2026-04-27 22:03:56,755] Trial 140 finished with values: [0.4540311292645746, 0.06530781286745374] and parameters: {'learning_rate': 0.0148611478253363, 'max_iter': 478, 'max_leaf_nodes': 52, 'max_depth': 12, 'min_samples_leaf': 32, 'l2_regularization': 1.4003535448455986, 'max_bins': 187}.
# [I 2026-04-27 22:04:05,494] Trial 147 finished with values: [0.4525921515270275, 0.07231586908053803] and parameters: {'learning_rate': 0.021370473928529945, 'max_iter': 522, 'max_leaf_nodes': 51, 'max_depth': 9, 'min_samples_leaf': 35, 'l2_regularization': 1.4233327167555059, 'max_bins': 75}.
# [I 2026-04-27 22:04:10,103] Trial 148 finished with values: [0.458118708930503, 0.055296353260752926] and parameters: {'learning_rate': 0.01338963268433341, 'max_iter': 456, 'max_leaf_nodes': 45, 'max_depth': 12, 'min_samples_leaf': 44, 'l2_regularization': 2.592247978109021, 'max_bins': 188}.

# %% [markdown]
# #### 6.5.2 Sélection du meilleur essai Optuna et évaluation du modèle HistGradientBoostingRegressor
#
# Après l'optimisation, l'étude Optuna est rechargée afin de sélectionner le meilleur compromis parmi les essais du front de Pareto.
#
# Le modèle HistGradientBoostingRegressor retenu est ensuite entraîné sur l'ensemble `train`, puis évalué sur les ensembles `train` et `valid`.
#
# Les métriques obtenues sont ajoutées au tableau global des résultats afin de comparer HistGradientBoostingRegressor aux modèles précédents.

# %%
# ============================================================
# Sélection du meilleur essai Optuna et évaluation HistGradientBoosting
# ============================================================

# Copie des ensembles utilisés pour HistGradientBoostingRegressor
X_train_hgb = X_train.copy()
X_valid_hgb = X_valid.copy()

# Chargement de l'étude Optuna déjà optimisée
study_hgb = optuna.load_study(
    study_name="study_hgb_new",
    storage=f"sqlite:///{filepath_output}study_hgb_new.db"
)


# ============================================================
# Sélection du meilleur essai du front de Pareto
# ============================================================

# Optuna retourne plusieurs meilleurs essais car l'étude est multi-objective
hgb_trials = study_hgb.best_trials

# Choix d'un compromis :
# - faible MAE moyenne en validation croisée temporelle
# - pénalité si le gap relatif dépasse 5 %
best_trial_hgb = min(
    hgb_trials,
    key=lambda t: t.values[0] + 50 * max(0, (t.values[1] / t.values[0]) - 0.05)
)

print("Selected trial:")
print(f"MAE = {best_trial_hgb.values[0]}")
print(f"GAP = {best_trial_hgb.values[1]}")


# ============================================================
# Récupération des meilleurs hyperparamètres
# ============================================================

# Copie des paramètres pour éviter de modifier directement l'objet Optuna
best_params_hgb = best_trial_hgb.params.copy()

# Ajout des paramètres fixes utilisés pendant l'optimisation
best_params_hgb["loss"] = "absolute_error"
best_params_hgb["early_stopping"] = False
best_params_hgb["random_state"] = 42
best_params_hgb["verbose"] = 0

print("Best_params_hgb:", best_params_hgb)


# ============================================================
# Entraînement du modèle HistGradientBoosting final
# ============================================================

best_model_hgb = HistGradientBoostingRegressor(
    **best_params_hgb
)

# Entraînement sur l'ensemble train
best_model_hgb.fit(X_train_hgb, y_train)


# ============================================================
# Évaluation sur train et validation
# ============================================================

# Prédictions
y_pred_train_hgb = best_model_hgb.predict(X_train_hgb)
y_pred_valid_hgb = best_model_hgb.predict(X_valid_hgb)

# Métriques train
mae_train_hgb = mean_absolute_error(y_train, y_pred_train_hgb)
rmse_train_hgb = np.sqrt(mean_squared_error(y_train, y_pred_train_hgb))
r2_train_hgb = r2_score(y_train, y_pred_train_hgb)
nmae_train_hgb = calculer_nmae(y_train, y_pred_train_hgb)

# Métriques validation
mae_valid_hgb = mean_absolute_error(y_valid, y_pred_valid_hgb)
rmse_valid_hgb = np.sqrt(mean_squared_error(y_valid, y_pred_valid_hgb))
r2_valid_hgb = r2_score(y_valid, y_pred_valid_hgb)
nmae_valid_hgb = calculer_nmae(y_valid, y_pred_valid_hgb)

# Pourcentage d'overfitting final
overfit_pct_hgb = (
    100 * max(0, mae_valid_hgb - mae_train_hgb) / mae_valid_hgb
    if mae_valid_hgb != 0 else np.nan
)


# ============================================================
# Affichage des résultats
# ============================================================

print("\n--- Résultats HistGradientBoostingRegressor ---")

print(f"MAE valid_hgb      : {mae_valid_hgb}")
print(f"MAE train_hgb      : {mae_train_hgb}")

print(f"NMAE valid_hgb     : {nmae_valid_hgb:.3f} %")
print(f"NMAE train_hgb     : {nmae_train_hgb:.3f} %")

print(f"RMSE valid_hgb     : {rmse_valid_hgb}")
print(f"RMSE train_hgb     : {rmse_train_hgb}")

print(f"R² valid_hgb       : {r2_valid_hgb}")
print(f"R² train_hgb       : {r2_train_hgb}")

print(f"Overfitting CV     : {best_trial_hgb.user_attrs['overfit_gap_pct']:.2f} %")
print(f"Overfitting final  : {overfit_pct_hgb:.2f} %")

# MAE moyenne obtenue pendant la validation croisée temporelle
MAE_CV_moyenne_hgb = best_trial_hgb.user_attrs["mean_mae_valid"]

print("MAE_CV_moyenne_hgb:", MAE_CV_moyenne_hgb)


# ============================================================
# Ajout au tableau global des résultats
# ============================================================

# Supprimer une ancienne ligne HistGradientBoosting si elle existe déjà
resultats = [
    r for r in resultats
    if r["Modèle"] != "HistGradientBoostingRegressor"
]

# Ajout du modèle HistGradientBoosting au tableau global
resultats.append(
    calculer_metriques(
        y_train,
        y_pred_train_hgb,
        y_valid,
        y_pred_valid_hgb,
        nom_modele="HistGradientBoostingRegressor",
        MAE_CV_moyenne=MAE_CV_moyenne_hgb
    )
)

# Tableau comparatif final, trié par performance sur validation
resultats_df = pd.DataFrame(resultats).sort_values("MAE_valid")

display(resultats_df)
# Out:
# Selected trial:
# MAE = 0.49207247538076204
# GAP = 0.023364241702935454
# Best_params_hgb: {'learning_rate': 0.0365442372934189, 'max_iter': 236, 'max_leaf_nodes': 35, 'max_depth': 4, 'min_samples_leaf': 23, 'l2_regularization': 0.4744445741439031, 'max_bins': 92, 'loss': 'absolute_error', 'early_stopping': False, 'random_state': 42, 'verbose': 0}
#
# --- Résultats HistGradientBoostingRegressor ---
# MAE valid_hgb      : 0.5246837646188517
# MAE train_hgb      : 0.4714366224171515
# NMAE valid_hgb     : 21.796 %
# NMAE train_hgb     : 19.311 %
# RMSE valid_hgb     : 1.1772050451217617
# RMSE train_hgb     : 1.0184935516362976
# R² valid_hgb       : 0.8713972282986078
# R² train_hgb       : 0.9053030131383675
# Overfitting CV     : 4.65 %
# Overfitting final  : 10.15 %
# MAE_CV_moyenne_hgb: 0.49207247538076204
#                             Modèle  MAE_train  NMAE_train (%)  RMSE_train  \
# 5                    LGBMRegressor       0.45           18.56        0.94
# 9    HistGradientBoostingRegressor       0.47           19.31        1.02
# 7              ExtraTreesRegressor       0.47           19.19        0.98
# 6                     XGBRegressor       0.49           20.01        0.98
# 8            RandomForestRegressor       0.53           21.89        1.06
# 4                            Lasso       0.72           29.44        1.21
# 3                            Ridge       0.72           29.42        1.20
# 2  Régression linéaire multivariée       0.72           29.62        1.18
# 0                             Naïf       0.95           38.84        1.66
# 1       Régression linéaire simple       1.05           43.05        1.88
#
#    R2_train  MAE_valid  NMAE_valid (%)  RMSE_valid  R2_valid  MAE_CV_moyenne  \
# 5      0.92       0.52           21.59        1.14      0.88            0.49
# 9      0.91       0.52           21.80        1.18      0.87            0.49
# 7      0.91       0.53           21.96        1.15      0.88            0.59
# 6      0.91       0.55           22.67        1.16      0.88            0.51
# 8      0.90       0.59           24.61        1.22      0.86            0.56
# 4      0.87       0.76           31.41        1.34      0.83            0.73
# 3      0.87       0.76           31.53        1.34      0.83            0.73
# 2      0.87       0.76           31.75        1.33      0.84             NaN
# 0      0.75       0.98           40.69        1.78      0.71             NaN
# 1      0.68       1.11           45.96        2.00      0.63             NaN
#
#    Gap_MAE_valid_train  Gap_R2_train_valid
# 5                 0.07                0.04
# 9                 0.05                0.03
# 7                 0.06                0.03
# 6                 0.06                0.04
# 8                 0.06                0.04
# 4                 0.04                0.03
# 3                 0.04                0.04
# 2                 0.04                0.04
# 0                 0.03                0.04
# 1                 0.06                0.05

# %%
# =====================================================================
# Sauvegarde et rechargement du meilleur modèle HistGradientBoosting
# =====================================================================

# Chemin complet du fichier de sauvegarde
model_path_hgb = best_models_path + "best_model_hgb.joblib"

# Sauvegarde du meilleur modèle HistGradientBoosting entraîné
joblib.dump(best_model_hgb, model_path_hgb)

print("Modèle HistGradientBoosting sauvegardé dans :", model_path_hgb)

# Rechargement du modèle sauvegardé
best_model_hgb = joblib.load(model_path_hgb)

print("Modèle HistGradientBoosting rechargé avec succès.")
# Out:
# Modèle HistGradientBoosting sauvegardé dans : /Users/mibrahim/Desktop/Varaiability/data/local_data/05_Modelisation/output/output_jour_nuit/Best_Models/best_model_hgb.joblib
# Modèle HistGradientBoosting rechargé avec succès.

# %% [markdown]
# #### 6.5.3 Visualisation des prédictions HistGradientBoosting

# %%
# ========================================================================
# Visualisation : valeurs réelles vs valeurs prédites HistGradientBoosting
# ========================================================================

# Cette cellule compare les valeurs réelles de la cible avec les prédictions
# du modèle HistGradientBoosting sur l'ensemble de validation.

plt.figure(figsize=(6, 6))

# Nuage de points :
# axe x : valeurs réelles
# axe y : valeurs prédites par HistGradientBoosting
plt.scatter(y_valid, y_pred_valid_hgb, alpha=0.5)

# Ligne idéale y = x
# Si les prédictions étaient parfaites, tous les points seraient sur cette ligne
min_val = min(y_valid.min(), y_pred_valid_hgb.min())
max_val = max(y_valid.max(), y_pred_valid_hgb.max())

plt.plot(
    [min_val, max_val],
    [min_val, max_val],
    "r--",
    label="Prédiction parfaite"
)

# Titres et labels
plt.xlabel("Valeurs réelles")
plt.ylabel("Valeurs prédites")
plt.title("HistGradientBoosting - Valeurs réelles vs valeurs prédites sur validation")

# Légende
plt.legend()

# Affichage
plt.show()

# %% [markdown]
# ## 7. Réseau de neurones
#
# On teste ensuite un réseau de neurones de type **MLP** (*Multi-Layer Perceptron*).
#
# Ce modèle peut capturer des relations non linéaires complexes entre les variables explicatives et la cible.
# Il est donc intéressant comme approche complémentaire aux modèles d'arbres et de boosting déjà testés.
#
# Cependant, un MLP demande plus de précautions, notamment la standardisation des variables, le choix de l'architecture, la régularisation, le dropout, l'early stopping et la surveillance du gap train/validation.
#
# L'objectif est de comparer le MLP aux modèles précédents, tout en contrôlant le risque de surapprentissage.

# %% [markdown]
# ### 7.1 Optimisation des hyperparamètres MLP avec Optuna
#
# Le MLP est optimisé avec Optuna en utilisant les folds temporels définis manuellement.
#
# Comme pour les modèles précédents, la sélection repose sur la MAE moyenne de validation croisée temporelle et sur le contrôle du gap train/validation.
#
# La standardisation, la régularisation, le dropout et l'early stopping sont utilisés afin de limiter le surapprentissage.

# %%
# ============================
# Construction du modèle MLP
# ============================

# Fixer les graines aléatoires pour rendre les résultats plus reproductibles
SEED = 42

np.random.seed(SEED)
tf.random.set_seed(SEED)


def build_pyramid_mlp(input_dim, hidden_layers, activation, dropout_rate, learning_rate, l2_reg):
    """
    Construit un réseau de neurones MLP de type pyramidal.

    Paramètres
    ----------
    input_dim : int
        Nombre de variables explicatives en entrée.

    hidden_layers : list
        Liste contenant le nombre de neurones dans chaque couche cachée.
        Exemple : [256, 128, 64]

    activation : str
        Fonction d'activation utilisée dans les couches cachées.

    dropout_rate : float
        Taux de dropout utilisé pour limiter le surapprentissage.

    learning_rate : float
        Taux d'apprentissage de l'optimiseur Adam.

    l2_reg : float
        Coefficient de régularisation L2 appliqué aux poids du réseau.

    Retour
    ------
    model : keras.Model
        Modèle MLP compilé.
    """

    # Initialisation du modèle séquentiel
    model = keras.Sequential()

    # Couche d'entrée
    model.add(layers.Input(shape=(input_dim,)))

    # Choix de l'initialisation des poids selon la fonction d'activation
    # he_normal est adapté à ReLU
    # glorot_uniform est plus général pour d'autres activations
    if activation == "relu":
        initializer = "he_normal"
    else:
        initializer = "glorot_uniform"

    # Construction des couches cachées
    for units in hidden_layers:

        # Couche dense avec régularisation L2
        # use_bias=False car BatchNormalization ajoute déjà un décalage appris
        model.add(
            layers.Dense(
                units,
                use_bias=False,
                kernel_initializer=initializer,
                kernel_regularizer=regularizers.l2(l2_reg)
            )
        )

        # Normalisation des activations pour stabiliser l'entraînement
        model.add(layers.BatchNormalization())

        # Fonction d'activation non linéaire
        model.add(layers.Activation(activation))

        # Dropout pour limiter le surapprentissage
        model.add(layers.Dropout(dropout_rate))

    # Couche de sortie
    # Une seule sortie continue pour la régression
    model.add(
        layers.Dense(
            1,
            activation="linear",
            kernel_initializer="glorot_uniform"
        )
    )

    # Compilation du modèle
    # La perte MAE est utilisée car c'est la métrique principale du notebook
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=learning_rate),
        loss="mae",
        metrics=[
            keras.metrics.MeanAbsoluteError(name="mae")
        ]
    )

    return model

# %%
# ============================================================
# Optimisation du MLP avec Optuna et folds temporels manuels
# ============================================================

# ------------------------------------------------------------
# Évaluation d'une combinaison d'hyperparamètres MLP
# ------------------------------------------------------------

def evaluate_params_keras_mlp(params, X, y, trial=None):
    """
    Évalue une combinaison d'hyperparamètres du MLP
    sur les folds temporels définis manuellement.

    Pour chaque fold :
    - les données train sont séparées en train interne et validation interne ;
    - la validation interne sert uniquement à l'early stopping ;
    - le fold de validation temporelle reste intact pour l'évaluation finale du fold.
    """

    # Listes pour stocker les métriques de chaque fold
    maes_valid = []
    maes_train = []

    rmses_valid = []
    rmses_train = []

    r2_trains = []
    r2_valids = []

    gaps = []

    # Génération des folds temporels manuels
    folds = get_folds(X, y)

    # Boucle sur les folds
    for step, (X_tr, X_v, y_tr, y_v) in enumerate(folds):

        # Nettoyage de la session TensorFlow avant chaque entraînement
        tf.keras.backend.clear_session()

        # Graine différente pour chaque fold, mais reproductible
        tf.keras.utils.set_random_seed(SEED + step)

        # Conversion des cibles en arrays numpy
        y_tr_np = np.asarray(y_tr).ravel()
        y_v_np = np.asarray(y_v).ravel()

        # Séparation interne du train du fold pour l'early stopping
        # X_v n'est pas utilisé ici : il reste réservé à l'évaluation du fold
        X_fit, X_es, y_fit, y_es = train_test_split(
            X_tr,
            y_tr_np,
            test_size=0.15,
            random_state=SEED,
            shuffle=False
        )

        # Standardisation à l'intérieur du fold
        # Le scaler est ajusté uniquement sur X_fit
        scaler = StandardScaler()

        X_fit_scaled = scaler.fit_transform(X_fit)
        X_es_scaled = scaler.transform(X_es)
        X_tr_scaled = scaler.transform(X_tr)
        X_v_scaled = scaler.transform(X_v)

        # Construction du modèle MLP avec les paramètres proposés
        model = build_pyramid_mlp(
            input_dim=X_fit_scaled.shape[1],
            hidden_layers=params["hidden_layers"],
            activation=params["activation"],
            dropout_rate=params["dropout_rate"],
            learning_rate=params["learning_rate"],
            l2_reg=params["l2_reg"]
        )

        # Early stopping : arrêt si la MAE de validation interne ne s'améliore plus
        early_stop = keras.callbacks.EarlyStopping(
            monitor="val_mae",
            mode="min",
            patience=30,
            min_delta=1e-4,
            restore_best_weights=True
        )

        # Réduction du learning rate si la validation stagne
        reduce_lr = keras.callbacks.ReduceLROnPlateau(
            monitor="val_mae",
            mode="min",
            factor=0.5,
            patience=10,
            min_delta=1e-4,
            min_lr=1e-6,
            verbose=0
        )

        # Entraînement du modèle
        model.fit(
            X_fit_scaled,
            y_fit,
            validation_data=(X_es_scaled, y_es),
            epochs=params["epochs"],
            batch_size=params["batch_size"],
            callbacks=[early_stop, reduce_lr],
            verbose=0,
            shuffle=False
        )

        # Prédictions sur train du fold et validation du fold
        pred_train = model.predict(X_tr_scaled, verbose=0).ravel()
        pred_valid = model.predict(X_v_scaled, verbose=0).ravel()

        # MAE train et validation
        mae_train = mean_absolute_error(y_tr_np, pred_train)
        mae_valid = mean_absolute_error(y_v_np, pred_valid)

        # RMSE train et validation
        rmse_train = np.sqrt(mean_squared_error(y_tr_np, pred_train))
        rmse_valid = np.sqrt(mean_squared_error(y_v_np, pred_valid))

        # R² train et validation
        r2_train = r2_score(y_tr_np, pred_train)
        r2_valid = r2_score(y_v_np, pred_valid)

        # Gap train-validation
        gap = max(0, mae_valid - mae_train)

        # Stockage des métriques
        maes_train.append(mae_train)
        maes_valid.append(mae_valid)

        rmses_train.append(rmse_train)
        rmses_valid.append(rmse_valid)

        r2_trains.append(r2_train)
        r2_valids.append(r2_valid)

        gaps.append(gap)

    # Moyennes des métriques sur tous les folds
    mean_mae_valid = np.mean(maes_valid)
    mean_mae_train = np.mean(maes_train)

    std_mae_valid = np.std(maes_valid)
    std_mae_train = np.std(maes_train)

    mean_rmse_valid = np.mean(rmses_valid)
    mean_rmse_train = np.mean(rmses_train)

    mean_r2_valid = np.mean(r2_valids)
    mean_r2_train = np.mean(r2_trains)

    mean_gap = np.mean(gaps)

    # Pourcentage de gap relatif
    gap_pct = (
        100 * max(0, mean_mae_valid - mean_mae_train) / mean_mae_valid
        if mean_mae_valid != 0 else 0
    )

    # Sauvegarde des informations utiles dans Optuna
    if trial is not None:
        trial.set_user_attr("mean_mae_valid", mean_mae_valid)
        trial.set_user_attr("mean_mae_train", mean_mae_train)

        trial.set_user_attr("std_mae_valid", std_mae_valid)
        trial.set_user_attr("std_mae_train", std_mae_train)

        trial.set_user_attr("mean_rmse_valid", mean_rmse_valid)
        trial.set_user_attr("mean_rmse_train", mean_rmse_train)

        trial.set_user_attr("mean_r2_valid", mean_r2_valid)
        trial.set_user_attr("mean_r2_train", mean_r2_train)

        trial.set_user_attr("mean_gap", mean_gap)
        trial.set_user_attr("std_gap", np.std(gaps))
        trial.set_user_attr("max_gap", np.max(gaps))
        trial.set_user_attr("overfit_gap_pct", gap_pct)

    # Optuna minimise ces deux objectifs
    return mean_mae_valid, mean_gap

# =====================================
# Fonction objective Optuna pour le MLP
# =====================================

def objective_keras_mlp(trial):

    # Choix de l'architecture du réseau
    architecture_name = trial.suggest_categorical(
        "architecture",
        ["128-64", "128-64-32"]
    )

    architecture_map = {
        "128-64": (128, 64),
        "128-64-32": (128, 64, 32)
    }

    # Hyperparamètres testés par Optuna
    params = {
        "hidden_layers": architecture_map[architecture_name],
        "activation": "relu",
        "dropout_rate": trial.suggest_float("dropout_rate", 0.0, 0.2),
        "l2_reg": trial.suggest_float("l2_reg", 1e-8, 1e-4, log=True),
        "learning_rate": trial.suggest_float("learning_rate", 1e-4, 3e-3, log=True),
        "batch_size": trial.suggest_categorical("batch_size", [64, 128, 256, 512]),
        "epochs": 1000
    }

    # Sauvegarde de l'architecture réelle dans Optuna
    trial.set_user_attr("hidden_layers", params["hidden_layers"])

    return evaluate_params_keras_mlp(
        params=params,
        X=X_dev,
        y=y_dev,
        trial=trial
    )

# ===================================================
# Création et lancement de l'étude Optuna pour le MLP
# ===================================================

study_keras_mlp = optuna.create_study(
    study_name="study_mlp",
    storage=f"sqlite:///{filepath_output}study_mlp.db",
    load_if_exists=True,
    directions=["minimize", "minimize"],
    sampler=optuna.samplers.TPESampler(
        n_startup_trials=20,
        seed=42
    )
)

# Lancement de l'optimisation
study_keras_mlp.optimize(
    objective_keras_mlp,
    n_trials=50,
    n_jobs=1
)
# Out:
# [I 2026-05-13 09:56:16,712] A new study created in RDB with name: study_mlp
# [I 2026-05-13 09:58:30,175] Trial 0 finished with values: [0.5465221944969902, 0.022242033283454046] and parameters: {'architecture': '128-64-32', 'dropout_rate': 0.146398788362281, 'l2_reg': 2.4810409748678096e-06, 'learning_rate': 0.0001700037298921101, 'batch_size': 256}.
# [I 2026-05-13 10:00:24,890] Trial 1 finished with values: [0.5291097157423322, 0.026937791597290234] and parameters: {'architecture': '128-64', 'dropout_rate': 0.19398197043239887, 'l2_reg': 2.136832907235876e-05, 'learning_rate': 0.00020589728197687926, 'batch_size': 512}.
# [I 2026-05-13 10:01:59,436] Trial 2 finished with values: [0.5356255795519207, 0.02681252862545208] and parameters: {'architecture': '128-64', 'dropout_rate': 0.1223705789444759, 'l2_reg': 3.613894271216526e-08, 'learning_rate': 0.00027010527749605503, 'batch_size': 256}.
# [I 2026-05-13 10:04:32,708] Trial 3 finished with values: [0.5602396105865627, 0.043690431598191595] and parameters: {'architecture': '128-64-32', 'dropout_rate': 0.009290082543999545, 'l2_reg': 2.692646910086179e-06, 'learning_rate': 0.0001786013788939711, 'batch_size': 256}.
# [I 2026-05-13 10:06:40,059] Trial 4 finished with values: [0.5316462041389445, 0.024310619909858694] and parameters: {'architecture': '128-64', 'dropout_rate': 0.1368466053024314, 'l2_reg': 5.762487216478591e-07, 'learning_rate': 0.00015144860262751404, 'batch_size': 256}.
# [I 2026-05-13 10:09:35,694] Trial 5 finished with values: [0.592084459393072, 0.016902151318631597] and parameters: {'architecture': '128-64', 'dropout_rate': 0.10401360423556216, 'l2_reg': 1.5375920235481744e-06, 'learning_rate': 0.00018752209455786411, 'batch_size': 64}.
# [I 2026-05-13 10:12:00,606] Trial 6 finished with values: [0.5428766025593899, 0.03671128530086232] and parameters: {'architecture': '128-64-32', 'dropout_rate': 0.0176985004103839, 'l2_reg': 6.08039019029659e-08, 'learning_rate': 0.00011662890273931399, 'batch_size': 512}.
# [I 2026-05-13 10:13:04,999] Trial 7 finished with values: [0.6253909671205606, 0.024846274148246916] and parameters: {'architecture': '128-64', 'dropout_rate': 0.1085392166316497, 'l2_reg': 3.661819220392421e-08, 'learning_rate': 0.0015308837415731373, 'batch_size': 128}.
# [I 2026-05-13 10:14:06,287] Trial 8 finished with values: [0.5257904730253892, 0.027176533900282837] and parameters: {'architecture': '128-64-32', 'dropout_rate': 0.14137146876952342, 'l2_reg': 8.24192526487645e-06, 'learning_rate': 0.0013780336485752, 'batch_size': 512}.
# [I 2026-05-13 10:15:49,970] Trial 9 finished with values: [0.5705514629207633, 0.03233971861322249] and parameters: {'architecture': '128-64', 'dropout_rate': 0.012711670057204728, 'l2_reg': 1.753594952976439e-07, 'learning_rate': 0.0003022283475646735, 'batch_size': 256}.
# [I 2026-05-13 10:16:50,133] Trial 10 finished with values: [0.6088610516380354, 0.022425098097680896] and parameters: {'architecture': '128-64-32', 'dropout_rate': 0
and parameters: {'architecture': '128-64-32', 'dropout_rate': 0.08212154258342147, 'l2_reg': 3.265509226695846e-07, 'learning_rate': 0.00013414588968887998, 'batch_size': 128}.
# [I 2026-05-13 10:40:30,858] Trial 25 finished with values: [0.6694213382604621, 0.017243870003783246] and parameters: {'architecture': '128-64', 'dropout_rate': 0.16631998083366753, 'l2_reg': 1.356069190596682e-08, 'learning_rate': 0.0009163594651807928, 'batch_size': 64}.
# [I 2026-05-13 10:42:00,560] Trial 26 finished with values: [0.6044615971380273, 0.014234734340132726] and parameters: {'architecture': '128-64-32', 'dropout_rate': 0.1797755153108568, 'l2_reg': 5.004389779788892e-07, 'learning_rate': 0.0029645037956555964, 'batch_size': 128}.
# [I 2026-05-13 10:43:30,340] Trial 27 finished with values: [0.6351627950009964, 0.022440083025938806] and parameters: {'architecture': '128-64', 'dropout_rate': 0.1601796468655999, 'l2_reg': 1.0288054042384985e-07, 'learning_rate': 0.00043820896932023344, 'batch_size': 64}.
# [I 2026-05-13 10:44:34,876] Trial 28 finished with values: [0.5675655995165083, 0.01810570445362339] and parameters: {'architecture': '128-64-32', 'dropout_rate': 0.1359961147672879, 'l2_reg': 4.3971116601528085e-05, 'learning_rate': 0.00023857372869218288, 'batch_size': 128}.
# [I 2026-05-13 10:46:40,212] Trial 29 finished with values: [0.5783461631705542, 0.017261364713260452] and parameters: {'architecture': '128-64-32', 'dropout_rate': 0.07823399570596377, 'l2_reg': 8.756820486612312e-06, 'learning_rate': 0.00013855121043366138, 'batch_size': 64}.
# [I 2026-05-13 10:48:15,979] Trial 30 finished with values: [0.5627387033493968, 0.018061137520285153] and parameters: {'architecture': '128-64', 'dropout_rate': 0.18293690252959302, 'l2_reg': 1.1535635582566058e-08, 'learning_rate': 0.00015116559440967446, 'batch_size': 128}.
# [I 2026-05-13 10:49:57,645] Trial 31 finished with values: [0.5743082663561702, 0.021910988970041234] and parameters: {'architecture': '128-64-32', 'dropout_rate': 0.14968210561897016, 'l2_reg': 5.263211067981154e-07, 'learning_rate': 0.00010066359415916041, 'batch_size': 128}.
# [I 2026-05-13 10:51:03,301] Trial 32 finished with values: [0.6262650636704303, 0.019763819519360903] and parameters: {'architecture': '128-64-32', 'dropout_rate': 0.18024812008860547, 'l2_reg': 4.6779054639446616e-07, 'learning_rate': 0.0020065494816822052, 'batch_size': 128}.
# [I 2026-05-13 10:52:14,411] Trial 33 finished with values: [0.6753305312973847, 0.017300676520651703] and parameters: {'architecture': '128-64', 'dropout_rate': 0.18892317435819514, 'l2_reg': 6.272594832159122e-07, 'learning_rate': 0.0028117376432965136, 'batch_size': 64}.
# [I 2026-05-13 10:53:14,723] Trial 34 finished with values: [0.60128568012691, 0.012355263882359857] and parameters: {'architecture': '128-64-32', 'dropout_rate': 0.17126821324733102, 'l2_reg': 1.4946555983928266e-07, 'learning_rate': 0.000989985835083498, 'batch_size': 128}.
# [I 2026-05-13 10:54:22,293] Trial 35 finished with values: [0.6134676099766411, 0.019799868137960003] and parameters: {'architecture': '128-64', 'dropout_rate': 0.16074779389412602, 'l2_reg': 2.0430142543745454e-07, 'learning_rate': 0.0009973741532777259, 'batch_size': 128}.
# [I 2026-05-13 10:56:37,797] Trial 36 finished with values: [0.5323692433409603, 0.02774927951591058] and parameters: {'architecture': '128-64', 'dropout_rate': 0.13299381269854235, 'l2_reg': 9.422492967388377e-08, 'learning_rate': 0.0003910891361220488, 'batch_size': 256}.
# [I 2026-05-13 10:57:54,291] Trial 37 finished with values: [0.571203700780072, 0.018246595916537017] and parameters: {'architecture': '128-64-32', 'dropout_rate': 0.17218916566970333, 'l2_reg': 1.9781760614961078e-08, 'learning_rate': 0.0002140237549351158, 'batch_size': 128}.
# [I 2026-05-13 11:00:36,391] Trial 38 finished with values: [0.5323008637933224, 0.02747110164572153] and parameters: {'architecture': '128-64', 'dropout_rate': 0.15091284623712922, 'l2_reg': 2.7363875654054816e-05, 'learning_rate': 0.00015685446788987382, 'batch_size': 256}.
# [I 2026-05-13 11:01:41,763] Trial 39 finished with values: [0.6030140119854819, 0.018430653690537674] and parameters: {'architecture': '128-64-32', 'dropout_rate': 0.11681022001839972, 'l2_reg': 1.0651871670072991e-07, 'learning_rate': 0.0011446717939159025, 'batch_size': 128}.
# [I 2026-05-13 11:02:50,035] Trial 40 finished with values: [0.5311297958770802, 0.034157812440448965] and parameters: {'architecture': '128-64', 'dropout_rate': 0.09321907836016768, 'l2_reg': 2.0906327075372744e-06, 'learning_rate': 0.0016910653737514814, 'batch_size': 512}.
# [I 2026-05-13 11:04:18,845] Trial 41 finished with values: [0.5652259732638036, 0.020004953793319624] and parameters: {'architecture': '128-64-32', 'dropout_rate': 0.1409660195760912, 'l2_reg': 1.108646994408097e-05, 'learning_rate': 0.00012374177542672974, 'batch_size': 128}.
# [I 2026-05-13 11:06:06,008] Trial 42 finished with values: [0.5387274825778404, 0.030306530630380968] and parameters: {'architecture': '128-64', 'dropout_rate': 0.19810019223901676, 'l2_reg': 3.8069287512132494e-05, 'learning_rate': 0.0007299115486330239, 'batch_size': 256}.
# [I 2026-05-13 11:08:54,057] Trial 43 finished with values: [0.5566458294941529, 0.020363488895161957] and parameters: {'architecture': '128-64-32', 'dropout_rate': 0.15574003698674804, 'l2_reg': 5.7516733882045896e-05, 'learning_rate': 0.00010674233196613842, 'batch_size': 64}.
# [I 2026-05-13 11:10:08,556] Trial 44 finished with values: [0.5259017121371296, 0.0378172928304977] and parameters: {'architecture': '128-64', 'dropout_rate': 0.14570649177295192, 'l2_reg': 7.013553715467951e-06, 'learning_rate': 0.001840303352165694, 'batch_size': 512}.
# [I 2026-05-13 11:11:55,570] Trial 45 finished with values: [0.557381894072051, 0.023031834758115433] and parameters: {'architecture': '128-64-32', 'dropout_rate': 0.17155662610127917, 'l2_reg': 1.4980809610158666e-05, 'learning_rate': 0.0005874997448098976, 'batch_size': 128}.
# [I 2026-05-13 11:13:06,690] Trial 46 finished with values: [0.6330629440768623, 0.025084615296852214] and parameters: {'architecture': '128-64', 'dropout_rate': 0.1284535246652175, 'l2_reg': 2.381873342386569e-07, 'learning_rate': 0.0011838685310380172, 'batch_size': 128}.
# [I 2026-05-13 11:14:50,584] Trial 47 finished with values: [0.5584556748206065, 0.023091007417701703] and parameters: {'architecture': '128-64-32', 'dropout_rate': 0.1909275251187344, 'l2_reg': 5.991747727593066e-08, 'learning_rate': 0.0001760590733047533, 'batch_size': 256}.
# [I 2026-05-13 11:16:04,024] Trial 48 finished with values: [0.5164592259014724, 0.03453447245188197] and parameters: {'architecture': '128-64', 'dropout_rate': 0.1389348455592413, 'l2_reg': 2.766085603447128e-06, 'learning_rate': 0.0015701895373394531, 'batch_size': 512}.
# [I 2026-05-13 11:17:14,504] Trial 49 finished with values: [0.6879204735674425, 0.014588211022082354] and parameters: {'architecture': '128-64', 'dropout_rate': 0.03161848599124971, 'l2_reg': 8.695120455351722e-07, 'learning_rate': 0.002408507267780772, 'batch_size': 64}.

# %% [markdown]
# ### 7.2 Sélection du meilleur essai Optuna et évaluation du modèle MLP
#
# Après l'optimisation, l'étude Optuna est rechargée afin de sélectionner le meilleur compromis parmi les essais du front de Pareto.
#
# Le modèle MLP retenu est ensuite reconstruit avec les meilleurs hyperparamètres, puis entraîné sur l'ensemble `train`.
#
# Les prédictions sont ensuite évaluées sur les ensembles `train` et `valid`, et les métriques obtenues sont ajoutées au tableau global des résultats afin de comparer le MLP aux modèles précédents.

# %%
# ============================================================
# Sélection du meilleur essai Optuna et évaluation du MLP
# ============================================================

# Chargement de l'étude Optuna déjà optimisée
study_keras_mlp = optuna.load_study(
    study_name="study_mlp",
    storage=f"sqlite:///{filepath_output}study_mlp.db"
)


# ============================================================
# Analyse des essais du front de Pareto
# ============================================================

# Optuna retourne plusieurs meilleurs essais car l'étude est multi-objective
pareto_trials = study_keras_mlp.best_trials

rows = []

for t in pareto_trials:
    rows.append({
        "trial": t.number,
        "mae_valid_objective": t.values[0],
        "gap_objective": t.values[1],

        # Métriques stockées pendant l'optimisation
        "mean_mae_train": t.user_attrs.get("mean_mae_train"),
        "mean_mae_valid": t.user_attrs.get("mean_mae_valid"),
        "std_mae_train": t.user_attrs.get("std_mae_train"),
        "std_mae_valid": t.user_attrs.get("std_mae_valid"),
        "mean_rmse_train": t.user_attrs.get("mean_rmse_train"),
        "mean_rmse_valid": t.user_attrs.get("mean_rmse_valid"),
        "mean_r2_train": t.user_attrs.get("mean_r2_train"),
        "mean_r2_valid": t.user_attrs.get("mean_r2_valid"),
        "mean_gap": t.user_attrs.get("mean_gap"),
        "std_gap": t.user_attrs.get("std_gap"),
        "max_gap": t.user_attrs.get("max_gap"),
        "overfit_gap_pct": t.user_attrs.get("overfit_gap_pct"),
        "hidden_layers": t.user_attrs.get("hidden_layers"),

        # Hyperparamètres Optuna
        "architecture": t.params.get("architecture"),
        "dropout_rate": t.params.get("dropout_rate"),
        "l2_reg": t.params.get("l2_reg"),
        "learning_rate": t.params.get("learning_rate"),
        "batch_size": t.params.get("batch_size"),
    })

# Tableau récapitulatif du front de Pareto
df_pareto_mlp = pd.DataFrame(rows)

df_pareto_mlp = df_pareto_mlp.sort_values(
    by=["mae_valid_objective", "gap_objective"],
    ascending=[True, True]
).reset_index(drop=True)

display(df_pareto_mlp)


# ============================================================
# Sélection du meilleur essai du front de Pareto
# ============================================================

# Choix d'un compromis :
# - faible MAE moyenne en validation croisée temporelle
# - pénalité si le gap relatif dépasse 5 %
best_trial_keras_mlp = min(
    pareto_trials,
    key=lambda t: t.values[0] + 50 * max(0, (t.values[1] / t.values[0]) - 0.05)
)

print("Selected Keras MLP trial:")
print(f"Trial = {best_trial_keras_mlp.number}")
print(f"MAE CV = {best_trial_keras_mlp.values[0]}")
print(f"GAP CV = {best_trial_keras_mlp.values[1]}")
print(f"Params = {best_trial_keras_mlp.params}")
print(f"Hidden layers = {best_trial_keras_mlp.user_attrs['hidden_layers']}")
# Out:
#    trial  mae_valid_objective  gap_objective  mean_mae_train  mean_mae_valid  \
# 0     48                 0.52           0.03            0.48            0.52
# 1     13                 0.53           0.03            0.50            0.53
# 2      8                 0.53           0.03            0.50            0.53
# 3      1                 0.53           0.03            0.50            0.53
# 4      4                 0.53           0.02            0.51            0.53
# 5      0                 0.55           0.02            0.53            0.55
# 6     20                 0.55           0.02            0.53            0.55
# 7     22                 0.57           0.02            0.55            0.57
# 8     34                 0.60           0.01            0.59            0.60
# 9     15                 0.64           0.01            0.64            0.64
#
#    std_mae_train  std_mae_valid  mean_rmse_train  mean_rmse_valid  \
# 0           0.02           0.01             0.98             1.06
# 1           0.04           0.02             1.00             1.07
# 2           0.03           0.01             0.99             1.06
# 3           0.03           0.01             1.01             1.07
# 4           0.03           0.01             1.01             1.07
# 5           0.03           0.01             1.03             1.09
# 6           0.02           0.02             1.05             1.10
# 7           0.02           0.02             1.07             1.12
# 8           0.03           0.02             1.12             1.16
# 9           0.03           0.01             1.19             1.21
#
#    mean_r2_train  ...  mean_gap  std_gap  max_gap  overfit_gap_pct  \
# 0           0.91  ...      0.03     0.02     0.06             6.69
# 1           0.91  ...      0.03     0.03     0.07             5.22
# 2           0.91  ...      0.03     0.03     0.06             4.80
# 3           0.90  ...      0.03     0.02     0.05             4.75
# 4           0.90  ...      0.02     0.02     0.05             4.22
# 5           0.90  ...      0.02     0.02     0.05             3.87
# 6           0.90  ...      0.02     0.02     0.04             2.76
# 7           0.89  ...      0.02     0.02     0.04             2.34
# 8           0.88  ...      0.01     0.01     0.03             1.78
# 9           0.87  ...      0.01     0.01     0.02             0.00
#
#    hidden_layers architecture dropout_rate  l2_reg  learning_rate  batch_size
# 0      [128, 64]       128-64         0.14    0.00           0.00         512
# 1  [128, 64, 32]    128-64-32         0.11    0.00           0.00         512
# 2  [128, 64, 32]    128-64-32         0.14    0.00           0.00         512
# 3      [128, 64]       128-64         0.19    0.00           0.00         512
# 4      [128, 64]       128-64         0.14    0.00           0.00         256
# 5  [128, 64, 32]    128-64-32         0.15    0.00           0.00         256
# 6      [128, 64]       128-64         0.17    0.00           0.00         128
# 7      [128, 64]       128-64         0.17    0.00           0.00          64
# 8  [128, 64, 32]    128-64-32         0.17    0.00           0.00         128
# 9  [128, 64, 32]    128-64-32         0.14    0.00           0.00          64
#
# [10 rows x 21 columns]
# Selected Keras MLP trial:
# Trial = 4
# MAE CV = 0.5316462041389445
# GAP CV = 0.024310619909858694
# Params = {'architecture': '128-64', 'dropout_rate': 0.1368466053024314, 'l2_reg': 5.762487216478591e-07, 'learning_rate': 0.00015144860262751404, 'batch_size': 256}
# Hidden layers = [128, 64]

# %%
# ============================================================
# Entraînement du modèle MLP final
# ============================================================

# Copie des ensembles utilisés pour le MLP
X_train_mlp = X_train.copy()
X_valid_mlp = X_valid.copy()

# Conversion des cibles en arrays numpy
y_train_np = np.asarray(y_train).ravel()
y_valid_np = np.asarray(y_valid).ravel()

# Récupération des meilleurs hyperparamètres
best_params_keras = best_trial_keras_mlp.params.copy()

params_final_keras = {
    "hidden_layers": best_trial_keras_mlp.user_attrs["hidden_layers"],
    "activation": "relu",
    "dropout_rate": best_params_keras["dropout_rate"],
    "l2_reg": best_params_keras["l2_reg"],
    "learning_rate": best_params_keras["learning_rate"],
    "batch_size": best_params_keras["batch_size"],
    "epochs": 1000
}

print("Paramètres finaux MLP :", params_final_keras)


# ============================================================
# Split interne pour early stopping
# ============================================================

# L'ensemble valid reste intact pour l'évaluation finale.
# L'early stopping utilise uniquement une partie de l'ensemble train.
X_fit, X_es, y_fit, y_es = train_test_split(
    X_train_mlp,
    y_train_np,
    test_size=0.15,
    random_state=SEED,
    shuffle=False
)


# ============================================================
# Standardisation des variables
# ============================================================

# Le scaler est ajusté uniquement sur X_fit
scaler_mlp = StandardScaler()

X_fit_scaled = scaler_mlp.fit_transform(X_fit)
X_es_scaled = scaler_mlp.transform(X_es)

X_train_scaled = scaler_mlp.transform(X_train_mlp)
X_valid_scaled = scaler_mlp.transform(X_valid_mlp)


# ============================================================
# Reconstruction du meilleur modèle MLP
# ============================================================

tf.keras.backend.clear_session()
tf.keras.utils.set_random_seed(SEED)

best_model_keras_mlp = build_pyramid_mlp(
    input_dim=X_fit_scaled.shape[1],
    hidden_layers=params_final_keras["hidden_layers"],
    activation=params_final_keras["activation"],
    dropout_rate=params_final_keras["dropout_rate"],
    learning_rate=params_final_keras["learning_rate"],
    l2_reg=params_final_keras["l2_reg"]
)


# ============================================================
# Callbacks : early stopping et réduction du learning rate
# ============================================================

early_stop = keras.callbacks.EarlyStopping(
    monitor="val_mae",
    mode="min",
    patience=30,
    min_delta=1e-4,
    restore_best_weights=True
)

reduce_lr = keras.callbacks.ReduceLROnPlateau(
    monitor="val_mae",
    mode="min",
    factor=0.5,
    patience=10,
    min_delta=1e-4,
    min_lr=1e-6,
    verbose=0
)


# ============================================================
# Entraînement final
# ============================================================

history_keras_mlp = best_model_keras_mlp.fit(
    X_fit_scaled,
    y_fit,
    validation_data=(X_es_scaled, y_es),
    epochs=params_final_keras["epochs"],
    batch_size=params_final_keras["batch_size"],
    callbacks=[early_stop, reduce_lr],
    verbose=1,
    shuffle=False
)

# Meilleure époque selon la MAE de validation interne
best_epoch_keras_mlp = np.argmin(history_keras_mlp.history["val_mae"]) + 1

print("Best epoch:", best_epoch_keras_mlp)
# Out:
# Paramètres finaux MLP : {'hidden_layers': [128, 64], 'activation': 'relu', 'dropout_rate': 0.1368466053024314, 'l2_reg': 5.762487216478591e-07, 'learning_rate': 0.00015144860262751404, 'batch_size': 256, 'epochs': 1000}
# Epoch 1/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 2.3244 - mae: 2.3241 - val_loss: 1.5812 - val_mae: 1.5810 - learning_rate: 1.5145e-04
# Epoch 2/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3611 - mae: 1.3609 - val_loss: 0.9183 - val_mae: 0.9181 - learning_rate: 1.5145e-04
# Epoch 3/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9602 - mae: 0.9600 - val_loss: 0.6830 - val_mae: 0.6828 - learning_rate: 1.5145e-04
# Epoch 4/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.8671 - mae: 0.8668 - val_loss: 0.6120 - val_mae: 0.6118 - learning_rate: 1.5145e-04
# Epoch 5/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.8286 - mae: 0.8284 - val_loss: 0.5943 - val_mae: 0.5941 - learning_rate: 1.5145e-04
# Epoch 6/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8084 - mae: 0.8081 - val_loss: 0.5837 - val_mae: 0.5835 - learning_rate: 1.5145e-04
# Epoch 7/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7889 - mae: 0.7887 - val_loss: 0.5834 - val_mae: 0.5832 - learning_rate: 1.5145e-04
# Epoch 8/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7736 - mae: 0.7734 - val_loss: 0.5749 - val_mae: 0.5746 - learning_rate: 1.5145e-04
# Epoch 9/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7584 - mae: 0.7582 - val_loss: 0.5731 - val_mae: 0.5729 - learning_rate: 1.5145e-04
# Epoch 10/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7517 - mae: 0.7515 - val_loss: 0.5702 - val_mae: 0.5700 - learning_rate: 1.5145e-04
# Epoch 11/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7421 - mae: 0.7419 - val_loss: 0.5666 - val_mae: 0.5664 - learning_rate: 1.5145e-04
# Epoch 12/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7327 - mae: 0.7325 - val_loss: 0.5685 - val_mae: 0.5683 - learning_rate: 1.5145e-04
# Epoch 13/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7238 - mae: 0.7235 - val_loss: 0.5674 - val_mae: 0.5672 - learning_rate: 1.5145e-04
# Epoch 14/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7160 - mae: 0.7158 - val_loss: 0.5642 - val_mae: 0.5640 - learning_rate: 1.5145e-04
# Epoch 15/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7111 - mae: 0.7108 - val_loss: 0.5627 - val_mae: 0.5625 - learning_rate: 1.5145e-04
# Epoch 16/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7068 - mae: 0.7066 - val_loss: 0.5676 - val_mae: 0.5674 - learning_rate: 1.5145e-04
# Epoch 17/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6948 - mae: 0.6946 - val_loss: 0.5599 - val_mae: 0.5597 - learning_rate: 1.5145e-04
# Epoch 18/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6900 - mae: 0.6898 - val_loss: 0.5583 - val_mae: 0.5580 - learning_rate: 1.5145e-04
# Epoch 19/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6873 - mae: 0.6871 - val_loss: 0.5558 - val_mae: 0.5555 - learning_rate: 1.5145e-04
# Epoch 20/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6815 - mae: 0.6813 - val_loss: 0.5553 - val_mae: 0.5551 - learning_rate: 1.5145e-04
# Epoch 21/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6749 - mae: 0.6747 - val_loss: 0.5541 - val_mae: 0.5539 - learning_rate: 1.5145e-04
# Epoch 22/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6721 - mae: 0.6719 - val_loss: 0.5554 - val_mae: 0.5552 - learning_rate: 1.5145e-04
# Epoch 23/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6654 - mae: 0.6652 - val_loss: 0.5506 - val_mae: 0.5504 - learning_rate: 1.5145e-04
# Epoch 24/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6603 - mae: 0.6600 - val_loss: 0.5469 - val_mae: 0.5467 - learning_rate: 1.5145e-04
# Epoch 25/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6533 - mae: 0.6531 - val_loss: 0.5380 - val_mae: 0.5378 - learning_rate: 1.5145e-04
# Epoch 26/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6515 - mae: 0.6513 - val_loss: 0.5411 - val_mae: 0.5409 - learning_rate: 1.5145e-04
# Epoch 27/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6477 - mae: 0.6474 - val_loss: 0.5351 - val_mae: 0.5349 - learning_rate: 1.5145e-04
# Epoch 28/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6416 - mae: 0.6414 - val_loss: 0.5348 - val_mae: 0.5345 - learning_rate: 1.5145e-04
# Epoch 29/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6384 - mae: 0.6382 - val_loss: 0.5442 - val_mae: 0.5439 - learning_rate: 1.5145e-04
# Epoch 30/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6357 - mae: 0.6354 - val_loss: 0.5318 - val_mae: 0.5316 - learning_rate: 1.5145e-04
# Epoch 31/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6325 - mae: 0.6322 - val_loss: 0.5297 - val_mae: 0.5295 - learning_rate: 1.5145e-04
# Epoch 32/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6279 - mae: 0.6277 - val_loss: 0.5331 - val_mae: 0.5329 - learning_rate: 1.5145e-04
# Epoch 33/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6220 - mae: 0.6218 - val_loss: 0.5322 - val_mae: 0.5320 - learning_rate: 1.5145e-04
# Epoch 34/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6186 - mae: 0.6184 - val_loss: 0.5290 - val_mae: 0.5287 - learning_rate: 1.5145e-04
# Epoch 35/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6163 - mae: 0.6161 - val_loss: 0.5249 - val_mae: 0.5247 - learning_rate: 1.5145e-04
# Epoch 36/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6150 - mae: 0.6147 - val_loss: 0.5283 - val_mae: 0.5281 - learning_rate: 1.5145e-04
# Epoch 37/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6118 - mae: 0.6116 - val_loss: 0.5344 - val_mae: 0.5342 - learning_rate: 1.5145e-04
# Epoch 38/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6098 - mae: 0.6096 - val_loss: 0.5269 - val_mae: 0.5266 - learning_rate: 1.5145e-04
# Epoch 39/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6083 - mae: 0.6081 - val_loss: 0.5278 - val_mae: 0.5276 - learning_rate: 1.5145e-04
# Epoch 40/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6031 - mae: 0.6029 - val_loss: 0.5259 - val_mae: 0.5257 - learning_rate: 1.5145e-04
# Epoch 41/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5990 - mae: 0.5987 - val_loss: 0.5264 - val_mae: 0.5262 - learning_rate: 1.5145e-04
# Epoch 42/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6011 - mae: 0.6009 - val_loss: 0.5170 - val_mae: 0.5167 - learning_rate: 1.5145e-04
# Epoch 43/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5929 - mae: 0.5927 - val_loss: 0.5181 - val_mae: 0.5179 - learning_rate: 1.5145e-04
# Epoch 44/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5917 - mae: 0.5914 - val_loss: 0.5140 - val_mae: 0.5138 - learning_rate: 1.5145e-04
# Epoch 45/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5883 - mae: 0.5881 - val_loss: 0.5175 - val_mae: 0.5172 - learning_rate: 1.5145e-04
# Epoch 46/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5853 - mae: 0.5851 - val_loss: 0.5098 - val_mae: 0.5096 - learning_rate: 1.5145e-04
# Epoch 47/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5873 - mae: 0.5871 - val_loss: 0.5171 - val_mae: 0.5168 - learning_rate: 1.5145e-04
# Epoch 48/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5814 - mae: 0.5812 - val_loss: 0.5113 - val_mae: 0.5111 - learning_rate: 1.5145e-04
# Epoch 49/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5804 - mae: 0.5802 - val_loss: 0.5014 - val_mae: 0.5011 - learning_rate: 1.5145e-04
# Epoch 50/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5773 - mae: 0.5771 - val_loss: 0.5104 - val_mae: 0.5101 - learning_rate: 1.5145e-04
# Epoch 51/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5771 - mae: 0.5768 - val_loss: 0.5093 - val_mae: 0.5090 - learning_rate: 1.5145e-04
# Epoch 52/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5712 - mae: 0.5710 - val_loss: 0.5065 - val_mae: 0.5063 - learning_rate: 1.5145e-04
# Epoch 53/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.
1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5100 - mae: 0.5097 - val_loss: 0.4755 - val_mae: 0.4752 - learning_rate: 3.7862e-05
# Epoch 128/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5068 - mae: 0.5065 - val_loss: 0.4772 - val_mae: 0.4769 - learning_rate: 1.8931e-05
# Epoch 129/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5096 - mae: 0.5093 - val_loss: 0.4763 - val_mae: 0.4760 - learning_rate: 1.8931e-05
# Epoch 130/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5074 - mae: 0.5072 - val_loss: 0.4765 - val_mae: 0.4762 - learning_rate: 1.8931e-05
# Epoch 131/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5081 - mae: 0.5079 - val_loss: 0.4759 - val_mae: 0.4757 - learning_rate: 1.8931e-05
# Epoch 132/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5054 - mae: 0.5052 - val_loss: 0.4764 - val_mae: 0.4762 - learning_rate: 1.8931e-05
# Epoch 133/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5047 - mae: 0.5045 - val_loss: 0.4766 - val_mae: 0.4763 - learning_rate: 1.8931e-05
# Epoch 134/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5047 - mae: 0.5044 - val_loss: 0.4758 - val_mae: 0.4756 - learning_rate: 1.8931e-05
# Epoch 135/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5045 - mae: 0.5043 - val_loss: 0.4759 - val_mae: 0.4756 - learning_rate: 1.8931e-05
# Epoch 136/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5061 - mae: 0.5059 - val_loss: 0.4755 - val_mae: 0.4753 - learning_rate: 1.8931e-05
# Epoch 137/1000
# 233/233 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5057 - mae: 0.5055 - val_loss: 0.4760 - val_mae: 0.4757 - learning_rate: 1.8931e-05
# Best epoch: 107

# %%
# ============================================================
# Évaluation sur train et validation
# ============================================================

# Prédictions
y_pred_train_keras_mlp = best_model_keras_mlp.predict(
    X_train_scaled,
    verbose=0
).ravel()

y_pred_valid_keras_mlp = best_model_keras_mlp.predict(
    X_valid_scaled,
    verbose=0
).ravel()

# Métriques train
mae_train_keras_mlp = mean_absolute_error(y_train_np, y_pred_train_keras_mlp)
rmse_train_keras_mlp = np.sqrt(mean_squared_error(y_train_np, y_pred_train_keras_mlp))
r2_train_keras_mlp = r2_score(y_train_np, y_pred_train_keras_mlp)
nmae_train_keras_mlp = calculer_nmae(y_train_np, y_pred_train_keras_mlp)

# Métriques validation
mae_valid_keras_mlp = mean_absolute_error(y_valid_np, y_pred_valid_keras_mlp)
rmse_valid_keras_mlp = np.sqrt(mean_squared_error(y_valid_np, y_pred_valid_keras_mlp))
r2_valid_keras_mlp = r2_score(y_valid_np, y_pred_valid_keras_mlp)
nmae_valid_keras_mlp = calculer_nmae(y_valid_np, y_pred_valid_keras_mlp)

# Pourcentage d'overfitting final
overfit_pct_keras_mlp = (
    100 * max(0, mae_valid_keras_mlp - mae_train_keras_mlp) / mae_valid_keras_mlp
    if mae_valid_keras_mlp != 0 else np.nan
)


# ============================================================
# Affichage des résultats
# ============================================================

print("\n--- Résultats Keras MLP ---")

print(f"MAE valid_mlp      : {mae_valid_keras_mlp}")
print(f"MAE train_mlp      : {mae_train_keras_mlp}")

print(f"NMAE valid_mlp     : {nmae_valid_keras_mlp:.3f} %")
print(f"NMAE train_mlp     : {nmae_train_keras_mlp:.3f} %")

print(f"RMSE valid_mlp     : {rmse_valid_keras_mlp}")
print(f"RMSE train_mlp     : {rmse_train_keras_mlp}")

print(f"R² valid_mlp       : {r2_valid_keras_mlp}")
print(f"R² train_mlp       : {r2_train_keras_mlp}")

print(f"Overfitting CV     : {best_trial_keras_mlp.user_attrs['overfit_gap_pct']:.2f} %")
print(f"Overfitting final  : {overfit_pct_keras_mlp:.2f} %")

# MAE moyenne obtenue pendant la validation croisée temporelle
MAE_CV_moyenne_keras_mlp = best_trial_keras_mlp.user_attrs["mean_mae_valid"]

print("Best_params_keras_mlp:", best_trial_keras_mlp.params)
print("Hidden_layers:", best_trial_keras_mlp.user_attrs["hidden_layers"])
print("MAE_CV_moyenne_keras_mlp:", MAE_CV_moyenne_keras_mlp)


# ============================================================
# Ajout au tableau global des résultats
# ============================================================

# Supprimer une ancienne ligne MLP si elle existe déjà
resultats = [
    r for r in resultats
    if r["Modèle"] != "Keras MLP"
]

# Ajout du MLP au tableau global
resultats.append(
    calculer_metriques(
        y_train_np,
        y_pred_train_keras_mlp,
        y_valid_np,
        y_pred_valid_keras_mlp,
        nom_modele="Keras MLP",
        MAE_CV_moyenne=MAE_CV_moyenne_keras_mlp
    )
)

# Tableau comparatif final, trié par performance sur validation
resultats_df = pd.DataFrame(resultats).sort_values("MAE_valid")

display(resultats_df)
# Out:
# --- Résultats Keras MLP ---
# MAE valid_mlp      : 0.5342552430394532
# MAE train_mlp      : 0.48001189010374457
# NMAE valid_mlp     : 22.194 %
# NMAE train_mlp     : 19.662 %
# RMSE valid_mlp     : 1.154194049654951
# RMSE train_mlp     : 0.9777541647649837
# R² valid_mlp       : 0.8763757239234978
# R² train_mlp       : 0.9127271935001853
# Overfitting CV     : 4.22 %
# Overfitting final  : 10.15 %
# Best_params_keras_mlp: {'architecture': '128-64', 'dropout_rate': 0.1368466053024314, 'l2_reg': 5.762487216478591e-07, 'learning_rate': 0.00015144860262751404, 'batch_size': 256}
# Hidden_layers: [128, 64]
# MAE_CV_moyenne_keras_mlp: 0.5316462041389445
#                              Modèle  MAE_train  NMAE_train (%)  RMSE_train  \
# 5                     LGBMRegressor       0.45           18.56        0.94
# 9     HistGradientBoostingRegressor       0.47           19.31        1.02
# 7               ExtraTreesRegressor       0.47           19.19        0.98
# 10                        Keras MLP       0.48           19.66        0.98
# 6                      XGBRegressor       0.49           20.01        0.98
# 8             RandomForestRegressor       0.53           21.89        1.06
# 4                             Lasso       0.72           29.44        1.21
# 3                             Ridge       0.72           29.42        1.20
# 2   Régression linéaire multivariée       0.72           29.62        1.18
# 0                              Naïf       0.95           38.84        1.66
# 1        Régression linéaire simple       1.05           43.05        1.88
#
#     R2_train  MAE_valid  NMAE_valid (%)  RMSE_valid  R2_valid  MAE_CV_moyenne  \
# 5       0.92       0.52           21.59        1.14      0.88            0.49
# 9       0.91       0.52           21.80        1.18      0.87            0.49
# 7       0.91       0.53           21.96        1.15      0.88            0.59
# 10      0.91       0.53           22.19        1.15      0.88            0.53
# 6       0.91       0.55           22.67        1.16      0.88            0.51
# 8       0.90       0.59           24.61        1.22      0.86            0.56
# 4       0.87       0.76           31.41        1.34      0.83            0.73
# 3       0.87       0.76           31.53        1.34      0.83            0.73
# 2       0.87       0.76           31.75        1.33      0.84             NaN
# 0       0.75       0.98           40.69        1.78      0.71             NaN
# 1       0.68       1.11           45.96        2.00      0.63             NaN
#
#     Gap_MAE_valid_train  Gap_R2_train_valid
# 5                  0.07                0.04
# 9                  0.05                0.03
# 7                  0.06                0.03
# 10                 0.05                0.04
# 6                  0.06                0.04
# 8                  0.06                0.04
# 4                  0.04                0.03
# 3                  0.04                0.04
# 2                  0.04                0.04
# 0                  0.03                0.04
# 1                  0.06                0.05

# %%
# =====================================================
# Sauvegarde et rechargement du meilleur modèle MLP
# =====================================================

# Chemins de sauvegarde
model_path_mlp = best_models_path + "best_model_keras_mlp.keras"
scaler_path_mlp = best_models_path + "scaler_mlp.joblib"

# Sauvegarde du meilleur modèle MLP entraîné
best_model_keras_mlp.save(model_path_mlp)

print("Modèle MLP sauvegardé dans :", model_path_mlp)

# Sauvegarde du scaler utilisé pour le MLP
joblib.dump(scaler_mlp, scaler_path_mlp)

print("Scaler MLP sauvegardé dans :", scaler_path_mlp)

# Rechargement du modèle sauvegardé
best_model_keras_mlp = keras.models.load_model(model_path_mlp)

print("Modèle MLP rechargé avec succès.")

# Rechargement du scaler sauvegardé
scaler_mlp = joblib.load(scaler_path_mlp)

print("Scaler MLP rechargé avec succès.")
# Out:
# Modèle MLP sauvegardé dans : /Users/mibrahim/Desktop/Varaiability/data/local_data/05_Modelisation/output/output_jour_nuit/Best_Models/best_model_keras_mlp.keras
# Scaler MLP sauvegardé dans : /Users/mibrahim/Desktop/Varaiability/data/local_data/05_Modelisation/output/output_jour_nuit/Best_Models/scaler_mlp.joblib
# Modèle MLP rechargé avec succès.
# Scaler MLP rechargé avec succès.

# %%
# =======================================
# Visualisation de l'apprentissage du MLP
# =======================================

# Cette cellule affiche l'évolution de la MAE pendant l'entraînement.
# On compare la MAE sur le train interne et sur la validation interne
# utilisée pour l'early stopping.

plt.figure(figsize=(8, 5))

# MAE sur l'ensemble d'entraînement interne
plt.plot(
    history_keras_mlp.history["mae"],
    label="MAE entraînement"
)

# MAE sur l'ensemble de validation interne
plt.plot(
    history_keras_mlp.history["val_mae"],
    label="MAE validation interne"
)

# Titres et labels
plt.xlabel("Époque")
plt.ylabel("MAE")
plt.title("MLP - Évolution de la MAE pendant l'entraînement")

# Légende
plt.legend()

# Affichage
plt.show()

# %% [markdown]
# ### 7.3 Visualisation des prédictions du modèle MLP

# %%
# ===========================================================
# Visualisation : valeurs réelles vs valeurs prédites MLP
# ===========================================================

# Cette cellule compare les valeurs réelles de la cible avec les prédictions
# du modèle MLP sur l'ensemble de validation.

plt.figure(figsize=(6, 6))

# Nuage de points :
# axe x : valeurs réelles
# axe y : valeurs prédites par le MLP
plt.scatter(y_valid_np, y_pred_valid_keras_mlp, alpha=0.5)

# Ligne idéale y = x
# Si les prédictions étaient parfaites, tous les points seraient sur cette ligne
min_val = min(y_valid_np.min(), y_pred_valid_keras_mlp.min())
max_val = max(y_valid_np.max(), y_pred_valid_keras_mlp.max())

plt.plot(
    [min_val, max_val],
    [min_val, max_val],
    "r--",
    label="Prédiction parfaite"
)

# Titres et labels
plt.xlabel("Valeurs réelles")
plt.ylabel("Valeurs prédites")
plt.title("MLP - Valeurs réelles vs valeurs prédites sur validation")

# Légende
plt.legend()

# Affichage
plt.show()

# %%
# ===========================
# FINAL DEV SET = TRAIN + VALID
# ===========================

X_dev = pd.concat([X_train, X_valid], axis=0)
y_dev = pd.concat([y_train, y_valid], axis=0)

# Refit scaler on train + valid only
scaler_final_mlp = StandardScaler()

X_dev_mlp = scaler_final_mlp.fit_transform(X_dev)
X_test_mlp = scaler_final_mlp.transform(X_test)

# NumPy arrays
X_dev_mlp = np.asarray(X_dev_mlp)
X_test_mlp = np.asarray(X_test_mlp)

y_dev_mlp = np.asarray(y_dev).reshape(-1, 1)
y_test_mlp = np.asarray(y_test).reshape(-1, 1)


history_mlp = best_model_mlp.fit(
    X_dev_mlp,
    y_dev_mlp,
    epochs=params["epochs"],
    batch_size=params["batch_size"],
    callbacks=[early_stop],
    validation_split=0.2,
    verbose=1,
    shuffle=False
)

# ===========================
# EVALUATION FINALE
# ===========================
y_pred_test_mlp = best_model_mlp.predict(X_test_mlp, verbose=0).flatten()
y_pred_train_mlp = best_model_mlp.predict(X_dev_mlp, verbose=0).flatten()

mae_test_mlp = mean_absolute_error(y_test, y_pred_test_mlp)
mae_train_mlp = mean_absolute_error(y_dev, y_pred_train_mlp)

rmse_test_mlp = np.sqrt(mean_squared_error(y_test, y_pred_test_mlp))
rmse_train_mlp = np.sqrt(mean_squared_error(y_dev, y_pred_train_mlp))

r2_test_mlp = r2_score(y_test, y_pred_test_mlp)
r2_train_mlp = r2_score(y_dev, y_pred_train_mlp)

nmae_test_mlp = round(mae_test_mlp / (np.mean(np.abs(y_test)) + 1e-6) * 100, 3)
nmae_train_mlp = round(mae_train_mlp / (np.mean(np.abs(y_dev)) + 1e-6) * 100, 3)

MAE_CV_moyenne_mlp = best_trial.values[0]

print("\n--- Résultats Deep Learning (MLPRegressor) ---")
print(f"MAE valid_mlp     : {mae_test_mlp}")
print(f"MAE train_mlp     : {mae_train_mlp}")

print(f"NMAE valid_mlp    : {nmae_test_mlp} %")
print(f"NMAE train_mlp    : {nmae_train_mlp} %")

print(f"RMSE valid_mlp    : {rmse_test_mlp}")
print(f"RMSE train_mlp    : {rmse_train_mlp}")

print(f"R² valid_mlp      : {r2_test_mlp}")
print(f"R² train_mlp      : {r2_train_mlp}")

print("Best params      :", params)
print("Best MAE CV score:", MAE_CV_moyenne_mlp)

# %%
plt.figure(figsize=(6,6))
plt.scatter(y_test, y_pred_test_mlp, alpha=0.5)
plt.plot([y_test.min(), y_test.max()],
         [y_test.min(), y_test.max()],
         'r--')
plt.xlim([0,20])
plt.ylim([0,20])
plt.xlabel("Valeurs réelles")
plt.ylabel("Valeurs prédites")
plt.title("MLPRegressor - Réel vs Prédit")
plt.show()

# %%
plt.plot(history_mlp.history['val_mae'], label='Validation MAE')
plt.plot(history_mlp.history['val_loss'], label='Validation Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## 8. Synthèse des performances sur validation
#
# Cette section récapitule les performances des différents modèles entraînés et évalués sur les ensembles `train` et `valid`.
#
# Le tableau de validation permet de :
#
# - comparer les modèles entre eux ;
# - analyser les écarts entre les performances sur `train` et sur `valid` ;
# - détecter un éventuel surapprentissage ;
# - identifier les modèles les plus prometteurs avant l'évaluation finale.
#
# L'ensemble `test` n'est pas utilisé à ce stade.
# Il reste volontairement indépendant afin de conserver son rôle d'évaluation finale sur des données jamais utilisées pendant la sélection des modèles ou l'optimisation des hyperparamètres.

# %%
display(resultats_df)
# Out:
#                              Modèle  MAE_train  NMAE_train (%)  RMSE_train  \
# 5                     LGBMRegressor       0.45           18.56        0.94
# 9     HistGradientBoostingRegressor       0.47           19.31        1.02
# 7               ExtraTreesRegressor       0.47           19.19        0.98
# 10                        Keras MLP       0.48           19.66        0.98
# 6                      XGBRegressor       0.49           20.01        0.98
# 8             RandomForestRegressor       0.53           21.89        1.06
# 4                             Lasso       0.72           29.44        1.21
# 3                             Ridge       0.72           29.42        1.20
# 2   Régression linéaire multivariée       0.72           29.62        1.18
# 0                              Naïf       0.95           38.84        1.66
# 1        Régression linéaire simple       1.05           43.05        1.88
#
#     R2_train  MAE_valid  NMAE_valid (%)  RMSE_valid  R2_valid  MAE_CV_moyenne  \
# 5       0.92       0.52           21.59        1.14      0.88            0.49
# 9       0.91       0.52           21.80        1.18      0.87            0.49
# 7       0.91       0.53           21.96        1.15      0.88            0.59
# 10      0.91       0.53           22.19        1.15      0.88            0.53
# 6       0.91       0.55           22.67        1.16      0.88            0.51
# 8       0.90       0.59           24.61        1.22      0.86            0.56
# 4       0.87       0.76           31.41        1.34      0.83            0.73
# 3       0.87       0.76           31.53        1.34      0.83            0.73
# 2       0.87       0.76           31.75        1.33      0.84             NaN
# 0       0.75       0.98           40.69        1.78      0.71             NaN
# 1       0.68       1.11           45.96        2.00      0.63             NaN
#
#     Gap_MAE_valid_train  Gap_R2_train_valid
# 5                  0.07                0.04
# 9                  0.05                0.03
# 7                  0.06                0.03
# 10                 0.05                0.04
# 6                  0.06                0.04
# 8                  0.06                0.04
# 4                  0.04                0.03
# 3                  0.04                0.04
# 2                  0.04                0.04
# 0                  0.03                0.04
# 1                  0.06                0.05

# %% [markdown]
# La figure suivante classe les modèles selon leur MAE sur l'ensemble de validation.
#
# Ce graphique permet d'identifier visuellement les modèles les plus prometteurs avant l'évaluation finale sur l'ensemble de test.

# %%
# =======================================================
# Visualisation des performances sur le jeu de validation
# avec gap affiché au milieu des barres
# =======================================================

# Conversion de la liste des résultats en DataFrame
resultats_valid = pd.DataFrame(resultats)

# Tri des modèles par MAE de validation croissante
resultats_valid = resultats_valid.sort_values("MAE_valid")

# Création du graphique
plt.figure(figsize=(11, 6))

bars = plt.barh(
    resultats_valid["Modèle"],
    resultats_valid["MAE_valid"]
)

# Ajout du gap MAE validation - train au milieu de chaque barre
for bar, gap in zip(bars, resultats_valid["Gap_MAE_valid_train"]):
    width = bar.get_width()

    plt.text(
        width / 2,                              # position au milieu de la barre
        bar.get_y() + bar.get_height() / 2,     # position verticale centrée
        f"ΔMAE = {gap:.4f}",
        ha="center",                           # centrage horizontal
        va="center"                            # centrage vertical
    )

# Labels et titre
plt.xlabel("MAE sur validation")
plt.ylabel("Modèle")
plt.title("Classement des modèles selon la MAE validation avec gap train/validation")

# Le meilleur modèle apparaît en haut
plt.gca().invert_yaxis()

# Ajustement de la mise en page
plt.tight_layout()

# Affichage
plt.show()

# %% [markdown]
# Le classement ci-dessous présente les modèles selon un score combinant plusieurs critères de validation :
#
# - la MAE de validation ;
# - le RMSE de validation ;
# - le gap relatif entre train et validation.
#
# Ce score permet de tenir compte à la fois de l'erreur moyenne, des grandes erreurs et du risque de surapprentissage.
#
# Les premiers modèles présentent des performances très proches.
# Cependant, le choix final se porte sur `ExtraTreesRegressor`, car il offre un bon compromis global entre MAE, RMSE, R² et gap train/validation.
#
# Même si certains modèles, comme `LGBMRegressor` ou `HistGradientBoostingRegressor`, obtiennent également de très bonnes performances, leur avantage n'est pas suffisamment marqué pour justifier un choix différent.
# En particulier, `LGBMRegressor` présente un gap train/validation légèrement plus élevé, ce qui peut indiquer une tendance un peu plus forte au surapprentissage.
#
# Le `MLP` présente aussi de bonnes performances, mais il est plus sensible au prétraitement, au choix de l'architecture, à l'initialisation et aux paramètres d'entraînement. Il est donc conservé comme modèle de comparaison, mais n'est pas retenu comme modèle final.
#
# Le modèle final retenu pour l'évaluation sur l'ensemble de test est donc :
#
# $$
# \text{ExtraTreesRegressor}
# $$

# %%
# ============================================================
# Classement des modèles avant l'évaluation finale sur test
# ============================================================

# Construction propre du tableau de validation
resultats_df = (
    pd.DataFrame(resultats)
    .drop_duplicates(subset="Modèle", keep="last")
    .reset_index(drop=True)
)

# Calcul d'un score combinant :
# - la MAE de validation ;
# - le gap train/validation relatif.
#
# Plus le score est faible, meilleur est le compromis.
resultats_df["score"] = resultats_df.apply(
    lambda row: row["MAE_valid"] + row["RMSE_valid"] + max(0, row["Gap_MAE_valid_train"]) / (row["MAE_valid"] + 1e-8),
    axis=1
)

# Classement des modèles par score croissant
resultats_df = resultats_df.sort_values("score").reset_index(drop=True)

# Affichage du classement complet
display(resultats_df)

# Affichage des trois meilleurs modèles pour comparaison
top3_models = resultats_df.head(3).copy()

print("Trois meilleurs modèles selon le score de validation :")

display(
    top3_models[
        [
            "Modèle",
            "MAE_valid",
            "RMSE_valid",
            "R2_valid",
            "Gap_MAE_valid_train",
            "score"
        ]
    ]
)

# ============================================================
# Sélection du modèle final retenu pour le test
# ============================================================

modele_final_nom = "ExtraTreesRegressor"

modele_final_validation = resultats_df[
    resultats_df["Modèle"] == modele_final_nom
].copy()

print("Modèle final retenu pour l'évaluation sur test :")

display(
    modele_final_validation[
        [
            "Modèle",
            "MAE_valid",
            "RMSE_valid",
            "R2_valid",
            "Gap_MAE_valid_train",
            "score"
        ]
    ]
)
# Out:
#                              Modèle  MAE_train  NMAE_train (%)  RMSE_train  \
# 0                     LGBMRegressor       0.45           18.56        0.94
# 1               ExtraTreesRegressor       0.47           19.19        0.98
# 2                         Keras MLP       0.48           19.66        0.98
# 3     HistGradientBoostingRegressor       0.47           19.31        1.02
# 4                      XGBRegressor       0.49           20.01        0.98
# 5             RandomForestRegressor       0.53           21.89        1.06
# 6   Régression linéaire multivariée       0.72           29.62        1.18
# 7                             Lasso       0.72           29.44        1.21
# 8                             Ridge       0.72           29.42        1.20
# 9                              Naïf       0.95           38.84        1.66
# 10       Régression linéaire simple       1.05           43.05        1.88
#
#     R2_train  MAE_valid  NMAE_valid (%)  RMSE_valid  R2_valid  MAE_CV_moyenne  \
# 0       0.92       0.52           21.59        1.14      0.88            0.49
# 1       0.91       0.53           21.96        1.15      0.88            0.59
# 2       0.91       0.53           22.19        1.15      0.88            0.53
# 3       0.91       0.52           21.80        1.18      0.87            0.49
# 4       0.91       0.55           22.67        1.16      0.88            0.51
# 5       0.90       0.59           24.61        1.22      0.86            0.56
# 6       0.87       0.76           31.75        1.33      0.84             NaN
# 7       0.87       0.76           31.41        1.34      0.83            0.73
# 8       0.87       0.76           31.53        1.34      0.83            0.73
# 9       0.75       0.98           40.69        1.78      0.71             NaN
# 10      0.68       1.11           45.96        2.00      0.63             NaN
#
#     Gap_MAE_valid_train  Gap_R2_train_valid  score
# 0                  0.07                0.04   1.78
# 1                  0.06                0.03   1.79
# 2                  0.05                0.04   1.79
# 3                  0.05                0.03   1.80
# 4                  0.06                0.04   1.81
# 5                  0.06                0.04   1.91
# 6                  0.04                0.04   2.15
# 7                  0.04                0.03   2.15
# 8                  0.04                0.04   2.15
# 9                  0.03                0.04   2.79
# 10                 0.06                0.05   3.16
# Trois meilleurs modèles selon le score de validation :
#                 Modèle  MAE_valid  RMSE_valid  R2_valid  Gap_MAE_valid_train  \
# 0        LGBMRegressor       0.52        1.14      0.88                 0.07
# 1  ExtraTreesRegressor       0.53        1.15      0.88                 0.06
# 2            Keras MLP       0.53        1.15      0.88                 0.05
#
#    score
# 0   1.78
# 1   1.79
# 2   1.79
# Modèle final retenu pour l'évaluation sur test :
#                 Modèle  MAE_valid  RMSE_valid  R2_valid  Gap_MAE_valid_train  \
# 1  ExtraTreesRegressor       0.53        1.15      0.88                 0.06
#
#    score
# 1   1.79

# %% [markdown]
# ## 9. Évaluation finale sur l'ensemble de test
#
# Après la comparaison des modèles sur l'ensemble de validation, le modèle final retenu est :
#
# $$
# \text{ExtraTreesRegressor}
# $$
#
# À partir de cette étape, l'objectif n'est plus de comparer plusieurs modèles, mais d'évaluer la capacité de généralisation du modèle final sélectionné.
#
# Le modèle ExtraTreesRegressor est donc réentraîné sur toute la période de développement :
#
# $$
# \text{développement} = \text{train} + \text{validation}
# $$
#
# Cela permet d'utiliser toutes les données disponibles avant l'évaluation finale, sans inclure l'ensemble de test.
#
# L'ensemble de test reste strictement indépendant.
# Il est utilisé une seule fois afin d'estimer la performance réelle du modèle final sur des données jamais utilisées pendant l'entraînement, la validation ou l'optimisation des hyperparamètres.

# %%
# ============================================================
# Réentraînement du modèle final ExtraTrees sur train + valid
# puis évaluation finale sur test
# ============================================================

# Modèle final retenu
modele_final_nom = "ExtraTreesRegressor"

# Données de développement : train + validation
X_dev_final = X_dev.copy()
y_dev_final = y_dev.copy()

# Données de test final
X_test_final = X_test.copy()
y_test_final = y_test.copy()


# ============================================================
# Reconstruction du modèle final avec les meilleurs paramètres
# ============================================================

# On utilise les meilleurs paramètres trouvés par Optuna pour ExtraTrees
best_params_final_etr = best_params_etr.copy()

final_model_etr = ExtraTreesRegressor(
    random_state=42,
    n_jobs=-1,
    **best_params_final_etr
)


# ============================================================
# Entraînement final sur tout l'ensemble de développement
# ============================================================

final_model_etr.fit(X_dev_final, y_dev_final)


# ============================================================
# Prédictions sur développement et test
# ============================================================

y_pred_dev_etr = final_model_etr.predict(X_dev_final)
y_pred_test_etr = final_model_etr.predict(X_test_final)


# ============================================================
# Calcul des métriques finales
# ============================================================

# Métriques développement
mae_dev_etr = mean_absolute_error(y_dev_final, y_pred_dev_etr)
nmae_dev_etr = calculer_nmae(y_dev_final, y_pred_dev_etr)
rmse_dev_etr = np.sqrt(mean_squared_error(y_dev_final, y_pred_dev_etr))
r2_dev_etr = r2_score(y_dev_final, y_pred_dev_etr)

# Métriques test
mae_test_etr = mean_absolute_error(y_test_final, y_pred_test_etr)
nmae_test_etr = calculer_nmae(y_test_final, y_pred_test_etr)
rmse_test_etr = np.sqrt(mean_squared_error(y_test_final, y_pred_test_etr))
r2_test_etr = r2_score(y_test_final, y_pred_test_etr)

# Gap test - développement
gap_mae_test_dev_etr = mae_test_etr - mae_dev_etr
gap_r2_dev_test_etr = r2_dev_etr - r2_test_etr


# ============================================================
# Affichage des résultats finaux
# ============================================================

print("\n--- Évaluation finale ExtraTreesRegressor ---")

print(f"MAE dev       : {mae_dev_etr}")
print(f"MAE test      : {mae_test_etr}")

print(f"NMAE dev      : {nmae_dev_etr:.3f} %")
print(f"NMAE test     : {nmae_test_etr:.3f} %")

print(f"RMSE dev      : {rmse_dev_etr}")
print(f"RMSE test     : {rmse_test_etr}")

print(f"R² dev        : {r2_dev_etr}")
print(f"R² test       : {r2_test_etr}")

print(f"Gap MAE test-dev : {gap_mae_test_dev_etr}")
print(f"Gap R² dev-test  : {gap_r2_dev_test_etr}")


# ============================================================
# Tableau final de synthèse
# ============================================================

resultat_test_final = pd.DataFrame([
    {
        "Modèle": modele_final_nom,
        
        "MAE_dev": mae_dev_etr,
        "NMAE_dev (%)": nmae_dev_etr,
        "RMSE_dev": rmse_dev_etr,
        "R2_dev": r2_dev_etr,
        
        "MAE_test": mae_test_etr,
        "NMAE_test (%)": nmae_test_etr,
        "RMSE_test": rmse_test_etr,
        "R2_test": r2_test_etr,
        
        "Gap_MAE_test_dev": gap_mae_test_dev_etr,
        "Gap_R2_dev_test": gap_r2_dev_test_etr
    }
])

display(resultat_test_final)
# Out:
# --- Évaluation finale ExtraTreesRegressor ---
# MAE dev       : 0.4726800942657611
# MAE test      : 0.7765642357116946
# NMAE dev      : 19.416 %
# NMAE test     : 33.090 %
# RMSE dev      : 1.0049473531369644
# RMSE test     : 1.487975468897241
# R² dev        : 0.9075052971057079
# R² test       : 0.7945292769475142
# Gap MAE test-dev : 0.30388414144593356
# Gap R² dev-test  : 0.11297602015819375
#                 Modèle  MAE_dev  NMAE_dev (%)  RMSE_dev  R2_dev  MAE_test  \
# 0  ExtraTreesRegressor     0.47         19.42      1.00    0.91      0.78
#
#    NMAE_test (%)  RMSE_test  R2_test  Gap_MAE_test_dev  Gap_R2_dev_test
# 0          33.09       1.49     0.79              0.30             0.11

# %% [markdown]
# ### Interprétation des résultats sur test
#
# Le modèle final `ExtraTreesRegressor` obtient une bonne performance sur l'ensemble de développement, avec une MAE de 0.47 et un R² de 0.91.
#
# Sur l'ensemble de test, les performances diminuent : la MAE passe à 0.78, le RMSE passe de 1.00 à 1.49, et le R² diminue de 0.91 à 0.79.
#
# Cette différence indique une perte de généralisation entre la période de développement et la période de test.
# Le gap de MAE entre test et développement est égal à 0.30, ce qui montre que le modèle commet des erreurs plus importantes sur les données futures.
#
# Cette dégradation peut être liée à un changement de distribution entre les années utilisées pour l'entraînement et la période de test, par exemple des conditions météorologiques différentes, des variations plus fortes de la production photovoltaïque ou des situations moins représentées dans les données de développement.
#
# Cependant, le modèle conserve un R² positif et relativement élevé sur test, ce qui indique qu'il garde une capacité prédictive réelle sur des données indépendantes.
#
# Ainsi, `ExtraTreesRegressor` reste le modèle final retenu, mais les résultats sur test montrent qu'il existe encore une marge d'amélioration pour renforcer la robustesse du modèle face aux changements temporels.

# %%
# ============================================================
# Sauvegarde du modèle final ExtraTrees
# ============================================================

model_path_final_etr = best_models_path + "final_model_etr_train_valid.joblib"

joblib.dump(final_model_etr, model_path_final_etr)

print("Modèle final ExtraTrees sauvegardé dans :", model_path_final_etr)
# Out:
# Modèle final ExtraTrees sauvegardé dans : /Users/mibrahim/Desktop/Varaiability/data/local_data/05_Modelisation/output/output_jour_nuit/Best_Models/final_model_etr_train_valid.joblib

# %% [markdown]
# ## 10. Conclusion générale
#
# Ce notebook suit une démarche progressive de modélisation :
#
# 1. une baseline naïve fixe le niveau minimal à battre ;
# 2. les modèles linéaires apportent une première lecture simple et interprétable ;
# 3. LazyPredict sert à identifier rapidement les familles de modèles prometteuses ;
# 4. les modèles d'arbres et de boosting sont optimisés avec Optuna ;
# 5. le MLP est testé comme approche non linéaire complémentaire ;
# 6. un modèle final est sélectionné sur la base des performances en validation, puis évalué une seule fois sur l'ensemble de test.
#
# La sélection finale ne repose pas uniquement sur la MAE de validation.
# Elle tient également compte du RMSE, qui pénalise davantage les grandes erreurs, ainsi que du gap train/validation, qui permet d'évaluer le risque de surapprentissage.
#
# Le modèle retenu pour l'évaluation finale est `ExtraTreesRegressor`, car il offre un bon compromis entre précision moyenne, stabilité et capacité à limiter les grandes erreurs.
#
# L'ensemble de test est volontairement utilisé uniquement à la dernière étape.
# Il permet d'estimer la capacité de généralisation réelle du modèle final sur une période indépendante, jamais utilisée pendant l'entraînement, la validation ou l'optimisation des hyperparamètres.
#
# L'évaluation finale montre que le modèle retenu conserve une capacité prédictive sur l'ensemble de test, avec un R² positif et relativement élevé.
# Cependant, les performances diminuent par rapport à l'ensemble de développement, ce qui indique une perte de généralisation sur les données futures.
#
# Cette baisse souligne l'importance de tester le modèle sur une période réellement indépendante, car les performances obtenues en validation peuvent être plus optimistes que celles observées sur des données futures.

# %% [markdown]
# ## 11. Interprétabilité du modèle final
#
# Après l'évaluation finale, on analyse maintenant le modèle retenu afin de mieux comprendre quelles variables influencent ses prédictions.
#
# Le modèle final est `ExtraTreesRegressor`.
# Comme il s'agit d'un modèle d'ensemble basé sur des arbres, plusieurs outils d'interprétabilité peuvent être utilisés :
#
# - l'importance native des variables du modèle ;
# - les valeurs SHAP.
#
# L'objectif n'est plus de sélectionner un modèle, mais d'interpréter le comportement du modèle final déjà retenu.

# %% [markdown]
# ### 11.1 Interprétabilité avec Feature Importance

# %%
# ============================================================
# Importance native des variables - ExtraTreesRegressor
# ============================================================

# Importance des variables selon le modèle ExtraTrees
feature_importance_etr = pd.DataFrame({
    "feature": X_dev_final.columns,
    "importance": final_model_etr.feature_importances_
})

# Tri décroissant
feature_importance_etr = feature_importance_etr.sort_values(
    "importance",
    ascending=False
).reset_index(drop=True)

# Affichage des 20 variables les plus importantes
display(feature_importance_etr.head(20))
# Out:
#                  feature  importance
# 0            abs_dtch_dt        0.29
# 1     region_abs_dghi_dt        0.12
# 2   region_clear_sky_bni        0.12
# 3             region_csi        0.08
# 4             region_bni        0.07
# 5   region_clear_sky_ghi        0.05
# 6            tch_solaire        0.04
# 7               cos_hour        0.03
# 8             region_ghi        0.02
# 9             region_bhi        0.02
# 10    region_azimuth_cos        0.02
# 11  region_clear_sky_dhi        0.01
# 12               solaire        0.01
# 13            region_toa        0.01
# 14              sin_hour        0.01
# 15               dtch_dt        0.01
# 16       region_altitude        0.01
# 17        abs_dtch_lag_3        0.01
# 18             tch_lag_3        0.01
# 19        region_dghi_dt        0.01

# %%
# ============================================================
# Visualisation des 20 variables les plus importantes
# ============================================================

top_features_etr = feature_importance_etr.head(20).sort_values("importance")

plt.figure(figsize=(10, 7))

plt.barh(
    top_features_etr["feature"],
    top_features_etr["importance"]
)

plt.xlabel("Importance")
plt.ylabel("Variable")
plt.title("ExtraTreesRegressor - Importance native des variables")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 11.2 Interprétabilité avec SHAP

# %%
import shap

# Pour éviter un calcul trop long, on peut prendre un échantillon
X_shap = X_test_final.sample(
    n=min(1000, len(X_test_final)),
    random_state=42
)

# Explainer adapté aux modèles d'arbres
explainer = shap.TreeExplainer(final_model_etr)

# Calcul des valeurs SHAP
shap_values = explainer.shap_values(X_shap)

# %%
# Importance globale avec SHAP
shap.summary_plot(
    shap_values,
    X_shap,
    plot_type="bar"
)

# %%
# Effet des variables sur les prédictions
shap.summary_plot(
    shap_values,
    X_shap
)

# %% [markdown]
# Le graphique SHAP permet d'analyser l'influence des variables sur les prédictions du modèle final `ExtraTreesRegressor`.
#
# Chaque point représente une observation de l'ensemble analysé.
# L'axe horizontal indique la valeur SHAP, c'est-à-dire l'impact de la variable sur la prédiction du modèle :
#
# - une valeur SHAP positive augmente la variabilité photovoltaïque prédite ;
# - une valeur SHAP négative diminue la variabilité photovoltaïque prédite.
#
# Les variables sont classées de haut en bas selon leur importance globale.
#
# D'après ce graphique, la variable `abs_dtch_dt` est la plus influente.
# Les valeurs élevées de cette variable ont généralement un impact positif sur la prédiction, ce qui signifie que lorsque la variation récente de production est forte, le modèle prédit une variabilité future plus élevée.
#
# D'autres variables importantes apparaissent également, notamment `region_clear_sky_bni`, `region_csi`, `region_bni` et `region_abs_dghi_dt`.
# Cela montre que le modèle utilise à la fois des informations liées à la production récente, à l'irradiance, aux conditions de ciel clair et aux variations météorologiques pour prédire la variabilité photovoltaïque.
#
# Ainsi, l'interprétation SHAP confirme que le modèle s'appuie sur des variables physiquement cohérentes avec le phénomène étudié.

# %%
# ============================================================
# Permutation importance sur l'ensemble de test
# ============================================================

from sklearn.inspection import permutation_importance

perm_importance = permutation_importance(
    final_model_etr,
    X_test_final,
    y_test_final,
    scoring="neg_mean_absolute_error",
    n_repeats=10,
    random_state=42,
    n_jobs=-1
)

perm_importance_df = pd.DataFrame({
    "feature": X_test_final.columns,
    "importance_mean": perm_importance.importances_mean,
    "importance_std": perm_importance.importances_std
})

perm_importance_df = perm_importance_df.sort_values(
    "importance_mean",
    ascending=False
).reset_index(drop=True)

display(perm_importance_df.head(20))
# Out:
#                  feature  importance_mean  importance_std
# 0            abs_dtch_dt             0.35            0.00
# 1   region_clear_sky_bni             0.19            0.00
# 2             region_bni             0.16            0.00
# 3             region_csi             0.14            0.00
# 4   region_clear_sky_ghi             0.09            0.00
# 5             region_dhi             0.08            0.00
# 6             region_bhi             0.07            0.00
# 7             region_ghi             0.07            0.00
# 8     region_abs_dghi_dt             0.07            0.00
# 9            tch_solaire             0.06            0.00
# 10              cos_hour             0.05            0.00
# 11               solaire             0.05            0.00
# 12            region_toa             0.04            0.00
# 13       region_altitude             0.04            0.00
# 14        region_dghi_dt             0.04            0.00
# 15  region_clear_sky_dhi             0.03            0.00
# 16              sin_hour             0.03            0.00
# 17    region_azimuth_cos             0.03            0.00
# 18             tch_lag_3             0.02            0.00
# 19  region_clear_sky_bhi             0.02            0.00

# %%
# ============================================================
# Visualisation de la permutation importance
# ============================================================

top_perm = perm_importance_df.head(20).sort_values("importance_mean")

plt.figure(figsize=(10, 7))

plt.barh(
    top_perm["feature"],
    top_perm["importance_mean"]
)

plt.xlabel("Augmentation de l'erreur MAE après permutation")
plt.ylabel("Variable")
plt.title("ExtraTreesRegressor - Permutation importance sur test")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Interprétation de la permutation importance
#
# La permutation importance permet d'évaluer l'importance réelle des variables sur l'ensemble de test.
#
# Le principe est le suivant : pour chaque variable, ses valeurs sont mélangées aléatoirement, puis on mesure l'augmentation de l'erreur du modèle.
# Si l'erreur augmente fortement après permutation d'une variable, cela signifie que le modèle dépend beaucoup de cette variable pour faire ses prédictions.
#
# Dans ce graphique, la variable `abs_dtch_dt` est la plus importante.
# Lorsque cette variable est perturbée, l'erreur MAE augmente fortement, ce qui indique que la variation récente de la production photovoltaïque joue un rôle majeur dans la prédiction de la variabilité future.
#
# Les variables liées à l'irradiance et aux conditions de ciel clair apparaissent également parmi les plus importantes, notamment :
#
# - `region_clear_sky_bni` ;
# - `region_bni` ;
# - `region_csi` ;
# - `region_clear_sky_ghi` ;
# - `region_abs_dghi_dt`.
#
# Cela est cohérent physiquement, car les variations de production photovoltaïque sont fortement influencées par les changements d'irradiance, les conditions de ciel clair et les variations rapides du rayonnement solaire.
#
# La présence de variables comme `cos_hour`, `sin_hour`, `tch_solaire` et `solaire` montre aussi que le modèle utilise des informations temporelles et de production récente pour améliorer ses prédictions.
#
# Ainsi, la permutation importance confirme que le modèle `ExtraTreesRegressor` s'appuie principalement sur des variables physiquement pertinentes pour prédire les rampes et la variabilité photovoltaïque.
